# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from data_wrangling import *

# %%
def myround(x, base=5):
    return base * round(x/base)

# %%
class Option:
    def __init__(self, strike: float, premium: float, expiry: str):
        self.strike = strike
        self.premium = premium
        self.expiry = expiry
        self.spot_price = None

    def insert_spot(self, spot_price: float):
        self.spot_price = spot_price
    
    def short_call(self):
        # Payoff for short call: premium received - intrinsic value of the option
        intrinsic_value = np.maximum(0, self.spot_price - self.strike)
        return self.premium - intrinsic_value
    
    def long_call(self):
        # Payoff for long call: intrinsic value - premium paid
        intrinsic_value = np.maximum(0, self.spot_price - self.strike)
        return intrinsic_value - self.premium
    
    def short_put(self):
        # Payoff for short put: premium received - intrinsic value of the option
        intrinsic_value = np.maximum(0, self.strike - self.spot_price)
        return self.premium - intrinsic_value
    
    def long_put(self):
        # Payoff for long put: intrinsic value - premium paid
        intrinsic_value = np.maximum(0, self.strike - self.spot_price)
        return intrinsic_value - self.premium


class IronCondor:
    def __init__(self, direction: str, strikes: dict, premiums: dict, expiry: str):
        """
        Initialize the Iron Condor strategy with strikes and premiums for the options.
        
        direction: long, (short) Iron Condor
        1. Short (Long) 1 OTM Put (strike 1)
        2. Long (Short) 1 close to ATM Put (strike 2)
        3. Long (Short) 1 close to ATM Call (strike 3)
        4. Short (Long) 1 OTM Call (strike 4)        

        strikes: a dictionary of strikes for the 4 options (strike1 to strike4)
        premiums: a dictionary of premiums for the 4 options (premium1 to premium4)
        expiry: expiration date of the options
        """
        self.strikes = strikes
        self.premiums = premiums
        self.direction = direction
        self.expiry = expiry
        self.short_put_option = Option(strikes['strike1'], premiums['premium1'], expiry)
        self.long_put_option = Option(strikes['strike2'], premiums['premium2'], expiry)
        self.long_call_option = Option(strikes['strike3'], premiums['premium3'], expiry)
        self.short_call_option = Option(strikes['strike4'], premiums['premium4'], expiry)

    def initial_cashflow(self):
        """
        Calculate the initial cashflow of the Iron Condor strategy.
        """
        if self.direction == "long":
            initial_cashflow = self.premiums['premium1'] - self.premiums['premium2'] - self.premiums['premium3'] + self.premiums['premium4']
        elif self.direction == "short":
            initial_cashflow = -self.premiums['premium1'] + self.premiums['premium2'] + self.premiums['premium3'] - self.premiums['premium4']
        
        return initial_cashflow

    def insert_spot(self, spot_price: float):
        """
        Insert the current spot price for all the options in the Iron Condor strategy.
        """
        self.short_put_option.insert_spot(spot_price)
        self.long_put_option.insert_spot(spot_price)
        self.long_call_option.insert_spot(spot_price)
        self.short_call_option.insert_spot(spot_price)
    
    def payoff(self):
        """
        Calculate the total payoff (profit or loss) of the Iron Condor strategy.
        
        direction: 'long' for long Iron Condor, 'short' for short Iron Condor
        """
        if self.direction == "long":
            short_put = self.short_put_option.short_put()
            long_put = self.long_put_option.long_put()
            long_call = self.long_call_option.long_call()
            short_call = self.short_call_option.short_call()
            total_payoff = short_put + long_put + long_call + short_call
        elif self.direction == "short":
            long_put = -self.long_put_option.long_put()
            short_put = -self.short_put_option.short_put()
            short_call = -self.short_call_option.short_call()
            long_call = -self.long_call_option.long_call()
            total_payoff = long_put + short_put + short_call + long_call
        
        return total_payoff.iloc[0] if isinstance(total_payoff, pd.Series) else total_payoff
    
    def target_profit(self):
        """
        Calculate the target profit for the Iron Condor strategy.
        """
        if self.direction == "long":
            self.long_call_option = Option(self.strikes['strike3'], self.premiums['premium3'], self.expiry)
            self.short_call_option = Option(self.strikes['strike4'], self.premiums['premium4'], self.expiry)
            self.long_call_option.insert_spot(self.strikes["strike4"] + 5)
            self.short_call_option.insert_spot(self.strikes["strike4"] + 5)
            target_profit = self.premiums["premium1"] - self.premiums["premium2"] + self.long_call_option.long_call() + self.short_call_option.short_call()
        elif self.direction == "short":
            target_profit = self.initial_cashflow()
        
        return target_profit

class OptionsBacktester:
    def __init__(self,
                 signal_df: pd.DataFrame,
                 spot_price_df: pd.DataFrame,
                 options_df: pd.DataFrame,
                 upper_threshold: float,
                 lower_threshold: float,
                 option_type: str,
                 dynamic_option_strategy: bool = False,
                 dynamic_strike: bool = False,):
        self.signal_df = signal_df
        self.signal_df.columns = ["signal"]
        self.spot_price_df = spot_price_df
        self.options_df = options_df
        self.upper_threshold = upper_threshold
        self.lower_threshold = lower_threshold
        self.option_type = option_type
        self.dynamic_option_strategy = dynamic_option_strategy
        self.dynamic_strike = dynamic_strike

        self.comb_df = pd.concat([self.signal_df, self.spot_price_df.shift(), self.options_df.shift()], axis=1)
        self.comb_df["action"] = np.where(self.comb_df["signal"] > self.upper_threshold, 1, np.where(self.comb_df["signal"] < self.lower_threshold, -1, 0))

    def long_short_vol_df(self):
        self.trading_df = {}
        for index, row in self.comb_df.iterrows():
            if row["action"] != 0:
                self.trading_df[index] = self.comb_df.loc[index]

# %% [markdown]
# # Filtering of Options Data

# %%
day_map = {0: "Monday", 1: "Tuesday", 2: "Wednesday", 3: "Thursday", 4: "Friday", 5: "Saturday", 6: "Sunday"}

xlu_options = pd.read_hdf("data/etf_options_data.hf5", key="XLU")
xlu_options = xlu_options.set_index("date")
xlu_options["strike_price"] = xlu_options["strike_price"] / 1000
xlu_filtered_options = xlu_options.groupby("date").apply(lambda x: x.query("exdate == exdate.max()")).reset_index(level=0, drop=True)
xlu_filtered_options["day"] = xlu_filtered_options.index.weekday.map(day_map)
xlu_filtered_options["ex_day"] = xlu_filtered_options["exdate"].dt.weekday.map(day_map)
xlu_filtered_options
# Out:
#            ticker     exdate cp_flag  strike_price  best_bid  best_offer  \
# date
# 2000-01-10    XLU 2000-01-22       C          31.0    0.0000      0.1250
# 2000-01-10    XLU 2000-01-22       P          29.0    1.4375      1.6250
# 2000-01-10    XLU 2000-01-22       P          30.0    2.3750      2.6250
# 2000-01-10    XLU 2000-01-22       C          28.0    0.0625      0.1875
# 2000-01-10    XLU 2000-01-22       C          27.0    0.5625      0.7500
# ...           ...        ...     ...           ...       ...         ...
# 2023-08-31    XLU 2023-09-08       P          73.5   10.2000     10.5500
# 2023-08-31    XLU 2023-09-08       P          90.0   26.7000     27.2000
# 2023-08-31    XLU 2023-09-08       P          72.5    9.3000      9.5500
# 2023-08-31    XLU 2023-09-08       P          73.0    9.8000     10.0500
# 2023-08-31    XLU 2023-09-08       P          95.0   31.7500     32.1000
#
#             open_interest  impl_volatility     delta     gamma     theta  \
# date
# 2000-01-10            0.0         0.423886  0.068868  0.062562 -4.271427
# 2000-01-10            0.0         0.271660 -0.839551  0.179317 -4.941929
# 2000-01-10            0.0         0.353248 -0.899561  0.099878 -4.593377
# 2000-01-10            0.0         0.143454  0.283783  0.471890 -3.686701
# 2000-01-10            0.0         0.140491  0.799844  0.397932 -2.952004
# ...                   ...              ...       ...       ...       ...
# 2023-08-31            0.0              NaN       NaN       NaN       NaN
# 2023-08-31            0.0              NaN       NaN       NaN       NaN
# 2023-08-31            0.0              NaN       NaN       NaN       NaN
# 2023-08-31            0.0              NaN       NaN       NaN       NaN
# 2023-08-31            0.0              NaN       NaN       NaN       NaN
#
#                 vega  volume       day    ex_day
# date
# 2000-01-10  0.662345     0.0    Monday  Saturday
# 2000-01-10  1.211415     0.0    Monday  Saturday
# 2000-01-10  0.872273     0.0    Monday  Saturday
# 2000-01-10  1.692336     0.0    Monday  Saturday
# 2000-01-10  1.393989     0.0    Monday  Saturday
# ...              ...     ...       ...       ...
# 2023-08-31       NaN     0.0  Thursday    Friday
# 2023-08-31       NaN     0.0  Thursday    Friday
# 2023-08-31       NaN     0.0  Thursday    Friday
# 2023-08-31       NaN     0.0  Thursday    Friday
# 2023-08-31       NaN     0.0  Thursday    Friday
#
# [247525 rows x 15 columns]

# %% [markdown]
# # Pulling XLE Data

# %%
xlu_pred = pd.read_csv("data/xle_pred7030_new.csv", parse_dates=True, index_col=0).rename(columns={"0": "Rolling Pred"})
xlu_iv = pd.read_csv("data/XLU_IV.csv", parse_dates=True, index_col=0)
xlu_vrp = (xlu_iv["Average IV"] - xlu_pred["Rolling Pred"]).dropna()

xlu_vrp_standardised = rolling_z_score(xlu_vrp, window=10)
xlu_vrp_standardised.plot()
# Out:
# <Axes: >

# %%
upper_threshold = 1.75
lower_threshold = -1.75

xlu_filtered_options["vrp"] = xlu_vrp_standardised
xlu_time_series = pd.read_hdf("data/etf_series.hf5", key="XLU")
xlu_time_series["day"] = xlu_time_series.index.weekday
xlu_time_series["vrp"] = xlu_vrp_standardised
xlu_time_series["signal"] = np.where(xlu_time_series["vrp"] > upper_threshold, 1, np.where(xlu_time_series["vrp"] < lower_threshold, -1, 0))
xlu_time_series["action"] = np.where((xlu_time_series["signal"] == 1)  & (xlu_time_series.index.weekday != 4), 1, 
                                     np.where((xlu_time_series["signal"] == -1) & (xlu_time_series.index.weekday != 4), -1, 
                                              0))
xlu_time_series.dropna(inplace=True)
xlu_time_series

def ensure_weekly_action(df):
    last_action = 0
    last_week = -1

    for i in range(len(df)):
        current_week = df.index[i].isocalendar()[1]  # Get the week number
        current_day = df["day"].iloc[i]

        if current_week != last_week:  # Reset at the start of a new week
            last_action = 0
            last_week = current_week

        if last_action != 0 and df["action"].iloc[i] != 0:
            # If an action has already occurred this week, set to 0
            df.at[df.index[i], "action"] = 0
        elif df["action"].iloc[i] != 0:
            # If this is the first action of the week, update last_action
            last_action = df["action"].iloc[i]

    return df

xlu_time_series = ensure_weekly_action(xlu_time_series)
xlu_time_series["action"] = xlu_time_series["action"].shift()
xlu_time_series
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2016-12-09  47.419998  47.980000  47.419998  47.959999  37.046829  16018900
# 2016-12-12  47.759998  48.509998  47.750000  48.459999  37.433064  21980100
# 2016-12-13  48.700001  49.000000  48.520000  48.959999  37.819290  20217000
# 2016-12-14  49.180000  49.439999  47.889999  47.950001  37.039108  28353900
# 2016-12-15  47.849998  48.340000  47.599998  48.290001  37.301743  17821600
# ...               ...        ...        ...        ...        ...       ...
# 2023-08-25  63.240002  63.950001  63.200001  63.630001  61.106991  12490500
# 2023-08-28  63.740002  64.089996  63.490002  63.619999  61.097385   8663200
# 2023-08-29  63.700001  64.050003  63.439999  63.860001  61.327869  11873100
# 2023-08-30  63.650002  64.070000  63.330002  63.570000  61.049362  11240400
# 2023-08-31  63.820000  63.880001  62.939999  62.959999  60.463551  13771100
#
#             day       vrp  signal  action
# Date
# 2016-12-09    4 -0.707107       0     NaN
# 2016-12-12    0  1.004399       0     0.0
# 2016-12-13    1  1.057973       0     0.0
# 2016-12-14    2  0.957447       0     0.0
# 2016-12-15    3 -1.307416       0     0.0
# ...         ...       ...     ...     ...
# 2023-08-25    4 -0.241710       0     0.0
# 2023-08-28    0  0.382918       0     0.0
# 2023-08-29    1  0.724174       0     0.0
# 2023-08-30    2  1.556968       0     0.0
# 2023-08-31    3  1.566679       0     0.0
#
# [1630 rows x 10 columns]

# %% [markdown]
# ## short iron condor

# %%
xlu_time_series.resample("W").last()["Close"].diff().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
ironcondor_tracker = {}

def find_nearest_strike_delta(atm_spot, date_index, delta_target, option_df, cp_flag):
    """
    Helper function to find the strike with delta closest to delta_target
    """

    options = option_df.loc[date_index].query(f"cp_flag == '{cp_flag}'")
    atm_delta = options.query("strike_price == @atm_spot")["delta"]
    try:
        if isinstance(atm_delta, pd.Series):
            atm_delta = atm_delta.values[0]
    except IndexError:
        print(f"Error: {date_index}, {cp_flag}")
        return None
    new_delta = atm_delta + delta_target
    return options.iloc[(options["delta"] - new_delta).abs().argmin()]["strike_price"]

for index, row in xlu_time_series.iterrows():
    if row["action"] == 1:
        print(f"date: {index}")
        direction = "short"

        index_loc = xlu_time_series.index.get_loc(index)

        current_spot_open = myround(xlu_time_series.iloc[index_loc]["Open"], 0.5)

        daily_options = xlu_filtered_options.loc[index]

        # atm_put_strike = daily_options[
        #     (daily_options["cp_flag"] == "P") &
        #     (daily_options["strike_price"] == prev_spot_close)
        # ]["strike_price"]
        # if isinstance(atm_put_strike, pd.Series):
        #     atm_put_strike = atm_put_strike.values[0]
        
        # atm_call_strike = daily_options[
        #     (daily_options["cp_flag"] == "C") &
        #     (daily_options["strike_price"] == prev_spot_close)
        # ]["strike_price"]
        # if isinstance(atm_call_strike, pd.Series):
        #     atm_call_strike = atm_call_strike.values[0]

        atm_put_strike = atm_call_strike = current_spot_open

        otm_put_strike = find_nearest_strike_delta(current_spot_open, index, 0.4, xlu_filtered_options, "P")
        otm_call_strike = find_nearest_strike_delta(current_spot_open, index, -0.3, xlu_filtered_options, "C")

        if otm_put_strike is None or otm_call_strike is None:
            continue
            
        else:
            print(f"date: {index}, current_spot_open: {current_spot_open}, OTM Put: {otm_put_strike}, ATM Put: {atm_put_strike}, ATM Call: {atm_call_strike}, OTM Call: {otm_call_strike}, \
                left wing: {abs(otm_put_strike - atm_put_strike)}, right wing: {abs(atm_call_strike - otm_call_strike)}")
            strikes = {
                "strike1": otm_put_strike,
                "strike2": atm_put_strike,
                "strike3": atm_call_strike,
                "strike4": otm_call_strike
            }

            premiums = {
                "premium1": xlu_filtered_options.loc[
                    (xlu_filtered_options.index == index) & 
                    (xlu_filtered_options["strike_price"] == strikes["strike1"]) & 
                    (xlu_filtered_options["cp_flag"] == 'P'), "best_offer"
                ],
                "premium2": xlu_filtered_options.loc[
                    (xlu_filtered_options.index == index) & 
                    (xlu_filtered_options["strike_price"] == strikes["strike2"]) & 
                    (xlu_filtered_options["cp_flag"] == 'P'), "best_bid"
                ],
                "premium3": xlu_filtered_options.loc[
                    (xlu_filtered_options.index == index) & 
                    (xlu_filtered_options["strike_price"] == strikes["strike3"]) & 
                    (xlu_filtered_options["cp_flag"] == 'C'), "best_bid"
                ],
                "premium4": xlu_filtered_options.loc[
                    (xlu_filtered_options.index == index) & 
                    (xlu_filtered_options["strike_price"] == strikes["strike4"]) & 
                    (xlu_filtered_options["cp_flag"] == 'C'), "best_offer"
                ]
            }        

            # print(f"date: {index}, Premiums: {premiums}")

            expiry = xlu_filtered_options.loc[index]["exdate"].max()

            ironcondor = IronCondor(direction=direction, strikes=strikes, premiums=premiums, expiry=expiry)
            ironcondor_tracker[index] = (ironcondor, ironcondor.target_profit().iloc[0], expiry)
# Out:
# date: 2017-02-16 00:00:00
# date: 2017-02-16 00:00:00, current_spot_open: 49.0, OTM Put: 41.5, ATM Put: 49.0, ATM Call: 49.0, OTM Call: 49.5,                 left wing: 7.5, right wing: 0.5
# date: 2017-03-02 00:00:00
# date: 2017-03-02 00:00:00, current_spot_open: 51.0, OTM Put: 41.5, ATM Put: 51.0, ATM Call: 51.0, OTM Call: 52.0,                 left wing: 9.5, right wing: 1.0
# date: 2017-04-07 00:00:00
# date: 2017-04-07 00:00:00, current_spot_open: 52.0, OTM Put: 51.0, ATM Put: 52.0, ATM Call: 52.0, OTM Call: 69.0,                 left wing: 1.0, right wing: 17.0
# date: 2017-05-18 00:00:00
# date: 2017-05-18 00:00:00, current_spot_open: 52.0, OTM Put: 51.0, ATM Put: 52.0, ATM Call: 52.0, OTM Call: 55.5,                 left wing: 1.0, right wing: 3.5
# date: 2017-10-12 00:00:00
# date: 2017-10-12 00:00:00, current_spot_open: 54.5, OTM Put: 53.0, ATM Put: 54.5, ATM Call: 54.5, OTM Call: 55.0,                 left wing: 1.5, right wing: 0.5
# date: 2017-10-26 00:00:00
# date: 2017-10-26 00:00:00, current_spot_open: 55.0, OTM Put: 54.0, ATM Put: 55.0, ATM Call: 55.0, OTM Call: 56.0,                 left wing: 1.0, right wing: 1.0
# date: 2018-03-07 00:00:00
# date: 2018-03-07 00:00:00, current_spot_open: 49.0, OTM Put: 47.5, ATM Put: 49.0, ATM Call: 49.0, OTM Call: 50.0,                 left wing: 1.5, right wing: 1.0
# date: 2018-03-20 00:00:00
# date: 2018-03-20 00:00:00, current_spot_open: 50.0, OTM Put: 48.5, ATM Put: 50.0, ATM Call: 50.0, OTM Call: 51.0,                 left wing: 1.5, right wing: 1.0
# date: 2018-04-24 00:00:00
# date: 2018-04-24 00:00:00, current_spot_open: 50.5, OTM Put: 48.0, ATM Put: 50.5, ATM Call: 50.5, OTM Call: 51.5,                 left wing: 2.5, right wing: 1.0
# date: 2018-05-08 00:00:00
# date: 2018-05-08 00:00:00, current_spot_open: 51.0, OTM Put: 49.5, ATM Put: 51.0, ATM Call: 51.0, OTM Call: 65.0,                 left wing: 1.5, right wing: 14.0
# date: 2018-06-12 00:00:00
# date: 2018-06-12 00:00:00, current_spot_open: 48.5, OTM Put: 41.5, ATM Put: 48.5, ATM Call: 48.5, OTM Call: 49.0,                 left wing: 7.0, right wing: 0.5
# date: 2018-07-10 00:00:00
# date: 2018-07-10 00:00:00, current_spot_open: 51.0, OTM Put: 25.0, ATM Put: 51.0, ATM Call: 51.0, OTM Call: 52.0,                 left wing: 26.0, right wing: 1.0
# date: 2018-09-07 00:00:00
# date: 2018-09-07 00:00:00, current_spot_open: 54.0, OTM Put: 52.5, ATM Put: 54.0, ATM Call: 54.0, OTM Call: 55.0,                 left wing: 1.5, right wing: 1.0
# date: 2018-09-25 00:00:00
# date: 2018-09-25 00:00:00, current_spot_open: 52.5, OTM Put: 51.0, ATM Put: 52.5, ATM Call: 52.5, OTM Call: 55.0,                 left wing: 1.5, right wing: 2.5
# date: 2018-10-11 00:00:00
# date: 2018-10-11 00:00:00, current_spot_open: 54.0, OTM Put: 52.5, ATM Put: 54.0, ATM Call: 54.0, OTM Call: 63.0,                 left wing: 1.5, right wing: 9.0
# date: 2019-01-16 00:00:00
# date: 2019-01-16 00:00:00, current_spot_open: 52.5, OTM Put: 44.5, ATM Put: 52.5, ATM Call: 52.5, OTM Call: 53.5,                 left wing: 8.0, right wing: 1.0
# date: 2019-01-31 00:00:00
# date: 2019-01-31 00:00:00, current_spot_open: 53.5, OTM Put: 44.5, ATM Put: 53.5, ATM Call: 53.5, OTM Call: 55.0,                 left wing: 9.0, right wing: 1.5
# date: 2019-02-22 00:00:00
# date: 2019-02-22 00:00:00, current_spot_open: 57.0, OTM Put: 55.0, ATM Put: 57.0, ATM Call: 57.0, OTM Call: 58.0,                 left wing: 2.0, right wing: 1.0
# date: 2019-04-17 00:00:00
# date: 2019-04-17 00:00:00, current_spot_open: 57.5, OTM Put: 56.0, ATM Put: 57.5, ATM Call: 57.5, OTM Call: 58.5,                 left wing: 1.5, right wing: 1.0
# date: 2019-06-12 00:00:00
# date: 2019-06-12 00:00:00, current_spot_open: 59.5, OTM Put: 57.5, ATM Put: 59.5, ATM Call: 59.5, OTM Call: 60.5,                 left wing: 2.0, right wing: 1.0
# date: 2019-07-09 00:00:00
# date: 2019-07-09 00:00:00, current_spot_open: 60.5, OTM Put: 44.0, ATM Put: 60.5, ATM Call: 60.5, OTM Call: 61.5,                 left wing: 16.5, right wing: 1.0
# date: 2019-09-06 00:00:00
# date: 2019-09-06 00:00:00, current_spot_open: 63.0, OTM Put: 61.5, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 64.0,                 left wing: 1.5, right wing: 1.0
# date: 2019-09-24 00:00:00
# date: 2019-09-24 00:00:00, current_spot_open: 64.0, OTM Put: 55.0, ATM Put: 64.0, ATM Call: 64.0, OTM Call: 65.0,                 left wing: 9.0, right wing: 1.0
# date: 2019-12-12 00:00:00
# date: 2019-12-12 00:00:00, current_spot_open: 63.0, OTM Put: 62.0, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 64.0,                 left wing: 1.0, right wing: 1.0
# date: 2019-12-20 00:00:00
# date: 2019-12-20 00:00:00, current_spot_open: 64.0, OTM Put: 55.5, ATM Put: 64.0, ATM Call: 64.0, OTM Call: 65.0,                 left wing: 8.5, right wing: 1.0
# date: 2020-01-28 00:00:00
# date: 2020-01-28 00:00:00, current_spot_open: 68.5, OTM Put: 66.5, ATM Put: 68.5, ATM Call: 68.5, OTM Call: 69.5,                 left wing: 2.0, right wing: 1.0
# date: 2020-02-25 00:00:00
# date: 2020-02-25 00:00:00, current_spot_open: 69.5, OTM Put: 68.0, ATM Put: 69.5, ATM Call: 69.5, OTM Call: 73.0,                 left wing: 1.5, right wing: 3.5
# date: 2020-05-21 00:00:00
# date: 2020-05-21 00:00:00, current_spot_open: 56.5, OTM Put: 54.5, ATM Put: 56.5, ATM Call: 56.5, OTM Call: 58.5,                 left wing: 2.0, right wing: 2.0
# date: 2020-05-27 00:00:00
# date: 2020-05-27 00:00:00, current_spot_open: 58.0, OTM Put: 56.0, ATM Put: 58.0, ATM Call: 58.0, OTM Call: 60.0,                 left wing: 2.0, right wing: 2.0
# date: 2020-07-08 00:00:00
# date: 2020-07-08 00:00:00, current_spot_open: 57.0, OTM Put: 46.0, ATM Put: 57.0, ATM Call: 57.0, OTM Call: 58.5,                 left wing: 11.0, right wing: 1.5
# date: 2020-07-28 00:00:00
# date: 2020-07-28 00:00:00, current_spot_open: 59.5, OTM Put: 30.0, ATM Put: 59.5, ATM Call: 59.5, OTM Call: 61.0,                 left wing: 29.5, right wing: 1.5
# date: 2020-09-09 00:00:00
# date: 2020-09-09 00:00:00, current_spot_open: 59.5, OTM Put: 54.0, ATM Put: 59.5, ATM Call: 59.5, OTM Call: 61.0,                 left wing: 5.5, right wing: 1.5
# date: 2020-09-22 00:00:00
# date: 2020-09-22 00:00:00, current_spot_open: 57.5, OTM Put: 50.0, ATM Put: 57.5, ATM Call: 57.5, OTM Call: 59.0,                 left wing: 7.5, right wing: 1.5
# date: 2020-10-29 00:00:00
# date: 2020-10-29 00:00:00, current_spot_open: 62.5, OTM Put: 51.0, ATM Put: 62.5, ATM Call: 62.5, OTM Call: 64.5,                 left wing: 11.5, right wing: 2.0
# date: 2020-11-04 00:00:00
# date: 2020-11-04 00:00:00, current_spot_open: 64.5, OTM Put: 61.5, ATM Put: 64.5, ATM Call: 64.5, OTM Call: 67.0,                 left wing: 3.0, right wing: 2.5
# date: 2020-12-16 00:00:00
# date: 2020-12-16 00:00:00, current_spot_open: 63.5, OTM Put: 62.0, ATM Put: 63.5, ATM Call: 63.5, OTM Call: 71.5,                 left wing: 1.5, right wing: 8.0
# date: 2020-12-29 00:00:00
# date: 2020-12-29 00:00:00, current_spot_open: 61.5, OTM Put: 58.5, ATM Put: 61.5, ATM Call: 61.5, OTM Call: 63.0,                 left wing: 3.0, right wing: 1.5
# date: 2021-01-05 00:00:00
# date: 2021-01-05 00:00:00, current_spot_open: 61.0, OTM Put: 56.0, ATM Put: 61.0, ATM Call: 61.0, OTM Call: 63.0,                 left wing: 5.0, right wing: 2.0
# date: 2021-02-17 00:00:00
# date: 2021-02-17 00:00:00, current_spot_open: 62.0, OTM Put: 59.5, ATM Put: 62.0, ATM Call: 62.0, OTM Call: 63.5,                 left wing: 2.5, right wing: 1.5
# date: 2021-04-21 00:00:00
# date: 2021-04-21 00:00:00, current_spot_open: 68.0, OTM Put: 66.5, ATM Put: 68.0, ATM Call: 68.0, OTM Call: 80.0,                 left wing: 1.5, right wing: 12.0
# date: 2021-06-02 00:00:00
# date: 2021-06-02 00:00:00, current_spot_open: 65.0, OTM Put: 63.0, ATM Put: 65.0, ATM Call: 65.0, OTM Call: 66.0,                 left wing: 2.0, right wing: 1.0
# date: 2021-06-10 00:00:00
# date: 2021-06-10 00:00:00, current_spot_open: 65.5, OTM Put: 30.0, ATM Put: 65.5, ATM Call: 65.5, OTM Call: 66.5,                 left wing: 35.5, right wing: 1.0
# date: 2021-08-05 00:00:00
# date: 2021-08-05 00:00:00, current_spot_open: 67.0, OTM Put: 50.0, ATM Put: 67.0, ATM Call: 67.0, OTM Call: 68.0,                 left wing: 17.0, right wing: 1.0
# date: 2021-09-14 00:00:00
# date: 2021-09-14 00:00:00, current_spot_open: 68.5, OTM Put: 66.5, ATM Put: 68.5, ATM Call: 68.5, OTM Call: 70.5,                 left wing: 2.0, right wing: 2.0
# date: 2021-10-19 00:00:00
# date: 2021-10-19 00:00:00, current_spot_open: 65.5, OTM Put: 50.0, ATM Put: 65.5, ATM Call: 65.5, OTM Call: 66.5,                 left wing: 15.5, right wing: 1.0
# date: 2021-11-09 00:00:00
# date: 2021-11-09 00:00:00, current_spot_open: 66.5, OTM Put: 64.0, ATM Put: 66.5, ATM Call: 66.5, OTM Call: 68.0,                 left wing: 2.5, right wing: 1.5
# date: 2021-12-14 00:00:00
# date: 2021-12-14 00:00:00, current_spot_open: 70.0, OTM Put: 68.0, ATM Put: 70.0, ATM Call: 70.0, OTM Call: 72.0,                 left wing: 2.0, right wing: 2.0
# date: 2022-04-05 00:00:00
# date: 2022-04-05 00:00:00, current_spot_open: 75.0, OTM Put: 69.0, ATM Put: 75.0, ATM Call: 75.0, OTM Call: 76.0,                 left wing: 6.0, right wing: 1.0
# date: 2022-05-26 00:00:00
# date: 2022-05-26 00:00:00, current_spot_open: 74.5, OTM Put: 72.0, ATM Put: 74.5, ATM Call: 74.5, OTM Call: 76.0,                 left wing: 2.5, right wing: 1.5
# date: 2022-06-07 00:00:00
# date: 2022-06-07 00:00:00, current_spot_open: 74.5, OTM Put: 70.0, ATM Put: 74.5, ATM Call: 74.5, OTM Call: 76.5,                 left wing: 4.5, right wing: 2.0
# date: 2022-07-12 00:00:00
# date: 2022-07-12 00:00:00, current_spot_open: 70.0, OTM Put: 66.0, ATM Put: 70.0, ATM Call: 70.0, OTM Call: 72.0,                 left wing: 4.0, right wing: 2.0
# date: 2022-08-24 00:00:00
# date: 2022-08-24 00:00:00, current_spot_open: 76.0, OTM Put: 61.0, ATM Put: 76.0, ATM Call: 76.0, OTM Call: 78.0,                 left wing: 15.0, right wing: 2.0
# date: 2022-11-29 00:00:00
# date: 2022-11-29 00:00:00, current_spot_open: 70.0, OTM Put: 67.0, ATM Put: 70.0, ATM Call: 70.0, OTM Call: 72.0,                 left wing: 3.0, right wing: 2.0
# date: 2023-01-12 00:00:00
# date: 2023-01-12 00:00:00, current_spot_open: 72.0, OTM Put: 70.0, ATM Put: 72.0, ATM Call: 72.0, OTM Call: 105.0,                 left wing: 2.0, right wing: 33.0
# date: 2023-01-26 00:00:00
# date: 2023-01-26 00:00:00, current_spot_open: 68.5, OTM Put: 62.0, ATM Put: 68.5, ATM Call: 68.5, OTM Call: 70.0,                 left wing: 6.5, right wing: 1.5
# date: 2023-04-04 00:00:00
# date: 2023-04-04 00:00:00, current_spot_open: 67.0, OTM Put: 50.0, ATM Put: 67.0, ATM Call: 67.0, OTM Call: 68.5,                 left wing: 17.0, right wing: 1.5
# date: 2023-04-14 00:00:00
# date: 2023-04-14 00:00:00, current_spot_open: 69.0, OTM Put: 65.5, ATM Put: 69.0, ATM Call: 69.0, OTM Call: 70.5,                 left wing: 3.5, right wing: 1.5
# date: 2023-04-18 00:00:00
# date: 2023-04-18 00:00:00, current_spot_open: 69.5, OTM Put: 67.5, ATM Put: 69.5, ATM Call: 69.5, OTM Call: 78.0,                 left wing: 2.0, right wing: 8.5
# date: 2023-06-15 00:00:00
# date: 2023-06-15 00:00:00, current_spot_open: 66.5, OTM Put: 64.5, ATM Put: 66.5, ATM Call: 66.5, OTM Call: 67.0,                 left wing: 2.0, right wing: 0.5
# date: 2023-07-06 00:00:00
# date: 2023-07-06 00:00:00, current_spot_open: 66.0, OTM Put: 64.0, ATM Put: 66.0, ATM Call: 66.0, OTM Call: 79.0,                 left wing: 2.0, right wing: 13.0
# date: 2023-08-09 00:00:00
# date: 2023-08-09 00:00:00, current_spot_open: 64.0, OTM Put: 33.0, ATM Put: 64.0, ATM Call: 64.0, OTM Call: 65.5,                 left wing: 31.0, right wing: 1.5

# %% [markdown]
# ## close early when signal turns -1

# %%
pnl_dict = {}

for index, (ironcondor, target_profit, expiry) in ironcondor_tracker.items():
    print(f"Processing date: {index}, expiry: {expiry}")
    if ironcondor is not None:
        # Check if `expiry` date is present, or find the closest available date before `expiry`
        if expiry not in xlu_time_series.index:
            print(f"Expiry date {expiry} not found; finding closest available date.")
            # Find the latest date before the `expiry` that is available in `xlu_time_series`
            available_dates = xlu_time_series.loc[:expiry].index
            if available_dates.empty:
                print(f"No available data for range {index} to {expiry}, skipping this trade.")
                continue
            expiry = available_dates[-1]  # Use the last available date before expiry
            print(f"Using adjusted expiry date: {expiry}")

        test_time_series = xlu_time_series.loc[index:expiry + pd.Timedelta(days=1)]
        options_test_df = xlu_filtered_options.loc[index:expiry + pd.Timedelta(days=1)]
        early_close = False

        for date, row in test_time_series.iterrows():
            if row["signal"] == -1:
                
                print(f"Closing on date: {date}")
                ic_strikes = ironcondor.strikes
                print(f"strike1: {ic_strikes['strike1']}, strike2: {ic_strikes['strike2']}, strike3: {ic_strikes['strike3']}, strike4: {ic_strikes['strike4']}")
                try:
                    # Long put (buy to open, sell to close)
                    long_put_sellback = options_test_df.loc[date][
                        (options_test_df.loc[date]["cp_flag"] == 'P') & 
                        (options_test_df.loc[date]["strike_price"] == ic_strikes["strike1"])
                    ]["best_bid"].values[0]
                except IndexError:
                    closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'P'] \
                        .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike1"]).abs()) \
                        .sort_values("distance").iloc[0]["strike_price"]
                    
                    # Use closest strike for long put (sell to close)
                    long_put_sellback = options_test_df.loc[date][
                        (options_test_df.loc[date]["cp_flag"] == 'P') & 
                        (options_test_df.loc[date]["strike_price"] == closest_strike)
                    ]["best_bid"].values[0]
                print(f"Long put sellback: {long_put_sellback}")

                try:
                    # Short put (sell to open, buy to close)
                    short_put_buyback = options_test_df.loc[date][
                        (options_test_df.loc[date]["cp_flag"] == 'P') & 
                        (options_test_df.loc[date]["strike_price"] == ic_strikes["strike2"])
                    ]["best_offer"].values[0]
                except IndexError:
                    closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'P'] \
                        .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike2"]).abs()) \
                        .sort_values("distance").iloc[0]["strike_price"]
                    
                    # Use closest strike for short put (buy to close)
                    short_put_buyback = options_test_df.loc[date][
                        (options_test_df.loc[date]["cp_flag"] == 'P') & 
                        (options_test_df.loc[date]["strike_price"] == closest_strike)
                    ]["best_offer"].values[0]
                print(f"Short put buyback: {short_put_buyback}")

                try:
                    # Short call (sell to open, buy to close)
                    short_call_buyback = options_test_df.loc[date][
                        (options_test_df.loc[date]["cp_flag"] == 'C') & 
                        (options_test_df.loc[date]["strike_price"] == ic_strikes["strike3"])
                    ]["best_offer"].values[0]
                except IndexError:
                    closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'C'] \
                        .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike3"]).abs()) \
                        .sort_values("distance").iloc[0]["strike_price"]
                    
                    # Use closest strike for short call (buy to close)
                    short_call_buyback = options_test_df.loc[date][
                        (options_test_df.loc[date]["cp_flag"] == 'C') & 
                        (options_test_df.loc[date]["strike_price"] == closest_strike)
                    ]["best_offer"].values[0]
                print(f"Short call buyback: {short_call_buyback}")

                try:
                    # Long call (buy to open, sell to close)
                    long_call_sellback = options_test_df.loc[date][
                        (options_test_df.loc[date]["cp_flag"] == 'C') & 
                        (options_test_df.loc[date]["strike_price"] == ic_strikes["strike4"])
                    ]["best_bid"].values[0]
                except IndexError:
                    closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'C'] \
                        .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike4"]).abs()) \
                        .sort_values("distance").iloc[0]["strike_price"]
                    
                    # Use closest strike for long call (sell to close)
                    long_call_sellback = options_test_df.loc[date][
                        (options_test_df.loc[date]["cp_flag"] == 'C') & 
                        (options_test_df.loc[date]["strike_price"] == closest_strike)
                    ]["best_bid"].values[0]
                print(f"Long call sellback: {long_call_sellback}")

                # Now calculate the closing cost
                if None not in [long_put_sellback, short_put_buyback, short_call_buyback, long_call_sellback]:
                    closing_cost = long_put_sellback - short_put_buyback - short_call_buyback + long_call_sellback
                else:
                    closing_cost = None  # Handle missing values appropriately
                print(f"Closing cost: {closing_cost}")

                ironcondor.insert_spot(xlu_time_series.loc[date]["Close"])
                pnl_dict[index] = ironcondor.payoff() - closing_cost
                print(f"Close iron condor early on date: {date} when signal is -1, pnl: {pnl_dict[index]}")
                early_close = True
                break
        if not early_close:
            try:
                ironcondor.insert_spot(xlu_time_series.loc[expiry]["Close"])
            except KeyError:
                ironcondor.insert_spot(xlu_time_series.loc[expiry - pd.Timedelta(days=1)]["Close"])
            
            print(f"Let iron condor expire: {expiry}, pnl: {ironcondor.payoff()}")
            pnl_dict[index] = ironcondor.payoff()
# Out:
# Processing date: 2017-02-16 00:00:00, expiry: 2017-02-24 00:00:00
# Let iron condor expire: 2017-02-24 00:00:00, pnl: -0.06000000000000005
# Processing date: 2017-03-02 00:00:00, expiry: 2017-03-10 00:00:00
# Closing on date: 2017-03-10 00:00:00
# strike1: 41.5, strike2: 51.0, strike3: 51.0, strike4: 52.0
# Long put sellback: 0.0
# Short put buyback: 0.81
# Short call buyback: 0.43
# Long call sellback: 0.07
# Closing cost: -1.17
# Close iron condor early on date: 2017-03-10 00:00:00 when signal is -1, pnl: 1.8799990844726562
# Processing date: 2017-04-07 00:00:00, expiry: 2017-04-21 00:00:00
# Let iron condor expire: 2017-04-21 00:00:00, pnl: 0.36999954223632814
# Processing date: 2017-05-18 00:00:00, expiry: 2017-05-26 00:00:00
# Closing on date: 2017-05-26 00:00:00
# strike1: 51.0, strike2: 52.0, strike3: 52.0, strike4: 55.5
# Long put sellback: 0.0
# Short put buyback: 0.07
# Short call buyback: 1.5
# Long call sellback: 0.0
# Closing cost: -1.57
# Close iron condor early on date: 2017-05-26 00:00:00 when signal is -1, pnl: 0.3799984741210938
# Processing date: 2017-10-12 00:00:00, expiry: 2017-10-20 00:00:00
# Let iron condor expire: 2017-10-20 00:00:00, pnl: 0.05999938964843751
# Processing date: 2017-10-26 00:00:00, expiry: 2017-11-03 00:00:00
# Expiry date 2017-11-03 00:00:00 not found; finding closest available date.
# Using adjusted expiry date: 2017-11-01 00:00:00
# Let iron condor expire: 2017-11-01 00:00:00, pnl: 0.3800013732910157
# Processing date: 2018-03-07 00:00:00, expiry: 2018-03-16 00:00:00
# Let iron condor expire: 2018-03-16 00:00:00, pnl: -0.14
# Processing date: 2018-03-20 00:00:00, expiry: 2018-03-29 00:00:00
# Closing on date: 2018-03-29 00:00:00
# strike1: 48.5, strike2: 50.0, strike3: 50.0, strike4: 51.0
# Long put sellback: 0.03
# Short put buyback: 0.23
# Short call buyback: 0.8
# Long call sellback: 0.23
# Closing cost: -0.77
# Close iron condor early on date: 2018-03-29 00:00:00 when signal is -1, pnl: 0.920001220703125
# Processing date: 2018-04-24 00:00:00, expiry: 2018-05-04 00:00:00
# Let iron condor expire: 2018-05-04 00:00:00, pnl: -0.23000000000000004
# Processing date: 2018-05-08 00:00:00, expiry: 2018-05-18 00:00:00
# Let iron condor expire: 2018-05-18 00:00:00, pnl: -0.53
# Processing date: 2018-06-12 00:00:00, expiry: 2018-06-22 00:00:00
# Let iron condor expire: 2018-06-22 00:00:00, pnl: 0.16000000000000014
# Processing date: 2018-07-10 00:00:00, expiry: 2018-07-20 00:00:00
# Let iron condor expire: 2018-07-20 00:00:00, pnl: -0.15000000000000005
# Processing date: 2018-09-07 00:00:00, expiry: 2018-09-21 00:00:00
# Let iron condor expire: 2018-09-21 00:00:00, pnl: -0.05999862670898437
# Processing date: 2018-09-25 00:00:00, expiry: 2018-10-05 00:00:00
# Let iron condor expire: 2018-10-05 00:00:00, pnl: -0.2900010681152345
# Processing date: 2018-10-11 00:00:00, expiry: 2018-10-19 00:00:00
# Closing on date: 2018-10-12 00:00:00
# strike1: 52.5, strike2: 54.0, strike3: 54.0, strike4: 63.0
# Long put sellback: 0.47
# Short put buyback: 1.28
# Short call buyback: 0.35
# Long call sellback: 0.0
# Closing cost: -1.1600000000000001
# Close iron condor early on date: 2018-10-12 00:00:00 when signal is -1, pnl: 1.0300007629394532
# Processing date: 2019-01-16 00:00:00, expiry: 2019-01-25 00:00:00
# Let iron condor expire: 2019-01-25 00:00:00, pnl: -0.04999969482421879
# Processing date: 2019-01-31 00:00:00, expiry: 2019-02-08 00:00:00
# Closing on date: 2019-02-08 00:00:00
# strike1: 44.5, strike2: 53.5, strike3: 53.5, strike4: 55.0
# Long put sellback: 0.0
# Short put buyback: 0.08
# Short call buyback: 2.27
# Long call sellback: 0.95
# Closing cost: -1.4000000000000001
# Close iron condor early on date: 2019-02-08 00:00:00 when signal is -1, pnl: 1.0100000000000002
# Processing date: 2019-02-22 00:00:00, expiry: 2019-03-08 00:00:00
# Closing on date: 2019-03-08 00:00:00
# strike1: 55.0, strike2: 57.0, strike3: 57.0, strike4: 58.0
# Long put sellback: 0.07
# Short put buyback: 0.51
# Short call buyback: 0.73
# Long call sellback: 0.21
# Closing cost: -0.96
# Close iron condor early on date: 2019-03-08 00:00:00 when signal is -1, pnl: 1.1900007629394531
# Processing date: 2019-04-17 00:00:00, expiry: 2019-04-26 00:00:00
# Expiry date 2019-04-26 00:00:00 not found; finding closest available date.
# Using adjusted expiry date: 2019-04-25 00:00:00
# Let iron condor expire: 2019-04-25 00:00:00, pnl: 0.1300016784667969
# Processing date: 2019-06-12 00:00:00, expiry: 2019-06-21 00:00:00
# Let iron condor expire: 2019-06-21 00:00:00, pnl: -0.039999999999999925
# Processing date: 2019-07-09 00:00:00, expiry: 2019-07-19 00:00:00
# Let iron condor expire: 2019-07-19 00:00:00, pnl: 0.6599989318847655
# Processing date: 2019-09-06 00:00:00, expiry: 2019-09-20 00:00:00
# Let iron condor expire: 2019-09-20 00:00:00, pnl: 0.09000106811523445
# Processing date: 2019-09-24 00:00:00, expiry: 2019-10-04 00:00:00
# Closing on date: 2019-10-03 00:00:00
# strike1: 55.0, strike2: 64.0, strike3: 64.0, strike4: 65.0
# Long put sellback: 0.0
# Short put buyback: 0.6
# Short call buyback: 0.42
# Long call sellback: 0.08
# Closing cost: -0.9400000000000001
# Close iron condor early on date: 2019-10-03 00:00:00 when signal is -1, pnl: 1.6500010681152344
# Processing date: 2019-12-12 00:00:00, expiry: 2019-12-20 00:00:00
# Let iron condor expire: 2019-12-20 00:00:00, pnl: -0.29000000000000004
# Processing date: 2019-12-20 00:00:00, expiry: 2020-01-03 00:00:00
# Let iron condor expire: 2020-01-03 00:00:00, pnl: 0.7099986267089844
# Processing date: 2020-01-28 00:00:00, expiry: 2020-02-07 00:00:00
# Closing on date: 2020-01-28 00:00:00
# strike1: 66.5, strike2: 68.5, strike3: 68.5, strike4: 69.5
# Long put sellback: 0.08
# Short put buyback: 0.55
# Short call buyback: 0.56
# Long call sellback: 0.16
# Closing cost: -0.87
# Close iron condor early on date: 2020-01-28 00:00:00 when signal is -1, pnl: 1.6500012207031252
# Processing date: 2020-02-25 00:00:00, expiry: 2020-03-06 00:00:00
# Closing on date: 2020-02-26 00:00:00
# strike1: 68.0, strike2: 69.5, strike3: 69.5, strike4: 73.0
# Long put sellback: 1.06
# Short put buyback: 2.21
# Short call buyback: 0.1
# Long call sellback: 0.0
# Closing cost: -1.25
# Close iron condor early on date: 2020-02-26 00:00:00 when signal is -1, pnl: 0.81
# Processing date: 2020-05-21 00:00:00, expiry: 2020-05-29 00:00:00
# Let iron condor expire: 2020-05-29 00:00:00, pnl: -0.9500000000000002
# Processing date: 2020-05-27 00:00:00, expiry: 2020-06-05 00:00:00
# Let iron condor expire: 2020-06-05 00:00:00, pnl: -0.8600000000000003
# Processing date: 2020-07-08 00:00:00, expiry: 2020-07-17 00:00:00
# Let iron condor expire: 2020-07-17 00:00:00, pnl: -0.3400000000000001
# Processing date: 2020-07-28 00:00:00, expiry: 2020-08-07 00:00:00
# Let iron condor expire: 2020-08-07 00:00:00, pnl: -0.3799999999999999
# Processing date: 2020-09-09 00:00:00, expiry: 2020-09-18 00:00:00
# Let iron condor expire: 2020-09-18 00:00:00, pnl: 0.020000457763671764
# Processing date: 2020-09-22 00:00:00, expiry: 2020-10-02 00:00:00
# Closing on date: 2020-09-24 00:00:00
# strike1: 50.0, strike2: 57.5, strike3: 57.5, strike4: 59.0
# Long put sellback: 0.02
# Short put buyback: 0.63
# Short call buyback: 0.92
# Long call sellback: 0.2
# Closing cost: -1.33
# Close iron condor early on date: 2020-09-24 00:00:00 when signal is -1, pnl: 2.2599995422363284
# Processing date: 2020-10-29 00:00:00, expiry: 2020-11-06 00:00:00
# Let iron condor expire: 2020-11-06 00:00:00, pnl: -0.00999725341796881
# Processing date: 2020-11-04 00:00:00, expiry: 2020-11-13 00:00:00
# Closing on date: 2020-11-10 00:00:00
# strike1: 61.5, strike2: 64.5, strike3: 64.5, strike4: 67.0
# Long put sellback: 0.07
# Short put buyback: 0.33
# Short call buyback: 2.09
# Long call sellback: 0.51
# Closing cost: -1.8399999999999996
# Close iron condor early on date: 2020-11-10 00:00:00 when signal is -1, pnl: 1.509997863769531
# Processing date: 2020-12-16 00:00:00, expiry: 2020-12-24 00:00:00
# Let iron condor expire: 2020-12-24 00:00:00, pnl: -0.4600000000000001
# Processing date: 2020-12-29 00:00:00, expiry: 2021-01-08 00:00:00
# Let iron condor expire: 2021-01-08 00:00:00, pnl: 0.20999816894531254
# Processing date: 2021-01-05 00:00:00, expiry: 2021-01-15 00:00:00
# Let iron condor expire: 2021-01-15 00:00:00, pnl: -0.5200016784667969
# Processing date: 2021-02-17 00:00:00, expiry: 2021-02-26 00:00:00
# Let iron condor expire: 2021-02-26 00:00:00, pnl: -1.52
# Processing date: 2021-04-21 00:00:00, expiry: 2021-04-30 00:00:00
# Let iron condor expire: 2021-04-30 00:00:00, pnl: -0.35999877929687496
# Processing date: 2021-06-02 00:00:00, expiry: 2021-06-11 00:00:00
# Expiry date 2021-06-11 00:00:00 not found; finding closest available date.
# Using adjusted expiry date: 2021-06-10 00:00:00
# Let iron condor expire: 2021-06-10 00:00:00, pnl: -0.1999990844726562
# Processing date: 2021-06-10 00:00:00, expiry: 2021-06-18 00:00:00
# Let iron condor expire: 2021-06-18 00:00:00, pnl: -0.6400015258789062
# Processing date: 2021-08-05 00:00:00, expiry: 2021-08-13 00:00:00
# Let iron condor expire: 2021-08-13 00:00:00, pnl: -0.21000000000000008
# Processing date: 2021-09-14 00:00:00, expiry: 2021-09-24 00:00:00
# Closing on date: 2021-09-24 00:00:00
# strike1: 66.5, strike2: 68.5, strike3: 68.5, strike4: 70.5
# Long put sellback: 1.48
# Short put buyback: 3.45
# Short call buyback: 0.04
# Long call sellback: 0.0
# Closing cost: -2.0100000000000002
# Close iron condor early on date: 2021-09-24 00:00:00 when signal is -1, pnl: 1.1500000000000004
# Processing date: 2021-10-19 00:00:00, expiry: 2021-10-29 00:00:00
# Closing on date: 2021-10-28 00:00:00
# strike1: 50.0, strike2: 65.5, strike3: 65.5, strike4: 66.5
# Long put sellback: 0.0
# Short put buyback: 0.13
# Short call buyback: 1.92
# Long call sellback: 1.01
# Closing cost: -1.0399999999999998
# Close iron condor early on date: 2021-10-28 00:00:00 when signal is -1, pnl: 0.8899999999999997
# Processing date: 2021-11-09 00:00:00, expiry: 2021-11-19 00:00:00
# Let iron condor expire: 2021-11-19 00:00:00, pnl: 0.2099969482421875
# Processing date: 2021-12-14 00:00:00, expiry: 2021-12-23 00:00:00
# Let iron condor expire: 2021-12-23 00:00:00, pnl: 0.770001220703125
# Processing date: 2022-04-05 00:00:00, expiry: 2022-04-14 00:00:00
# Let iron condor expire: 2022-04-14 00:00:00, pnl: -0.030000000000000138
# Processing date: 2022-05-26 00:00:00, expiry: 2022-06-03 00:00:00
# Let iron condor expire: 2022-06-03 00:00:00, pnl: 0.9199984741210937
# Processing date: 2022-06-07 00:00:00, expiry: 2022-06-17 00:00:00
# Closing on date: 2022-06-14 00:00:00
# strike1: 70.0, strike2: 74.5, strike3: 74.5, strike4: 76.5
# Long put sellback: 4.2
# Short put buyback: 10.55
# Short call buyback: 0.17
# Long call sellback: 0.0
# Closing cost: -6.5200000000000005
# Close iron condor early on date: 2022-06-14 00:00:00 when signal is -1, pnl: 3.5300000000000007
# Processing date: 2022-07-12 00:00:00, expiry: 2022-07-22 00:00:00
# Let iron condor expire: 2022-07-22 00:00:00, pnl: 0.9900003051757813
# Processing date: 2022-08-24 00:00:00, expiry: 2022-09-02 00:00:00
# Closing on date: 2022-08-31 00:00:00
# strike1: 61.0, strike2: 76.0, strike3: 76.0, strike4: 78.0
# Long put sellback: 0.0
# Short put buyback: 1.86
# Short call buyback: 0.28
# Long call sellback: 0.03
# Closing cost: -2.1100000000000003
# Close iron condor early on date: 2022-08-31 00:00:00 when signal is -1, pnl: 1.8199963378906252
# Processing date: 2022-11-29 00:00:00, expiry: 2022-12-09 00:00:00
# Let iron condor expire: 2022-12-09 00:00:00, pnl: 0.5699981689453125
# Processing date: 2023-01-12 00:00:00, expiry: 2023-01-20 00:00:00
# Let iron condor expire: 2023-01-20 00:00:00, pnl: -2.97
# Processing date: 2023-01-26 00:00:00, expiry: 2023-02-03 00:00:00
# Closing on date: 2023-02-03 00:00:00
# strike1: 62.0, strike2: 68.5, strike3: 68.5, strike4: 70.0
# Long put sellback: 0.04
# Short put buyback: 1.22
# Short call buyback: 0.78
# Long call sellback: 0.22
# Closing cost: -1.74
# Close iron condor early on date: 2023-02-03 00:00:00 when signal is -1, pnl: 2.420003662109375
# Processing date: 2023-04-04 00:00:00, expiry: 2023-04-14 00:00:00
# Let iron condor expire: 2023-04-14 00:00:00, pnl: -0.3000000000000001
# Processing date: 2023-04-14 00:00:00, expiry: 2023-04-28 00:00:00
# Let iron condor expire: 2023-04-28 00:00:00, pnl: 1.2200033569335937
# Processing date: 2023-04-18 00:00:00, expiry: 2023-04-28 00:00:00
# Let iron condor expire: 2023-04-28 00:00:00, pnl: -0.009996643066406297
# Processing date: 2023-06-15 00:00:00, expiry: 2023-06-23 00:00:00
# Let iron condor expire: 2023-06-23 00:00:00, pnl: -0.7900012207031251
# Processing date: 2023-07-06 00:00:00, expiry: 2023-07-14 00:00:00
# Let iron condor expire: 2023-07-14 00:00:00, pnl: -1.7199984741210936
# Processing date: 2023-08-09 00:00:00, expiry: 2023-08-18 00:00:00
# Let iron condor expire: 2023-08-18 00:00:00, pnl: 0.6000016784667969

# %%
pd.DataFrame(pnl_dict.items(), columns=["Date", "PnL"]).set_index("Date").PnL.cumsum().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Optimisation

# %%
from bayes_opt import BayesianOptimization

# %%
def myround(x, base=5):
    return base * round(x/base)

def calculate_sharpe_ratio(pnl_series):
    returns = pnl_series.pct_change().dropna()
    sharpe_ratio = np.mean(returns) / np.std(returns)
    return sharpe_ratio * np.sqrt(252)

def calculate_sortino_ratio(pnl_series):
    returns = pnl_series.pct_change().dropna()
    sortino_ratio = np.mean(returns) / np.std(returns[returns < 0])
    return sortino_ratio * np.sqrt(252)

def ensure_weekly_action(df):
    last_action = 0
    last_week = -1

    for i in range(len(df)):
        current_week = df.index[i].isocalendar()[1]  # Get the week number
        current_day = df["day"].iloc[i]

        if current_week != last_week:  # Reset at the start of a new week
            last_action = 0
            last_week = current_week

        if last_action != 0 and df["action"].iloc[i] != 0:
            # If an action has already occurred this week, set to 0
            df.at[df.index[i], "action"] = 0
        elif df["action"].iloc[i] != 0:
            # If this is the first action of the week, update last_action
            last_action = df["action"].iloc[i]

    return df

def find_nearest_strike_delta(atm_spot, date_index, delta_target, option_df, cp_flag):
    """
    Helper function to find the strike with delta closest to delta_target
    """

    options = option_df.loc[date_index].query(f"cp_flag == '{cp_flag}'")
    atm_delta = options.query("strike_price == @atm_spot")["delta"]
    try:
        if isinstance(atm_delta, pd.Series):
            atm_delta = atm_delta.values[0]
    except IndexError:
        print(f"Error: {date_index}, {cp_flag}")
        return None
    new_delta = atm_delta + delta_target
    return options.iloc[(options["delta"] - new_delta).abs().argmin()]["strike_price"]

class Option:
    def __init__(self, strike: float, premium: float, expiry: str):
        self.strike = strike
        self.premium = premium
        self.expiry = expiry
        self.spot_price = None

    def insert_spot(self, spot_price: float):
        self.spot_price = spot_price
    
    def short_call(self):
        # Payoff for short call: premium received - intrinsic value of the option
        intrinsic_value = np.maximum(0, self.spot_price - self.strike)
        return self.premium - intrinsic_value
    
    def long_call(self):
        # Payoff for long call: intrinsic value - premium paid
        intrinsic_value = np.maximum(0, self.spot_price - self.strike)
        return intrinsic_value - self.premium
    
    def short_put(self):
        # Payoff for short put: premium received - intrinsic value of the option
        intrinsic_value = np.maximum(0, self.strike - self.spot_price)
        return self.premium - intrinsic_value
    
    def long_put(self):
        # Payoff for long put: intrinsic value - premium paid
        intrinsic_value = np.maximum(0, self.strike - self.spot_price)
        return intrinsic_value - self.premium


class IronCondor:
    def __init__(self, direction: str, strikes: dict, premiums: dict, expiry: str):
        """
        Initialize the Iron Condor strategy with strikes and premiums for the options.
        
        direction: long, (short) Iron Condor
        1. Short (Long) 1 OTM Put (strike 1)
        2. Long (Short) 1 close to ATM Put (strike 2)
        3. Long (Short) 1 close to ATM Call (strike 3)
        4. Short (Long) 1 OTM Call (strike 4)        

        strikes: a dictionary of strikes for the 4 options (strike1 to strike4)
        premiums: a dictionary of premiums for the 4 options (premium1 to premium4)
        expiry: expiration date of the options
        """
        self.strikes = strikes
        self.premiums = premiums
        self.direction = direction
        self.expiry = expiry
        self.short_put_option = Option(strikes['strike1'], premiums['premium1'], expiry)
        self.long_put_option = Option(strikes['strike2'], premiums['premium2'], expiry)
        self.long_call_option = Option(strikes['strike3'], premiums['premium3'], expiry)
        self.short_call_option = Option(strikes['strike4'], premiums['premium4'], expiry)

    def initial_cashflow(self):
        """
        Calculate the initial cashflow of the Iron Condor strategy.
        """
        if self.direction == "long":
            initial_cashflow = self.premiums['premium1'] - self.premiums['premium2'] - self.premiums['premium3'] + self.premiums['premium4']
        elif self.direction == "short":
            initial_cashflow = -self.premiums['premium1'] + self.premiums['premium2'] + self.premiums['premium3'] - self.premiums['premium4']
        
        return initial_cashflow

    def insert_spot(self, spot_price: float):
        """
        Insert the current spot price for all the options in the Iron Condor strategy.
        """
        self.short_put_option.insert_spot(spot_price)
        self.long_put_option.insert_spot(spot_price)
        self.long_call_option.insert_spot(spot_price)
        self.short_call_option.insert_spot(spot_price)
    
    def payoff(self):
        """
        Calculate the total payoff (profit or loss) of the Iron Condor strategy.
        
        direction: 'long' for long Iron Condor, 'short' for short Iron Condor
        """
        if self.direction == "long":
            short_put = self.short_put_option.short_put()
            long_put = self.long_put_option.long_put()
            long_call = self.long_call_option.long_call()
            short_call = self.short_call_option.short_call()
            total_payoff = short_put + long_put + long_call + short_call
        elif self.direction == "short":
            long_put = -self.long_put_option.long_put()
            short_put = -self.short_put_option.short_put()
            short_call = -self.short_call_option.short_call()
            long_call = -self.long_call_option.long_call()
            total_payoff = long_put + short_put + short_call + long_call
        
        return total_payoff.iloc[0] if isinstance(total_payoff, pd.Series) else total_payoff
    
    def target_profit(self):
        """
        Calculate the target profit for the Iron Condor strategy.
        """
        if self.direction == "long":
            self.long_call_option = Option(self.strikes['strike3'], self.premiums['premium3'], self.expiry)
            self.short_call_option = Option(self.strikes['strike4'], self.premiums['premium4'], self.expiry)
            self.long_call_option.insert_spot(self.strikes["strike4"] + 5)
            self.short_call_option.insert_spot(self.strikes["strike4"] + 5)
            target_profit = self.premiums["premium1"] - self.premiums["premium2"] + self.long_call_option.long_call() + self.short_call_option.short_call()
        elif self.direction == "short":
            target_profit = self.initial_cashflow()
        
        return target_profit

class OptionsBacktester:
    def __init__(self,
                 signal_df: pd.DataFrame,
                 spot_price_df: pd.DataFrame,
                 options_df: pd.DataFrame,
                 upper_threshold: float,
                 lower_threshold: float,
                 option_type: str,
                 dynamic_option_strategy: bool = False,
                 dynamic_strike: bool = False,):
        self.signal_df = signal_df
        self.signal_df.columns = ["signal"]
        self.spot_price_df = spot_price_df
        self.options_df = options_df
        self.upper_threshold = upper_threshold
        self.lower_threshold = lower_threshold
        self.option_type = option_type
        self.dynamic_option_strategy = dynamic_option_strategy
        self.dynamic_strike = dynamic_strike

        self.comb_df = pd.concat([self.signal_df, self.spot_price_df.shift(), self.options_df.shift()], axis=1)
        self.comb_df["action"] = np.where(self.comb_df["signal"] > self.upper_threshold, 1, np.where(self.comb_df["signal"] < self.lower_threshold, -1, 0))

    def long_short_vol_df(self):
        self.trading_df = {}
        for index, row in self.comb_df.iterrows():
            if row["action"] != 0:
                self.trading_df[index] = self.comb_df.loc[index]

# %%
def objective_function(window, upper_threshold, lower_threshold):
    try:
        # Options data
        day_map = {0: "Monday", 1: "Tuesday", 2: "Wednesday", 3: "Thursday", 4: "Friday", 5: "Saturday", 6: "Sunday"}

        xlu_options = pd.read_hdf("data/etf_options_data.hf5", key="XLU")
        xlu_options = xlu_options.set_index("date")
        xlu_options["strike_price"] = xlu_options["strike_price"] / 1000
        xlu_filtered_options = xlu_options.groupby("date").apply(lambda x: x.query("exdate == exdate.max()")).reset_index(level=0, drop=True)
        xlu_filtered_options["day"] = xlu_filtered_options.index.weekday.map(day_map)
        xlu_filtered_options["ex_day"] = xlu_filtered_options["exdate"].dt.weekday.map(day_map)

        # Setting time series data
        xlu_pred = pd.read_csv("data/xlu_pred.csv", parse_dates=True, index_col=0).rename(columns={"0": "Rolling Pred"})
        xlu_iv = pd.read_csv("data/XLU_IV.csv", parse_dates=True, index_col=0)
        xlu_vrp = (xlu_iv["Average IV"] - xlu_pred["Rolling Pred"]).dropna()

        xlu_vrp_standardised = rolling_z_score(xlu_vrp, window=int(window))

        xlu_filtered_options["vrp"] = xlu_vrp_standardised
        xlu_time_series = pd.read_hdf("data/etf_series.hf5", key="XLU")
        xlu_time_series["day"] = xlu_time_series.index.weekday
        xlu_time_series["vrp"] = xlu_vrp_standardised
        xlu_time_series["signal"] = np.where(xlu_time_series["vrp"] > upper_threshold, 1, np.where(xlu_time_series["vrp"] < lower_threshold, -1, 0))
        xlu_time_series["action"] = np.where((xlu_time_series["signal"] == 1)  & (xlu_time_series.index.weekday != 4), 1, 
                                            np.where((xlu_time_series["signal"] == -1) & (xlu_time_series.index.weekday != 4), -1, 
                                                    0))
        xlu_time_series.dropna(inplace=True)
        xlu_time_series

        xlu_time_series = ensure_weekly_action(xlu_time_series)
        xlu_time_series["action"] = xlu_time_series["action"].shift(-1)

        # Strategy backtesting
        ironcondor_tracker = {}

        for index, row in xlu_time_series.iterrows():
            if row["action"] == 1:
                print(f"date: {index}")
                direction = "short"

                index_loc = xlu_time_series.index.get_loc(index)

                current_spot_open = myround(xlu_time_series.iloc[index_loc]["Open"], 0.5)

                daily_options = xlu_filtered_options.loc[index]

                atm_put_strike = atm_call_strike = current_spot_open

                otm_put_strike = find_nearest_strike_delta(current_spot_open, index, 0.4, xlu_filtered_options, "P")
                otm_call_strike = find_nearest_strike_delta(current_spot_open, index, -0.3, xlu_filtered_options, "C")

                if otm_put_strike is None or otm_call_strike is None:
                    continue
                    
                else:
                    print(f"date: {index}, current_spot_open: {current_spot_open}, OTM Put: {otm_put_strike}, ATM Put: {atm_put_strike}, ATM Call: {atm_call_strike}, OTM Call: {otm_call_strike}, \
                        left wing: {abs(otm_put_strike - atm_put_strike)}, right wing: {abs(atm_call_strike - otm_call_strike)}")
                    strikes = {
                        "strike1": otm_put_strike,
                        "strike2": atm_put_strike,
                        "strike3": atm_call_strike,
                        "strike4": otm_call_strike
                    }

                    premiums = {
                        "premium1": xlu_filtered_options.loc[
                            (xlu_filtered_options.index == index) & 
                            (xlu_filtered_options["strike_price"] == strikes["strike1"]) & 
                            (xlu_filtered_options["cp_flag"] == 'P'), "best_offer"
                        ],
                        "premium2": xlu_filtered_options.loc[
                            (xlu_filtered_options.index == index) & 
                            (xlu_filtered_options["strike_price"] == strikes["strike2"]) & 
                            (xlu_filtered_options["cp_flag"] == 'P'), "best_bid"
                        ],
                        "premium3": xlu_filtered_options.loc[
                            (xlu_filtered_options.index == index) & 
                            (xlu_filtered_options["strike_price"] == strikes["strike3"]) & 
                            (xlu_filtered_options["cp_flag"] == 'C'), "best_bid"
                        ],
                        "premium4": xlu_filtered_options.loc[
                            (xlu_filtered_options.index == index) & 
                            (xlu_filtered_options["strike_price"] == strikes["strike4"]) & 
                            (xlu_filtered_options["cp_flag"] == 'C'), "best_offer"
                        ]
                    }        

                    # print(f"date: {index}, Premiums: {premiums}")

                    expiry = xlu_filtered_options.loc[index]["exdate"].max()

                    ironcondor = IronCondor(direction=direction, strikes=strikes, premiums=premiums, expiry=expiry)
                    ironcondor_tracker[index] = (ironcondor, ironcondor.target_profit().iloc[0], expiry)

        # Calculate the payoff of the Iron Condor strategy
        pnl_dict = {}

        for index, (ironcondor, target_profit, expiry) in ironcondor_tracker.items():
            print(f"Processing date: {index}, expiry: {expiry}")
            if ironcondor is not None:
                # Check if `expiry` date is present, or find the closest available date before `expiry`
                if expiry not in xlu_time_series.index:
                    print(f"Expiry date {expiry} not found; finding closest available date.")
                    # Find the latest date before the `expiry` that is available in `xlu_time_series`
                    available_dates = xlu_time_series.loc[:expiry].index
                    if available_dates.empty:
                        print(f"No available data for range {index} to {expiry}, skipping this trade.")
                        continue
                    expiry = available_dates[-1]  # Use the last available date before expiry
                    print(f"Using adjusted expiry date: {expiry}")

                test_time_series = xlu_time_series.loc[index:expiry + pd.Timedelta(days=1)]
                options_test_df = xlu_filtered_options.loc[index:expiry + pd.Timedelta(days=1)]
                early_close = False

                for date, row in test_time_series.iterrows():
                    if row["signal"] == -1:
                        
                        print(f"Closing on date: {date}")
                        ic_strikes = ironcondor.strikes
                        print(f"strike1: {ic_strikes['strike1']}, strike2: {ic_strikes['strike2']}, strike3: {ic_strikes['strike3']}, strike4: {ic_strikes['strike4']}")
                        try:
                            # Long put (buy to open, sell to close)
                            long_put_sellback = options_test_df.loc[date][
                                (options_test_df.loc[date]["cp_flag"] == 'P') & 
                                (options_test_df.loc[date]["strike_price"] == ic_strikes["strike1"])
                            ]["best_bid"].values[0]
                        except IndexError:
                            closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'P'] \
                                .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike1"]).abs()) \
                                .sort_values("distance").iloc[0]["strike_price"]
                            
                            # Use closest strike for long put (sell to close)
                            long_put_sellback = options_test_df.loc[date][
                                (options_test_df.loc[date]["cp_flag"] == 'P') & 
                                (options_test_df.loc[date]["strike_price"] == closest_strike)
                            ]["best_bid"].values[0]
                        print(f"Long put sellback: {long_put_sellback}")

                        try:
                            # Short put (sell to open, buy to close)
                            short_put_buyback = options_test_df.loc[date][
                                (options_test_df.loc[date]["cp_flag"] == 'P') & 
                                (options_test_df.loc[date]["strike_price"] == ic_strikes["strike2"])
                            ]["best_offer"].values[0]
                        except IndexError:
                            closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'P'] \
                                .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike2"]).abs()) \
                                .sort_values("distance").iloc[0]["strike_price"]
                            
                            # Use closest strike for short put (buy to close)
                            short_put_buyback = options_test_df.loc[date][
                                (options_test_df.loc[date]["cp_flag"] == 'P') & 
                                (options_test_df.loc[date]["strike_price"] == closest_strike)
                            ]["best_offer"].values[0]
                        print(f"Short put buyback: {short_put_buyback}")

                        try:
                            # Short call (sell to open, buy to close)
                            short_call_buyback = options_test_df.loc[date][
                                (options_test_df.loc[date]["cp_flag"] == 'C') & 
                                (options_test_df.loc[date]["strike_price"] == ic_strikes["strike3"])
                            ]["best_offer"].values[0]
                        except IndexError:
                            closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'C'] \
                                .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike3"]).abs()) \
                                .sort_values("distance").iloc[0]["strike_price"]
                            
                            # Use closest strike for short call (buy to close)
                            short_call_buyback = options_test_df.loc[date][
                                (options_test_df.loc[date]["cp_flag"] == 'C') & 
                                (options_test_df.loc[date]["strike_price"] == closest_strike)
                            ]["best_offer"].values[0]
                        print(f"Short call buyback: {short_call_buyback}")

                        try:
                            # Long call (buy to open, sell to close)
                            long_call_sellback = options_test_df.loc[date][
                                (options_test_df.loc[date]["cp_flag"] == 'C') & 
                                (options_test_df.loc[date]["strike_price"] == ic_strikes["strike4"])
                            ]["best_bid"].values[0]
                        except IndexError:
                            closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'C'] \
                                .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike4"]).abs()) \
                                .sort_values("distance").iloc[0]["strike_price"]
                            
                            # Use closest strike for long call (sell to close)
                            long_call_sellback = options_test_df.loc[date][
                                (options_test_df.loc[date]["cp_flag"] == 'C') & 
                                (options_test_df.loc[date]["strike_price"] == closest_strike)
                            ]["best_bid"].values[0]
                        print(f"Long call sellback: {long_call_sellback}")

                        # Now calculate the closing cost
                        if None not in [long_put_sellback, short_put_buyback, short_call_buyback, long_call_sellback]:
                            closing_cost = long_put_sellback - short_put_buyback - short_call_buyback + long_call_sellback
                        else:
                            closing_cost = None  # Handle missing values appropriately
                        print(f"Closing cost: {closing_cost}")

                        ironcondor.insert_spot(xlu_time_series.loc[date]["Close"])
                        pnl_dict[index] = ironcondor.payoff() - closing_cost
                        print(f"Close iron condor early on date: {date} when signal is -1, pnl: {pnl_dict[index]}")
                        early_close = True
                        break
                if not early_close:
                    try:
                        ironcondor.insert_spot(xlu_time_series.loc[expiry]["Close"])
                        print(f"Let iron condor expire: {expiry}, pnl: {ironcondor.payoff()}")
                        pnl_dict[index] = ironcondor.payoff()    
                    except KeyError:
                        try:
                            ironcondor.insert_spot(xlu_time_series.loc[expiry + pd.Timedelta(days=1)]["Close"])
                            print(f"Let iron condor expire: {expiry}, pnl: {ironcondor.payoff()}")
                            pnl_dict[index] = ironcondor.payoff()           
                        except KeyError:
                            try:
                                ironcondor.insert_spot(xlu_time_series.loc[expiry - pd.Timedelta(days=1)]["Close"])
                                print(f"Let iron condor expire: {expiry}, pnl: {ironcondor.payoff()}")
                                pnl_dict[index] = ironcondor.payoff()    
                            except KeyError:
                                print(f"Warning: Unable to insert spot for index {index} with expiry {expiry}, PnL set to 0")
                                pnl_dict[index] = 0
                                continue
                                    
                    
                    # print(f"Let iron condor expire: {expiry}, pnl: {ironcondor.payoff()}")
                    # pnl_dict[index] = ironcondor.payoff()         

        pnl_series = pd.DataFrame(pnl_dict.items(), columns=["Date", "PnL"]).set_index("Date").PnL
        if pnl_series.empty:
            print("Warning: pnl_series is empty. Returning a large negative value to indicate failure.")
            return -10  # Large negative finite value to discourage this parameter set

        # Calculate returns and check standard deviation
        returns = pnl_series.pct_change().dropna()
        if returns.std() == 0:
            print("Warning: Standard deviation of returns is zero. Returning a large negative value.")
            return -10  # Avoid infinite Sharpe by returning -10

        # Calculate and return Sharpe ratio
        sharpe_ratio = calculate_sharpe_ratio(pnl_series)

        # Check for unreasonable Sharpe ratio values
        if np.isnan(sharpe_ratio) or np.isinf(sharpe_ratio) or sharpe_ratio > 10:
            print("Warning: Sharpe ratio is NaN, inf, or unreasonably high. Returning a large negative value.")
            return -10  # Return a large but finite negative value

        return sharpe_ratio

    except Exception as e:
        print(f"An error occurred: {e}. Returning a large negative value.")
        return -10  # Return a large negative value on error
            # sharpe_ratio = calculate_sharpe_ratio(pnl_series)

            # if np.isnan(sharpe_ratio) or np.isinf(sharpe_ratio) or sharpe_ratio > 10:
            #     print("Warning: Sharpe ratio is NaN, inf, or unreasonably high. Returning a large negative value.")
            #     return -10
            # return sharpe_ratio

# %%
pbounds = {
    'window': (5, 30),
    'upper_threshold': (1.0, 3.0),  # Adjust upper threshold range as necessary
    'lower_threshold': (-3.0, -1.0)  # Adjust lower threshold range as necessary
}

# Set up Bayesian optimization with lambda to pass additional arguments
optimizer = BayesianOptimization(
    f=lambda window, upper_threshold, lower_threshold: objective_function(
        window, upper_threshold, lower_threshold
    ),
    pbounds=pbounds,
    random_state=42,
    verbose=2
)

optimizer.maximize(init_points=10, n_iter=50)
# Out:
# |   iter    |  target   | lower_... | upper_... |  window   |
# -------------------------------------------------------------
# date: 2017-09-13 00:00:00
# date: 2017-09-13 00:00:00, current_spot_open: 55.0, OTM Put: 54.0, ATM Put: 55.0, ATM Call: 55.0, OTM Call: 61.5,                         left wing: 1.0, right wing: 6.5
# date: 2019-12-18 00:00:00
# date: 2019-12-18 00:00:00, current_spot_open: 64.5, OTM Put: 63.5, ATM Put: 64.5, ATM Call: 64.5, OTM Call: 65.0,                         left wing: 1.0, right wing: 0.5
# date: 2020-02-26 00:00:00
# date: 2020-02-26 00:00:00, current_spot_open: 68.0, OTM Put: 66.0, ATM Put: 68.0, ATM Call: 68.0, OTM Call: 70.0,                         left wing: 2.0, right wing: 2.0
# Processing date: 2017-09-13 00:00:00, expiry: 2017-09-22 00:00:00
# Let iron condor expire: 2017-09-22 00:00:00, pnl: -0.36000000000000004
# Processing date: 2019-12-18 00:00:00, expiry: 2019-12-27 00:00:00
# Let iron condor expire: 2019-12-27 00:00:00, pnl: 0.42999725341796874
# Processing date: 2020-02-26 00:00:00, expiry: 2020-03-06 00:00:00
# Closing on date: 2020-03-02 00:00:00
# strike1: 66.0, strike2: 68.0, strike3: 68.0, strike4: 70.0
# Long put sellback: 1.31
# Short put buyback: 2.58
# Short call buyback: 0.38
# Long call sellback: 0.02
# Closing cost: -1.63
# Close iron condor early on date: 2020-03-02 00:00:00 when signal is -1, pnl: 0.7699999999999998
# | 1         | -7.465    | -2.251    | 2.901     | 23.3      |
# date: 2016-10-28 00:00:00
# date: 2016-10-28 00:00:00, current_spot_open: 48.5, OTM Put: 46.0, ATM Put: 48.5, ATM Call: 48.5, OTM Call: 51.5,                         left wing: 2.5, right wing: 3.0
# date: 2016-11-25 00:00:00
# date: 2016-11-25 00:00:00, current_spot_open: 46.5, OTM Put: 40.0, ATM Put: 46.5, ATM Call: 46.5, OTM Call: 47.5,                         left wing: 6.5, right wing: 1.0
# date: 2016-12-09 00:00:00
# date: 2016-12-09 00:00:00, current_spot_open: 47.5, OTM Put: 45.0, ATM Put: 47.5, ATM Call: 47.5, OTM Call: 48.5,                         left wing: 2.5, right wing: 1.0
# date: 2016-12-20 00:00:00
# date: 2016-12-20 00:00:00, current_spot_open: 48.5, OTM Put: 46.0, ATM Put: 48.5, ATM Call: 48.5, OTM Call: 49.5,                         left wing: 2.5, right wing: 1.0
# date: 2016-12-23 00:00:00
# date: 2016-12-23 00:00:00, current_spot_open: 48.5, OTM Put: 46.0, ATM Put: 48.5, ATM Call: 48.5, OTM Call: 49.5,                         left wing: 2.5, right wing: 1.0
# date: 2016-12-30 00:00:00
# date: 2016-12-30 00:00:00, current_spot_open: 49.0, OTM Put: 47.5, ATM Put: 49.0, ATM Call: 49.0, OTM Call: 50.5,                         left wing: 1.5, right wing: 1.5
# date: 2017-01-06 00:00:00
# date: 2017-01-06 00:00:00, current_spot_open: 48.5, OTM Put: 25.0, ATM Put: 48.5, ATM Call: 48.5, OTM Call: 49.5,                         left wing: 23.5, right wing: 1.0
# date: 2017-01-13 00:00:00
# date: 2017-01-13 00:00:00, current_spot_open: 48.5, OTM Put: 47.0, ATM Put: 48.5, ATM Call: 48.5, OTM Call: 49.5,                         left wing: 1.5, right wing: 1.0
# date: 2017-01-25 00:00:00
# date: 2017-01-25 00:00:00, current_spot_open: 48.0, OTM Put: 40.5, ATM Put: 48.0, ATM Call: 48.0, OTM Call: 49.0,                         left wing: 7.5, right wing: 1.0
# date: 2017-01-27 00:00:00
# date: 2017-01-27 00:00:00, current_spot_open: 48.5, OTM Put: 47.0, ATM Put: 48.5, ATM Call: 48.5, OTM Call: 49.5,                         left wing: 1.5, right wing: 1.0
# date: 2017-02-14 00:00:00
# date: 2017-02-14 00:00:00, current_spot_open: 49.5, OTM Put: 48.5, ATM Put: 49.5, ATM Call: 49.5, OTM Call: 50.5,                         left wing: 1.0, right wing: 1.0
# date: 2017-02-17 00:00:00
# date: 2017-02-17 00:00:00, current_spot_open: 49.5, OTM Put: 47.5, ATM Put: 49.5, ATM Call: 49.5, OTM Call: 50.5,                         left wing: 2.0, right wing: 1.0
# date: 2017-03-07 00:00:00
# date: 2017-03-07 00:00:00, current_spot_open: 51.5, OTM Put: 50.5, ATM Put: 51.5, ATM Call: 51.5, OTM Call: 52.5,                         left wing: 1.0, right wing: 1.0
# date: 2017-03-14 00:00:00
# date: 2017-03-14 00:00:00, current_spot_open: 51.0, OTM Put: 49.5, ATM Put: 51.0, ATM Call: 51.0, OTM Call: 51.5,                         left wing: 1.5, right wing: 0.5
# date: 2017-04-03 00:00:00
# date: 2017-04-03 00:00:00, current_spot_open: 51.5, OTM Put: 50.0, ATM Put: 51.5, ATM Call: 51.5, OTM Call: 52.5,                         left wing: 1.5, right wing: 1.0
# date: 2017-04-17 00:00:00
# date: 2017-04-17 00:00:00, current_spot_open: 52.0, OTM Put: 50.0, ATM Put: 52.0, ATM Call: 52.0, OTM Call: 53.0,                         left wing: 2.0, right wing: 1.0
# date: 2017-05-05 00:00:00
# date: 2017-05-05 00:00:00, current_spot_open: 51.5, OTM Put: 41.0, ATM Put: 51.5, ATM Call: 51.5, OTM Call: 52.5,                         left wing: 10.5, right wing: 1.0
# date: 2017-05-15 00:00:00
# date: 2017-05-15 00:00:00, current_spot_open: 51.5, OTM Put: 44.5, ATM Put: 51.5, ATM Call: 51.5, OTM Call: 52.0,                         left wing: 7.0, right wing: 0.5
# date: 2017-05-26 00:00:00
# date: 2017-05-26 00:00:00, current_spot_open: 53.5, OTM Put: 52.0, ATM Put: 53.5, ATM Call: 53.5, OTM Call: 54.5,                         left wing: 1.5, right wing: 1.0
# date: 2017-06-07 00:00:00
# date: 2017-06-07 00:00:00, current_spot_open: 54.0, OTM Put: 53.0, ATM Put: 54.0, ATM Call: 54.0, OTM Call: 54.5,                         left wing: 1.0, right wing: 0.5
# date: 2017-06-09 00:00:00
# date: 2017-06-09 00:00:00, current_spot_open: 53.5, OTM Put: 52.0, ATM Put: 53.5, ATM Call: 53.5, OTM Call: 54.0,                         left wing: 1.5, right wing: 0.5
# date: 2017-06-26 00:00:00
# date: 2017-06-26 00:00:00, current_spot_open: 53.5, OTM Put: 52.0, ATM Put: 53.5, ATM Call: 53.5, OTM Call: 56.5,                         left wing: 1.5, right wing: 3.0
# date: 2017-07-19 00:00:00
# date: 2017-07-19 00:00:00, current_spot_open: 52.5, OTM Put: 51.0, ATM Put: 52.5, ATM Call: 52.5, OTM Call: 53.0,                         left wing: 1.5, right wing: 0.5
# date: 2017-08-25 00:00:00
# date: 2017-08-25 00:00:00, current_spot_open: 55.0, OTM Put: 52.5, ATM Put: 55.0, ATM Call: 55.0, OTM Call: 56.0,                         left wing: 2.5, right wing: 1.0
# date: 2017-09-01 00:00:00
# date: 2017-09-01 00:00:00, current_spot_open: 55.0, OTM Put: 54.0, ATM Put: 55.0, ATM Call: 55.0, OTM Call: 56.0,                         left wing: 1.0, right wing: 1.0
# date: 2017-10-06 00:00:00
# date: 2017-10-06 00:00:00, current_spot_open: 53.0, OTM Put: 41.0, ATM Put: 53.0, ATM Call: 53.0, OTM Call: 54.0,                         left wing: 12.0, right wing: 1.0
# date: 2017-10-20 00:00:00
# date: 2017-10-20 00:00:00, current_spot_open: 54.5, OTM Put: 45.5, ATM Put: 54.5, ATM Call: 54.5, OTM Call: 55.5,                         left wing: 9.0, right wing: 1.0
# date: 2017-10-27 00:00:00
# date: 2017-10-27 00:00:00, current_spot_open: 54.5, OTM Put: 45.5, ATM Put: 54.5, ATM Call: 54.5, OTM Call: 55.5,                         left wing: 9.0, right wing: 1.0
# date: 2017-11-29 00:00:00
# date: 2017-11-29 00:00:00, current_spot_open: 56.0, OTM Put: 47.5, ATM Put: 56.0, ATM Call: 56.0, OTM Call: 56.5,                         left wing: 8.5, right wing: 0.5
# date: 2017-12-11 00:00:00
# date: 2017-12-11 00:00:00, current_spot_open: 56.0, OTM Put: 54.5, ATM Put: 56.0, ATM Call: 56.0, OTM Call: 56.5,                         left wing: 1.5, right wing: 0.5
# date: 2017-12-29 00:00:00
# date: 2017-12-29 00:00:00, current_spot_open: 53.0, OTM Put: 51.5, ATM Put: 53.0, ATM Call: 53.0, OTM Call: 54.0,                         left wing: 1.5, right wing: 1.0
# date: 2018-01-16 00:00:00
# date: 2018-01-16 00:00:00, current_spot_open: 50.5, OTM Put: 49.0, ATM Put: 50.5, ATM Call: 50.5, OTM Call: 52.0,                         left wing: 1.5, right wing: 1.5
# date: 2018-01-24 00:00:00
# date: 2018-01-24 00:00:00, current_spot_open: 50.5, OTM Put: 49.0, ATM Put: 50.5, ATM Call: 50.5, OTM Call: 52.0,                         left wing: 1.5, right wing: 1.5
# date: 2018-02-26 00:00:00
# date: 2018-02-26 00:00:00, current_spot_open: 50.5, OTM Put: 48.5, ATM Put: 50.5, ATM Call: 50.5, OTM Call: 52.0,                         left wing: 2.0, right wing: 1.5
# date: 2018-03-09 00:00:00
# date: 2018-03-09 00:00:00, current_spot_open: 49.0, OTM Put: 46.5, ATM Put: 49.0, ATM Call: 49.0, OTM Call: 50.0,                         left wing: 2.5, right wing: 1.0
# date: 2018-03-16 00:00:00
# date: 2018-03-16 00:00:00, current_spot_open: 50.0, OTM Put: 39.0, ATM Put: 50.0, ATM Call: 50.0, OTM Call: 51.0,                         left wing: 11.0, right wing: 1.0
# date: 2018-04-03 00:00:00
# date: 2018-04-03 00:00:00, current_spot_open: 50.0, OTM Put: 42.5, ATM Put: 50.0, ATM Call: 50.0, OTM Call: 51.0,                         left wing: 7.5, right wing: 1.0
# date: 2018-04-06 00:00:00
# date: 2018-04-06 00:00:00, current_spot_open: 51.0, OTM Put: 49.5, ATM Put: 51.0, ATM Call: 51.0, OTM Call: 53.0,                         left wing: 1.5, right wing: 2.0
# date: 2018-04-23 00:00:00
# date: 2018-04-23 00:00:00, current_spot_open: 50.5, OTM Put: 49.0, ATM Put: 50.5, ATM Call: 50.5, OTM Call: 51.5,                         left wing: 1.5, right wing: 1.0
# date: 2018-04-30 00:00:00
# date: 2018-04-30 00:00:00, current_spot_open: 52.0, OTM Put: 50.5, ATM Put: 52.0, ATM Call: 52.0, OTM Call: 53.5,                         left wing: 1.5, right wing: 1.5
# date: 2018-05-04 00:00:00
# date: 2018-05-04 00:00:00, current_spot_open: 51.5, OTM Put: 49.5, ATM Put: 51.5, ATM Call: 51.5, OTM Call: 52.5,                         left wing: 2.0, right wing: 1.0
# date: 2018-05-22 00:00:00
# date: 2018-05-22 00:00:00, current_spot_open: 49.0, OTM Put: 43.0, ATM Put: 49.0, ATM Call: 49.0, OTM Call: 50.0,                         left wing: 6.0, right wing: 1.0
# date: 2018-05-25 00:00:00
# date: 2018-05-25 00:00:00, current_spot_open: 50.5, OTM Put: 49.0, ATM Put: 50.5, ATM Call: 50.5, OTM Call: 51.5,                         left wing: 1.5, right wing: 1.0
# date: 2018-06-13 00:00:00
# date: 2018-06-13 00:00:00, current_spot_open: 49.0, OTM Put: 48.0, ATM Put: 49.0, ATM Call: 49.0, OTM Call: 50.0,                         left wing: 1.0, right wing: 1.0
# date: 2018-07-06 00:00:00
# date: 2018-07-06 00:00:00, current_spot_open: 53.0, OTM Put: 49.5, ATM Put: 53.0, ATM Call: 53.0, OTM Call: 54.0,                         left wing: 3.5, right wing: 1.0
# date: 2018-07-18 00:00:00
# date: 2018-07-18 00:00:00, current_spot_open: 52.5, OTM Put: 51.0, ATM Put: 52.5, ATM Call: 52.5, OTM Call: 53.5,                         left wing: 1.5, right wing: 1.0
# date: 2018-07-24 00:00:00
# date: 2018-07-24 00:00:00, current_spot_open: 52.0, OTM Put: 49.5, ATM Put: 52.0, ATM Call: 52.0, OTM Call: 53.0,                         left wing: 2.5, right wing: 1.0
# date: 2018-07-27 00:00:00
# date: 2018-07-27 00:00:00, current_spot_open: 53.0, OTM Put: 51.5, ATM Put: 53.0, ATM Call: 53.0, OTM Call: 54.5,                         left wing: 1.5, right wing: 1.5
# date: 2018-08-07 00:00:00
# date: 2018-08-07 00:00:00, current_spot_open: 53.0, OTM Put: 42.0, ATM Put: 53.0, ATM Call: 53.0, OTM Call: 54.0,                         left wing: 11.0, right wing: 1.0
# date: 2018-08-10 00:00:00
# date: 2018-08-10 00:00:00, current_spot_open: 53.5, OTM Put: 52.0, ATM Put: 53.5, ATM Call: 53.5, OTM Call: 55.0,                         left wing: 1.5, right wing: 1.5
# date: 2018-08-29 00:00:00
# date: 2018-08-29 00:00:00, current_spot_open: 53.5, OTM Put: 50.0, ATM Put: 53.5, ATM Call: 53.5, OTM Call: 54.0,                         left wing: 3.5, right wing: 0.5
# date: 2018-08-31 00:00:00
# date: 2018-08-31 00:00:00, current_spot_open: 54.0, OTM Put: 52.5, ATM Put: 54.0, ATM Call: 54.0, OTM Call: 57.0,                         left wing: 1.5, right wing: 3.0
# date: 2018-09-14 00:00:00
# date: 2018-09-14 00:00:00, current_spot_open: 54.5, OTM Put: 53.0, ATM Put: 54.5, ATM Call: 54.5, OTM Call: 55.5,                         left wing: 1.5, right wing: 1.0
# date: 2018-10-23 00:00:00
# date: 2018-10-23 00:00:00, current_spot_open: 54.5, OTM Put: 53.0, ATM Put: 54.5, ATM Call: 54.5, OTM Call: 56.0,                         left wing: 1.5, right wing: 1.5
# date: 2018-11-07 00:00:00
# date: 2018-11-07 00:00:00, current_spot_open: 54.5, OTM Put: 44.0, ATM Put: 54.5, ATM Call: 54.5, OTM Call: 55.5,                         left wing: 10.5, right wing: 1.0
# date: 2018-11-09 00:00:00
# date: 2018-11-09 00:00:00, current_spot_open: 54.5, OTM Put: 40.0, ATM Put: 54.5, ATM Call: 54.5, OTM Call: 55.5,                         left wing: 14.5, right wing: 1.0
# date: 2018-11-23 00:00:00
# date: 2018-11-23 00:00:00, current_spot_open: 54.0, OTM Put: 50.5, ATM Put: 54.0, ATM Call: 54.0, OTM Call: 55.5,                         left wing: 3.5, right wing: 1.5
# date: 2018-12-03 00:00:00
# date: 2018-12-03 00:00:00, current_spot_open: 55.5, OTM Put: 40.0, ATM Put: 55.5, ATM Call: 55.5, OTM Call: 56.5,                         left wing: 15.5, right wing: 1.0
# date: 2018-12-07 00:00:00
# date: 2018-12-07 00:00:00, current_spot_open: 56.0, OTM Put: 53.0, ATM Put: 56.0, ATM Call: 56.0, OTM Call: 57.5,                         left wing: 3.0, right wing: 1.5
# date: 2018-12-14 00:00:00
# date: 2018-12-14 00:00:00, current_spot_open: 57.0, OTM Put: 55.5, ATM Put: 57.0, ATM Call: 57.0, OTM Call: 58.0,                         left wing: 1.5, right wing: 1.0
# date: 2018-12-21 00:00:00
# date: 2018-12-21 00:00:00, current_spot_open: 54.5, OTM Put: 52.5, ATM Put: 54.5, ATM Call: 54.5, OTM Call: 56.5,                         left wing: 2.0, right wing: 2.0
# date: 2019-02-05 00:00:00
# date: 2019-02-05 00:00:00, current_spot_open: 54.5, OTM Put: 50.0, ATM Put: 54.5, ATM Call: 54.5, OTM Call: 55.5,                         left wing: 4.5, right wing: 1.0
# date: 2019-02-12 00:00:00
# date: 2019-02-12 00:00:00, current_spot_open: 55.5, OTM Put: 45.0, ATM Put: 55.5, ATM Call: 55.5, OTM Call: 56.5,                         left wing: 10.5, right wing: 1.0
# date: 2019-02-15 00:00:00
# date: 2019-02-15 00:00:00, current_spot_open: 55.5, OTM Put: 52.5, ATM Put: 55.5, ATM Call: 55.5, OTM Call: 56.5,                         left wing: 3.0, right wing: 1.0
# date: 2019-02-26 00:00:00
# date: 2019-02-26 00:00:00, current_spot_open: 57.0, OTM Put: 56.0, ATM Put: 57.0, ATM Call: 57.0, OTM Call: 58.0,                         left wing: 1.0, right wing: 1.0
# date: 2019-03-01 00:00:00
# date: 2019-03-01 00:00:00, current_spot_open: 57.0, OTM Put: 55.5, ATM Put: 57.0, ATM Call: 57.0, OTM Call: 58.0,                         left wing: 1.5, right wing: 1.0
# date: 2019-03-13 00:00:00
# date: 2019-03-13 00:00:00, current_spot_open: 58.0, OTM Put: 56.5, ATM Put: 58.0, ATM Call: 58.0, OTM Call: 58.5,                         left wing: 1.5, right wing: 0.5
# date: 2019-03-15 00:00:00
# date: 2019-03-15 00:00:00, current_spot_open: 58.0, OTM Put: 53.0, ATM Put: 58.0, ATM Call: 58.0, OTM Call: 59.0,                         left wing: 5.0, right wing: 1.0
# date: 2019-04-03 00:00:00
# date: 2019-04-03 00:00:00, current_spot_open: 57.5, OTM Put: 49.5, ATM Put: 57.5, ATM Call: 57.5, OTM Call: 58.5,                         left wing: 8.0, right wing: 1.0
# date: 2019-04-15 00:00:00
# date: 2019-04-15 00:00:00, current_spot_open: 58.5, OTM Put: 57.0, ATM Put: 58.5, ATM Call: 58.5, OTM Call: 59.5,                         left wing: 1.5, right wing: 1.0
# date: 2019-06-04 00:00:00
# date: 2019-06-04 00:00:00, current_spot_open: 59.0, OTM Put: 57.5, ATM Put: 59.0, ATM Call: 59.0, OTM Call: 60.0,                         left wing: 1.5, right wing: 1.0
# date: 2019-06-14 00:00:00
# date: 2019-06-14 00:00:00, current_spot_open: 60.0, OTM Put: 50.5, ATM Put: 60.0, ATM Call: 60.0, OTM Call: 61.0,                         left wing: 9.5, right wing: 1.0
# date: 2019-06-21 00:00:00
# date: 2019-06-21 00:00:00, current_spot_open: 60.5, OTM Put: 51.5, ATM Put: 60.5, ATM Call: 60.5, OTM Call: 61.5,                         left wing: 9.0, right wing: 1.0
# date: 2019-07-08 00:00:00
# date: 2019-07-08 00:00:00, current_spot_open: 60.5, OTM Put: 56.5, ATM Put: 60.5, ATM Call: 60.5, OTM Call: 61.5,                         left wing: 4.0, right wing: 1.0
# date: 2019-07-16 00:00:00
# date: 2019-07-16 00:00:00, current_spot_open: 60.5, OTM Put: 58.5, ATM Put: 60.5, ATM Call: 60.5, OTM Call: 61.5,                         left wing: 2.0, right wing: 1.0
# date: 2019-07-26 00:00:00
# date: 2019-07-26 00:00:00, current_spot_open: 60.0, OTM Put: 58.0, ATM Put: 60.0, ATM Call: 60.0, OTM Call: 61.0,                         left wing: 2.0, right wing: 1.0
# date: 2019-08-21 00:00:00
# date: 2019-08-21 00:00:00, current_spot_open: 61.5, OTM Put: 52.5, ATM Put: 61.5, ATM Call: 61.5, OTM Call: 62.5,                         left wing: 9.0, right wing: 1.0
# date: 2019-08-30 00:00:00
# date: 2019-08-30 00:00:00, current_spot_open: 63.0, OTM Put: 61.0, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 64.5,                         left wing: 2.0, right wing: 1.5
# date: 2019-09-20 00:00:00
# date: 2019-09-20 00:00:00, current_spot_open: 63.5, OTM Put: 55.0, ATM Put: 63.5, ATM Call: 63.5, OTM Call: 64.5,                         left wing: 8.5, right wing: 1.0
# date: 2019-10-01 00:00:00
# date: 2019-10-01 00:00:00, current_spot_open: 64.5, OTM Put: 62.0, ATM Put: 64.5, ATM Call: 64.5, OTM Call: 65.5,                         left wing: 2.5, right wing: 1.0
# date: 2019-10-08 00:00:00
# date: 2019-10-08 00:00:00, current_spot_open: 64.5, OTM Put: 63.0, ATM Put: 64.5, ATM Call: 64.5, OTM Call: 66.0,                         left wing: 1.5, right wing: 1.5
# date: 2019-11-19 00:00:00
# date: 2019-11-19 00:00:00, current_spot_open: 63.0, OTM Put: 61.5, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 64.0,                         left wing: 1.5, right wing: 1.0
# date: 2019-11-29 00:00:00
# date: 2019-11-29 00:00:00, current_spot_open: 63.0, OTM Put: 61.0, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 64.0,                         left wing: 2.0, right wing: 1.0
# date: 2019-12-10 00:00:00
# date: 2019-12-10 00:00:00, current_spot_open: 63.0, OTM Put: 62.0, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 64.0,                         left wing: 1.0, right wing: 1.0
# date: 2019-12-18 00:00:00
# date: 2019-12-18 00:00:00, current_spot_open: 64.5, OTM Put: 63.5, ATM Put: 64.5, ATM Call: 64.5, OTM Call: 65.0,                         left wing: 1.0, right wing: 0.5
# date: 2019-12-31 00:00:00
# date: 2019-12-31 00:00:00, current_spot_open: 64.5, OTM Put: 62.0, ATM Put: 64.5, ATM Call: 64.5, OTM Call: 65.5,                         left wing: 2.5, right wing: 1.0
# date: 2020-01-14 00:00:00
# date: 2020-01-14 00:00:00, current_spot_open: 65.0, OTM Put: 63.5, ATM Put: 65.0, ATM Call: 65.0, OTM Call: 65.5,                         left wing: 1.5, right wing: 0.5
# date: 2020-01-31 00:00:00
# date: 2020-01-31 00:00:00, current_spot_open: 69.0, OTM Put: 66.5, ATM Put: 69.0, ATM Call: 69.0, OTM Call: 70.5,                         left wing: 2.5, right wing: 1.5
# date: 2020-02-26 00:00:00
# date: 2020-02-26 00:00:00, current_spot_open: 68.0, OTM Put: 66.0, ATM Put: 68.0, ATM Call: 68.0, OTM Call: 70.0,                         left wing: 2.0, right wing: 2.0
# date: 2020-03-11 00:00:00
# date: 2020-03-11 00:00:00, current_spot_open: 62.5, OTM Put: 56.5, ATM Put: 62.5, ATM Call: 62.5, OTM Call: 67.0,                         left wing: 6.0, right wing: 4.5
# date: 2020-03-13 00:00:00
# date: 2020-03-13 00:00:00, current_spot_open: 58.0, OTM Put: 45.0, ATM Put: 58.0, ATM Call: 58.0, OTM Call: 68.0,                         left wing: 13.0, right wing: 10.0
# date: 2020-04-09 00:00:00
# date: 2020-04-09 00:00:00, current_spot_open: 59.0, OTM Put: 30.0, ATM Put: 59.0, ATM Call: 59.0, OTM Call: 62.0,                         left wing: 29.0, right wing: 3.0
# date: 2020-04-17 00:00:00
# date: 2020-04-17 00:00:00, current_spot_open: 60.0, OTM Put: 49.0, ATM Put: 60.0, ATM Call: 60.0, OTM Call: 63.5,                         left wing: 11.0, right wing: 3.5
# date: 2020-04-28 00:00:00
# date: 2020-04-28 00:00:00, current_spot_open: 60.0, OTM Put: 57.0, ATM Put: 60.0, ATM Call: 60.0, OTM Call: 62.5,                         left wing: 3.0, right wing: 2.5
# date: 2020-05-01 00:00:00
# date: 2020-05-01 00:00:00, current_spot_open: 56.5, OTM Put: 52.0, ATM Put: 56.5, ATM Call: 56.5, OTM Call: 59.0,                         left wing: 4.5, right wing: 2.5
# date: 2020-05-08 00:00:00
# date: 2020-05-08 00:00:00, current_spot_open: 55.5, OTM Put: 40.0, ATM Put: 55.5, ATM Call: 55.5, OTM Call: 57.5,                         left wing: 15.5, right wing: 2.0
# date: 2020-05-22 00:00:00
# date: 2020-05-22 00:00:00, current_spot_open: 56.0, OTM Put: 49.0, ATM Put: 56.0, ATM Call: 56.0, OTM Call: 58.0,                         left wing: 7.0, right wing: 2.0
# date: 2020-06-03 00:00:00
# date: 2020-06-03 00:00:00, current_spot_open: 61.0, OTM Put: 30.0, ATM Put: 61.0, ATM Call: 61.0, OTM Call: 62.5,                         left wing: 31.0, right wing: 1.5
# date: 2020-06-05 00:00:00
# date: 2020-06-05 00:00:00, current_spot_open: 61.0, OTM Put: 57.0, ATM Put: 61.0, ATM Call: 61.0, OTM Call: 63.0,                         left wing: 4.0, right wing: 2.0
# date: 2020-06-23 00:00:00
# date: 2020-06-23 00:00:00, current_spot_open: 58.0, OTM Put: 55.5, ATM Put: 58.0, ATM Call: 58.0, OTM Call: 61.5,                         left wing: 2.5, right wing: 3.5
# date: 2020-07-08 00:00:00
# date: 2020-07-08 00:00:00, current_spot_open: 57.0, OTM Put: 46.0, ATM Put: 57.0, ATM Call: 57.0, OTM Call: 58.5,                         left wing: 11.0, right wing: 1.5
# date: 2020-07-24 00:00:00
# date: 2020-07-24 00:00:00, current_spot_open: 61.0, OTM Put: 58.0, ATM Put: 61.0, ATM Call: 61.0, OTM Call: 63.5,                         left wing: 3.0, right wing: 2.5
# date: 2020-08-17 00:00:00
# date: 2020-08-17 00:00:00, current_spot_open: 60.5, OTM Put: 58.0, ATM Put: 60.5, ATM Call: 60.5, OTM Call: 62.0,                         left wing: 2.5, right wing: 1.5
# date: 2020-08-21 00:00:00
# date: 2020-08-21 00:00:00, current_spot_open: 59.5, OTM Put: 56.5, ATM Put: 59.5, ATM Call: 59.5, OTM Call: 61.5,                         left wing: 3.0, right wing: 2.0
# date: 2020-09-15 00:00:00
# date: 2020-09-15 00:00:00, current_spot_open: 60.5, OTM Put: 58.5, ATM Put: 60.5, ATM Call: 60.5, OTM Call: 62.0,                         left wing: 2.0, right wing: 1.5
# date: 2020-09-28 00:00:00
# date: 2020-09-28 00:00:00, current_spot_open: 59.0, OTM Put: 56.5, ATM Put: 59.0, ATM Call: 59.0, OTM Call: 60.5,                         left wing: 2.5, right wing: 1.5
# date: 2020-10-13 00:00:00
# date: 2020-10-13 00:00:00, current_spot_open: 63.5, OTM Put: 61.0, ATM Put: 63.5, ATM Call: 63.5, OTM Call: 65.0,                         left wing: 2.5, right wing: 1.5
# date: 2020-10-19 00:00:00
# date: 2020-10-19 00:00:00, current_spot_open: 64.0, OTM Put: 62.0, ATM Put: 64.0, ATM Call: 64.0, OTM Call: 66.0,                         left wing: 2.0, right wing: 2.0
# date: 2020-10-23 00:00:00
# date: 2020-10-23 00:00:00, current_spot_open: 65.0, OTM Put: 61.5, ATM Put: 65.0, ATM Call: 65.0, OTM Call: 67.0,                         left wing: 3.5, right wing: 2.0
# date: 2020-11-27 00:00:00
# date: 2020-11-27 00:00:00, current_spot_open: 64.5, OTM Put: 62.0, ATM Put: 64.5, ATM Call: 64.5, OTM Call: 67.5,                         left wing: 2.5, right wing: 3.0
# date: 2020-12-07 00:00:00
# date: 2020-12-07 00:00:00, current_spot_open: 62.0, OTM Put: 45.0, ATM Put: 62.0, ATM Call: 62.0, OTM Call: 63.5,                         left wing: 17.0, right wing: 1.5
# date: 2020-12-11 00:00:00
# date: 2020-12-11 00:00:00, current_spot_open: 62.0, OTM Put: 59.5, ATM Put: 62.0, ATM Call: 62.0, OTM Call: 67.5,                         left wing: 2.5, right wing: 5.5
# date: 2020-12-24 00:00:00
# date: 2020-12-24 00:00:00, current_spot_open: 61.0, OTM Put: 57.0, ATM Put: 61.0, ATM Call: 61.0, OTM Call: 62.0,                         left wing: 4.0, right wing: 1.0
# date: 2020-12-31 00:00:00
# date: 2020-12-31 00:00:00, current_spot_open: 62.0, OTM Put: 45.0, ATM Put: 62.0, ATM Call: 62.0, OTM Call: 63.0,                         left wing: 17.0, right wing: 1.0
# date: 2021-01-20 00:00:00
# date: 2021-01-20 00:00:00, current_spot_open: 62.5, OTM Put: 40.0, ATM Put: 62.5, ATM Call: 62.5, OTM Call: 64.0,                         left wing: 22.5, right wing: 1.5
# date: 2021-01-22 00:00:00
# date: 2021-01-22 00:00:00, current_spot_open: 62.5, OTM Put: 57.5, ATM Put: 62.5, ATM Call: 62.5, OTM Call: 64.0,                         left wing: 5.0, right wing: 1.5
# date: 2021-02-05 00:00:00
# date: 2021-02-05 00:00:00, current_spot_open: 63.5, OTM Put: 60.5, ATM Put: 63.5, ATM Call: 63.5, OTM Call: 65.0,                         left wing: 3.0, right wing: 1.5
# date: 2021-04-07 00:00:00
# date: 2021-04-07 00:00:00, current_spot_open: 65.0, OTM Put: 63.0, ATM Put: 65.0, ATM Call: 65.0, OTM Call: 66.0,                         left wing: 2.0, right wing: 1.0
# date: 2021-04-09 00:00:00
# date: 2021-04-09 00:00:00, current_spot_open: 65.0, OTM Put: 62.5, ATM Put: 65.0, ATM Call: 65.0, OTM Call: 71.0,                         left wing: 2.5, right wing: 6.0
# date: 2021-04-16 00:00:00
# date: 2021-04-16 00:00:00, current_spot_open: 67.0, OTM Put: 62.5, ATM Put: 67.0, ATM Call: 67.0, OTM Call: 71.0,                         left wing: 4.5, right wing: 4.0
# date: 2021-05-03 00:00:00
# date: 2021-05-03 00:00:00, current_spot_open: 67.0, OTM Put: 64.5, ATM Put: 67.0, ATM Call: 67.0, OTM Call: 68.5,                         left wing: 2.5, right wing: 1.5
# date: 2021-05-18 00:00:00
# date: 2021-05-18 00:00:00, current_spot_open: 65.0, OTM Put: 55.0, ATM Put: 65.0, ATM Call: 65.0, OTM Call: 66.5,                         left wing: 10.0, right wing: 1.5
# date: 2021-05-21 00:00:00
# date: 2021-05-21 00:00:00, current_spot_open: 66.0, OTM Put: 62.0, ATM Put: 66.0, ATM Call: 66.0, OTM Call: 67.5,                         left wing: 4.0, right wing: 1.5
# date: 2021-06-02 00:00:00
# date: 2021-06-02 00:00:00, current_spot_open: 65.0, OTM Put: 63.0, ATM Put: 65.0, ATM Call: 65.0, OTM Call: 66.0,                         left wing: 2.0, right wing: 1.0
# date: 2021-06-08 00:00:00
# date: 2021-06-08 00:00:00, current_spot_open: 65.5, OTM Put: 64.0, ATM Put: 65.5, ATM Call: 65.5, OTM Call: 67.5,                         left wing: 1.5, right wing: 2.0
# date: 2021-06-14 00:00:00
# date: 2021-06-14 00:00:00, current_spot_open: 66.0, OTM Put: 64.5, ATM Put: 66.0, ATM Call: 66.0, OTM Call: 67.0,                         left wing: 1.5, right wing: 1.0
# date: 2021-07-12 00:00:00
# date: 2021-07-12 00:00:00, current_spot_open: 64.5, OTM Put: 56.5, ATM Put: 64.5, ATM Call: 64.5, OTM Call: 65.5,                         left wing: 8.0, right wing: 1.0
# date: 2021-08-03 00:00:00
# date: 2021-08-03 00:00:00, current_spot_open: 66.5, OTM Put: 58.5, ATM Put: 66.5, ATM Call: 66.5, OTM Call: 70.0,                         left wing: 8.0, right wing: 3.5
# date: 2021-08-13 00:00:00
# date: 2021-08-13 00:00:00, current_spot_open: 68.5, OTM Put: 65.0, ATM Put: 68.5, ATM Call: 68.5, OTM Call: 70.0,                         left wing: 3.5, right wing: 1.5
# date: 2021-09-15 00:00:00
# date: 2021-09-15 00:00:00, current_spot_open: 68.0, OTM Put: 66.0, ATM Put: 68.0, ATM Call: 68.0, OTM Call: 69.0,                         left wing: 2.0, right wing: 1.0
# date: 2021-09-17 00:00:00
# date: 2021-09-17 00:00:00, current_spot_open: 67.5, OTM Put: 65.5, ATM Put: 67.5, ATM Call: 67.5, OTM Call: 75.0,                         left wing: 2.0, right wing: 7.5
# date: 2021-10-15 00:00:00
# date: 2021-10-15 00:00:00, current_spot_open: 66.0, OTM Put: 63.5, ATM Put: 66.0, ATM Call: 66.0, OTM Call: 67.5,                         left wing: 2.5, right wing: 1.5
# date: 2021-10-27 00:00:00
# date: 2021-10-27 00:00:00, current_spot_open: 67.5, OTM Put: 66.0, ATM Put: 67.5, ATM Call: 67.5, OTM Call: 70.0,                         left wing: 1.5, right wing: 2.5
# date: 2021-10-29 00:00:00
# date: 2021-10-29 00:00:00, current_spot_open: 67.5, OTM Put: 65.5, ATM Put: 67.5, ATM Call: 67.5, OTM Call: 69.5,                         left wing: 2.0, right wing: 2.0
# date: 2021-11-29 00:00:00
# date: 2021-11-29 00:00:00, current_spot_open: 67.5, OTM Put: 61.0, ATM Put: 67.5, ATM Call: 67.5, OTM Call: 69.0,                         left wing: 6.5, right wing: 1.5
# date: 2021-12-27 00:00:00
# date: 2021-12-27 00:00:00, current_spot_open: 70.0, OTM Put: 67.0, ATM Put: 70.0, ATM Call: 70.0, OTM Call: 71.5,                         left wing: 3.0, right wing: 1.5
# date: 2021-12-31 00:00:00
# date: 2021-12-31 00:00:00, current_spot_open: 71.0, OTM Put: 50.0, ATM Put: 71.0, ATM Call: 71.0, OTM Call: 72.5,                         left wing: 21.0, right wing: 1.5
# date: 2022-01-21 00:00:00
# date: 2022-01-21 00:00:00, current_spot_open: 69.5, OTM Put: 66.5, ATM Put: 69.5, ATM Call: 69.5, OTM Call: 72.0,                         left wing: 3.0, right wing: 2.5
# date: 2022-02-22 00:00:00
# date: 2022-02-22 00:00:00, current_spot_open: 66.5, OTM Put: 63.5, ATM Put: 66.5, ATM Call: 66.5, OTM Call: 73.5,                         left wing: 3.0, right wing: 7.0
# date: 2022-03-22 00:00:00
# date: 2022-03-22 00:00:00, current_spot_open: 71.0, OTM Put: 68.0, ATM Put: 71.0, ATM Call: 71.0, OTM Call: 72.5,                         left wing: 3.0, right wing: 1.5
# date: 2022-03-29 00:00:00
# date: 2022-03-29 00:00:00, current_spot_open: 73.0, OTM Put: 50.0, ATM Put: 73.0, ATM Call: 73.0, OTM Call: 74.5,                         left wing: 23.0, right wing: 1.5
# date: 2022-04-20 00:00:00
# date: 2022-04-20 00:00:00, current_spot_open: 77.0, OTM Put: 74.0, ATM Put: 77.0, ATM Call: 77.0, OTM Call: 78.5,                         left wing: 3.0, right wing: 1.5
# date: 2022-04-22 00:00:00
# date: 2022-04-22 00:00:00, current_spot_open: 75.5, OTM Put: 72.0, ATM Put: 75.5, ATM Call: 75.5, OTM Call: 79.0,                         left wing: 3.5, right wing: 3.5
# date: 2022-05-17 00:00:00
# date: 2022-05-17 00:00:00, current_spot_open: 72.0, OTM Put: 67.0, ATM Put: 72.0, ATM Call: 72.0, OTM Call: 74.0,                         left wing: 5.0, right wing: 2.0
# date: 2022-06-03 00:00:00
# date: 2022-06-03 00:00:00, current_spot_open: 74.5, OTM Put: 71.5, ATM Put: 74.5, ATM Call: 74.5, OTM Call: 76.5,                         left wing: 3.0, right wing: 2.0
# date: 2022-06-29 00:00:00
# date: 2022-06-29 00:00:00, current_spot_open: 69.5, OTM Put: 66.5, ATM Put: 69.5, ATM Call: 69.5, OTM Call: 71.5,                         left wing: 3.0, right wing: 2.0
# date: 2022-07-15 00:00:00
# date: 2022-07-15 00:00:00, current_spot_open: 69.5, OTM Put: 64.0, ATM Put: 69.5, ATM Call: 69.5, OTM Call: 71.5,                         left wing: 5.5, right wing: 2.0
# date: 2022-08-08 00:00:00
# date: 2022-08-08 00:00:00, current_spot_open: 75.0, OTM Put: 72.5, ATM Put: 75.0, ATM Call: 75.0, OTM Call: 77.0,                         left wing: 2.5, right wing: 2.0
# date: 2022-08-17 00:00:00
# Error: 2022-08-17 00:00:00, P
# Error: 2022-08-17 00:00:00, C
# date: 2022-08-19 00:00:00
# Error: 2022-08-19 00:00:00, P
# Error: 2022-08-19 00:00:00, C
# date: 2022-09-23 00:00:00
# date: 2022-09-23 00:00:00, current_spot_open: 72.0, OTM Put: 67.0, ATM Put: 72.0, ATM Call: 72.0, OTM Call: 75.0,                         left wing: 5.0, right wing: 3.0
# date: 2022-10-11 00:00:00
# Error: 2022-10-11 00:00:00, P
# Error: 2022-10-11 00:00:00, C
# date: 2022-11-01 00:00:00
# date: 2022-11-01 00:00:00, current_spot_open: 67.0, OTM Put: 62.5, ATM Put: 67.0, ATM Call: 67.0, OTM Call: 69.5,                         left wing: 4.5, right wing: 2.5
# date: 2022-11-04 00:00:00
# date: 2022-11-04 00:00:00, current_spot_open: 67.0, OTM Put: 62.0, ATM Put: 67.0, ATM Call: 67.0, OTM Call: 69.5,                         left wing: 5.0, right wing: 2.5
# date: 2022-11-25 00:00:00
# date: 2022-11-25 00:00:00, current_spot_open: 71.0, OTM Put: 67.0, ATM Put: 71.0, ATM Call: 71.0, OTM Call: 73.0,                         left wing: 4.0, right wing: 2.0
# date: 2022-12-09 00:00:00
# date: 2022-12-09 00:00:00, current_spot_open: 71.0, OTM Put: 67.5, ATM Put: 71.0, ATM Call: 71.0, OTM Call: 73.5,                         left wing: 3.5, right wing: 2.5
# date: 2022-12-21 00:00:00
# date: 2022-12-21 00:00:00, current_spot_open: 70.0, OTM Put: 55.0, ATM Put: 70.0, ATM Call: 70.0, OTM Call: 71.5,                         left wing: 15.0, right wing: 1.5
# date: 2022-12-23 00:00:00
# date: 2022-12-23 00:00:00, current_spot_open: 70.0, OTM Put: 57.0, ATM Put: 70.0, ATM Call: 70.0, OTM Call: 72.0,                         left wing: 13.0, right wing: 2.0
# date: 2022-12-30 00:00:00
# date: 2022-12-30 00:00:00, current_spot_open: 71.0, OTM Put: 67.5, ATM Put: 71.0, ATM Call: 71.0, OTM Call: 73.5,                         left wing: 3.5, right wing: 2.5
# date: 2023-01-24 00:00:00
# date: 2023-01-24 00:00:00, current_spot_open: 69.5, OTM Put: 65.5, ATM Put: 69.5, ATM Call: 69.5, OTM Call: 76.5,                         left wing: 4.0, right wing: 7.0
# date: 2023-01-27 00:00:00
# date: 2023-01-27 00:00:00, current_spot_open: 68.5, OTM Put: 57.0, ATM Put: 68.5, ATM Call: 68.5, OTM Call: 70.5,                         left wing: 11.5, right wing: 2.0
# date: 2023-02-17 00:00:00
# date: 2023-02-17 00:00:00, current_spot_open: 68.0, OTM Put: 60.0, ATM Put: 68.0, ATM Call: 68.0, OTM Call: 69.5,                         left wing: 8.0, right wing: 1.5
# date: 2023-03-10 00:00:00
# date: 2023-03-10 00:00:00, current_spot_open: 66.0, OTM Put: 63.0, ATM Put: 66.0, ATM Call: 66.0, OTM Call: 95.0,                         left wing: 3.0, right wing: 29.0
# date: 2023-04-04 00:00:00
# date: 2023-04-04 00:00:00, current_spot_open: 67.0, OTM Put: 50.0, ATM Put: 67.0, ATM Call: 67.0, OTM Call: 68.5,                         left wing: 17.0, right wing: 1.5
# date: 2023-04-12 00:00:00
# date: 2023-04-12 00:00:00, current_spot_open: 70.0, OTM Put: 67.5, ATM Put: 70.0, ATM Call: 70.0, OTM Call: 71.5,                         left wing: 2.5, right wing: 1.5
# date: 2023-04-19 00:00:00
# date: 2023-04-19 00:00:00, current_spot_open: 69.0, OTM Put: 50.0, ATM Put: 69.0, ATM Call: 69.0, OTM Call: 70.0,                         left wing: 19.0, right wing: 1.0
# date: 2023-04-21 00:00:00
# date: 2023-04-21 00:00:00, current_spot_open: 70.0, OTM Put: 67.0, ATM Put: 70.0, ATM Call: 70.0, OTM Call: 72.0,                         left wing: 3.0, right wing: 2.0
# date: 2023-05-23 00:00:00
# date: 2023-05-23 00:00:00, current_spot_open: 66.0, OTM Put: 63.0, ATM Put: 66.0, ATM Call: 66.0, OTM Call: 75.0,                         left wing: 3.0, right wing: 9.0
# date: 2023-06-16 00:00:00
# date: 2023-06-16 00:00:00, current_spot_open: 67.0, OTM Put: 63.5, ATM Put: 67.0, ATM Call: 67.0, OTM Call: 68.0,                         left wing: 3.5, right wing: 1.0
# date: 2023-07-14 00:00:00
# date: 2023-07-14 00:00:00, current_spot_open: 67.0, OTM Put: 64.5, ATM Put: 67.0, ATM Call: 67.0, OTM Call: 68.5,                         left wing: 2.5, right wing: 1.5
# date: 2023-07-31 00:00:00
# date: 2023-07-31 00:00:00, current_spot_open: 67.5, OTM Put: 65.5, ATM Put: 67.5, ATM Call: 67.5, OTM Call: 69.0,                         left wing: 2.0, right wing: 1.5
# date: 2023-08-14 00:00:00
# date: 2023-08-14 00:00:00, current_spot_open: 64.5, OTM Put: 62.5, ATM Put: 64.5, ATM Call: 64.5, OTM Call: 66.0,                         left wing: 2.0, right wing: 1.5
# date: 2023-08-18 00:00:00
# date: 2023-08-18 00:00:00, current_spot_open: 63.0, OTM Put: 55.0, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 64.5,                         left wing: 8.0, right wing: 1.5
# Processing date: 2016-10-28 00:00:00, expiry: 2016-11-11 00:00:00
# Expiry date 2016-11-11 00:00:00 not found; finding closest available date.
# Using adjusted expiry date: 2016-11-10 00:00:00
# Closing on date: 2016-11-10 00:00:00
# strike1: 46.0, strike2: 48.5, strike3: 48.5, strike4: 51.5
# Long put sellback: 0.55
# Short put buyback: 2.31
# Short call buyback: 0.06
# Long call sellback: 0.0
# Closing cost: -1.82
# Close iron condor early on date: 2016-11-10 00:00:00 when signal is -1, pnl: 0.09000122070312488
# Processing date: 2016-11-25 00:00:00, expiry: 2016-12-09 00:00:00
# Let iron condor expire: 2016-12-09 00:00:00, pnl: -0.1600000000000001
# Processing date: 2016-12-09 00:00:00, expiry: 2016-12-23 00:00:00
# Let iron condor expire: 2016-12-23 00:00:00, pnl: 0.010000000000000064
# Processing date: 2016-12-20 00:00:00, expiry: 2016-12-30 00:00:00
# Let iron condor expire: 2016-12-30 00:00:00, pnl: 0.6700003051757814
# Processing date: 2016-12-23 00:00:00, expiry: 2017-01-06 00:00:00
# Let iron condor expire: 2017-01-06 00:00:00, pnl: 0.3699981689453125
# Processing date: 2016-12-30 00:00:00, expiry: 2017-01-13 00:00:00
# Let iron condor expire: 2017-01-13 00:00:00, pnl: 0.2999983215332031
# Processing date: 2017-01-06 00:00:00, expiry: 2017-01-20 00:00:00
# Let iron condor expire: 2017-01-20 00:00:00, pnl: 0.6400006103515624
# Processing date: 2017-01-13 00:00:00, expiry: 2017-01-27 00:00:00
# Let iron condor expire: 2017-01-27 00:00:00, pnl: 0.5399993896484375
# Processing date: 2017-01-25 00:00:00, expiry: 2017-02-03 00:00:00
# Closing on date: 2017-02-03 00:00:00
# strike1: 40.5, strike2: 48.0, strike3: 48.0, strike4: 49.0
# Long put sellback: 0.0
# Short put buyback: 0.22
# Short call buyback: 1.13
# Long call sellback: 0.46
# Closing cost: -0.8899999999999999
# Close iron condor early on date: 2017-02-03 00:00:00 when signal is -1, pnl: 0.6999984741210937
# Processing date: 2017-01-27 00:00:00, expiry: 2017-02-10 00:00:00
# Closing on date: 2017-02-03 00:00:00
# strike1: 47.0, strike2: 48.5, strike3: 48.5, strike4: 49.5
# Long put sellback: 0.08
# Short put buyback: 0.36
# Short call buyback: 0.76
# Long call sellback: 0.26
# Closing cost: -0.78
# Close iron condor early on date: 2017-02-03 00:00:00 when signal is -1, pnl: 0.9999984741210938
# Processing date: 2017-02-14 00:00:00, expiry: 2017-02-24 00:00:00
# Let iron condor expire: 2017-02-24 00:00:00, pnl: -0.41999999999999993
# Processing date: 2017-02-17 00:00:00, expiry: 2017-03-03 00:00:00
# Let iron condor expire: 2017-03-03 00:00:00, pnl: -0.32000000000000006
# Processing date: 2017-03-07 00:00:00, expiry: 2017-03-17 00:00:00
# Let iron condor expire: 2017-03-17 00:00:00, pnl: 0.4499995422363281
# Processing date: 2017-03-14 00:00:00, expiry: 2017-03-24 00:00:00
# Let iron condor expire: 2017-03-24 00:00:00, pnl: 0.18000000000000005
# Processing date: 2017-04-03 00:00:00, expiry: 2017-04-13 00:00:00
# Let iron condor expire: 2017-04-13 00:00:00, pnl: 0.5099996948242188
# Processing date: 2017-04-17 00:00:00, expiry: 2017-04-28 00:00:00
# Let iron condor expire: 2017-04-28 00:00:00, pnl: 0.4200007629394531
# Processing date: 2017-05-05 00:00:00, expiry: 2017-05-19 00:00:00
# Closing on date: 2017-05-18 00:00:00
# strike1: 41.0, strike2: 51.5, strike3: 51.5, strike4: 52.5
# Long put sellback: 0.0
# Short put buyback: 0.2
# Short call buyback: 0.64
# Long call sellback: 0.13
# Closing cost: -0.7100000000000001
# Close iron condor early on date: 2017-05-18 00:00:00 when signal is -1, pnl: 1.0599989318847656
# Processing date: 2017-05-15 00:00:00, expiry: 2017-05-26 00:00:00
# Closing on date: 2017-05-18 00:00:00
# strike1: 44.5, strike2: 51.5, strike3: 51.5, strike4: 52.0
# Long put sellback: 0.0
# Short put buyback: 0.2
# Short call buyback: 0.64
# Long call sellback: 0.32
# Closing cost: -0.52
# Close iron condor early on date: 2017-05-18 00:00:00 when signal is -1, pnl: 0.6099989318847656
# Processing date: 2017-05-26 00:00:00, expiry: 2017-06-09 00:00:00
# Let iron condor expire: 2017-06-09 00:00:00, pnl: 0.4200018310546875
# Processing date: 2017-06-07 00:00:00, expiry: 2017-06-16 00:00:00
# Let iron condor expire: 2017-06-16 00:00:00, pnl: 0.4799993896484375
# Processing date: 2017-06-09 00:00:00, expiry: 2017-06-23 00:00:00
# Let iron condor expire: 2017-06-23 00:00:00, pnl: 0.3899990844726562
# Processing date: 2017-06-26 00:00:00, expiry: 2017-07-07 00:00:00
# Closing on date: 2017-06-29 00:00:00
# strike1: 52.0, strike2: 53.5, strike3: 53.5, strike4: 56.5
# Long put sellback: 0.32
# Short put buyback: 1.52
# Short call buyback: 0.03
# Long call sellback: 0.0
# Closing cost: -1.23
# Close iron condor early on date: 2017-06-29 00:00:00 when signal is -1, pnl: -0.2399990844726565
# Processing date: 2017-07-19 00:00:00, expiry: 2017-07-28 00:00:00
# Let iron condor expire: 2017-07-28 00:00:00, pnl: -0.06
# Processing date: 2017-08-25 00:00:00, expiry: 2017-09-08 00:00:00
# Closing on date: 2017-09-08 00:00:00
# strike1: 52.5, strike2: 55.0, strike3: 55.0, strike4: 56.0
# Long put sellback: 0.02
# Short put buyback: 0.45
# Short call buyback: 0.51
# Long call sellback: 0.05
# Closing cost: -0.8899999999999999
# Close iron condor early on date: 2017-09-08 00:00:00 when signal is -1, pnl: 1.1099993896484375
# Processing date: 2017-09-01 00:00:00, expiry: 2017-09-15 00:00:00
# Closing on date: 2017-09-08 00:00:00
# strike1: 54.0, strike2: 55.0, strike3: 55.0, strike4: 56.0
# Long put sellback: 0.12
# Short put buyback: 0.45
# Short call buyback: 0.51
# Long call sellback: 0.05
# Closing cost: -0.79
# Close iron condor early on date: 2017-09-08 00:00:00 when signal is -1, pnl: 1.1199993896484375
# Processing date: 2017-10-06 00:00:00, expiry: 2017-10-20 00:00:00
# Closing on date: 2017-10-20 00:00:00
# strike1: 41.0, strike2: 53.0, strike3: 53.0, strike4: 54.0
# Long put sellback: 0.0
# Short put buyback: 0.08
# Short call buyback: 1.94
# Long call sellback: 1.03
# Closing cost: -0.99
# Close iron condor early on date: 2017-10-20 00:00:00 when signal is -1, pnl: 0.74
# Processing date: 2017-10-20 00:00:00, expiry: 2017-11-03 00:00:00
# Closing on date: 2017-10-20 00:00:00
# strike1: 45.5, strike2: 54.5, strike3: 54.5, strike4: 55.5
# Long put sellback: 0.0
# Short put buyback: 0.34
# Short call buyback: 0.68
# Long call sellback: 0.18
# Closing cost: -0.8400000000000001
# Close iron condor early on date: 2017-10-20 00:00:00 when signal is -1, pnl: 1.2299993896484376
# Processing date: 2017-10-27 00:00:00, expiry: 2017-11-10 00:00:00
# Closing on date: 2017-11-08 00:00:00
# strike1: 45.5, strike2: 54.5, strike3: 54.5, strike4: 55.5
# Long put sellback: 0.0
# Short put buyback: 0.07
# Short call buyback: 1.27
# Long call sellback: 0.44
# Closing cost: -0.9000000000000001
# Close iron condor early on date: 2017-11-08 00:00:00 when signal is -1, pnl: 0.5900000000000001
# Processing date: 2017-11-29 00:00:00, expiry: 2017-12-08 00:00:00
# Let iron condor expire: 2017-12-08 00:00:00, pnl: 0.28999893188476566
# Processing date: 2017-12-11 00:00:00, expiry: 2017-12-22 00:00:00
# Closing on date: 2017-12-22 00:00:00
# strike1: 54.5, strike2: 56.0, strike3: 56.0, strike4: 56.5
# Long put sellback: 2.0
# Short put buyback: 3.6
# Short call buyback: 0.02
# Long call sellback: 0.0
# Closing cost: -1.62
# Close iron condor early on date: 2017-12-22 00:00:00 when signal is -1, pnl: 0.7700000000000002
# Processing date: 2017-12-29 00:00:00, expiry: 2018-01-12 00:00:00
# Let iron condor expire: 2018-01-12 00:00:00, pnl: -0.7899999999999999
# Processing date: 2018-01-16 00:00:00, expiry: 2018-01-26 00:00:00
# Let iron condor expire: 2018-01-26 00:00:00, pnl: 0.28999908447265615
# Processing date: 2018-01-24 00:00:00, expiry: 2018-02-02 00:00:00
# Let iron condor expire: 2018-02-02 00:00:00, pnl: 0.16000106811523435
# Processing date: 2018-02-26 00:00:00, expiry: 2018-03-09 00:00:00
# Let iron condor expire: 2018-03-09 00:00:00, pnl: -0.19999847412109378
# Processing date: 2018-03-09 00:00:00, expiry: 2018-03-23 00:00:00
# Let iron condor expire: 2018-03-23 00:00:00, pnl: 0.8299986267089845
# Processing date: 2018-03-16 00:00:00, expiry: 2018-03-29 00:00:00
# Let iron condor expire: 2018-03-29 00:00:00, pnl: 0.24000122070312493
# Processing date: 2018-04-03 00:00:00, expiry: 2018-04-13 00:00:00
# Let iron condor expire: 2018-04-13 00:00:00, pnl: 0.6300009155273438
# Processing date: 2018-04-06 00:00:00, expiry: 2018-04-20 00:00:00
# Let iron condor expire: 2018-04-20 00:00:00, pnl: 0.23999923706054685
# Processing date: 2018-04-23 00:00:00, expiry: 2018-05-04 00:00:00
# Let iron condor expire: 2018-05-04 00:00:00, pnl: -0.29000000000000015
# Processing date: 2018-04-30 00:00:00, expiry: 2018-05-11 00:00:00
# Let iron condor expire: 2018-05-11 00:00:00, pnl: -0.71
# Processing date: 2018-05-04 00:00:00, expiry: 2018-05-18 00:00:00
# Let iron condor expire: 2018-05-18 00:00:00, pnl: -1.21
# Processing date: 2018-05-22 00:00:00, expiry: 2018-06-01 00:00:00
# Let iron condor expire: 2018-06-01 00:00:00, pnl: -0.39
# Processing date: 2018-05-25 00:00:00, expiry: 2018-06-08 00:00:00
# Closing on date: 2018-06-04 00:00:00
# strike1: 49.0, strike2: 50.5, strike3: 50.5, strike4: 51.5
# Long put sellback: 0.27
# Short put buyback: 1.19
# Short call buyback: 0.17
# Long call sellback: 0.03
# Closing cost: -1.0599999999999998
# Close iron condor early on date: 2018-06-04 00:00:00 when signal is -1, pnl: 1.0200013732910154
# Processing date: 2018-06-13 00:00:00, expiry: 2018-06-22 00:00:00
# Let iron condor expire: 2018-06-22 00:00:00, pnl: -0.33000000000000007
# Processing date: 2018-07-06 00:00:00, expiry: 2018-07-20 00:00:00
# Let iron condor expire: 2018-07-20 00:00:00, pnl: 0.12000091552734382
# Processing date: 2018-07-18 00:00:00, expiry: 2018-07-27 00:00:00
# Let iron condor expire: 2018-07-27 00:00:00, pnl: 0.5500006103515624
# Processing date: 2018-07-24 00:00:00, expiry: 2018-08-03 00:00:00
# Let iron condor expire: 2018-08-03 00:00:00, pnl: -0.23000000000000004
# Processing date: 2018-07-27 00:00:00, expiry: 2018-08-10 00:00:00
# Let iron condor expire: 2018-08-10 00:00:00, pnl: 0.840001678466797
# Processing date: 2018-08-07 00:00:00, expiry: 2018-08-17 00:00:00
# Let iron condor expire: 2018-08-17 00:00:00, pnl: -0.2600000000000001
# Processing date: 2018-08-10 00:00:00, expiry: 2018-08-24 00:00:00
# Let iron condor expire: 2018-08-24 00:00:00, pnl: 0.5500004577636719
# Processing date: 2018-08-29 00:00:00, expiry: 2018-09-07 00:00:00
# Let iron condor expire: 2018-09-07 00:00:00, pnl: -0.02999999999999997
# Processing date: 2018-08-31 00:00:00, expiry: 2018-09-14 00:00:00
# Let iron condor expire: 2018-09-14 00:00:00, pnl: 0.47000076293945314
# Processing date: 2018-09-14 00:00:00, expiry: 2018-09-28 00:00:00
# Closing on date: 2018-09-20 00:00:00
# strike1: 53.0, strike2: 54.5, strike3: 54.5, strike4: 55.5
# Long put sellback: 0.49
# Short put buyback: 1.7
# Short call buyback: 0.04
# Long call sellback: 0.0
# Closing cost: -1.25
# Close iron condor early on date: 2018-09-20 00:00:00 when signal is -1, pnl: 0.9200013732910157
# Processing date: 2018-10-23 00:00:00, expiry: 2018-11-02 00:00:00
# Closing on date: 2018-10-25 00:00:00
# strike1: 53.0, strike2: 54.5, strike3: 54.5, strike4: 56.0
# Long put sellback: 0.17
# Short put buyback: 0.66
# Short call buyback: 0.55
# Long call sellback: 0.09
# Closing cost: -0.9500000000000001
# Close iron condor early on date: 2018-10-25 00:00:00 when signal is -1, pnl: 1.6799989318847657
# Processing date: 2018-11-07 00:00:00, expiry: 2018-11-16 00:00:00
# Let iron condor expire: 2018-11-16 00:00:00, pnl: 0.4199989318847656
# Processing date: 2018-11-09 00:00:00, expiry: 2018-11-23 00:00:00
# Let iron condor expire: 2018-11-23 00:00:00, pnl: 0.45000061035156247
# Processing date: 2018-11-23 00:00:00, expiry: 2018-12-07 00:00:00
# Let iron condor expire: 2018-12-07 00:00:00, pnl: -0.4099999999999999
# Processing date: 2018-12-03 00:00:00, expiry: 2018-12-14 00:00:00
# Let iron condor expire: 2018-12-14 00:00:00, pnl: -0.20999999999999996
# Processing date: 2018-12-07 00:00:00, expiry: 2018-12-21 00:00:00
# Let iron condor expire: 2018-12-21 00:00:00, pnl: -0.9799986267089845
# Processing date: 2018-12-14 00:00:00, expiry: 2018-12-28 00:00:00
# Let iron condor expire: 2018-12-28 00:00:00, pnl: -0.6099999999999997
# Processing date: 2018-12-21 00:00:00, expiry: 2019-01-04 00:00:00
# Let iron condor expire: 2019-01-04 00:00:00, pnl: -0.5999995422363282
# Processing date: 2019-02-05 00:00:00, expiry: 2019-02-15 00:00:00
# Let iron condor expire: 2019-02-15 00:00:00, pnl: -0.22000000000000003
# Processing date: 2019-02-12 00:00:00, expiry: 2019-02-22 00:00:00
# Let iron condor expire: 2019-02-22 00:00:00, pnl: -0.2599999999999999
# Processing date: 2019-02-15 00:00:00, expiry: 2019-03-01 00:00:00
# Let iron condor expire: 2019-03-01 00:00:00, pnl: -0.20999999999999996
# Processing date: 2019-02-26 00:00:00, expiry: 2019-03-08 00:00:00
# Let iron condor expire: 2019-03-08 00:00:00, pnl: 0.09000076293945314
# Processing date: 2019-03-01 00:00:00, expiry: 2019-03-15 00:00:00
# Let iron condor expire: 2019-03-15 00:00:00, pnl: -0.18000000000000005
# Processing date: 2019-03-13 00:00:00, expiry: 2019-03-22 00:00:00
# Closing on date: 2019-03-22 00:00:00
# strike1: 56.5, strike2: 58.0, strike3: 58.0, strike4: 58.5
# Long put sellback: 0.09
# Short put buyback: 0.39
# Short call buyback: 0.92
# Long call sellback: 0.59
# ...
# Let iron condor expire: 2019-10-18 00:00:00, pnl: 0.9699996948242187
# Processing date: 2019-11-19 00:00:00, expiry: 2019-11-29 00:00:00
# Let iron condor expire: 2019-11-29 00:00:00, pnl: 0.6000007629394531
# Processing date: 2019-11-22 00:00:00, expiry: 2019-12-06 00:00:00
# Let iron condor expire: 2019-12-06 00:00:00, pnl: 0.5100009155273437
# Processing date: 2019-11-29 00:00:00, expiry: 2019-12-13 00:00:00
# Let iron condor expire: 2019-12-13 00:00:00, pnl: 0.3900010681152344
# Processing date: 2019-12-06 00:00:00, expiry: 2019-12-20 00:00:00
# Let iron condor expire: 2019-12-20 00:00:00, pnl: -0.10999999999999999
# Processing date: 2019-12-18 00:00:00, expiry: 2019-12-27 00:00:00
# Let iron condor expire: 2019-12-27 00:00:00, pnl: 0.42999725341796874
# Processing date: 2019-12-31 00:00:00, expiry: 2020-01-10 00:00:00
# Let iron condor expire: 2020-01-10 00:00:00, pnl: 0.6100015258789062
# Processing date: 2020-01-14 00:00:00, expiry: 2020-01-24 00:00:00
# Let iron condor expire: 2020-01-24 00:00:00, pnl: -0.020000000000000018
# Processing date: 2020-01-31 00:00:00, expiry: 2020-02-14 00:00:00
# Let iron condor expire: 2020-02-14 00:00:00, pnl: -0.3899993896484375
# Processing date: 2020-02-26 00:00:00, expiry: 2020-03-06 00:00:00
# Let iron condor expire: 2020-03-06 00:00:00, pnl: 0.2500006103515625
# Processing date: 2020-03-11 00:00:00, expiry: 2020-03-20 00:00:00
# Let iron condor expire: 2020-03-20 00:00:00, pnl: -3.369999999999999
# Processing date: 2020-03-13 00:00:00, expiry: 2020-03-27 00:00:00
# Let iron condor expire: 2020-03-27 00:00:00, pnl: 0.020000305175781552
# Processing date: 2020-04-09 00:00:00, expiry: 2020-04-17 00:00:00
# Let iron condor expire: 2020-04-17 00:00:00, pnl: 0.9600012207031249
# Processing date: 2020-04-17 00:00:00, expiry: 2020-05-01 00:00:00
# Let iron condor expire: 2020-05-01 00:00:00, pnl: -1.4799989318847664
# Processing date: 2020-04-24 00:00:00, expiry: 2020-05-08 00:00:00
# Let iron condor expire: 2020-05-08 00:00:00, pnl: 0.5199998474121095
# Processing date: 2020-05-01 00:00:00, expiry: 2020-05-15 00:00:00
# Let iron condor expire: 2020-05-15 00:00:00, pnl: 0.2900013732910156
# Processing date: 2020-05-08 00:00:00, expiry: 2020-05-22 00:00:00
# Let iron condor expire: 2020-05-22 00:00:00, pnl: 0.7800004577636719
# Processing date: 2020-05-15 00:00:00, expiry: 2020-05-29 00:00:00
# Let iron condor expire: 2020-05-29 00:00:00, pnl: -0.9999999999999996
# Processing date: 2020-05-22 00:00:00, expiry: 2020-06-05 00:00:00
# Let iron condor expire: 2020-06-05 00:00:00, pnl: -0.5299999999999998
# Processing date: 2020-06-02 00:00:00, expiry: 2020-06-12 00:00:00
# Let iron condor expire: 2020-06-12 00:00:00, pnl: -0.6000018310546875
# Processing date: 2020-06-05 00:00:00, expiry: 2020-06-19 00:00:00
# Let iron condor expire: 2020-06-19 00:00:00, pnl: -1.979998321533203
# Processing date: 2020-06-23 00:00:00, expiry: 2020-07-02 00:00:00
# Let iron condor expire: 2020-07-02 00:00:00, pnl: 1.3500015258789062
# Processing date: 2020-06-26 00:00:00, expiry: 2020-07-10 00:00:00
# Let iron condor expire: 2020-07-10 00:00:00, pnl: -0.40000045776367177
# Processing date: 2020-07-08 00:00:00, expiry: 2020-07-17 00:00:00
# Let iron condor expire: 2020-07-17 00:00:00, pnl: -0.3400000000000001
# Processing date: 2020-07-10 00:00:00, expiry: 2020-07-24 00:00:00
# Let iron condor expire: 2020-07-24 00:00:00, pnl: -0.3999999999999999
# Processing date: 2020-07-24 00:00:00, expiry: 2020-08-07 00:00:00
# Let iron condor expire: 2020-08-07 00:00:00, pnl: 0.9399983215332031
# Processing date: 2020-08-12 00:00:00, expiry: 2020-08-21 00:00:00
# Let iron condor expire: 2020-08-21 00:00:00, pnl: -0.050001831054687695
# Processing date: 2020-08-17 00:00:00, expiry: 2020-08-28 00:00:00
# Let iron condor expire: 2020-08-28 00:00:00, pnl: -0.3800003051757813
# Processing date: 2020-08-21 00:00:00, expiry: 2020-09-04 00:00:00
# Let iron condor expire: 2020-09-04 00:00:00, pnl: 1.1799989318847657
# Processing date: 2020-08-28 00:00:00, expiry: 2020-09-11 00:00:00
# Let iron condor expire: 2020-09-11 00:00:00, pnl: -0.18999969482421875
# Processing date: 2020-09-14 00:00:00, expiry: 2020-09-25 00:00:00
# Let iron condor expire: 2020-09-25 00:00:00, pnl: 0.710001220703125
# Processing date: 2020-09-22 00:00:00, expiry: 2020-10-02 00:00:00
# Let iron condor expire: 2020-10-02 00:00:00, pnl: -0.30000000000000004
# Processing date: 2020-09-28 00:00:00, expiry: 2020-10-09 00:00:00
# Let iron condor expire: 2020-10-09 00:00:00, pnl: -0.52
# Processing date: 2020-10-12 00:00:00, expiry: 2020-10-23 00:00:00
# Let iron condor expire: 2020-10-23 00:00:00, pnl: -0.1100000000000001
# Processing date: 2020-10-19 00:00:00, expiry: 2020-10-30 00:00:00
# Let iron condor expire: 2020-10-30 00:00:00, pnl: -0.4499989318847657
# Processing date: 2020-10-23 00:00:00, expiry: 2020-11-06 00:00:00
# Let iron condor expire: 2020-11-06 00:00:00, pnl: 0.6299972534179688
# Processing date: 2020-10-30 00:00:00, expiry: 2020-11-13 00:00:00
# Let iron condor expire: 2020-11-13 00:00:00, pnl: -0.5900000000000001
# Processing date: 2020-11-27 00:00:00, expiry: 2020-12-11 00:00:00
# Let iron condor expire: 2020-12-11 00:00:00, pnl: -0.9199983215332033
# Processing date: 2020-12-07 00:00:00, expiry: 2020-12-18 00:00:00
# Let iron condor expire: 2020-12-18 00:00:00, pnl: 0.9699990844726563
# Processing date: 2020-12-11 00:00:00, expiry: 2020-12-24 00:00:00
# Let iron condor expire: 2020-12-24 00:00:00, pnl: -1.3000009155273435
# Processing date: 2020-12-24 00:00:00, expiry: 2020-12-31 00:00:00
# Let iron condor expire: 2020-12-31 00:00:00, pnl: -0.21000000000000008
# Processing date: 2020-12-31 00:00:00, expiry: 2021-01-08 00:00:00
# Let iron condor expire: 2021-01-08 00:00:00, pnl: 0.5499981689453125
# Processing date: 2021-01-20 00:00:00, expiry: 2021-01-29 00:00:00
# Let iron condor expire: 2021-01-29 00:00:00, pnl: 0.7800015258789064
# Processing date: 2021-01-22 00:00:00, expiry: 2021-02-05 00:00:00
# Let iron condor expire: 2021-02-05 00:00:00, pnl: 0.08999984741210937
# Processing date: 2021-02-05 00:00:00, expiry: 2021-02-19 00:00:00
# Let iron condor expire: 2021-02-19 00:00:00, pnl: -1.1000001525878909
# Processing date: 2021-02-12 00:00:00, expiry: 2021-02-26 00:00:00
# Let iron condor expire: 2021-02-26 00:00:00, pnl: -0.9300000000000002
# Processing date: 2021-03-03 00:00:00, expiry: 2021-03-12 00:00:00
# Let iron condor expire: 2021-03-12 00:00:00, pnl: -1.2799999999999998
# Processing date: 2021-03-05 00:00:00, expiry: 2021-03-19 00:00:00
# Let iron condor expire: 2021-03-19 00:00:00, pnl: -0.4099999999999999
# Processing date: 2021-04-06 00:00:00, expiry: 2021-04-16 00:00:00
# Let iron condor expire: 2021-04-16 00:00:00, pnl: -0.2400000000000002
# Processing date: 2021-04-09 00:00:00, expiry: 2021-04-23 00:00:00
# Let iron condor expire: 2021-04-23 00:00:00, pnl: -1.4200018310546874
# Processing date: 2021-04-16 00:00:00, expiry: 2021-04-30 00:00:00
# Let iron condor expire: 2021-04-30 00:00:00, pnl: -0.43999877929687503
# Processing date: 2021-05-03 00:00:00, expiry: 2021-05-14 00:00:00
# Let iron condor expire: 2021-05-14 00:00:00, pnl: -0.049996337890624964
# Processing date: 2021-05-18 00:00:00, expiry: 2021-05-28 00:00:00
# Let iron condor expire: 2021-05-28 00:00:00, pnl: 0.9599963378906251
# Processing date: 2021-05-21 00:00:00, expiry: 2021-06-04 00:00:00
# Let iron condor expire: 2021-06-04 00:00:00, pnl: 0.4799993896484375
# Processing date: 2021-06-01 00:00:00, expiry: 2021-06-11 00:00:00
# Let iron condor expire: 2021-06-11 00:00:00, pnl: 0.21999938964843735
# Processing date: 2021-06-08 00:00:00, expiry: 2021-06-18 00:00:00
# Let iron condor expire: 2021-06-18 00:00:00, pnl: -0.5600015258789064
# Processing date: 2021-06-14 00:00:00, expiry: 2021-06-25 00:00:00
# Let iron condor expire: 2021-06-25 00:00:00, pnl: -0.69
# Processing date: 2021-07-12 00:00:00, expiry: 2021-07-23 00:00:00
# Let iron condor expire: 2021-07-23 00:00:00, pnl: -0.12999999999999995
# Processing date: 2021-08-03 00:00:00, expiry: 2021-08-13 00:00:00
# Let iron condor expire: 2021-08-13 00:00:00, pnl: -3.030000305175781
# Processing date: 2021-08-13 00:00:00, expiry: 2021-08-27 00:00:00
# Let iron condor expire: 2021-08-27 00:00:00, pnl: 0.9300033569335939
# Processing date: 2021-09-15 00:00:00, expiry: 2021-09-24 00:00:00
# Let iron condor expire: 2021-09-24 00:00:00, pnl: -1.04
# Processing date: 2021-09-17 00:00:00, expiry: 2021-10-01 00:00:00
# Let iron condor expire: 2021-10-01 00:00:00, pnl: -0.7300000000000001
# Processing date: 2021-10-15 00:00:00, expiry: 2021-10-29 00:00:00
# Let iron condor expire: 2021-10-29 00:00:00, pnl: 0.0699963378906251
# Processing date: 2021-10-25 00:00:00, expiry: 2021-11-05 00:00:00
# Let iron condor expire: 2021-11-05 00:00:00, pnl: 0.309998779296875
# Processing date: 2021-10-29 00:00:00, expiry: 2021-11-12 00:00:00
# Let iron condor expire: 2021-11-12 00:00:00, pnl: 0.1400015258789063
# Processing date: 2021-11-19 00:00:00, expiry: 2021-12-03 00:00:00
# Let iron condor expire: 2021-12-03 00:00:00, pnl: 0.6299984741210938
# Processing date: 2021-11-29 00:00:00, expiry: 2021-12-10 00:00:00
# Let iron condor expire: 2021-12-10 00:00:00, pnl: -0.53
# Processing date: 2021-12-15 00:00:00, expiry: 2021-12-23 00:00:00
# Let iron condor expire: 2021-12-23 00:00:00, pnl: 0.539998779296875
# Processing date: 2021-12-17 00:00:00, expiry: 2021-12-31 00:00:00
# Let iron condor expire: 2021-12-31 00:00:00, pnl: 0.6899981689453125
# Processing date: 2021-12-23 00:00:00, expiry: 2021-12-31 00:00:00
# Let iron condor expire: 2021-12-31 00:00:00, pnl: -0.31999999999999984
# Processing date: 2021-12-31 00:00:00, expiry: 2022-01-14 00:00:00
# Let iron condor expire: 2022-01-14 00:00:00, pnl: -0.4299984741210936
# Processing date: 2022-01-21 00:00:00, expiry: 2022-02-04 00:00:00
# Let iron condor expire: 2022-02-04 00:00:00, pnl: 0.3000033569335938
# Processing date: 2022-02-22 00:00:00, expiry: 2022-03-04 00:00:00
# Let iron condor expire: 2022-03-04 00:00:00, pnl: -3.8999993896484373
# Processing date: 2022-03-22 00:00:00, expiry: 2022-04-01 00:00:00
# Let iron condor expire: 2022-04-01 00:00:00, pnl: -0.4299999999999997
# Processing date: 2022-03-25 00:00:00, expiry: 2022-04-08 00:00:00
# Let iron condor expire: 2022-04-08 00:00:00, pnl: -0.2999999999999998
# Processing date: 2022-04-04 00:00:00, expiry: 2022-04-14 00:00:00
# Let iron condor expire: 2022-04-14 00:00:00, pnl: 0.07000366210937503
# Processing date: 2022-04-14 00:00:00, expiry: 2022-04-22 00:00:00
# Let iron condor expire: 2022-04-22 00:00:00, pnl: -0.6
# Processing date: 2022-04-22 00:00:00, expiry: 2022-05-06 00:00:00
# Let iron condor expire: 2022-05-06 00:00:00, pnl: -1.5100009155273437
# Processing date: 2022-05-17 00:00:00, expiry: 2022-05-27 00:00:00
# Let iron condor expire: 2022-05-27 00:00:00, pnl: -0.4900000000000002
# Processing date: 2022-06-03 00:00:00, expiry: 2022-06-17 00:00:00
# Let iron condor expire: 2022-06-17 00:00:00, pnl: -1.5200000000000005
# Processing date: 2022-06-29 00:00:00, expiry: 2022-07-08 00:00:00
# Let iron condor expire: 2022-07-08 00:00:00, pnl: 0.9900003051757812
# Processing date: 2022-07-12 00:00:00, expiry: 2022-07-22 00:00:00
# Let iron condor expire: 2022-07-22 00:00:00, pnl: 0.9900003051757813
# Processing date: 2022-07-15 00:00:00, expiry: 2022-07-29 00:00:00
# Let iron condor expire: 2022-07-29 00:00:00, pnl: -0.3500000000000001
# Processing date: 2022-08-05 00:00:00, expiry: 2022-08-19 00:00:00
# Let iron condor expire: 2022-08-19 00:00:00, pnl: -0.9199999999999999
# Processing date: 2022-08-16 00:00:00, expiry: 2022-08-26 00:00:00
# Let iron condor expire: 2022-08-26 00:00:00, pnl: 0.1499990844726562
# Processing date: 2022-08-26 00:00:00, expiry: 2022-09-09 00:00:00
# Let iron condor expire: 2022-09-09 00:00:00, pnl: 1.0100027465820314
# Processing date: 2022-09-23 00:00:00, expiry: 2022-10-07 00:00:00
# Let iron condor expire: 2022-10-07 00:00:00, pnl: -3.1099999999999994
# Processing date: 2022-10-26 00:00:00, expiry: 2022-11-04 00:00:00
# Let iron condor expire: 2022-11-04 00:00:00, pnl: 0.12000366210937496
# Processing date: 2022-10-31 00:00:00, expiry: 2022-11-11 00:00:00
# Let iron condor expire: 2022-11-11 00:00:00, pnl: 0.8099981689453125
# Processing date: 2022-11-04 00:00:00, expiry: 2022-11-18 00:00:00
# Let iron condor expire: 2022-11-18 00:00:00, pnl: 0.09000152587890642
# Processing date: 2022-11-25 00:00:00, expiry: 2022-12-09 00:00:00
# Let iron condor expire: 2022-12-09 00:00:00, pnl: 1.3500018310546875
# Processing date: 2022-12-09 00:00:00, expiry: 2022-12-23 00:00:00
# Let iron condor expire: 2022-12-23 00:00:00, pnl: 1.8500036621093752
# Processing date: 2022-12-21 00:00:00, expiry: 2022-12-30 00:00:00
# Let iron condor expire: 2022-12-30 00:00:00, pnl: 0.6100000000000001
# Processing date: 2022-12-23 00:00:00, expiry: 2023-01-06 00:00:00
# Let iron condor expire: 2023-01-06 00:00:00, pnl: 0.51
# Processing date: 2022-12-30 00:00:00, expiry: 2023-01-13 00:00:00
# Let iron condor expire: 2023-01-13 00:00:00, pnl: 1.3699981689453127
# Processing date: 2023-01-24 00:00:00, expiry: 2023-02-03 00:00:00
# Let iron condor expire: 2023-02-03 00:00:00, pnl: -1.989996337890625
# Processing date: 2023-01-27 00:00:00, expiry: 2023-02-10 00:00:00
# Let iron condor expire: 2023-02-10 00:00:00, pnl: 0.7099990844726562
# Processing date: 2023-02-17 00:00:00, expiry: 2023-03-03 00:00:00
# Let iron condor expire: 2023-03-03 00:00:00, pnl: -0.4099999999999999
# Processing date: 2023-02-24 00:00:00, expiry: 2023-03-10 00:00:00
# Let iron condor expire: 2023-03-10 00:00:00, pnl: -0.0800018310546875
# Processing date: 2023-03-08 00:00:00, expiry: 2023-03-17 00:00:00
# Let iron condor expire: 2023-03-17 00:00:00, pnl: -0.24000122070312507
# Processing date: 2023-03-10 00:00:00, expiry: 2023-03-24 00:00:00
# Let iron condor expire: 2023-03-24 00:00:00, pnl: 1.4700024414062498
# Processing date: 2023-04-03 00:00:00, expiry: 2023-04-14 00:00:00
# Let iron condor expire: 2023-04-14 00:00:00, pnl: -1.9899993896484374
# Processing date: 2023-04-11 00:00:00, expiry: 2023-04-21 00:00:00
# Let iron condor expire: 2023-04-21 00:00:00, pnl: 1.1099972534179687
# Processing date: 2023-04-18 00:00:00, expiry: 2023-04-28 00:00:00
# Let iron condor expire: 2023-04-28 00:00:00, pnl: -0.009996643066406297
# Processing date: 2023-04-21 00:00:00, expiry: 2023-05-05 00:00:00
# Let iron condor expire: 2023-05-05 00:00:00, pnl: 0.35999877929687496
# Processing date: 2023-05-03 00:00:00, expiry: 2023-05-12 00:00:00
# Let iron condor expire: 2023-05-12 00:00:00, pnl: -0.32999877929687516
# Processing date: 2023-05-10 00:00:00, expiry: 2023-05-19 00:00:00
# Let iron condor expire: 2023-05-19 00:00:00, pnl: -1.979999389648437
# Processing date: 2023-05-12 00:00:00, expiry: 2023-05-26 00:00:00
# Let iron condor expire: 2023-05-26 00:00:00, pnl: -4.3
# Processing date: 2023-05-22 00:00:00, expiry: 2023-06-02 00:00:00
# Let iron condor expire: 2023-06-02 00:00:00, pnl: -2.239997253417969
# Processing date: 2023-06-13 00:00:00, expiry: 2023-06-23 00:00:00
# Let iron condor expire: 2023-06-23 00:00:00, pnl: -0.04000122070312506
# Processing date: 2023-06-16 00:00:00, expiry: 2023-06-30 00:00:00
# Let iron condor expire: 2023-06-30 00:00:00, pnl: -0.5599975585937501
# Processing date: 2023-07-14 00:00:00, expiry: 2023-07-28 00:00:00
# Let iron condor expire: 2023-07-28 00:00:00, pnl: 1.0299990844726563
# Processing date: 2023-07-31 00:00:00, expiry: 2023-08-11 00:00:00
# Let iron condor expire: 2023-08-11 00:00:00, pnl: -0.9599999999999997
# Processing date: 2023-08-14 00:00:00, expiry: 2023-08-25 00:00:00
# Let iron condor expire: 2023-08-25 00:00:00, pnl: 0.1600010681152344
# Processing date: 2023-08-18 00:00:00, expiry: 2023-09-01 00:00:00
# Expiry date 2023-09-01 00:00:00 not found; finding closest available date.
# Using adjusted expiry date: 2023-08-31 00:00:00
# Let iron condor expire: 2023-08-31 00:00:00, pnl: 1.1799990844726562
# Processing date: 2023-08-29 00:00:00, expiry: 2023-09-08 00:00:00
# Expiry date 2023-09-08 00:00:00 not found; finding closest available date.
# Using adjusted expiry date: 2023-08-31 00:00:00
# Let iron condor expire: 2023-08-31 00:00:00, pnl: 0.2799990844726563
# | 60        | 1.08      | -2.614    | 1.001     | 8.787     |
# =============================================================

# %%
res = optimizer.res
res_df = pd.DataFrame(res)
res_df[res_df["target"] > 0]
# Out:
#       target                                             params
# 1   1.224053  {'lower_threshold': -1.8026830316059268, 'uppe...
# 4   1.313779  {'lower_threshold': -1.3351147183991565, 'uppe...
# 10  1.322521  {'lower_threshold': -1.2384557825466223, 'uppe...
# 20  1.154701  {'lower_threshold': -2.7463681864879765, 'uppe...
# 27  1.103102  {'lower_threshold': -2.9514930630886904, 'uppe...
# 28  1.095410  {'lower_threshold': -2.9392910591938755, 'uppe...
# 29  1.114172  {'lower_threshold': -2.9903588800387904, 'uppe...
# 31  1.106029  {'lower_threshold': -1.8966845778419097, 'uppe...
# 35  1.154701  {'lower_threshold': -2.9548825499564413, 'uppe...
# 36  1.167117  {'lower_threshold': -2.904366707722708, 'upper...
# 39  1.167117  {'lower_threshold': -2.1435487582159825, 'uppe...
# 41  1.151658  {'lower_threshold': -2.176751570669995, 'upper...
# 42  1.089621  {'lower_threshold': -1.2584104103769433, 'uppe...
# 46  1.060797  {'lower_threshold': -2.032608586083459, 'upper...
# 47  1.108553  {'lower_threshold': -2.183231733234644, 'upper...
# 49  1.151658  {'lower_threshold': -2.9924265087564685, 'uppe...
# 51  1.119424  {'lower_threshold': -1.0165830168524057, 'uppe...
# 53  3.853870  {'lower_threshold': -1.0104907732072848, 'uppe...
# 57  0.568286  {'lower_threshold': -1.1019894103911632, 'uppe...
# 59  1.080063  {'lower_threshold': -2.613959530774019, 'upper...

# %%
res_df.iloc[57]["params"]
# Out:
# {'lower_threshold': -1.1019894103911632,
#  'upper_threshold': 1.6844905007838182,
#  'window': 11.997753293517594}

# %% [markdown]
# # Optimisation Results

# %%
def objective_function(window, upper_threshold, lower_threshold):
    # Options data
    day_map = {0: "Monday", 1: "Tuesday", 2: "Wednesday", 3: "Thursday", 4: "Friday", 5: "Saturday", 6: "Sunday"}

    xlu_options = pd.read_hdf("data/etf_options_data.hf5", key="XLU")
    xlu_options = xlu_options.set_index("date")
    xlu_options["strike_price"] = xlu_options["strike_price"] / 1000
    xlu_filtered_options = xlu_options.groupby("date").apply(lambda x: x.query("exdate == exdate.max()")).reset_index(level=0, drop=True)
    xlu_filtered_options["day"] = xlu_filtered_options.index.weekday.map(day_map)
    xlu_filtered_options["ex_day"] = xlu_filtered_options["exdate"].dt.weekday.map(day_map)

    # Setting time series data
    xlu_pred = pd.read_csv("data/xlu_pred.csv", parse_dates=True, index_col=0).rename(columns={"0": "Rolling Pred"})
    xlu_iv = pd.read_csv("data/XLU_IV.csv", parse_dates=True, index_col=0)
    xlu_vrp = (xlu_iv["Average IV"] - xlu_pred["Rolling Pred"]).dropna()

    xlu_vrp_standardised = rolling_z_score(xlu_vrp, window=int(window))

    xlu_filtered_options["vrp"] = xlu_vrp_standardised
    xlu_time_series = pd.read_hdf("data/etf_series.hf5", key="XLU")
    xlu_time_series["day"] = xlu_time_series.index.weekday
    xlu_time_series["vrp"] = xlu_vrp_standardised
    xlu_time_series["signal"] = np.where(xlu_time_series["vrp"] > upper_threshold, 1, np.where(xlu_time_series["vrp"] < lower_threshold, -1, 0))
    xlu_time_series["action"] = np.where((xlu_time_series["signal"] == 1)  & (xlu_time_series.index.weekday != 4), 1, 
                                        np.where((xlu_time_series["signal"] == -1) & (xlu_time_series.index.weekday != 4), -1, 
                                                0))
    xlu_time_series.dropna(inplace=True)
    xlu_time_series

    xlu_time_series = ensure_weekly_action(xlu_time_series)
    xlu_time_series["action"] = xlu_time_series["action"].shift(-1)

    # Strategy backtesting
    ironcondor_tracker = {}

    for index, row in xlu_time_series.iterrows():
        if row["action"] == 1:
            print(f"date: {index}")
            direction = "short"

            index_loc = xlu_time_series.index.get_loc(index)

            current_spot_open = myround(xlu_time_series.iloc[index_loc]["Open"], 0.5)

            daily_options = xlu_filtered_options.loc[index]

            atm_put_strike = atm_call_strike = current_spot_open

            otm_put_strike = find_nearest_strike_delta(current_spot_open, index, 0.4, xlu_filtered_options, "P")
            otm_call_strike = find_nearest_strike_delta(current_spot_open, index, -0.3, xlu_filtered_options, "C")

            if otm_put_strike is None or otm_call_strike is None:
                continue
                
            else:
                print(f"date: {index}, current_spot_open: {current_spot_open}, OTM Put: {otm_put_strike}, ATM Put: {atm_put_strike}, ATM Call: {atm_call_strike}, OTM Call: {otm_call_strike}, \
                    left wing: {abs(otm_put_strike - atm_put_strike)}, right wing: {abs(atm_call_strike - otm_call_strike)}")
                strikes = {
                    "strike1": otm_put_strike,
                    "strike2": atm_put_strike,
                    "strike3": atm_call_strike,
                    "strike4": otm_call_strike
                }

                premiums = {
                    "premium1": xlu_filtered_options.loc[
                        (xlu_filtered_options.index == index) & 
                        (xlu_filtered_options["strike_price"] == strikes["strike1"]) & 
                        (xlu_filtered_options["cp_flag"] == 'P'), "best_offer"
                    ],
                    "premium2": xlu_filtered_options.loc[
                        (xlu_filtered_options.index == index) & 
                        (xlu_filtered_options["strike_price"] == strikes["strike2"]) & 
                        (xlu_filtered_options["cp_flag"] == 'P'), "best_bid"
                    ],
                    "premium3": xlu_filtered_options.loc[
                        (xlu_filtered_options.index == index) & 
                        (xlu_filtered_options["strike_price"] == strikes["strike3"]) & 
                        (xlu_filtered_options["cp_flag"] == 'C'), "best_bid"
                    ],
                    "premium4": xlu_filtered_options.loc[
                        (xlu_filtered_options.index == index) & 
                        (xlu_filtered_options["strike_price"] == strikes["strike4"]) & 
                        (xlu_filtered_options["cp_flag"] == 'C'), "best_offer"
                    ]
                }        

                # print(f"date: {index}, Premiums: {premiums}")

                expiry = xlu_filtered_options.loc[index]["exdate"].max()

                ironcondor = IronCondor(direction=direction, strikes=strikes, premiums=premiums, expiry=expiry)
                ironcondor_tracker[index] = (ironcondor, ironcondor.target_profit().iloc[0], expiry)

    # Calculate the payoff of the Iron Condor strategy
    pnl_dict = {}

    for index, (ironcondor, target_profit, expiry) in ironcondor_tracker.items():
        print(f"Processing date: {index}, expiry: {expiry}")
        if ironcondor is not None:
            # Check if `expiry` date is present, or find the closest available date before `expiry`
            if expiry not in xlu_time_series.index:
                print(f"Expiry date {expiry} not found; finding closest available date.")
                # Find the latest date before the `expiry` that is available in `xle_time_series`
                available_dates = xlu_time_series.loc[:expiry].index
                if available_dates.empty:
                    print(f"No available data for range {index} to {expiry}, skipping this trade.")
                    continue
                expiry = available_dates[-1]  # Use the last available date before expiry
                print(f"Using adjusted expiry date: {expiry}")

            test_time_series = xlu_time_series.loc[index:expiry + pd.Timedelta(days=1)]
            options_test_df = xlu_filtered_options.loc[index:expiry + pd.Timedelta(days=1)]
            early_close = False

            for date, row in test_time_series.iterrows():
                if row["signal"] == -1:
                    
                    print(f"Closing on date: {date}")
                    ic_strikes = ironcondor.strikes
                    print(f"strike1: {ic_strikes['strike1']}, strike2: {ic_strikes['strike2']}, strike3: {ic_strikes['strike3']}, strike4: {ic_strikes['strike4']}")
                    try:
                        # Long put (buy to open, sell to close)
                        long_put_sellback = options_test_df.loc[date][
                            (options_test_df.loc[date]["cp_flag"] == 'P') & 
                            (options_test_df.loc[date]["strike_price"] == ic_strikes["strike1"])
                        ]["best_bid"].values[0]
                    except IndexError:
                        closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'P'] \
                            .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike1"]).abs()) \
                            .sort_values("distance").iloc[0]["strike_price"]
                        
                        # Use closest strike for long put (sell to close)
                        long_put_sellback = options_test_df.loc[date][
                            (options_test_df.loc[date]["cp_flag"] == 'P') & 
                            (options_test_df.loc[date]["strike_price"] == closest_strike)
                        ]["best_bid"].values[0]
                    print(f"Long put sellback: {long_put_sellback}")

                    try:
                        # Short put (sell to open, buy to close)
                        short_put_buyback = options_test_df.loc[date][
                            (options_test_df.loc[date]["cp_flag"] == 'P') & 
                            (options_test_df.loc[date]["strike_price"] == ic_strikes["strike2"])
                        ]["best_offer"].values[0]
                    except IndexError:
                        closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'P'] \
                            .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike2"]).abs()) \
                            .sort_values("distance").iloc[0]["strike_price"]
                        
                        # Use closest strike for short put (buy to close)
                        short_put_buyback = options_test_df.loc[date][
                            (options_test_df.loc[date]["cp_flag"] == 'P') & 
                            (options_test_df.loc[date]["strike_price"] == closest_strike)
                        ]["best_offer"].values[0]
                    print(f"Short put buyback: {short_put_buyback}")

                    try:
                        # Short call (sell to open, buy to close)
                        short_call_buyback = options_test_df.loc[date][
                            (options_test_df.loc[date]["cp_flag"] == 'C') & 
                            (options_test_df.loc[date]["strike_price"] == ic_strikes["strike3"])
                        ]["best_offer"].values[0]
                    except IndexError:
                        closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'C'] \
                            .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike3"]).abs()) \
                            .sort_values("distance").iloc[0]["strike_price"]
                        
                        # Use closest strike for short call (buy to close)
                        short_call_buyback = options_test_df.loc[date][
                            (options_test_df.loc[date]["cp_flag"] == 'C') & 
                            (options_test_df.loc[date]["strike_price"] == closest_strike)
                        ]["best_offer"].values[0]
                    print(f"Short call buyback: {short_call_buyback}")

                    try:
                        # Long call (buy to open, sell to close)
                        long_call_sellback = options_test_df.loc[date][
                            (options_test_df.loc[date]["cp_flag"] == 'C') & 
                            (options_test_df.loc[date]["strike_price"] == ic_strikes["strike4"])
                        ]["best_bid"].values[0]
                    except IndexError:
                        closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'C'] \
                            .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike4"]).abs()) \
                            .sort_values("distance").iloc[0]["strike_price"]
                        
                        # Use closest strike for long call (sell to close)
                        long_call_sellback = options_test_df.loc[date][
                            (options_test_df.loc[date]["cp_flag"] == 'C') & 
                            (options_test_df.loc[date]["strike_price"] == closest_strike)
                        ]["best_bid"].values[0]
                    print(f"Long call sellback: {long_call_sellback}")

                    # Now calculate the closing cost
                    if None not in [long_put_sellback, short_put_buyback, short_call_buyback, long_call_sellback]:
                        closing_cost = long_put_sellback - short_put_buyback - short_call_buyback + long_call_sellback
                    else:
                        closing_cost = None  # Handle missing values appropriately
                    print(f"Closing cost: {closing_cost}")

                    ironcondor.insert_spot(xlu_time_series.loc[date]["Close"])
                    pnl_dict[index] = ironcondor.payoff() - closing_cost
                    print(f"Close iron condor early on date: {date} when signal is -1, pnl: {pnl_dict[index]}")
                    early_close = True
                    break
            if not early_close:
                try:
                    ironcondor.insert_spot(xlu_time_series.loc[expiry]["Close"])
                    print(f"Let iron condor expire: {expiry}, pnl: {ironcondor.payoff()}")
                    pnl_dict[index] = ironcondor.payoff()    
                except KeyError:
                    try:
                        ironcondor.insert_spot(xlu_time_series.loc[expiry + pd.Timedelta(days=1)]["Close"])
                        print(f"Let iron condor expire: {expiry}, pnl: {ironcondor.payoff()}")
                        pnl_dict[index] = ironcondor.payoff()           
                    except KeyError:
                        try:
                            ironcondor.insert_spot(xlu_time_series.loc[expiry - pd.Timedelta(days=1)]["Close"])
                            print(f"Let iron condor expire: {expiry}, pnl: {ironcondor.payoff()}")
                            pnl_dict[index] = ironcondor.payoff()    
                        except KeyError:
                            print(f"Warning: Unable to insert spot for index {index} with expiry {expiry}, PnL set to 0")
                            pnl_dict[index] = 0
                            continue
                                
                
                # print(f"Let iron condor expire: {expiry}, pnl: {ironcondor.payoff()}")
                # pnl_dict[index] = ironcondor.payoff()         

    pnl_series = pd.DataFrame(pnl_dict.items(), columns=["Date", "PnL"]).set_index("Date").PnL
    return pnl_series

pnl_series = objective_function(12.00, 1.6844905007838182, -1.1019894103911632)
# Out:
# date: 2016-10-28 00:00:00
# date: 2016-10-28 00:00:00, current_spot_open: 48.5, OTM Put: 46.0, ATM Put: 48.5, ATM Call: 48.5, OTM Call: 51.5,                     left wing: 2.5, right wing: 3.0
# date: 2016-12-09 00:00:00
# date: 2016-12-09 00:00:00, current_spot_open: 47.5, OTM Put: 45.0, ATM Put: 47.5, ATM Call: 47.5, OTM Call: 48.5,                     left wing: 2.5, right wing: 1.0
# date: 2016-12-23 00:00:00
# date: 2016-12-23 00:00:00, current_spot_open: 48.5, OTM Put: 46.0, ATM Put: 48.5, ATM Call: 48.5, OTM Call: 49.5,                     left wing: 2.5, right wing: 1.0
# date: 2017-01-18 00:00:00
# date: 2017-01-18 00:00:00, current_spot_open: 49.0, OTM Put: 47.5, ATM Put: 49.0, ATM Call: 49.0, OTM Call: 50.0,                     left wing: 1.5, right wing: 1.0
# date: 2017-01-25 00:00:00
# date: 2017-01-25 00:00:00, current_spot_open: 48.0, OTM Put: 40.5, ATM Put: 48.0, ATM Call: 48.0, OTM Call: 49.0,                     left wing: 7.5, right wing: 1.0
# date: 2017-01-27 00:00:00
# date: 2017-01-27 00:00:00, current_spot_open: 48.5, OTM Put: 47.0, ATM Put: 48.5, ATM Call: 48.5, OTM Call: 49.5,                     left wing: 1.5, right wing: 1.0
# date: 2017-02-17 00:00:00
# date: 2017-02-17 00:00:00, current_spot_open: 49.5, OTM Put: 47.5, ATM Put: 49.5, ATM Call: 49.5, OTM Call: 50.5,                     left wing: 2.0, right wing: 1.0
# date: 2017-03-07 00:00:00
# date: 2017-03-07 00:00:00, current_spot_open: 51.5, OTM Put: 50.5, ATM Put: 51.5, ATM Call: 51.5, OTM Call: 52.5,                     left wing: 1.0, right wing: 1.0
# date: 2017-03-14 00:00:00
# date: 2017-03-14 00:00:00, current_spot_open: 51.0, OTM Put: 49.5, ATM Put: 51.0, ATM Call: 51.0, OTM Call: 51.5,                     left wing: 1.5, right wing: 0.5
# date: 2017-04-03 00:00:00
# date: 2017-04-03 00:00:00, current_spot_open: 51.5, OTM Put: 50.0, ATM Put: 51.5, ATM Call: 51.5, OTM Call: 52.5,                     left wing: 1.5, right wing: 1.0
# date: 2017-04-19 00:00:00
# date: 2017-04-19 00:00:00, current_spot_open: 52.0, OTM Put: 50.5, ATM Put: 52.0, ATM Call: 52.0, OTM Call: 54.5,                     left wing: 1.5, right wing: 2.5
# date: 2017-05-16 00:00:00
# date: 2017-05-16 00:00:00, current_spot_open: 52.0, OTM Put: 51.0, ATM Put: 52.0, ATM Call: 52.0, OTM Call: 58.5,                     left wing: 1.0, right wing: 6.5
# date: 2017-06-07 00:00:00
# date: 2017-06-07 00:00:00, current_spot_open: 54.0, OTM Put: 53.0, ATM Put: 54.0, ATM Call: 54.0, OTM Call: 54.5,                     left wing: 1.0, right wing: 0.5
# date: 2017-07-19 00:00:00
# date: 2017-07-19 00:00:00, current_spot_open: 52.5, OTM Put: 51.0, ATM Put: 52.5, ATM Call: 52.5, OTM Call: 53.0,                     left wing: 1.5, right wing: 0.5
# date: 2017-08-28 00:00:00
# date: 2017-08-28 00:00:00, current_spot_open: 55.5, OTM Put: 54.5, ATM Put: 55.5, ATM Call: 55.5, OTM Call: 56.5,                     left wing: 1.0, right wing: 1.0
# date: 2017-10-09 00:00:00
# date: 2017-10-09 00:00:00, current_spot_open: 53.5, OTM Put: 52.0, ATM Put: 53.5, ATM Call: 53.5, OTM Call: 54.5,                     left wing: 1.5, right wing: 1.0
# date: 2017-10-23 00:00:00
# date: 2017-10-23 00:00:00, current_spot_open: 55.0, OTM Put: 53.5, ATM Put: 55.0, ATM Call: 55.0, OTM Call: 56.0,                     left wing: 1.5, right wing: 1.0
# date: 2017-10-27 00:00:00
# date: 2017-10-27 00:00:00, current_spot_open: 54.5, OTM Put: 45.5, ATM Put: 54.5, ATM Call: 54.5, OTM Call: 55.5,                     left wing: 9.0, right wing: 1.0
# date: 2017-11-29 00:00:00
# date: 2017-11-29 00:00:00, current_spot_open: 56.0, OTM Put: 47.5, ATM Put: 56.0, ATM Call: 56.0, OTM Call: 56.5,                     left wing: 8.5, right wing: 0.5
# date: 2018-01-31 00:00:00
# date: 2018-01-31 00:00:00, current_spot_open: 50.5, OTM Put: 44.0, ATM Put: 50.5, ATM Call: 50.5, OTM Call: 51.5,                     left wing: 6.5, right wing: 1.0
# date: 2018-02-27 00:00:00
# date: 2018-02-27 00:00:00, current_spot_open: 50.0, OTM Put: 48.5, ATM Put: 50.0, ATM Call: 50.0, OTM Call: 52.0,                     left wing: 1.5, right wing: 2.0
# date: 2018-03-13 00:00:00
# date: 2018-03-13 00:00:00, current_spot_open: 50.0, OTM Put: 48.5, ATM Put: 50.0, ATM Call: 50.0, OTM Call: 51.5,                     left wing: 1.5, right wing: 1.5
# date: 2018-03-16 00:00:00
# date: 2018-03-16 00:00:00, current_spot_open: 50.0, OTM Put: 39.0, ATM Put: 50.0, ATM Call: 50.0, OTM Call: 51.0,                     left wing: 11.0, right wing: 1.0
# date: 2018-04-06 00:00:00
# date: 2018-04-06 00:00:00, current_spot_open: 51.0, OTM Put: 49.5, ATM Put: 51.0, ATM Call: 51.0, OTM Call: 53.0,                     left wing: 1.5, right wing: 2.0
# date: 2018-04-23 00:00:00
# date: 2018-04-23 00:00:00, current_spot_open: 50.5, OTM Put: 49.0, ATM Put: 50.5, ATM Call: 50.5, OTM Call: 51.5,                     left wing: 1.5, right wing: 1.0
# date: 2018-05-04 00:00:00
# date: 2018-05-04 00:00:00, current_spot_open: 51.5, OTM Put: 49.5, ATM Put: 51.5, ATM Call: 51.5, OTM Call: 52.5,                     left wing: 2.0, right wing: 1.0
# date: 2018-06-13 00:00:00
# date: 2018-06-13 00:00:00, current_spot_open: 49.0, OTM Put: 48.0, ATM Put: 49.0, ATM Call: 49.0, OTM Call: 50.0,                     left wing: 1.0, right wing: 1.0
# date: 2018-07-31 00:00:00
# date: 2018-07-31 00:00:00, current_spot_open: 52.5, OTM Put: 45.0, ATM Put: 52.5, ATM Call: 52.5, OTM Call: 53.5,                     left wing: 7.5, right wing: 1.0
# date: 2018-08-31 00:00:00
# date: 2018-08-31 00:00:00, current_spot_open: 54.0, OTM Put: 52.5, ATM Put: 54.0, ATM Call: 54.0, OTM Call: 57.0,                     left wing: 1.5, right wing: 3.0
# date: 2018-10-23 00:00:00
# date: 2018-10-23 00:00:00, current_spot_open: 54.5, OTM Put: 53.0, ATM Put: 54.5, ATM Call: 54.5, OTM Call: 56.0,                     left wing: 1.5, right wing: 1.5
# date: 2018-11-09 00:00:00
# date: 2018-11-09 00:00:00, current_spot_open: 54.5, OTM Put: 40.0, ATM Put: 54.5, ATM Call: 54.5, OTM Call: 55.5,                     left wing: 14.5, right wing: 1.0
# date: 2018-12-03 00:00:00
# date: 2018-12-03 00:00:00, current_spot_open: 55.5, OTM Put: 40.0, ATM Put: 55.5, ATM Call: 55.5, OTM Call: 56.5,                     left wing: 15.5, right wing: 1.0
# date: 2018-12-10 00:00:00
# date: 2018-12-10 00:00:00, current_spot_open: 56.5, OTM Put: 54.5, ATM Put: 56.5, ATM Call: 56.5, OTM Call: 58.0,                     left wing: 2.0, right wing: 1.5
# date: 2018-12-14 00:00:00
# date: 2018-12-14 00:00:00, current_spot_open: 57.0, OTM Put: 55.5, ATM Put: 57.0, ATM Call: 57.0, OTM Call: 58.0,                     left wing: 1.5, right wing: 1.0
# date: 2018-12-21 00:00:00
# date: 2018-12-21 00:00:00, current_spot_open: 54.5, OTM Put: 52.5, ATM Put: 54.5, ATM Call: 54.5, OTM Call: 56.5,                     left wing: 2.0, right wing: 2.0
# date: 2019-02-06 00:00:00
# date: 2019-02-06 00:00:00, current_spot_open: 54.5, OTM Put: 49.5, ATM Put: 54.5, ATM Call: 54.5, OTM Call: 55.5,                     left wing: 5.0, right wing: 1.0
# date: 2019-02-19 00:00:00
# date: 2019-02-19 00:00:00, current_spot_open: 56.0, OTM Put: 54.0, ATM Put: 56.0, ATM Call: 56.0, OTM Call: 57.0,                     left wing: 2.0, right wing: 1.0
# date: 2019-03-18 00:00:00
# date: 2019-03-18 00:00:00, current_spot_open: 58.0, OTM Put: 56.0, ATM Put: 58.0, ATM Call: 58.0, OTM Call: 59.0,                     left wing: 2.0, right wing: 1.0
# date: 2019-04-15 00:00:00
# date: 2019-04-15 00:00:00, current_spot_open: 58.5, OTM Put: 57.0, ATM Put: 58.5, ATM Call: 58.5, OTM Call: 59.5,                     left wing: 1.5, right wing: 1.0
# date: 2019-06-04 00:00:00
# date: 2019-06-04 00:00:00, current_spot_open: 59.0, OTM Put: 57.5, ATM Put: 59.0, ATM Call: 59.0, OTM Call: 60.0,                     left wing: 1.5, right wing: 1.0
# date: 2019-06-21 00:00:00
# date: 2019-06-21 00:00:00, current_spot_open: 60.5, OTM Put: 51.5, ATM Put: 60.5, ATM Call: 60.5, OTM Call: 61.5,                     left wing: 9.0, right wing: 1.0
# date: 2019-07-26 00:00:00
# date: 2019-07-26 00:00:00, current_spot_open: 60.0, OTM Put: 58.0, ATM Put: 60.0, ATM Call: 60.0, OTM Call: 61.0,                     left wing: 2.0, right wing: 1.0
# date: 2019-09-20 00:00:00
# date: 2019-09-20 00:00:00, current_spot_open: 63.5, OTM Put: 55.0, ATM Put: 63.5, ATM Call: 63.5, OTM Call: 64.5,                     left wing: 8.5, right wing: 1.0
# date: 2019-10-01 00:00:00
# date: 2019-10-01 00:00:00, current_spot_open: 64.5, OTM Put: 62.0, ATM Put: 64.5, ATM Call: 64.5, OTM Call: 65.5,                     left wing: 2.5, right wing: 1.0
# date: 2019-11-29 00:00:00
# date: 2019-11-29 00:00:00, current_spot_open: 63.0, OTM Put: 61.0, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 64.0,                     left wing: 2.0, right wing: 1.0
# date: 2019-12-11 00:00:00
# date: 2019-12-11 00:00:00, current_spot_open: 63.0, OTM Put: 62.0, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 63.5,                     left wing: 1.0, right wing: 0.5
# date: 2020-01-31 00:00:00
# date: 2020-01-31 00:00:00, current_spot_open: 69.0, OTM Put: 66.5, ATM Put: 69.0, ATM Call: 69.0, OTM Call: 70.5,                     left wing: 2.5, right wing: 1.5
# date: 2020-02-26 00:00:00
# date: 2020-02-26 00:00:00, current_spot_open: 68.0, OTM Put: 66.0, ATM Put: 68.0, ATM Call: 68.0, OTM Call: 70.0,                     left wing: 2.0, right wing: 2.0
# date: 2020-03-13 00:00:00
# date: 2020-03-13 00:00:00, current_spot_open: 58.0, OTM Put: 45.0, ATM Put: 58.0, ATM Call: 58.0, OTM Call: 68.0,                     left wing: 13.0, right wing: 10.0
# date: 2020-04-14 00:00:00
# date: 2020-04-14 00:00:00, current_spot_open: 60.0, OTM Put: 49.0, ATM Put: 60.0, ATM Call: 60.0, OTM Call: 63.0,                     left wing: 11.0, right wing: 3.0
# date: 2020-04-17 00:00:00
# date: 2020-04-17 00:00:00, current_spot_open: 60.0, OTM Put: 49.0, ATM Put: 60.0, ATM Call: 60.0, OTM Call: 63.5,                     left wing: 11.0, right wing: 3.5
# date: 2020-06-03 00:00:00
# date: 2020-06-03 00:00:00, current_spot_open: 61.0, OTM Put: 30.0, ATM Put: 61.0, ATM Call: 61.0, OTM Call: 62.5,                     left wing: 31.0, right wing: 1.5
# date: 2020-06-10 00:00:00
# date: 2020-06-10 00:00:00, current_spot_open: 61.5, OTM Put: 58.5, ATM Put: 61.5, ATM Call: 61.5, OTM Call: 64.0,                     left wing: 3.0, right wing: 2.5
# date: 2020-08-17 00:00:00
# date: 2020-08-17 00:00:00, current_spot_open: 60.5, OTM Put: 58.0, ATM Put: 60.5, ATM Call: 60.5, OTM Call: 62.0,                     left wing: 2.5, right wing: 1.5
# date: 2020-09-29 00:00:00
# date: 2020-09-29 00:00:00, current_spot_open: 59.0, OTM Put: 56.5, ATM Put: 59.0, ATM Call: 59.0, OTM Call: 60.5,                     left wing: 2.5, right wing: 1.5
# date: 2020-10-28 00:00:00
# date: 2020-10-28 00:00:00, current_spot_open: 64.0, OTM Put: 60.5, ATM Put: 64.0, ATM Call: 64.0, OTM Call: 67.5,                     left wing: 3.5, right wing: 3.5
# date: 2020-11-27 00:00:00
# date: 2020-11-27 00:00:00, current_spot_open: 64.5, OTM Put: 62.0, ATM Put: 64.5, ATM Call: 64.5, OTM Call: 67.5,                     left wing: 2.5, right wing: 3.0
# date: 2020-12-11 00:00:00
# date: 2020-12-11 00:00:00, current_spot_open: 62.0, OTM Put: 59.5, ATM Put: 62.0, ATM Call: 62.0, OTM Call: 67.5,                     left wing: 2.5, right wing: 5.5
# date: 2020-12-30 00:00:00
# date: 2020-12-30 00:00:00, current_spot_open: 61.5, OTM Put: 56.0, ATM Put: 61.5, ATM Call: 61.5, OTM Call: 62.5,                     left wing: 5.5, right wing: 1.0
# date: 2020-12-31 00:00:00
# date: 2020-12-31 00:00:00, current_spot_open: 62.0, OTM Put: 45.0, ATM Put: 62.0, ATM Call: 62.0, OTM Call: 63.0,                     left wing: 17.0, right wing: 1.0
# date: 2021-01-22 00:00:00
# date: 2021-01-22 00:00:00, current_spot_open: 62.5, OTM Put: 57.5, ATM Put: 62.5, ATM Call: 62.5, OTM Call: 64.0,                     left wing: 5.0, right wing: 1.5
# date: 2021-02-09 00:00:00
# date: 2021-02-09 00:00:00, current_spot_open: 63.0, OTM Put: 59.5, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 64.0,                     left wing: 3.5, right wing: 1.0
# date: 2021-04-09 00:00:00
# date: 2021-04-09 00:00:00, current_spot_open: 65.0, OTM Put: 62.5, ATM Put: 65.0, ATM Call: 65.0, OTM Call: 71.0,                     left wing: 2.5, right wing: 6.0
# date: 2021-06-02 00:00:00
# date: 2021-06-02 00:00:00, current_spot_open: 65.0, OTM Put: 63.0, ATM Put: 65.0, ATM Call: 65.0, OTM Call: 66.0,                     left wing: 2.0, right wing: 1.0
# date: 2021-06-15 00:00:00
# date: 2021-06-15 00:00:00, current_spot_open: 66.5, OTM Put: 65.0, ATM Put: 66.5, ATM Call: 66.5, OTM Call: 67.5,                     left wing: 1.5, right wing: 1.0
# date: 2021-07-12 00:00:00
# date: 2021-07-12 00:00:00, current_spot_open: 64.5, OTM Put: 56.5, ATM Put: 64.5, ATM Call: 64.5, OTM Call: 65.5,                     left wing: 8.0, right wing: 1.0
# date: 2021-08-03 00:00:00
# date: 2021-08-03 00:00:00, current_spot_open: 66.5, OTM Put: 58.5, ATM Put: 66.5, ATM Call: 66.5, OTM Call: 70.0,                     left wing: 8.0, right wing: 3.5
# date: 2021-09-17 00:00:00
# date: 2021-09-17 00:00:00, current_spot_open: 67.5, OTM Put: 65.5, ATM Put: 67.5, ATM Call: 67.5, OTM Call: 75.0,                     left wing: 2.0, right wing: 7.5
# date: 2021-10-27 00:00:00
# date: 2021-10-27 00:00:00, current_spot_open: 67.5, OTM Put: 66.0, ATM Put: 67.5, ATM Call: 67.5, OTM Call: 70.0,                     left wing: 1.5, right wing: 2.5
# date: 2021-10-29 00:00:00
# date: 2021-10-29 00:00:00, current_spot_open: 67.5, OTM Put: 65.5, ATM Put: 67.5, ATM Call: 67.5, OTM Call: 69.5,                     left wing: 2.0, right wing: 2.0
# date: 2021-11-29 00:00:00
# date: 2021-11-29 00:00:00, current_spot_open: 67.5, OTM Put: 61.0, ATM Put: 67.5, ATM Call: 67.5, OTM Call: 69.0,                     left wing: 6.5, right wing: 1.5
# date: 2021-12-31 00:00:00
# date: 2021-12-31 00:00:00, current_spot_open: 71.0, OTM Put: 50.0, ATM Put: 71.0, ATM Call: 71.0, OTM Call: 72.5,                     left wing: 21.0, right wing: 1.5
# date: 2022-01-24 00:00:00
# date: 2022-01-24 00:00:00, current_spot_open: 69.0, OTM Put: 66.0, ATM Put: 69.0, ATM Call: 69.0, OTM Call: 72.5,                     left wing: 3.0, right wing: 3.5
# date: 2022-03-22 00:00:00
# date: 2022-03-22 00:00:00, current_spot_open: 71.0, OTM Put: 68.0, ATM Put: 71.0, ATM Call: 71.0, OTM Call: 72.5,                     left wing: 3.0, right wing: 1.5
# date: 2022-03-29 00:00:00
# date: 2022-03-29 00:00:00, current_spot_open: 73.0, OTM Put: 50.0, ATM Put: 73.0, ATM Call: 73.0, OTM Call: 74.5,                     left wing: 23.0, right wing: 1.5
# date: 2022-04-22 00:00:00
# date: 2022-04-22 00:00:00, current_spot_open: 75.5, OTM Put: 72.0, ATM Put: 75.5, ATM Call: 75.5, OTM Call: 79.0,                     left wing: 3.5, right wing: 3.5
# date: 2022-08-19 00:00:00
# Error: 2022-08-19 00:00:00, P
# Error: 2022-08-19 00:00:00, C
# date: 2022-09-23 00:00:00
# date: 2022-09-23 00:00:00, current_spot_open: 72.0, OTM Put: 67.0, ATM Put: 72.0, ATM Call: 72.0, OTM Call: 75.0,                     left wing: 5.0, right wing: 3.0
# date: 2022-11-01 00:00:00
# date: 2022-11-01 00:00:00, current_spot_open: 67.0, OTM Put: 62.5, ATM Put: 67.0, ATM Call: 67.0, OTM Call: 69.5,                     left wing: 4.5, right wing: 2.5
# date: 2022-11-04 00:00:00
# date: 2022-11-04 00:00:00, current_spot_open: 67.0, OTM Put: 62.0, ATM Put: 67.0, ATM Call: 67.0, OTM Call: 69.5,                     left wing: 5.0, right wing: 2.5
# date: 2022-11-25 00:00:00
# date: 2022-11-25 00:00:00, current_spot_open: 71.0, OTM Put: 67.0, ATM Put: 71.0, ATM Call: 71.0, OTM Call: 73.0,                     left wing: 4.0, right wing: 2.0
# date: 2022-12-09 00:00:00
# date: 2022-12-09 00:00:00, current_spot_open: 71.0, OTM Put: 67.5, ATM Put: 71.0, ATM Call: 71.0, OTM Call: 73.5,                     left wing: 3.5, right wing: 2.5
# date: 2022-12-30 00:00:00
# date: 2022-12-30 00:00:00, current_spot_open: 71.0, OTM Put: 67.5, ATM Put: 71.0, ATM Call: 71.0, OTM Call: 73.5,                     left wing: 3.5, right wing: 2.5
# date: 2023-01-27 00:00:00
# date: 2023-01-27 00:00:00, current_spot_open: 68.5, OTM Put: 57.0, ATM Put: 68.5, ATM Call: 68.5, OTM Call: 70.5,                     left wing: 11.5, right wing: 2.0
# date: 2023-04-12 00:00:00
# date: 2023-04-12 00:00:00, current_spot_open: 70.0, OTM Put: 67.5, ATM Put: 70.0, ATM Call: 70.0, OTM Call: 71.5,                     left wing: 2.5, right wing: 1.5
# date: 2023-04-24 00:00:00
# date: 2023-04-24 00:00:00, current_spot_open: 69.5, OTM Put: 50.0, ATM Put: 69.5, ATM Call: 69.5, OTM Call: 71.0,                     left wing: 19.5, right wing: 1.5
# date: 2023-05-24 00:00:00
# date: 2023-05-24 00:00:00, current_spot_open: 66.0, OTM Put: 64.0, ATM Put: 66.0, ATM Call: 66.0, OTM Call: 80.0,                     left wing: 2.0, right wing: 14.0
# date: 2023-06-16 00:00:00
# date: 2023-06-16 00:00:00, current_spot_open: 67.0, OTM Put: 63.5, ATM Put: 67.0, ATM Call: 67.0, OTM Call: 68.0,                     left wing: 3.5, right wing: 1.0
# date: 2023-07-14 00:00:00
# date: 2023-07-14 00:00:00, current_spot_open: 67.0, OTM Put: 64.5, ATM Put: 67.0, ATM Call: 67.0, OTM Call: 68.5,                     left wing: 2.5, right wing: 1.5
# date: 2023-08-02 00:00:00
# date: 2023-08-02 00:00:00, current_spot_open: 66.0, OTM Put: 61.0, ATM Put: 66.0, ATM Call: 66.0, OTM Call: 67.5,                     left wing: 5.0, right wing: 1.5
# date: 2023-08-18 00:00:00
# date: 2023-08-18 00:00:00, current_spot_open: 63.0, OTM Put: 55.0, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 64.5,                     left wing: 8.0, right wing: 1.5
# Processing date: 2016-10-28 00:00:00, expiry: 2016-11-11 00:00:00
# Expiry date 2016-11-11 00:00:00 not found; finding closest available date.
# Using adjusted expiry date: 2016-11-10 00:00:00
# Closing on date: 2016-11-02 00:00:00
# strike1: 46.0, strike2: 48.5, strike3: 48.5, strike4: 51.5
# Long put sellback: 0.16
# Short put buyback: 0.97
# Short call buyback: 0.45
# Long call sellback: 0.0
# Closing cost: -1.26
# Close iron condor early on date: 2016-11-02 00:00:00 when signal is -1, pnl: 1.2299981689453126
# Processing date: 2016-12-09 00:00:00, expiry: 2016-12-23 00:00:00
# Let iron condor expire: 2016-12-23 00:00:00, pnl: 0.010000000000000064
# Processing date: 2016-12-23 00:00:00, expiry: 2017-01-06 00:00:00
# Let iron condor expire: 2017-01-06 00:00:00, pnl: 0.3699981689453125
# Processing date: 2017-01-18 00:00:00, expiry: 2017-01-27 00:00:00
# Let iron condor expire: 2017-01-27 00:00:00, pnl: 0.029999389648437513
# Processing date: 2017-01-25 00:00:00, expiry: 2017-02-03 00:00:00
# Closing on date: 2017-02-03 00:00:00
# strike1: 40.5, strike2: 48.0, strike3: 48.0, strike4: 49.0
# Long put sellback: 0.0
# Short put buyback: 0.22
# Short call buyback: 1.13
# Long call sellback: 0.46
# Closing cost: -0.8899999999999999
# Close iron condor early on date: 2017-02-03 00:00:00 when signal is -1, pnl: 0.6999984741210937
# Processing date: 2017-01-27 00:00:00, expiry: 2017-02-10 00:00:00
# Closing on date: 2017-02-03 00:00:00
# strike1: 47.0, strike2: 48.5, strike3: 48.5, strike4: 49.5
# Long put sellback: 0.08
# Short put buyback: 0.36
# Short call buyback: 0.76
# Long call sellback: 0.26
# Closing cost: -0.78
# Close iron condor early on date: 2017-02-03 00:00:00 when signal is -1, pnl: 0.9999984741210938
# Processing date: 2017-02-17 00:00:00, expiry: 2017-03-03 00:00:00
# Closing on date: 2017-03-03 00:00:00
# strike1: 47.5, strike2: 49.5, strike3: 49.5, strike4: 50.5
# Long put sellback: 0.02
# Short put buyback: 0.15
# Short call buyback: 2.08
# Long call sellback: 1.19
# Closing cost: -1.02
# Close iron condor early on date: 2017-03-03 00:00:00 when signal is -1, pnl: 0.7
# Processing date: 2017-03-07 00:00:00, expiry: 2017-03-17 00:00:00
# Closing on date: 2017-03-17 00:00:00
# strike1: 50.5, strike2: 51.5, strike3: 51.5, strike4: 52.5
# Long put sellback: 0.2
# Short put buyback: 0.62
# Short call buyback: 0.35
# Long call sellback: 0.07
# Closing cost: -0.7
# Close iron condor early on date: 2017-03-17 00:00:00 when signal is -1, pnl: 1.149999542236328
# Processing date: 2017-03-14 00:00:00, expiry: 2017-03-24 00:00:00
# Closing on date: 2017-03-17 00:00:00
# strike1: 49.5, strike2: 51.0, strike3: 51.0, strike4: 51.5
# Long put sellback: 0.06
# Short put buyback: 0.37
# Short call buyback: 0.61
# Long call sellback: 0.33
# Closing cost: -0.5899999999999999
# Close iron condor early on date: 2017-03-17 00:00:00 when signal is -1, pnl: 1.0400004577636717
# Processing date: 2017-04-03 00:00:00, expiry: 2017-04-13 00:00:00
# Let iron condor expire: 2017-04-13 00:00:00, pnl: 0.5099996948242188
# Processing date: 2017-04-19 00:00:00, expiry: 2017-04-28 00:00:00
# Let iron condor expire: 2017-04-28 00:00:00, pnl: 0.36000076293945316
# Processing date: 2017-05-16 00:00:00, expiry: 2017-05-26 00:00:00
# Closing on date: 2017-05-18 00:00:00
# strike1: 51.0, strike2: 52.0, strike3: 52.0, strike4: 58.5
# Long put sellback: 0.08
# Short put buyback: 0.39
# Short call buyback: 0.33
# Long call sellback: 0.0
# Closing cost: -0.64
# Close iron condor early on date: 2017-05-18 00:00:00 when signal is -1, pnl: 1.1100010681152344
# Processing date: 2017-06-07 00:00:00, expiry: 2017-06-16 00:00:00
# Let iron condor expire: 2017-06-16 00:00:00, pnl: 0.4799993896484375
# Processing date: 2017-07-19 00:00:00, expiry: 2017-07-28 00:00:00
# Closing on date: 2017-07-27 00:00:00
# strike1: 51.0, strike2: 52.5, strike3: 52.5, strike4: 53.0
# Long put sellback: 0.02
# Short put buyback: 0.15
# Short call buyback: 0.73
# Long call sellback: 0.37
# Closing cost: -0.49
# Close iron condor early on date: 2017-07-27 00:00:00 when signal is -1, pnl: 0.43
# Processing date: 2017-08-28 00:00:00, expiry: 2017-09-08 00:00:00
# Let iron condor expire: 2017-09-08 00:00:00, pnl: 0.3300006103515625
# Processing date: 2017-10-09 00:00:00, expiry: 2017-10-20 00:00:00
# Let iron condor expire: 2017-10-20 00:00:00, pnl: -0.3500000000000001
# Processing date: 2017-10-23 00:00:00, expiry: 2017-11-03 00:00:00
# Let iron condor expire: 2017-11-03 00:00:00, pnl: 0.44000091552734377
# Processing date: 2017-10-27 00:00:00, expiry: 2017-11-10 00:00:00
# Closing on date: 2017-11-08 00:00:00
# strike1: 45.5, strike2: 54.5, strike3: 54.5, strike4: 55.5
# Long put sellback: 0.0
# Short put buyback: 0.07
# Short call buyback: 1.27
# Long call sellback: 0.44
# Closing cost: -0.9000000000000001
# Close iron condor early on date: 2017-11-08 00:00:00 when signal is -1, pnl: 0.5900000000000001
# Processing date: 2017-11-29 00:00:00, expiry: 2017-12-08 00:00:00
# Let iron condor expire: 2017-12-08 00:00:00, pnl: 0.28999893188476566
# Processing date: 2018-01-31 00:00:00, expiry: 2018-02-09 00:00:00
# Closing on date: 2018-02-02 00:00:00
# strike1: 44.0, strike2: 50.5, strike3: 50.5, strike4: 51.5
# Long put sellback: 0.01
# Short put buyback: 0.95
# Short call buyback: 0.37
# Long call sellback: 0.11
# Closing cost: -1.2
# Close iron condor early on date: 2018-02-02 00:00:00 when signal is -1, pnl: 1.310001068115234
# Processing date: 2018-02-27 00:00:00, expiry: 2018-03-09 00:00:00
# Let iron condor expire: 2018-03-09 00:00:00, pnl: 0.29000152587890626
# Processing date: 2018-03-13 00:00:00, expiry: 2018-03-23 00:00:00
# Let iron condor expire: 2018-03-23 00:00:00, pnl: -0.14999862670898437
# Processing date: 2018-03-16 00:00:00, expiry: 2018-03-29 00:00:00
# Let iron condor expire: 2018-03-29 00:00:00, pnl: 0.24000122070312493
# Processing date: 2018-04-06 00:00:00, expiry: 2018-04-20 00:00:00
# Let iron condor expire: 2018-04-20 00:00:00, pnl: 0.23999923706054685
# Processing date: 2018-04-23 00:00:00, expiry: 2018-05-04 00:00:00
# Let iron condor expire: 2018-05-04 00:00:00, pnl: -0.29000000000000015
# Processing date: 2018-05-04 00:00:00, expiry: 2018-05-18 00:00:00
# Closing on date: 2018-05-09 00:00:00
# strike1: 49.5, strike2: 51.5, strike3: 51.5, strike4: 52.5
# Long put sellback: 0.4
# Short put buyback: 1.91
# Short call buyback: 0.03
# Long call sellback: 0.0
# Closing cost: -1.5399999999999998
# Close iron condor early on date: 2018-05-09 00:00:00 when signal is -1, pnl: 0.44000061035156235
# Processing date: 2018-06-13 00:00:00, expiry: 2018-06-22 00:00:00
# Let iron condor expire: 2018-06-22 00:00:00, pnl: -0.33000000000000007
# Processing date: 2018-07-31 00:00:00, expiry: 2018-08-10 00:00:00
# Let iron condor expire: 2018-08-10 00:00:00, pnl: 0.2899983215332031
# Processing date: 2018-08-31 00:00:00, expiry: 2018-09-14 00:00:00
# Closing on date: 2018-09-06 00:00:00
# strike1: 52.5, strike2: 54.0, strike3: 54.0, strike4: 57.0
# Long put sellback: 0.0
# Short put buyback: 0.15
# Short call buyback: 0.91
# Long call sellback: 0.0
# Closing cost: -1.06
# Close iron condor early on date: 2018-09-06 00:00:00 when signal is -1, pnl: 1.0599995422363282
# Processing date: 2018-10-23 00:00:00, expiry: 2018-11-02 00:00:00
# Closing on date: 2018-10-25 00:00:00
# strike1: 53.0, strike2: 54.5, strike3: 54.5, strike4: 56.0
# Long put sellback: 0.17
# Short put buyback: 0.66
# Short call buyback: 0.55
# Long call sellback: 0.09
# Closing cost: -0.9500000000000001
# Close iron condor early on date: 2018-10-25 00:00:00 when signal is -1, pnl: 1.6799989318847657
# Processing date: 2018-11-09 00:00:00, expiry: 2018-11-23 00:00:00
# Let iron condor expire: 2018-11-23 00:00:00, pnl: 0.45000061035156247
# Processing date: 2018-12-03 00:00:00, expiry: 2018-12-14 00:00:00
# Let iron condor expire: 2018-12-14 00:00:00, pnl: -0.20999999999999996
# Processing date: 2018-12-10 00:00:00, expiry: 2018-12-21 00:00:00
# Let iron condor expire: 2018-12-21 00:00:00, pnl: -0.8699999999999998
# Processing date: 2018-12-14 00:00:00, expiry: 2018-12-28 00:00:00
# Let iron condor expire: 2018-12-28 00:00:00, pnl: -0.6099999999999997
# Processing date: 2018-12-21 00:00:00, expiry: 2019-01-04 00:00:00
# Closing on date: 2019-01-03 00:00:00
# strike1: 52.5, strike2: 54.5, strike3: 54.5, strike4: 56.5
# Long put sellback: 0.83
# Short put buyback: 2.42
# Short call buyback: 0.07
# Long call sellback: 0.0
# Closing cost: -1.66
# Close iron condor early on date: 2019-01-03 00:00:00 when signal is -1, pnl: 0.7899999999999998
# Processing date: 2019-02-06 00:00:00, expiry: 2019-02-15 00:00:00
# Let iron condor expire: 2019-02-15 00:00:00, pnl: -0.28
# Processing date: 2019-02-19 00:00:00, expiry: 2019-03-01 00:00:00
# Let iron condor expire: 2019-03-01 00:00:00, pnl: -0.26
# Processing date: 2019-03-18 00:00:00, expiry: 2019-03-29 00:00:00
# Closing on date: 2019-03-22 00:00:00
# strike1: 56.0, strike2: 58.0, strike3: 58.0, strike4: 59.0
# Long put sellback: 0.06
# Short put buyback: 0.39
# Short call buyback: 0.92
# Long call sellback: 0.34
# Closing cost: -0.9099999999999999
# Close iron condor early on date: 2019-03-22 00:00:00 when signal is -1, pnl: 1.149998321533203
# Processing date: 2019-04-15 00:00:00, expiry: 2019-04-26 00:00:00
# Let iron condor expire: 2019-04-26 00:00:00, pnl: 0.2499984741210938
# Processing date: 2019-06-04 00:00:00, expiry: 2019-06-14 00:00:00
# Closing on date: 2019-06-06 00:00:00
# strike1: 57.5, strike2: 59.0, strike3: 59.0, strike4: 60.0
# Long put sellback: 0.01
# Short put buyback: 0.1
# Short call buyback: 1.63
# Long call sellback: 0.78
# Closing cost: -0.94
# Close iron condor early on date: 2019-06-06 00:00:00 when signal is -1, pnl: 0.6699999999999999
# Processing date: 2019-06-21 00:00:00, expiry: 2019-07-05 00:00:00
# Let iron condor expire: 2019-07-05 00:00:00, pnl: 0.6699996948242188
# Processing date: 2019-07-26 00:00:00, expiry: 2019-08-09 00:00:00
# Let iron condor expire: 2019-08-09 00:00:00, pnl: -0.02999893188476549
# Processing date: 2019-09-20 00:00:00, expiry: 2019-10-04 00:00:00
# Let iron condor expire: 2019-10-04 00:00:00, pnl: -0.16999999999999993
# Processing date: 2019-10-01 00:00:00, expiry: 2019-10-11 00:00:00
# Let iron condor expire: 2019-10-11 00:00:00, pnl: 0.24999816894531246
# Processing date: 2019-11-29 00:00:00, expiry: 2019-12-13 00:00:00
# Let iron condor expire: 2019-12-13 00:00:00, pnl: 0.3900010681152344
# Processing date: 2019-12-11 00:00:00, expiry: 2019-12-20 00:00:00
# Closing on date: 2019-12-17 00:00:00
# strike1: 62.0, strike2: 63.0, strike3: 63.0, strike4: 63.5
# Long put sellback: 0.04
# Short put buyback: 0.14
# Short call buyback: 1.43
# Long call sellback: 0.92
# Closing cost: -0.61
# Close iron condor early on date: 2019-12-17 00:00:00 when signal is -1, pnl: 0.6900000000000001
# Processing date: 2020-01-31 00:00:00, expiry: 2020-02-14 00:00:00
# Closing on date: 2020-02-05 00:00:00
# strike1: 66.5, strike2: 69.0, strike3: 69.0, strike4: 70.5
# Long put sellback: 0.04
# Short put buyback: 0.63
# Short call buyback: 0.37
# Long call sellback: 0.03
# Closing cost: -0.9299999999999999
# Close iron condor early on date: 2020-02-05 00:00:00 when signal is -1, pnl: 1.7200009155273437
# Processing date: 2020-02-26 00:00:00, expiry: 2020-03-06 00:00:00
# Closing on date: 2020-03-02 00:00:00
# strike1: 66.0, strike2: 68.0, strike3: 68.0, strike4: 70.0
# Long put sellback: 1.31
# Short put buyback: 2.58
# Short call buyback: 0.38
# Long call sellback: 0.02
# Closing cost: -1.63
# Close iron condor early on date: 2020-03-02 00:00:00 when signal is -1, pnl: 0.7699999999999998
# Processing date: 2020-03-13 00:00:00, expiry: 2020-03-27 00:00:00
# Closing on date: 2020-03-18 00:00:00
# strike1: 45.0, strike2: 58.0, strike3: 58.0, strike4: 68.0
# Long put sellback: 0.49
# Short put buyback: 5.5
# Short call buyback: 1.46
# Long call sellback: 0.0
# Closing cost: -6.47
# Close iron condor early on date: 2020-03-18 00:00:00 when signal is -1, pnl: 5.960001525878907
# Processing date: 2020-04-14 00:00:00, expiry: 2020-04-24 00:00:00
# Let iron condor expire: 2020-04-24 00:00:00, pnl: 0.9599996948242187
# Processing date: 2020-04-17 00:00:00, expiry: 2020-05-01 00:00:00
# Let iron condor expire: 2020-05-01 00:00:00, pnl: -1.4799989318847664
# Processing date: 2020-06-03 00:00:00, expiry: 2020-06-12 00:00:00
# Let iron condor expire: 2020-06-12 00:00:00, pnl: -1.0400018310546877
# Processing date: 2020-06-10 00:00:00, expiry: 2020-06-19 00:00:00
# Let iron condor expire: 2020-06-19 00:00:00, pnl: -1.5899999999999999
# Processing date: 2020-08-17 00:00:00, expiry: 2020-08-28 00:00:00
# Let iron condor expire: 2020-08-28 00:00:00, pnl: -0.3800003051757813
# Processing date: 2020-09-29 00:00:00, expiry: 2020-10-09 00:00:00
# Closing on date: 2020-10-07 00:00:00
# strike1: 56.5, strike2: 59.0, strike3: 59.0, strike4: 60.5
# Long put sellback: 0.0
# Short put buyback: 0.05
# Short call buyback: 3.55
# Long call sellback: 2.01
# Closing cost: -1.5899999999999999
# Close iron condor early on date: 2020-10-07 00:00:00 when signal is -1, pnl: 1.04
# Processing date: 2020-10-28 00:00:00, expiry: 2020-11-06 00:00:00
# Closing on date: 2020-11-05 00:00:00
# strike1: 60.5, strike2: 64.0, strike3: 64.0, strike4: 67.5
# Long put sellback: 0.05
# Short put buyback: 0.75
# Short call buyback: 1.06
# Long call sellback: 0.01
# Closing cost: -1.75
# Close iron condor early on date: 2020-11-05 00:00:00 when signal is -1, pnl: 3.270003356933594
# Processing date: 2020-11-27 00:00:00, expiry: 2020-12-11 00:00:00
# Let iron condor expire: 2020-12-11 00:00:00, pnl: -0.9199983215332033
# Processing date: 2020-12-11 00:00:00, expiry: 2020-12-24 00:00:00
# Let iron condor expire: 2020-12-24 00:00:00, pnl: -1.3000009155273435
# Processing date: 2020-12-30 00:00:00, expiry: 2021-01-08 00:00:00
# Closing on date: 2021-01-07 00:00:00
# strike1: 56.0, strike2: 61.5, strike3: 61.5, strike4: 62.5
# Long put sellback: 0.03
# Short put buyback: 0.48
# Short call buyback: 0.82
# Long call sellback: 0.33
# Closing cost: -0.94
# Close iron condor early on date: 2021-01-07 00:00:00 when signal is -1, pnl: 1.5299986267089842
# Processing date: 2020-12-31 00:00:00, expiry: 2021-01-08 00:00:00
# Closing on date: 2021-01-07 00:00:00
# strike1: 45.0, strike2: 62.0, strike3: 62.0, strike4: 63.0
# Long put sellback: 0.0
# Short put buyback: 0.7
# Short call buyback: 0.54
# Long call sellback: 0.23
# Closing cost: -1.01
# Close iron condor early on date: 2021-01-07 00:00:00 when signal is -1, pnl: 1.7000013732910157
# Processing date: 2021-01-22 00:00:00, expiry: 2021-02-05 00:00:00
# Closing on date: 2021-01-28 00:00:00
# strike1: 57.5, strike2: 62.5, strike3: 62.5, strike4: 64.0
# Long put sellback: 0.03
# Short put buyback: 0.77
# Short call buyback: 0.87
# Long call sellback: 0.17
# Closing cost: -1.44
# Close iron condor early on date: 2021-01-28 00:00:00 when signal is -1, pnl: 2.610001678466797
# Processing date: 2021-02-09 00:00:00, expiry: 2021-02-19 00:00:00
# Let iron condor expire: 2021-02-19 00:00:00, pnl: -0.7500001525878907
# Processing date: 2021-04-09 00:00:00, expiry: 2021-04-23 00:00:00
# Let iron condor expire: 2021-04-23 00:00:00, pnl: -1.4200018310546874
# Processing date: 2021-06-02 00:00:00, expiry: 2021-06-11 00:00:00
# Let iron condor expire: 2021-06-11 00:00:00, pnl: -0.24
# Processing date: 2021-06-15 00:00:00, expiry: 2021-06-25 00:00:00
# Closing on date: 2021-06-23 00:00:00
# strike1: 65.0, strike2: 66.5, strike3: 66.5, strike4: 67.5
# Long put sellback: 1.4
# Short put buyback: 3.2
# Short call buyback: 0.03
# Long call sellback: 0.0
# Closing cost: -1.8300000000000003
# Close iron condor early on date: 2021-06-23 00:00:00 when signal is -1, pnl: 1.1500000000000004
# Processing date: 2021-07-12 00:00:00, expiry: 2021-07-23 00:00:00
# Closing on date: 2021-07-22 00:00:00
# strike1: 56.5, strike2: 64.5, strike3: 64.5, strike4: 65.5
# Long put sellback: 0.02
# Short put buyback: 0.43
# Short call buyback: 0.87
# Long call sellback: 0.29
# Closing cost: -0.99
# Close iron condor early on date: 2021-07-22 00:00:00 when signal is -1, pnl: 1.4800027465820313
# Processing date: 2021-08-03 00:00:00, expiry: 2021-08-13 00:00:00
# Let iron condor expire: 2021-08-13 00:00:00, pnl: -3.030000305175781
# Processing date: 2021-09-17 00:00:00, expiry: 2021-10-01 00:00:00
# Closing on date: 2021-09-24 00:00:00
# strike1: 65.5, strike2: 67.5, strike3: 67.5, strike4: 75.0
# Long put sellback: 0.9
# Short put buyback: 2.49
# Short call buyback: 0.09
# Long call sellback: 0.0
# Closing cost: -1.6800000000000004
# Close iron condor early on date: 2021-09-24 00:00:00 when signal is -1, pnl: 0.9500000000000003
# Processing date: 2021-10-27 00:00:00, expiry: 2021-11-05 00:00:00
# Let iron condor expire: 2021-11-05 00:00:00, pnl: 0.5600012207031251
# Processing date: 2021-10-29 00:00:00, expiry: 2021-11-12 00:00:00
# Closing on date: 2021-11-12 00:00:00
# strike1: 65.5, strike2: 67.5, strike3: 67.5, strike4: 69.5
# Long put sellback: 0.24
# Short put buyback: 1.19
# Short call buyback: 0.35
# Long call sellback: 0.01
# Closing cost: -1.2899999999999998
# Close iron condor early on date: 2021-11-12 00:00:00 when signal is -1, pnl: 1.430001525878906
# Processing date: 2021-11-29 00:00:00, expiry: 2021-12-10 00:00:00
# Closing on date: 2021-12-06 00:00:00
# strike1: 61.0, strike2: 67.5, strike3: 67.5, strike4: 69.0
# Long put sellback: 0.04
# Short put buyback: 0.6
# Short call buyback: 1.63
# Long call sellback: 0.66
# Closing cost: -1.5299999999999998
# Close iron condor early on date: 2021-12-06 00:00:00 when signal is -1, pnl: 1.5699996948242185
# Processing date: 2021-12-31 00:00:00, expiry: 2022-01-14 00:00:00
# Closing on date: 2022-01-14 00:00:00
# strike1: 50.0, strike2: 71.0, strike3: 71.0, strike4: 72.5
# Long put sellback: 0.0
# Short put buyback: 1.84
# Short call buyback: 0.27
# Long call sellback: 0.04
# Closing cost: -2.0700000000000003
# Close iron condor early on date: 2022-01-14 00:00:00 when signal is -1, pnl: 1.6400015258789067
# Processing date: 2022-01-24 00:00:00, expiry: 2022-02-04 00:00:00
# Closing on date: 2022-02-02 00:00:00
# strike1: 66.0, strike2: 69.0, strike3: 69.0, strike4: 72.5
# Long put sellback: 0.06
# Short put buyback: 0.64
# Short call buyback: 1.02
# Long call sellback: 0.0
# Closing cost: -1.6
# Close iron condor early on date: 2022-02-02 00:00:00 when signal is -1, pnl: 2.520003662109375
# Processing date: 2022-03-22 00:00:00, expiry: 2022-04-01 00:00:00
# Let iron condor expire: 2022-04-01 00:00:00, pnl: -0.4299999999999997
# Processing date: 2022-03-29 00:00:00, expiry: 2022-04-08 00:00:00
# Closing on date: 2022-04-07 00:00:00
# strike1: 50.0, strike2: 73.0, strike3: 73.0, strike4: 74.5
# Long put sellback: 0.0
# Short put buyback: 0.08
# Short call buyback: 3.9
# Long call sellback: 2.39
# Closing cost: -1.5899999999999999
# Close iron condor early on date: 2022-04-07 00:00:00 when signal is -1, pnl: 1.1400000000000001
# Processing date: 2022-04-22 00:00:00, expiry: 2022-05-06 00:00:00
# Closing on date: 2022-05-04 00:00:00
# strike1: 72.0, strike2: 75.5, strike3: 75.5, strike4: 79.0
# Long put sellback: 0.7
# Short put buyback: 3.3
# Short call buyback: 0.06
# Long call sellback: 0.0
# Closing cost: -2.6599999999999997
# Close iron condor early on date: 2022-05-04 00:00:00 when signal is -1, pnl: 1.3199972534179685
# Processing date: 2022-09-23 00:00:00, expiry: 2022-10-07 00:00:00
# Closing on date: 2022-09-30 00:00:00
# strike1: 67.0, strike2: 72.0, strike3: 72.0, strike4: 75.0
# Long put sellback: 1.97
# Short put buyback: 6.7
# Short call buyback: 0.06
# Long call sellback: 0.0
# Closing cost: -4.79
# Close iron condor early on date: 2022-09-30 00:00:00 when signal is -1, pnl: 1.6800000000000006
# Processing date: 2022-11-01 00:00:00, expiry: 2022-11-11 00:00:00
# Closing on date: 2022-11-11 00:00:00
# strike1: 62.5, strike2: 67.0, strike3: 67.0, strike4: 69.5
# Long put sellback: 0.04
# Short put buyback: 0.74
# Short call buyback: 1.95
# Long call sellback: 0.51
# Closing cost: -2.1399999999999997
# Close iron condor early on date: 2022-11-11 00:00:00 when signal is -1, pnl: 2.8699981689453122
# Processing date: 2022-11-04 00:00:00, expiry: 2022-11-18 00:00:00
# Closing on date: 2022-11-11 00:00:00
# strike1: 62.0, strike2: 67.0, strike3: 67.0, strike4: 69.5
# Long put sellback: 0.03
# Short put buyback: 0.74
# Short call buyback: 1.95
# Long call sellback: 0.51
# Closing cost: -2.1500000000000004
# Close iron condor early on date: 2022-11-11 00:00:00 when signal is -1, pnl: 3.0099981689453132
# Processing date: 2022-11-25 00:00:00, expiry: 2022-12-09 00:00:00
# Let iron condor expire: 2022-12-09 00:00:00, pnl: 1.3500018310546875
# Processing date: 2022-12-09 00:00:00, expiry: 2022-12-23 00:00:00
# Closing on date: 2022-12-13 00:00:00
# strike1: 67.5, strike2: 71.0, strike3: 71.0, strike4: 73.5
# Long put sellback: 0.08
# Short put buyback: 0.57
# Short call buyback: 2.12
# Long call sellback: 0.48
# Closing cost: -2.13
# Close iron condor early on date: 2022-12-13 00:00:00 when signal is -1, pnl: 2.400001831054688
# Processing date: 2022-12-30 00:00:00, expiry: 2023-01-13 00:00:00
# Closing on date: 2023-01-13 00:00:00
# strike1: 67.5, strike2: 71.0, strike3: 71.0, strike4: 73.5
# Long put sellback: 0.07
# Short put buyback: 0.73
# Short call buyback: 1.13
# Long call sellback: 0.15
# Closing cost: -1.64
# Close iron condor early on date: 2023-01-13 00:00:00 when signal is -1, pnl: 3.0099981689453124
# Processing date: 2023-01-27 00:00:00, expiry: 2023-02-10 00:00:00
# Closing on date: 2023-02-10 00:00:00
# strike1: 57.0, strike2: 68.5, strike3: 68.5, strike4: 70.5
# Long put sellback: 0.0
# Short put buyback: 1.37
# Short call buyback: 0.67
# Long call sellback: 0.1
# Closing cost: -1.94
# Close iron condor early on date: 2023-02-10 00:00:00 when signal is -1, pnl: 2.649999084472656
# Processing date: 2023-04-12 00:00:00, expiry: 2023-04-21 00:00:00
# Let iron condor expire: 2023-04-21 00:00:00, pnl: 0.7600027465820313
# Processing date: 2023-04-24 00:00:00, expiry: 2023-05-05 00:00:00
# Let iron condor expire: 2023-05-05 00:00:00, pnl: 0.7699987792968751
# Processing date: 2023-05-24 00:00:00, expiry: 2023-06-02 00:00:00
# Closing on date: 2023-06-02 00:00:00
# strike1: 64.0, strike2: 66.0, strike3: 66.0, strike4: 80.0
# Long put sellback: 0.33
# Short put buyback: 1.21
# Short call buyback: 0.48
# Long call sellback: 0.0
# Closing cost: -1.3599999999999999
# Close iron condor early on date: 2023-06-02 00:00:00 when signal is -1, pnl: 0.780002746582031
# Processing date: 2023-06-16 00:00:00, expiry: 2023-06-30 00:00:00
# Closing on date: 2023-06-29 00:00:00
# strike1: 63.5, strike2: 67.0, strike3: 67.0, strike4: 68.0
# Long put sellback: 0.09
# Short put buyback: 2.28
# Short call buyback: 0.03
# Long call sellback: 0.0
# Closing cost: -2.2199999999999998
# Close iron condor early on date: 2023-06-29 00:00:00 when signal is -1, pnl: 0.9400012207031248
# Processing date: 2023-07-14 00:00:00, expiry: 2023-07-28 00:00:00
# Closing on date: 2023-07-21 00:00:00
# strike1: 64.5, strike2: 67.0, strike3: 67.0, strike4: 68.5
# Long put sellback: 0.06
# Short put buyback: 0.32
# Short call buyback: 1.97
# Long call sellback: 0.88
# Closing cost: -1.35
# Close iron condor early on date: 2023-07-21 00:00:00 when signal is -1, pnl: 0.9600009155273439
# Processing date: 2023-08-02 00:00:00, expiry: 2023-08-11 00:00:00
# Closing on date: 2023-08-04 00:00:00
# strike1: 61.0, strike2: 66.0, strike3: 66.0, strike4: 67.5
# Long put sellback: 0.13
# Short put buyback: 2.15
# Short call buyback: 0.18
# Long call sellback: 0.04
# Closing cost: -2.16
# Close iron condor early on date: 2023-08-04 00:00:00 when signal is -1, pnl: 1.170001678466797
# Processing date: 2023-08-18 00:00:00, expiry: 2023-09-01 00:00:00
# Expiry date 2023-09-01 00:00:00 not found; finding closest available date.
# Using adjusted expiry date: 2023-08-31 00:00:00
# Let iron condor expire: 2023-08-31 00:00:00, pnl: 1.1799990844726562

# %%
pnl_series.cumsum().plot()
# Out:
# <Axes: xlabel='Date'>
