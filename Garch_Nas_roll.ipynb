# %%
#!pip install arch

# %%
from arch import arch_model
import pandas as pd
import wrds
import numpy as np
import yfinance as yf
# Out:
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
db =\
(
    wrds
    .Connection()nasbramlinasbramlinasbramli
)
# Out:
# Enter your WRDS username [nasruddinislambinramli]:nasbramli
# Enter your password:········
# WRDS recommends setting up a .pgpass file.
# Create .pgpass file now [y/n]?: y
# Enter your WRDS username [nasbramli]:nasbramli
# Enter your password:········
# Created .pgpass file successfully.
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done

# %%
fama_french_query =\
(
    """
    SELECT date, mktrf, smb, hml, rf 
    FROM ff.factors_monthly
    WHERE date >= '2000-01-01' AND date < '2024-01-01'
    """
)

# %%
ff_df =\
(
    db
    .raw_sql(fama_french_query)
)

# %%
(
    ff_df
    .to_csv('fama_french.csv', index = False)
)

# %%
fama_french =\
(
    pd
    .read_csv('fama_french.csv')
)

# %%
fama_french["Date"]=\
(
    fama_french
    .date
    .apply(lambda x: str(x)
          )
)

fama_french["Date"]=\
(
    pd
    .to_datetime(fama_french.Date,
                 format="%Y-%m-%d"
                )
)

fama_french =\
(
    fama_french
    .set_index("Date", inplace = False)
)

# %%
russell = {}

for key in key:
    
    data =\
    (
        pd
        .read_hdf('all_tickers_time_series.hf5', 
                  key=key)
    )
    
    if isinstance(data, pd.Series):
        
        data =\
        (
            data
            .to_frame()
        )
        
    data =\
    (
        data
        .drop_duplicates()
    )
    
    data =\
    (
        data
        .dropna()
    )
    
    if isinstance(data, pd.DataFrame) and 'date' in data.columns:
        data['Date'] =\
        (
            pd
            .to_datetime(data['date'], 
                         format="%Y-%m-%d")
        )
        
        data =\
        (
            data
            .drop(columns=['date'])
        )
        
        data =\
        (
            data
            .set_index('Date')
        )
    
    
    russell[key] = data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 russell = {}
# ----> 3 for key in key:
#       5     data =\
#       6     (
#       7         pd
#       8         .read_hdf('all_tickers_time_series.hf5',
#       9                   key=key)
#      10     )
#      12     if isinstance(data, pd.Series):
#
# NameError: name 'key' is not defined

# %%
stock_data = {}

# %%
for ticker, data in russell.items():

    df =\
    (
        pd
        .DataFrame(data)
    )

    print(f"Columns for {ticker}: {df.columns.tolist()}")
    
    if 'prc' in df.columns:
        
        df['returns'] =\
        (
            np.log(df['prc']
                   /
                   df['prc'].shift(1)
                  )
        )
        
        df['r_vol'] =\
        (
            df['returns']
            .rolling(window = 252)
            .std()
            *
            np
            .sqrt
            (252)
        )
        
        
        stock_data[ticker] = df
    else:
        print(f"'prc' column not found for {ticker}. Available columns: {df.columns.tolist()}")

# %%
# Check for duplicates in returns
for ticker, data in stock_data.items():
    
    r_vol =\
    (
        data['r_vol']
    )
    
    # Check for duplicates
    if r_vol.index.duplicated().any():
        
        print(f"Duplicates found in returns for {ticker}. Resolving...")
        
        r_vol =\
        (
            r_vol[~r_vol.index.duplicated(keep='first')]  # Keep the first occurrence
        )
        
    # Check for duplicates in Fama-French factors
    if fama_french.index.duplicated().any():
        
        print("Duplicates found in Fama-French factors. Resolving...")
        
        fama_french =\
        (
            fama_french[~fama_french.index.duplicated(keep='first')]  # Keep the first occurrence
        )

    # Align with Fama-French factors
    aligned_r_vol =\
    (
        r_vol
        .reindex(fama_french.index)
        .dropna()
    )
    
    aligned_factors =\
    (
        fama_french
        .loc[aligned_r_vol.index] # Align factors with returns
    )

    # Now both aligned_returns and aligned_factors have the same index
    print(f"Aligned returns for {ticker}:\n{aligned_r_vol.head()}")
    
    print(f"Aligned Fama-French factors:\n{aligned_factors.head()}")
    
    # Fit the GARCH-X model
    model =\
    (
        arch_model(aligned_r_vol,
                   vol='Garch',
                   p=1, 
                   q=1,
                   x=aligned_factors.values,
                   dist='Normal')
    )
    
    try:
        results =\
        (
            model
            .fit(disp='off')
        )
        
        print(f"Results for {ticker}:")
        
        print(results.summary())
        
    except Exception as e:
        
        print(f"Error fitting GARCH model for {ticker}: {e}")

# %%
for ticker, data in stock_data.items():
    
    r_vol = data['r_vol']
    
    if r_vol.index.duplicated().any():
        print(f"Duplicates found in returns for {ticker}. Resolving...")
        r_vol =\
        (
            r_vol
            [~r_vol.index.duplicated(keep='first')]
        )
    
    if fama_french.index.duplicated().any():
        print("Duplicates found in Fama-French factors. Resolving...")
        fama_french =\
        (
            fama_french
            [~fama_french.index.duplicated(keep='first')]
        )

    r_vol.index =\
    (
        pd
        .to_datetime
        (r_vol.index)
    )
    
    fama_french.index =\
    (
        pd
        .to_datetime
        (fama_french.index)
    )
    
    aligned_factors =\
    (
        pd
        .merge_asof(r_vol.sort_index(), 
                    fama_french.sort_index(), 
                    left_index=True, 
                    right_index=True, 
                    direction='backward')
    )
    
    aligned_factors =\
    (
        aligned_factors
        .dropna()
    )

    aligned_r_vol =\
    (
        r_vol
        .loc
        [aligned_factors.index]
    )

    print(f"Aligned returns for {ticker}:\n{aligned_r_vol.head()}")
    
    print(f"Aligned Fama-French factors:\n{aligned_factors.head()}")
    
    model =\
    (
        arch_model(aligned_r_vol,
                   vol='Garch',
                   p=1, 
                   q=1,
                   x=aligned_factors.values,
                   dist='Normal')
    )
    
    try:
        results =\
        (
            model
            .fit
            (disp='off')
        )
        
        print(f"Results for {ticker}:")
        
        print(results.summary())
        
    except Exception as e:
        
        print(f"Error fitting GARCH model for {ticker}: {e}")

# %%
start= '2000-01-01'
end= '2024-01-01'

# %%
xlu =\
(
    yf
    .download('XLU',
              start, 
              end)
)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
xlu
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2000-01-03  28.937500  28.937500  27.218750  27.453125  11.514972    176700
# 2000-01-04  27.468750  27.468750  26.625000  26.625000  11.167624     93500
# 2000-01-05  27.218750  27.421875  26.859375  27.296875  11.449432    273400
# 2000-01-06  27.250000  27.250000  26.937500  27.250000  11.429774     34500
# 2000-01-07  27.296875  27.484375  27.171875  27.484375  11.528082     46200
# ...               ...        ...        ...        ...        ...       ...
# 2023-12-22  62.639999  63.240002  62.500000  62.619999  61.195446  13223700
# 2023-12-26  62.520000  63.240002  62.500000  63.000000  61.566807   9537500
# 2023-12-27  62.880001  63.080002  62.639999  62.959999  61.527718   9492200
# 2023-12-28  62.759998  63.500000  62.759998  63.410000  61.967476   8673200
# 2023-12-29  63.270000  63.459999  62.910000  63.330002  61.889301  11239000
#
# [6037 rows x 6 columns]

# %%
log_ret=\
(
    np
    .log(xlu
         /xlu.shift(1))
    .dropna()
)

# %%
log_returns =\
(
    log_ret
    ['Adj Close']
)

# %%
log_returns =\
(
    pd
    .Series(log_returns)
)

# %%
figarch_model =\
(
    arch_model(log_returns, 
               vol='FIGARCH',
               p=1,
               q=1)
)

# %%
figarch_result =\
(
    figarch_model.fit()
)
# Out:
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001515. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Iteration:      1,   Func. Count:      7,   Neg. LLF: 113740062884.80727
# Iteration:      2,   Func. Count:     22,   Neg. LLF: 33155.316255762045
# Iteration:      3,   Func. Count:     35,   Neg. LLF: 1.4215891543403696e+19
# Iteration:      4,   Func. Count:     49,   Neg. LLF: 54589356.63239171
# Iteration:      5,   Func. Count:     63,   Neg. LLF: 283662415531722.06
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -19184.40291361946
#             Iterations: 6
#             Function evaluations: 73
#             Gradient evaluations: 5

# %%
print(figarch_result.summary())
# Out:
#                     Constant Mean - FIGARCH Model Results
# ==============================================================================
# Dep. Variable:              Adj Close   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                    FIGARCH   Log-Likelihood:                19184.4
# Distribution:                  Normal   AIC:                          -38358.8
# Method:            Maximum Likelihood   BIC:                          -38325.3
#                                         No. Observations:                 6036
# Date:                Wed, Oct 30 2024   Df Residuals:                     6035
# Time:                        00:25:43   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu         5.2572e-04  9.461e-05      5.557  2.751e-08 [3.403e-04,7.112e-04]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      2.1643e-06  1.236e-10  1.750e+04      0.000 [2.164e-06,2.165e-06]
# phi            0.2000  4.128e-02      4.845  1.267e-06     [  0.119,  0.281]
# d              0.5000  3.606e-02     13.867  1.002e-43     [  0.429,  0.571]
# beta           0.6300  2.485e-02     25.352 8.578e-142     [  0.581,  0.679]
# ============================================================================
#
# Covariance estimator: robust

# %%
predicted_volatility =\
(
    figarch_result
    .conditional_volatility
)

# %%
predicted_volatility
# Out:
# Date
# 2000-01-04    0.016311
# 2000-01-05    0.017750
# 2000-01-06    0.018361
# 2000-01-07    0.018072
# 2000-01-10    0.017717
#                 ...
# 2023-12-22    0.013639
# 2023-12-26    0.013164
# 2023-12-27    0.012568
# 2023-12-28    0.011863
# 2023-12-29    0.011341
# Name: cond_vol, Length: 6036, dtype: float64

# %%
rmse =\
(
    np
    .sqrt(np.mean((log_returns - predicted_volatility) ** 2))
)

# %%
def smape(actual, predicted):
    return 100 * np.mean(np.abs(actual - predicted) / ((np.abs(actual) + np.abs(predicted)) / 2))

# %%
smape_value =\
(
    smape(log_returns, 
          predicted_volatility)
)

# %%
print(rmse)
print(smape_value)
# Out:
# 0.017277039336398417
# 130.489486869027

# %%
garch_model =\
(
    arch_model(log_returns, 
               vol='Garch',
               p=1,
               q=1)
)

# %%
import matplotlib.pyplot as plt

# %%
plt\
    .plot(log_returns, alpha = 0.7, label ='Actual')

plt\
    .plot(predicted_volatility, label = 'Predicted')

plt\
    .grid()

plt\
    .legend()

# %%
log_returns
# Out:
# Date
# 2000-01-04   -0.030629
# 2000-01-05    0.024921
# 2000-01-06   -0.001718
# 2000-01-07    0.008564
# 2000-01-10    0.003405
#                 ...
# 2023-12-22    0.003359
# 2023-12-26    0.006050
# 2023-12-27   -0.000635
# 2023-12-28    0.007122
# 2023-12-29   -0.001262
# Name: Adj Close, Length: 6036, dtype: float64

# %%
rolling_window = 5
predictions = []
model_fits = []

for i in range(rolling_window, len(log_returns)):
    
    model =\
    (
        arch_model(log_returns[i-rolling_window:i],
                   vol='FIGARCH',
                   p=1,
                   q=1)
    )
    
    model_fit =\
    (
        model
        .fit(disp="off")
    )
    
    forecast =\
    (
        model_fit
        .forecast(horizon=1)
    )
    
    date =\
    (
        log_returns
        .index[i]
    )
    
    prediction =\
    (
        forecast
        .variance.values[0][0]
    )
    
    predictions.append((date, prediction))
    model_fits.append(model_fit)
# Out:
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003286. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001415. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 5.77e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 6.548e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 6.345e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 5.089e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 4.642e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.825e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001565. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002326. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003556. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003588. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003533. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 5.146e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0005351. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004178. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004195. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000403. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004024. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.893e-06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 1000 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 7.6e-06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 1000 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 6.446e-06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 1000 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.383e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 6.459e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 7.324e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 6.164e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 5.326e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 4.101e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001971. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001794. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001723. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001914. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001954. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004349. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004684. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0007115. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002854. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001752. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0005592. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0006468. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003446. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000216. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001849. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 4.975e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 2.792e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 2.582e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002457. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002303. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002573. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000256. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004212. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001875. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001678. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002278. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000225. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001344. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001162. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 7.678e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 6.276e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 4.859e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.444e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.291e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.611e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 5.137e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001125. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001066. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001127. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004242. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004595. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002778. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002802. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002893. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001828. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001315. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001584. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003743. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003823. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002758. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002212. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000249. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002239. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002326. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002578. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.324e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 6.436e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 6.649e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001608. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001982. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002023. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002204. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001874. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002056. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001232. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001533. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000219. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002257. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002671. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002682. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# ...
# estimating the model parameters. The scale of y is 3.826e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 4.321e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003815. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003677. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003005. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003032. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.00025. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.115e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 8.866e-06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 1000 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 6.83e-06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 1000 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 6.624e-06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 1000 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.238e-06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 1000 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 2.047e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.972e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 4.16e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 4.887e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 5.92e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 6.803e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 7.333e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 5.011e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 5.257e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 4.326e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002381. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002977. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003791. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003749. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003741. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 9.619e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001103. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 8.864e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001001. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 9.032e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 7.95e-06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 1000 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(

# %%
actual_returns =\
(
    log_returns[rolling_window:]
)

# %%
predictions_df =\
(
    pd
    .DataFrame(predictions,
               columns=['Date',
                        'Predicted'])
)

predictions_df.set_index('Date', inplace=True)

# %%
predictions_df
# Out:
#             Predicted
# Date
# 2000-01-11   0.000021
# 2000-01-12   0.000142
# 2000-01-13   0.000059
# 2000-01-14   0.000065
# 2000-01-18   0.000063
# ...               ...
# 2023-12-22   0.000108
# 2023-12-26   0.000090
# 2023-12-27   0.000100
# 2023-12-28   0.000090
# 2023-12-29   0.000011
#
# [6031 rows x 1 columns]

# %%
predicted_volatility =\
(
    np
    .sqrt(predictions_df) 
)

# %%
prediction_dates =\
(
    actual_returns.index
)

# %%
plt\
    .plot(actual_returns.index,
          actual_returns.values,
          label='Actual')

plt\
    .plot(prediction_dates,
          predicted_volatility,
          label='Rolling Prediction (Volatility)')

plt\
    .grid()

plt\
    .legend()

# %%
predicted_volatility
# Out:
#             Predicted
# Date
# 2000-01-11   0.004570
# 2000-01-12   0.011896
# 2000-01-13   0.007673
# 2000-01-14   0.008091
# 2000-01-18   0.007965
# ...               ...
# 2023-12-22   0.010380
# 2023-12-26   0.009477
# 2023-12-27   0.010005
# 2023-12-28   0.009503
# 2023-12-29   0.003303
#
# [6031 rows x 1 columns]

# %%
roll_smape =\
(
    smape(actual_returns, predicted_volatility['Predicted'])
)

# %%
rmse_roll =\
(
    np.sqrt(np.mean((actual_returns.values - predicted_volatility['Predicted']) ** 2))
)

# %%
print(roll_smape)
print(rmse_roll)
# Out:
# 131.2186755563055
# 0.016714410026892494

# %%
# predictions_df\
#     .to_csv('XLU_figarch_Nas.csv',
#             index = True)

# %%
model_fits
# Out:
# [                    Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                14.5477
#  Distribution:                  Normal   AIC:                          -19.0955
#  Method:            Maximum Likelihood   BIC:                          -21.0483
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:44:13   Df Model:                            1
#                                    Mean Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  mu         4.5395e-03  6.520e-03      0.696      0.486 [-8.239e-03,1.732e-02]
#                                 Volatility Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  omega      1.9596e-05  8.527e-04  2.298e-02      0.982 [-1.652e-03,1.691e-03]
#  phi        6.3419e-07      0.883  7.182e-07      1.000      [ -1.731,  1.731]
#  d              1.0000      2.650      0.377      0.706      [ -4.194,  6.194]
#  beta       4.4131e-07      0.956  4.618e-07      1.000      [ -1.873,  1.873]
#  =============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x127238e90,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                15.0631
#  Distribution:                  Normal   AIC:                          -20.1263
#  Method:            Maximum Likelihood   BIC:                          -22.0791
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:44:13   Df Model:                            1
#                                    Mean Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  mu         4.8697e-03  5.392e-03      0.903      0.366 [-5.699e-03,1.544e-02]
#                                 Volatility Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  omega      7.0763e-05  7.834e-05      0.903      0.366 [-8.278e-05,2.243e-04]
#  phi            0.5000      0.618      0.809      0.419      [ -0.711,  1.711]
#  d              0.0000      0.262      0.000      1.000      [ -0.514,  0.514]
#  beta           0.5000      0.815      0.613      0.540      [ -1.098,  2.098]
#  =============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x12723b7d0,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                17.3323
#  Distribution:                  Normal   AIC:                          -24.6647
#  Method:            Maximum Likelihood   BIC:                          -26.6175
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:44:14   Df Model:                            1
#                                    Mean Model
#  ==============================================================================
#                    coef    std err          t      P>|t|       95.0% Conf. Int.
#  ------------------------------------------------------------------------------
#  mu         -2.1947e-03  2.967e-03     -0.740      0.459 [-8.009e-03,3.620e-03]
#                                 Volatility Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  omega      2.5679e-06  4.402e-06      0.583      0.560 [-6.060e-06,1.120e-05]
#  phi            0.0000      0.469      0.000      1.000      [ -0.919,  0.919]
#  d              0.4404      0.868      0.507      0.612      [ -1.261,  2.142]
#  beta           0.4404      0.641      0.687      0.492      [ -0.816,  1.696]
#  =============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x12723be50,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                16.9895
#  Distribution:                  Normal   AIC:                          -23.9791
#  Method:            Maximum Likelihood   BIC:                          -25.9319
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:44:14   Df Model:                            1
#                                    Mean Model
#  ==============================================================================
#                    coef    std err          t      P>|t|       95.0% Conf. Int.
#  ------------------------------------------------------------------------------
#  mu         -3.7064e-03  5.668e-03     -0.654      0.513 [-1.482e-02,7.403e-03]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      3.2732e-05  1.283e-05      2.552  1.071e-02 [7.592e-06,5.787e-05]
#  phi            0.5000      1.706      0.293      0.769     [ -2.843,  3.843]
#  d          3.8284e-07      0.578  6.619e-07      1.000     [ -1.134,  1.134]
#  beta           0.5000      0.269      1.856  6.346e-02  [-2.802e-02,  1.028]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x127149190,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                17.0683
#  Distribution:                  Normal   AIC:                          -24.1366
#  Method:            Maximum Likelihood   BIC:                          -26.0894
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:44:14   Df Model:                            1
#                                    Mean Model
#  ==============================================================================
#                    coef    std err          t      P>|t|       95.0% Conf. Int.
#  ------------------------------------------------------------------------------
#  mu         -3.7887e-03  1.100e-02     -0.344      0.731 [-2.535e-02,1.777e-02]
#                                 Volatility Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  omega      3.1722e-05  2.823e-05      1.124      0.261 [-2.360e-05,8.704e-05]
#  phi            0.5000      6.274  7.970e-02      0.936      [-11.796, 12.796]
#  d              0.0000      1.615      0.000      1.000      [ -3.166,  3.166]
#  beta           0.5000      1.532      0.326      0.744      [ -2.503,  3.503]
#  =============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x127218fd0,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                17.6200
#  Distribution:                  Normal   AIC:                          -25.2400
#  Method:            Maximum Likelihood   BIC:                          -27.1928
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:44:14   Df Model:                            1
#                                     Mean Model
#  ===============================================================================
#                    coef    std err          t      P>|t|        95.0% Conf. Int.
#  -------------------------------------------------------------------------------
#  mu         -5.2767e-03  2.100e-03     -2.513  1.196e-02 [-9.392e-03,-1.162e-03]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      2.2453e-05  1.435e-06     15.644  3.676e-55 [1.964e-05,2.527e-05]
#  phi            0.4901      1.835      0.267      0.789     [ -3.106,  4.086]
#  d              0.0198      0.494  4.017e-02      0.968     [ -0.948,  0.988]
#  beta           0.5099      1.621      0.315      0.753     [ -2.668,  3.688]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x12721b390,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                17.8497
#  Distribution:                  Normal   AIC:                          -25.6993
#  Method:            Maximum Likelihood   BIC:                          -27.6521
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:44:14   Df Model:                            1
#                                    Mean Model
#  ==============================================================================
#                    coef    std err          t      P>|t|       95.0% Conf. Int.
#  ------------------------------------------------------------------------------
#  mu         -3.0011e-03  1.873e-03     -1.602      0.109 [-6.673e-03,6.709e-04]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      2.2967e-05  8.839e-11  2.598e+05      0.000 [2.297e-05,2.297e-05]
#  phi            0.5000      1.789      0.280      0.780     [ -3.006,  4.006]
#  d              0.0000      0.422      0.000      1.000     [ -0.828,  0.828]
#  beta           0.5000      1.715      0.292      0.771     [ -2.862,  3.862]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x127218710,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                18.5209
#  Distribution:                  Normal   AIC:                          -27.0418
#  Method:            Maximum Likelihood   BIC:                          -28.9946
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:44:14   Df Model:                            1
#                                    Mean Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  mu         2.1964e-04  1.995e-03      0.110      0.912 [-3.691e-03,4.130e-03]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      5.6112e-06  1.596e-09   3515.048      0.000 [5.608e-06,5.614e-06]
#  phi            0.3200      7.201  4.444e-02      0.965     [-13.794, 14.434]
#  d              0.2000      2.942  6.799e-02      0.946     [ -5.565,  5.965]
#  beta           0.0520     23.060  2.255e-03      0.998     [-45.144, 45.248]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x127219710,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                14.8114
#  Distribution:                  Normal   AIC:                          -19.6228
#  Method:            Maximum Likelihood   BIC:                          -21.5756
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:44:14   Df Model:                            1
#                                    Mean Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  mu         8.2388e-03  4.881e-03      1.688  9.143e-02 [-1.328e-03,1.781e-02]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      7.8243e-05  3.025e-05      2.586  9.705e-03 [1.895e-05,1.375e-04]
#  phi            0.5000      0.499      1.002      0.316     [ -0.478,  1.478]
#  d              0.0000      0.122      0.000      1.000     [ -0.239,  0.239]
#  beta           0.5000      0.823      0.607      0.544     [ -1.114,  2.114]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x12722b350,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                13.8208
#  Distribution:                  Normal   AIC:                          -17.6417
#  Method:            Maximum Likelihood   BIC:                          -19.5945
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:44:14   Df Model:                            1
#                                    Mean Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  mu         3.9048e-03  1.983e-02      0.197      0.844 [-3.495e-02,4.276e-02]
#                                 Volatility Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  omega      1.1629e-04  1.124e-03      0.103      0.918 [-2.086e-03,2.319e-03]
#  phi            0.5000      0.363      1.378      0.168      [ -0.211,  1.211]
#  d          1.5686e-09      1.715  9.147e-10      1.000      [ -3.361,  3.361]
#  beta           0.5000      0.570      0.878      0.380      [ -0.616,  1.616]
#  =============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x12722b890,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                12.7594
#  Distribution:                  Normal   AIC:                          -15.5187
#  Method:            Maximum Likelihood   BIC:                          -17.4715
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:44:14   Df Model:                            1
#                                    Mean Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  mu         1.5256e-06  4.472e-03  3.411e-04      1.000 [-8.764e-03,8.767e-03]
#                                 Volatility Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  omega      1.7782e-04  7.245e-04      0.245      0.806 [-1.242e-03,1.598e-03]
#  phi            0.5000      1.049      0.476      0.634      [ -1.557,  2.557]
#  d          7.0524e-13      0.754  9.354e-13      1.000      [ -1.478,  1.478]
#  beta           0.5000      1.454      0.344      0.731      [ -2.349,  3.349]
#  =============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x127a2c610,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                12.7599
#  Distribution:                  Normal   AIC:                          -15.5198
#  Method:            Maximum Likelihood   BIC:                          -17.4726
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:44:14   Df Model:                            1
#                                    Mean Model
#  ==============================================================================
#                    coef    std err          t      P>|t|       95.0% Conf. Int.
#  ------------------------------------------------------------------------------
#  mu         -6.4380e-04  5.717e-03     -0.113      0.910 [-1.185e-02,1.056e-02]
#                                 Volatility Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  omega      2.6413e-05  2.566e-04      0.103      0.918 [-4.764e-04,5.292e-04]
#  phi            0.0000      0.311      0.000      1.000      [ -0.610,  0.610]
#  d              0.2894      1.431      0.202      0.840      [ -2.515,  3.093]
#  beta           0.2894      0.566      0.511      0.609      [ -0.820,  1.399]
#  =============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x127229f50,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                13.3893
#  Distribution:                  Normal   AIC:                          -16.7786
#  Method:            Maximum Likelihood   BIC:                          -18.7314
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:44:14   Df Model:                            1
#                                     Mean Model
#  ===============================================================================
#                    coef    std err          t      P>|t|        95.0% Conf. Int.
#  -------------------------------------------------------------------------------
#  mu         -6.1377e-03  6.214e-06   -987.778      0.000 [-6.150e-03,-6.126e-03]
#                                 Volatility Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  omega          0.0000  2.059e-08      0.000      1.000 [-4.036e-08,4.036e-08]
#  phi            0.0000      3.948      0.000      1.000      [ -7.737,  7.737]
#  d              1.0000  8.043e-03    124.325      0.000      [  0.984,  1.016]
#  beta           0.0000      3.948      0.000      1.000      [ -7.737,  7.737]
#  =============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x1271f32d0,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                17.5950
#  Distribution:                  Normal   AIC:                          -25.1899
#  Method:            Maximum Likelihood   BIC:                          -27.1427
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:44:14   Df Model:                            1
#                                    Mean Model
#  ==============================================================================
#                   coef    std err          t      P>|t|        95.0% Conf. Int.
#  ------------------------------------------------------------------------------
#  mu            -0.0108  1.828e-06  -5891.587      0.000 [-1.077e-02,-1.077e-02]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      5.3860e-08  4.213e-10    127.838      0.000 [5.303e-08,5.469e-08]
#  phi            0.2068      0.540      0.383      0.702     [ -0.851,  1.265]
#  d              0.5864      0.849      0.690      0.490     [ -1.078,  2.251]
#  beta           0.7932      0.592      1.339      0.181     [ -0.368,  1.954]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x127252dd0,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                11.7380
#  Distribution:                  Normal   AIC:                          -13.4759
#  Method:            Maximum Likelihood   BIC:                          -15.4287
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:44:14   Df Model:                            1
#                                    Mean Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  mu         1.0203e-03  7.711e-03      0.132      0.895 [-1.409e-02,1.613e-02]
#                                 Volatility Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  omega      2.6755e-04  1.165e-03      0.230      0.818 [-2.017e-03,2.552e-03]
#  phi            0.5000      0.120      4.182  2.893e-05      [  0.266,  0.734]
#  d          1.3193e-10      0.631  2.089e-10      1.000      [ -1.238,  1.238]
#  beta           0.5000      0.176      2.835  4.588e-03      [  0.154,  0.846]
#  =============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x127250e90,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                12.3568
#  Distribution:                  Normal   AIC:                          -14.7137
#  Method:            Maximum Likelihood   BIC:                          -16.6665
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:44:14   Df Model:                            1
#                                   Mean Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  mu         4.2530e-03  2.100e-03      2.025  4.283e-02 [1.373e-04,8.369e-03]
#                                 Volatility Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  omega      2.0889e-04  8.824e-04      0.237      0.813 [-1.521e-03,1.938e-03]
#  phi            0.5000      0.161      3.109  1.877e-03      [  0.185,  0.815]
#  d          6.8652e-07      0.560  1.227e-06      1.000      [ -1.097,  1.097]
#  beta           0.5000      0.317      1.577      0.115      [ -0.122,  1.122]
#  =============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x1271f0c50,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                12.3798
#  Distribution:                  Normal   AIC:                          -14.7597
#  Method:            Maximum Likelihood   BIC:                          -16.7125
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:44:14   Df Model:                            1
#                                   Mean Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  mu         3.8095e-03  1.530e-03      2.490  1.277e-02 [8.111e-04,6.808e-03]
#                                 Volatility Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  omega      2.3202e-06  1.662e-05      0.140      0.889 [-3.025e-05,3.489e-05]
#  phi            0.2116      0.154      1.372      0.170   [-9.058e-02,  0.514]
#  d              0.5768      0.835      0.690      0.490      [ -1.061,  2.214]
#  beta           0.7884      0.764      1.031      0.302      [ -0.710,  2.287]
#  =============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x127228450,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                12.4469
#  Distribution:                  Normal   AIC:                          -14.8937
#  Method:            Maximum Likelihood   BIC:                          -16.8465
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:44:14   Df Model:                            1
#                                   Mean Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  mu         5.1111e-03  1.262e-03      4.051  5.092e-05 [2.638e-03,7.584e-03]
#                                 Volatility Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  omega      2.0148e-04  1.066e-03      0.189      0.850 [-1.889e-03,2.292e-03]
#  phi            0.5000      0.179      2.794  5.211e-03      [  0.149,  0.851]
#  d          1.9941e-13      0.618  3.227e-13      1.000      [ -1.211,  1.211]
#  beta           0.5000      0.366      1.368      0.171      [ -0.216,  1.216]
#  =============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x1272ba310,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                16.1508
#  Distribution:                  Normal   AIC:                          -22.3016
#  Method:            Maximum Likelihood   BIC:                          -24.2544
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:44:14   Df Model:                            1
#                                     Mean Model
#  ===============================================================================
#                    coef    std err          t      P>|t|        95.0% Conf. Int.
#  -------------------------------------------------------------------------------
#  mu         -3.5610e-03  1.239e-05   -287.451      0.000 [-3.585e-03,-3.537e-03]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      5.8964e-06  1.457e-08    404.619      0.000 [5.868e-06,5.925e-06]
#  phi        4.5398e-04      0.309  1.469e-03      0.999     [ -0.605,  0.606]
#  d              0.9991  1.512e-02     66.083      0.000     [  0.969,  1.029]
#  beta       1.8418e-03      0.299  6.152e-03      0.995     [ -0.585,  0.589]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x1272bbdd0,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                24.0358
#  Distribution:                  Normal   AIC:                          -38.0716
#  Method:            Maximum Likelihood   BIC:                          -40.0244
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:44:14   Df Model:                            1
#                                     Mean Model
#  ===============================================================================
#                    coef    std err          t      P>|t|        95.0% Conf. Int.
#  -------------------------------------------------------------------------------
#  mu         -4.4905e-03  1.939e-06  -2316.257      0.000 [-4.494e-03,-4.487e-03]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      7.7283e-07  9.874e-10    782.713      0.000 [7.709e-07,7.748e-07]
#  phi            0.0800      2.020  3.960e-02      0.968     [ -3.880,  4.040]
#  d              0.2000      0.780      0.256      0.798     [ -1.329,  1.729]
#  beta           0.2520      2.920  8.629e-02      0.931     [ -5.472,  5.976]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x1272bb650,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                22.3122
#  Distribution:                  Normal   AIC:                          -34.6245
#  Method:            Maximum Likelihood   BIC:                          -36.5773
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:44:14   Df Model:                            1
#                                     Mean Model
#  ===============================================================================
#                    coef    std err          t      P>|t|        95.0% Conf. Int.
#  -------------------------------------------------------------------------------
#  mu         -2.3746e-03  1.458e-06  -1628.842      0.000 [-2.377e-03,-2.372e-03]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      1.5086e-06  5.529e-10   2728.334      0.000 [1.507e-06,1.510e-06]
#  phi            0.0800      0.466      0.172      0.864     [ -0.834,  0.994]
#  d              0.2000      0.313      0.639      0.523     [ -0.414,  0.814]
#  beta           0.2520      0.433      0.581      0.561     [ -0.598,  1.102]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x12722a490,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                22.8577
#  Distribution:                  Normal   AIC:                          -35.7154
#  Method:            Maximum Likelihood   BIC:                          -37.6682
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:44:14   Df Model:                            1
#                                     Mean Model
#  ===============================================================================
#                    coef    std err          t      P>|t|        95.0% Conf. Int.
#  -------------------------------------------------------------------------------
#  mu         -1.5007e-03  8.364e-06   -179.426      0.000 [-1.517e-03,-1.484e-03]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      1.4784e-07  1.634e-09     90.464      0.000 [1.446e-07,1.510e-07]
#  phi        2.8215e-15      2.537  1.112e-15      1.000     [ -4.973,  4.973]
#  d              0.4295      8.309  5.169e-02      0.959     [-15.856, 16.715]
#  beta           0.4295      5.148  8.344e-02      0.934     [ -9.660, 10.519]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x127236310,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                18.5864
#  Distribution:                  Normal   AIC:                          -27.1728
#  Method:            Maximum Likelihood   BIC:                          -29.1256
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:44:14   Df Model:                            1
#                                    Mean Model
#  ==============================================================================
#                    coef    std err          t      P>|t|       95.0% Conf. Int.
#  ------------------------------------------------------------------------------
#  mu         -4.2275e-03  2.547e-03     -1.660  9.690e-02 [-9.219e-03,7.637e-04]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      7.8184e-06  1.227e-10  6.372e+04      0.000 [7.818e-06,7.819e-06]
#  phi            0.3215      1.823      0.176      0.860     [ -3.252,  3.895]
#  d              0.1965      0.402      0.489      0.625     [ -0.591,  0.984]
#  beta           0.4748      1.233      0.385      0.700     [ -1.942,  2.891]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x127237050,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                17.0241
#  Distribution:                  Normal   AIC:                          -24.0482
#  Method:            Maximum Likelihood   BIC:                          -26.0010
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:44:15   Df Model:                            1
#                                    Mean Model
#  ==============================================================================
#                    coef    std err          t      P>|t|       95.0% Conf. Int.
#  ------------------------------------------------------------------------------
#  mu         -6.5639e-03  4.528e-03     -1.450      0.147 [-1.544e-02,2.311e-03]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      4.9244e-05  8.907e-06      5.529  3.227e-08 [3.179e-05,6.670e-05]
#  phi            0.2376      4.368  5.439e-02      0.957     [ -8.324,  8.799]
#  d              0.0000      0.655      0.000      1.000     [ -1.284,  1.284]
#  beta           0.2376      0.499      0.476      0.634     [ -0.740,  1.215]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x1272b9650,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                16.7120
#  Distribution:                  Normal   AIC:                          -23.4240
#  Method:            Maximum Likelihood   BIC:                          -25.3768
#                                          No. Observations:                    5
# ...
#  d              0.5398      1.720      0.314      0.754      [ -2.831,  3.911]
#  beta           0.7699      6.116      0.126      0.900      [-11.216, 12.756]
#  =============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x12828ec90,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                20.9035
#  Distribution:                  Normal   AIC:                          -31.8070
#  Method:            Maximum Likelihood   BIC:                          -33.7598
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:45:08   Df Model:                            1
#                                   Mean Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  mu         7.0439e-03  1.876e-03      3.754  1.739e-04 [3.366e-03,1.072e-02]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      1.9709e-06  4.458e-09    442.120      0.000 [1.962e-06,1.980e-06]
#  phi            0.3200      0.120      2.660  7.816e-03   [8.421e-02,  0.556]
#  d              0.2000      0.189      1.058      0.290     [ -0.171,  0.571]
#  beta           0.4680      0.161      2.914  3.573e-03     [  0.153,  0.783]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x12828f710,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                20.8634
#  Distribution:                  Normal   AIC:                          -31.7267
#  Method:            Maximum Likelihood   BIC:                          -33.6795
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:45:08   Df Model:                            1
#                                   Mean Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  mu         6.7814e-03  4.112e-06   1649.084      0.000 [6.773e-03,6.789e-03]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      2.8501e-06  9.476e-10   3007.682      0.000 [2.848e-06,2.852e-06]
#  phi            0.4352      0.731      0.595      0.552     [ -0.998,  1.869]
#  d              0.1295      0.223      0.580      0.562     [ -0.308,  0.567]
#  beta           0.5648      0.850      0.664      0.506     [ -1.101,  2.231]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x12808c590,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                20.2448
#  Distribution:                  Normal   AIC:                          -30.4897
#  Method:            Maximum Likelihood   BIC:                          -32.4425
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:45:08   Df Model:                            1
#                                   Mean Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  mu         6.2949e-03  5.571e-06   1129.892      0.000 [6.284e-03,6.306e-03]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      2.5826e-06  9.016e-10   2864.439      0.000 [2.581e-06,2.584e-06]
#  phi            0.3200      0.374      0.856      0.392     [ -0.413,  1.053]
#  d              0.2000      0.227      0.883      0.377     [ -0.244,  0.644]
#  beta           0.4680      0.392      1.195      0.232     [ -0.299,  1.235]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x12828e790,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                22.0193
#  Distribution:                  Normal   AIC:                          -34.0385
#  Method:            Maximum Likelihood   BIC:                          -35.9913
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:45:08   Df Model:                            1
#                                   Mean Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  mu         3.9531e-03  7.108e-06    556.130      0.000 [3.939e-03,3.967e-03]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      1.7295e-06  1.305e-09   1325.661      0.000 [1.727e-06,1.732e-06]
#  phi            0.4325      1.178      0.367      0.713     [ -1.876,  2.741]
#  d              0.1350      0.282      0.479      0.632     [ -0.417,  0.687]
#  beta           0.5675      1.404      0.404      0.686     [ -2.185,  3.320]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x128299710,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                21.8284
#  Distribution:                  Normal   AIC:                          -33.6569
#  Method:            Maximum Likelihood   BIC:                          -35.6097
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:45:08   Df Model:                            1
#                                   Mean Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  mu         4.9753e-03  3.729e-06   1334.093      0.000 [4.968e-03,4.983e-03]
#                                 Volatility Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  omega      2.0477e-16  8.611e-10  2.378e-07      1.000 [-1.688e-09,1.688e-09]
#  phi            0.0909      0.230      0.396      0.692      [ -0.359,  0.541]
#  d              0.5433      0.973      0.558      0.577      [ -1.365,  2.451]
#  beta           0.6342      0.554      1.144      0.253      [ -0.452,  1.721]
#  =============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x12829a190,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                23.2525
#  Distribution:                  Normal   AIC:                          -36.5049
#  Method:            Maximum Likelihood   BIC:                          -38.4577
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:45:08   Df Model:                            1
#                                   Mean Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  mu         3.6913e-03  1.189e-06   3105.353      0.000 [3.689e-03,3.694e-03]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      7.7750e-07  5.657e-10   1374.465      0.000 [7.764e-07,7.786e-07]
#  phi            0.3200      1.597      0.200      0.841     [ -2.809,  3.449]
#  d              0.2000      0.177      1.133      0.257     [ -0.146,  0.546]
#  beta           0.4680      1.508      0.310      0.756     [ -2.487,  3.423]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x12829ac10,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                22.0307
#  Distribution:                  Normal   AIC:                          -34.0614
#  Method:            Maximum Likelihood   BIC:                          -36.0142
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:45:08   Df Model:                            1
#                                   Mean Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  mu         2.3457e-03  5.268e-06    445.256      0.000 [2.335e-03,2.356e-03]
#                                Volatility Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  omega      1.6933e-06  6.878e-10   2461.847      0.000 [1.692e-06,1.695e-06]
#  phi            0.0798      1.225  6.510e-02      0.948     [ -2.322,  2.481]
#  d              0.2020      0.252      0.801      0.423     [ -0.292,  0.696]
#  beta           0.2538      1.123      0.226      0.821     [ -1.948,  2.456]
#  ============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x12829b6d0,
#                      Constant Mean - FIGARCH Model Results
#  ==============================================================================
#  Dep. Variable:              Adj Close   R-squared:                       0.000
#  Mean Model:             Constant Mean   Adj. R-squared:                  0.000
#  Vol Model:                    FIGARCH   Log-Likelihood:                21.2039
#  Distribution:                  Normal   AIC:                          -32.4078
#  Method:            Maximum Likelihood   BIC:                          -34.3606
#                                          No. Observations:                    5
#  Date:                Wed, Oct 30 2024   Df Residuals:                        4
#  Time:                        00:45:08   Df Model:                            1
#                                   Mean Model
#  ============================================================================
#                   coef    std err          t      P>|t|      95.0% Conf. Int.
#  ----------------------------------------------------------------------------
#  mu         1.4491e-03  7.218e-04      2.008  4.469e-02 [3.434e-05,2.864e-03]
#                                 Volatility Model
#  =============================================================================
#                   coef    std err          t      P>|t|       95.0% Conf. Int.
#  -----------------------------------------------------------------------------
#  omega      5.3215e-14  5.009e-08  1.062e-06      1.000 [-9.818e-08,9.818e-08]
#  phi        6.9094e-09     27.208  2.539e-10      1.000      [-53.327, 53.327]
#  d              0.5277     42.992  1.227e-02      0.990      [-83.736, 84.791]
#  beta           0.5277      5.955  8.861e-02      0.929      [-11.144, 12.199]
#  =============================================================================
#
#  Covariance estimator: robust
#  ARCHModelResult, id: 0x12828fc10,
#  ...]

# %%
residuals = []

for model_f in model_fits:
    residual = model_fit.resid
    
    residuals.append(residual)

# %%
from statsmodels.stats.diagnostic import acorr_ljungbox

# %%
max_lag = min(10,
              len(residuals) - 1)

# %%
residuals = np.ravel(residuals)

# %%
ljung_box_result =\
(
    acorr_ljungbox(residuals,
                   lags=max_lag,
                   return_df=True)
)

# %%
ljung_box_result
# Out:
#           lb_stat  lb_pvalue
# 1    19458.311921        0.0
# 2    22231.739558        0.0
# 3    25005.368928        0.0
# 4    44461.729124        0.0
# 5    74613.728793        0.0
# 6    94068.814225        0.0
# 7    96841.781946        0.0
# 8    99614.951399        0.0
# 9   119068.085107        0.0
# 10  149215.084444        0.0

# %%
max_lag = min(10, len(residual)-1)

# %%
ljung_box_result = acorr_ljungbox(residual,
                                  lags=max_lag,
                                  return_df=True)

# %%
ljung_box_result
# Out:
# Ljung-Box Test Results:
#     lb_stat  lb_pvalue
# 1  3.624517   0.056934
# 2  3.832587   0.147151
# 3  4.336740   0.227323
# 4  5.229049   0.264593
