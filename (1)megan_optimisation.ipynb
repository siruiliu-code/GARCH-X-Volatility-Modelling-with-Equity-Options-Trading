# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from data_wrangling import *

# %%
def myround(x, base=5):
    return base * round(x/base)

# %%
class Option:
    def __init__(self, strike: float, premium: float, expiry: str):
        self.strike = strike
        self.premium = premium
        self.expiry = expiry
        self.spot_price = None

    def insert_spot(self, spot_price: float):
        self.spot_price = spot_price
    
    def short_call(self):
        # Payoff for short call: premium received - intrinsic value of the option
        intrinsic_value = np.maximum(0, self.spot_price - self.strike)
        return self.premium - intrinsic_value
    
    def long_call(self):
        # Payoff for long call: intrinsic value - premium paid
        intrinsic_value = np.maximum(0, self.spot_price - self.strike)
        return intrinsic_value - self.premium
    
    def short_put(self):
        # Payoff for short put: premium received - intrinsic value of the option
        intrinsic_value = np.maximum(0, self.strike - self.spot_price)
        return self.premium - intrinsic_value
    
    def long_put(self):
        # Payoff for long put: intrinsic value - premium paid
        intrinsic_value = np.maximum(0, self.strike - self.spot_price)
        return intrinsic_value - self.premium


class IronCondor:
    def __init__(self, direction: str, strikes: dict, premiums: dict, expiry: str):
        """
        Initialize the Iron Condor strategy with strikes and premiums for the options.
        
        direction: long, (short) Iron Condor
        1. Short (Long) 1 OTM Put (strike 1)
        2. Long (Short) 1 close to ATM Put (strike 2)
        3. Long (Short) 1 close to ATM Call (strike 3)
        4. Short (Long) 1 OTM Call (strike 4)        

        strikes: a dictionary of strikes for the 4 options (strike1 to strike4)
        premiums: a dictionary of premiums for the 4 options (premium1 to premium4)
        expiry: expiration date of the options
        """
        self.strikes = strikes
        self.premiums = premiums
        self.direction = direction
        self.expiry = expiry
        self.short_put_option = Option(strikes['strike1'], premiums['premium1'], expiry)
        self.long_put_option = Option(strikes['strike2'], premiums['premium2'], expiry)
        self.long_call_option = Option(strikes['strike3'], premiums['premium3'], expiry)
        self.short_call_option = Option(strikes['strike4'], premiums['premium4'], expiry)

    def initial_cashflow(self):
        """
        Calculate the initial cashflow of the Iron Condor strategy.
        """
        if self.direction == "long":
            initial_cashflow = self.premiums['premium1'] - self.premiums['premium2'] - self.premiums['premium3'] + self.premiums['premium4']
        elif self.direction == "short":
            initial_cashflow = -self.premiums['premium1'] + self.premiums['premium2'] + self.premiums['premium3'] - self.premiums['premium4']
        
        return initial_cashflow

    def insert_spot(self, spot_price: float):
        """
        Insert the current spot price for all the options in the Iron Condor strategy.
        """
        self.short_put_option.insert_spot(spot_price)
        self.long_put_option.insert_spot(spot_price)
        self.long_call_option.insert_spot(spot_price)
        self.short_call_option.insert_spot(spot_price)
    
    def payoff(self):
        """
        Calculate the total payoff (profit or loss) of the Iron Condor strategy.
        
        direction: 'long' for long Iron Condor, 'short' for short Iron Condor
        """
        if self.direction == "long":
            short_put = self.short_put_option.short_put()
            long_put = self.long_put_option.long_put()
            long_call = self.long_call_option.long_call()
            short_call = self.short_call_option.short_call()
            total_payoff = short_put + long_put + long_call + short_call
        elif self.direction == "short":
            long_put = -self.long_put_option.long_put()
            short_put = -self.short_put_option.short_put()
            short_call = -self.short_call_option.short_call()
            long_call = -self.long_call_option.long_call()
            total_payoff = long_put + short_put + short_call + long_call
        
        return total_payoff.iloc[0] if isinstance(total_payoff, pd.Series) else total_payoff
    
    def target_profit(self):
        """
        Calculate the target profit for the Iron Condor strategy.
        """
        if self.direction == "long":
            self.long_call_option = Option(self.strikes['strike3'], self.premiums['premium3'], self.expiry)
            self.short_call_option = Option(self.strikes['strike4'], self.premiums['premium4'], self.expiry)
            self.long_call_option.insert_spot(self.strikes["strike4"] + 5)
            self.short_call_option.insert_spot(self.strikes["strike4"] + 5)
            target_profit = self.premiums["premium1"] - self.premiums["premium2"] + self.long_call_option.long_call() + self.short_call_option.short_call()
        elif self.direction == "short":
            target_profit = self.initial_cashflow()
        
        return target_profit

class OptionsBacktester:
    def __init__(self,
                 signal_df: pd.DataFrame,
                 spot_price_df: pd.DataFrame,
                 options_df: pd.DataFrame,
                 upper_threshold: float,
                 lower_threshold: float,
                 option_type: str,
                 dynamic_option_strategy: bool = False,
                 dynamic_strike: bool = False,):
        self.signal_df = signal_df
        self.signal_df.columns = ["signal"]
        self.spot_price_df = spot_price_df
        self.options_df = options_df
        self.upper_threshold = upper_threshold
        self.lower_threshold = lower_threshold
        self.option_type = option_type
        self.dynamic_option_strategy = dynamic_option_strategy
        self.dynamic_strike = dynamic_strike

        self.comb_df = pd.concat([self.signal_df, self.spot_price_df.shift(), self.options_df.shift()], axis=1)
        self.comb_df["action"] = np.where(self.comb_df["signal"] > self.upper_threshold, 1, np.where(self.comb_df["signal"] < self.lower_threshold, -1, 0))

    def long_short_vol_df(self):
        self.trading_df = {}
        for index, row in self.comb_df.iterrows():
            if row["action"] != 0:
                self.trading_df[index] = self.comb_df.loc[index]

# %% [markdown]
# ## filtering of options data

# %%
day_map = {0: "Monday", 1: "Tuesday", 2: "Wednesday", 3: "Thursday", 4: "Friday", 5: "Saturday", 6: "Sunday"}

xlu_options = pd.read_hdf("data/etf_options_data.hf5", key="XLU")
xlu_options = xlu_options.set_index("date")
xlu_options["strike_price"] = xlu_options["strike_price"] / 1000
xlu_filtered_options = xlu_options.groupby("date").apply(lambda x: x.query("exdate == exdate.max()")).reset_index(level=0, drop=True)
xlu_filtered_options["day"] = xlu_filtered_options.index.weekday.map(day_map)
xlu_filtered_options["ex_day"] = xlu_filtered_options["exdate"].dt.weekday.map(day_map)
xlu_filtered_options
# Out:
#            ticker     exdate cp_flag  strike_price  best_bid  best_offer  \
# date
# 2000-01-10    XLU 2000-01-22       C          31.0    0.0000      0.1250
# 2000-01-10    XLU 2000-01-22       P          29.0    1.4375      1.6250
# 2000-01-10    XLU 2000-01-22       P          30.0    2.3750      2.6250
# 2000-01-10    XLU 2000-01-22       C          28.0    0.0625      0.1875
# 2000-01-10    XLU 2000-01-22       C          27.0    0.5625      0.7500
# ...           ...        ...     ...           ...       ...         ...
# 2023-08-31    XLU 2023-09-08       P          73.5   10.2000     10.5500
# 2023-08-31    XLU 2023-09-08       P          90.0   26.7000     27.2000
# 2023-08-31    XLU 2023-09-08       P          72.5    9.3000      9.5500
# 2023-08-31    XLU 2023-09-08       P          73.0    9.8000     10.0500
# 2023-08-31    XLU 2023-09-08       P          95.0   31.7500     32.1000
#
#             open_interest  impl_volatility     delta     gamma     theta  \
# date
# 2000-01-10            0.0         0.423886  0.068868  0.062562 -4.271427
# 2000-01-10            0.0         0.271660 -0.839551  0.179317 -4.941929
# 2000-01-10            0.0         0.353248 -0.899561  0.099878 -4.593377
# 2000-01-10            0.0         0.143454  0.283783  0.471890 -3.686701
# 2000-01-10            0.0         0.140491  0.799844  0.397932 -2.952004
# ...                   ...              ...       ...       ...       ...
# 2023-08-31            0.0              NaN       NaN       NaN       NaN
# 2023-08-31            0.0              NaN       NaN       NaN       NaN
# 2023-08-31            0.0              NaN       NaN       NaN       NaN
# 2023-08-31            0.0              NaN       NaN       NaN       NaN
# 2023-08-31            0.0              NaN       NaN       NaN       NaN
#
#                 vega  volume       day    ex_day
# date
# 2000-01-10  0.662345     0.0    Monday  Saturday
# 2000-01-10  1.211415     0.0    Monday  Saturday
# 2000-01-10  0.872273     0.0    Monday  Saturday
# 2000-01-10  1.692336     0.0    Monday  Saturday
# 2000-01-10  1.393989     0.0    Monday  Saturday
# ...              ...     ...       ...       ...
# 2023-08-31       NaN     0.0  Thursday    Friday
# 2023-08-31       NaN     0.0  Thursday    Friday
# 2023-08-31       NaN     0.0  Thursday    Friday
# 2023-08-31       NaN     0.0  Thursday    Friday
# 2023-08-31       NaN     0.0  Thursday    Friday
#
# [247525 rows x 15 columns]

# %% [markdown]
# ## pulling XLU data

# %%
xlu_pred = pd.read_csv("data/xlu_pred.csv", parse_dates=True, index_col=0).rename(columns={"0": "Rolling Pred"})
xlu_iv = pd.read_csv("data/XLU_IV.csv", parse_dates=True, index_col=0)
xlu_vrp = (xlu_iv["Average IV"] - xlu_pred["Rolling Pred"]).dropna()

xlu_vrp_standardised = rolling_z_score(xlu_vrp, window=10)
xlu_vrp_standardised.plot()
# Out:
# <Axes: >

# %%
upper_threshold = 1.75
lower_threshold = -1.75

xlu_filtered_options["vrp"] = xlu_vrp_standardised
xlu_time_series = pd.read_hdf("data/etf_series.hf5", key="XLU")
xlu_time_series["day"] = xlu_time_series.index.weekday
xlu_time_series["vrp"] = xlu_vrp_standardised
xlu_time_series["signal"] = np.where(xlu_time_series["vrp"] > upper_threshold, 1, np.where(xlu_time_series["vrp"] < lower_threshold, -1, 0))
xlu_time_series["action"] = np.where((xlu_time_series["signal"] == 1)  & (xlu_time_series.index.weekday != 4), 1, 
                                     np.where((xlu_time_series["signal"] == -1) & (xlu_time_series.index.weekday != 4), -1, 
                                              0))
xlu_time_series.dropna(inplace=True)
xlu_time_series

def ensure_weekly_action(df):
    last_action = 0
    last_week = -1

    for i in range(len(df)):
        current_week = df.index[i].isocalendar()[1]  # Get the week number
        current_day = df["day"].iloc[i]

        if current_week != last_week:  # Reset at the start of a new week
            last_action = 0
            last_week = current_week

        if last_action != 0 and df["action"].iloc[i] != 0:
            # If an action has already occurred this week, set to 0
            df.at[df.index[i], "action"] = 0
        elif df["action"].iloc[i] != 0:
            # If this is the first action of the week, update last_action
            last_action = df["action"].iloc[i]

    return df

xlu_time_series = ensure_weekly_action(xlu_time_series)
xlu_time_series["action"] = xlu_time_series["action"].shift()
xlu_time_series
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2016-10-21  48.070000  48.250000  47.790001  48.000000  37.077724  18153600
# 2016-10-24  48.209999  48.360001  47.889999  48.180000  37.216782  10744700
# 2016-10-25  48.119999  48.480000  48.060001  48.480000  37.448517   9886300
# 2016-10-26  48.349998  48.660000  48.110001  48.599998  37.541203  10851000
# 2016-10-27  48.320000  48.509998  47.970001  48.310001  37.317204  15554900
# ...               ...        ...        ...        ...        ...       ...
# 2023-08-25  63.240002  63.950001  63.200001  63.630001  61.106991  12490500
# 2023-08-28  63.740002  64.089996  63.490002  63.619999  61.097385   8663200
# 2023-08-29  63.700001  64.050003  63.439999  63.860001  61.327869  11873100
# 2023-08-30  63.650002  64.070000  63.330002  63.570000  61.049362  11240400
# 2023-08-31  63.820000  63.880001  62.939999  62.959999  60.463551  13771100
#
#             day       vrp  signal  action
# Date
# 2016-10-21    4  0.707107       0     NaN
# 2016-10-24    0  1.149116       0     0.0
# 2016-10-25    1  0.987097       0     0.0
# 2016-10-26    2  0.863118       0     0.0
# 2016-10-27    3  1.308180       0     0.0
# ...         ...       ...     ...     ...
# 2023-08-25    4  0.825264       0     0.0
# 2023-08-28    0  1.091595       0     0.0
# 2023-08-29    1  0.908478       0     0.0
# 2023-08-30    2  1.160441       0     0.0
# 2023-08-31    3  0.844838       0     0.0
#
# [1725 rows x 10 columns]

# %% [markdown]
# ### scenario 1: short iron condor

# %%
xlu_time_series.resample("W").last()["Close"].diff().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
ironcondor_tracker = {}

def find_nearest_strike_delta(atm_spot, date_index, delta_target, option_df, cp_flag):
    """
    Helper function to find the strike with delta closest to delta_target
    """

    options = option_df.loc[date_index].query(f"cp_flag == '{cp_flag}'")
    atm_delta = options.query("strike_price == @atm_spot")["delta"]
    try:
        if isinstance(atm_delta, pd.Series):
            atm_delta = atm_delta.values[0]
    except IndexError:
        print(f"Error: {date_index}, {cp_flag}")
        return None
    new_delta = atm_delta + delta_target
    return options.iloc[(options["delta"] - new_delta).abs().argmin()]["strike_price"]

for index, row in xlu_time_series.iterrows():
    if row["action"] == 1:
        print(f"date: {index}")
        direction = "short"

        index_loc = xlu_time_series.index.get_loc(index)

        current_spot_open = myround(xlu_time_series.iloc[index_loc]["Open"], 0.5)

        daily_options = xlu_filtered_options.loc[index]

        # atm_put_strike = daily_options[
        #     (daily_options["cp_flag"] == "P") &
        #     (daily_options["strike_price"] == prev_spot_close)
        # ]["strike_price"]
        # if isinstance(atm_put_strike, pd.Series):
        #     atm_put_strike = atm_put_strike.values[0]
        
        # atm_call_strike = daily_options[
        #     (daily_options["cp_flag"] == "C") &
        #     (daily_options["strike_price"] == prev_spot_close)
        # ]["strike_price"]
        # if isinstance(atm_call_strike, pd.Series):
        #     atm_call_strike = atm_call_strike.values[0]

        atm_put_strike = atm_call_strike = current_spot_open

        otm_put_strike = find_nearest_strike_delta(current_spot_open, index, 0.4, xlu_filtered_options, "P")
        otm_call_strike = find_nearest_strike_delta(current_spot_open, index, -0.3, xlu_filtered_options, "C")

        if otm_put_strike is None or otm_call_strike is None:
            continue
            
        else:
            print(f"date: {index}, current_spot_open: {current_spot_open}, OTM Put: {otm_put_strike}, ATM Put: {atm_put_strike}, ATM Call: {atm_call_strike}, OTM Call: {otm_call_strike}, \
                left wing: {abs(otm_put_strike - atm_put_strike)}, right wing: {abs(atm_call_strike - otm_call_strike)}")
            strikes = {
                "strike1": otm_put_strike,
                "strike2": atm_put_strike,
                "strike3": atm_call_strike,
                "strike4": otm_call_strike
            }

            premiums = {
                "premium1": xlu_filtered_options.loc[
                    (xlu_filtered_options.index == index) & 
                    (xlu_filtered_options["strike_price"] == strikes["strike1"]) & 
                    (xlu_filtered_options["cp_flag"] == 'P'), "best_offer"
                ],
                "premium2": xlu_filtered_options.loc[
                    (xlu_filtered_options.index == index) & 
                    (xlu_filtered_options["strike_price"] == strikes["strike2"]) & 
                    (xlu_filtered_options["cp_flag"] == 'P'), "best_bid"
                ],
                "premium3": xlu_filtered_options.loc[
                    (xlu_filtered_options.index == index) & 
                    (xlu_filtered_options["strike_price"] == strikes["strike3"]) & 
                    (xlu_filtered_options["cp_flag"] == 'C'), "best_bid"
                ],
                "premium4": xlu_filtered_options.loc[
                    (xlu_filtered_options.index == index) & 
                    (xlu_filtered_options["strike_price"] == strikes["strike4"]) & 
                    (xlu_filtered_options["cp_flag"] == 'C'), "best_offer"
                ]
            }        

            # print(f"date: {index}, Premiums: {premiums}")

            expiry = xlu_filtered_options.loc[index]["exdate"].max()

            ironcondor = IronCondor(direction=direction, strikes=strikes, premiums=premiums, expiry=expiry)
            ironcondor_tracker[index] = (ironcondor, ironcondor.target_profit().iloc[0], expiry)
# Out:
# date: 2016-11-01 00:00:00
# date: 2016-11-01 00:00:00, current_spot_open: 49.5, OTM Put: 47.5, ATM Put: 49.5, ATM Call: 49.5, OTM Call: 54.5,                 left wing: 2.0, right wing: 5.0
# date: 2016-11-29 00:00:00
# date: 2016-11-29 00:00:00, current_spot_open: 48.0, OTM Put: 43.0, ATM Put: 48.0, ATM Call: 48.0, OTM Call: 49.0,                 left wing: 5.0, right wing: 1.0
# date: 2016-12-13 00:00:00
# date: 2016-12-13 00:00:00, current_spot_open: 48.5, OTM Put: 46.5, ATM Put: 48.5, ATM Call: 48.5, OTM Call: 49.5,                 left wing: 2.0, right wing: 1.0
# date: 2016-12-28 00:00:00
# date: 2016-12-28 00:00:00, current_spot_open: 48.5, OTM Put: 47.0, ATM Put: 48.5, ATM Call: 48.5, OTM Call: 49.5,                 left wing: 1.5, right wing: 1.0
# date: 2017-01-20 00:00:00
# date: 2017-01-20 00:00:00, current_spot_open: 48.5, OTM Put: 45.5, ATM Put: 48.5, ATM Call: 48.5, OTM Call: 49.5,                 left wing: 3.0, right wing: 1.0
# date: 2017-01-31 00:00:00
# date: 2017-01-31 00:00:00, current_spot_open: 48.5, OTM Put: 41.0, ATM Put: 48.5, ATM Call: 48.5, OTM Call: 49.5,                 left wing: 7.5, right wing: 1.0
# date: 2017-02-22 00:00:00
# date: 2017-02-22 00:00:00, current_spot_open: 50.0, OTM Put: 41.5, ATM Put: 50.0, ATM Call: 50.0, OTM Call: 51.0,                 left wing: 8.5, right wing: 1.0
# date: 2017-03-09 00:00:00
# date: 2017-03-09 00:00:00, current_spot_open: 51.0, OTM Put: 50.0, ATM Put: 51.0, ATM Call: 51.0, OTM Call: 53.0,                 left wing: 1.0, right wing: 2.0
# date: 2017-03-16 00:00:00
# date: 2017-03-16 00:00:00, current_spot_open: 52.0, OTM Put: 51.0, ATM Put: 52.0, ATM Call: 52.0, OTM Call: 57.0,                 left wing: 1.0, right wing: 5.0
# date: 2017-04-06 00:00:00
# date: 2017-04-06 00:00:00, current_spot_open: 51.5, OTM Put: 48.0, ATM Put: 51.5, ATM Call: 51.5, OTM Call: 52.0,                 left wing: 3.5, right wing: 0.5
# date: 2017-05-18 00:00:00
# date: 2017-05-18 00:00:00, current_spot_open: 52.0, OTM Put: 51.0, ATM Put: 52.0, ATM Call: 52.0, OTM Call: 55.5,                 left wing: 1.0, right wing: 3.5
# date: 2017-06-02 00:00:00
# date: 2017-06-02 00:00:00, current_spot_open: 54.5, OTM Put: 53.5, ATM Put: 54.5, ATM Call: 54.5, OTM Call: 55.5,                 left wing: 1.0, right wing: 1.0
# date: 2017-07-21 00:00:00
# date: 2017-07-21 00:00:00, current_spot_open: 53.0, OTM Put: 44.5, ATM Put: 53.0, ATM Call: 53.0, OTM Call: 53.5,                 left wing: 8.5, right wing: 0.5
# date: 2017-10-25 00:00:00
# date: 2017-10-25 00:00:00, current_spot_open: 54.5, OTM Put: 49.5, ATM Put: 54.5, ATM Call: 54.5, OTM Call: 55.5,                 left wing: 5.0, right wing: 1.0
# date: 2017-12-01 00:00:00
# date: 2017-12-01 00:00:00, current_spot_open: 57.0, OTM Put: 55.5, ATM Put: 57.0, ATM Call: 57.0, OTM Call: 61.5,                 left wing: 1.5, right wing: 4.5
# date: 2018-03-02 00:00:00
# date: 2018-03-02 00:00:00, current_spot_open: 49.0, OTM Put: 47.0, ATM Put: 49.0, ATM Call: 49.0, OTM Call: 50.5,                 left wing: 2.0, right wing: 1.5
# date: 2018-03-15 00:00:00
# date: 2018-03-15 00:00:00, current_spot_open: 50.0, OTM Put: 48.0, ATM Put: 50.0, ATM Call: 50.0, OTM Call: 51.0,                 left wing: 2.0, right wing: 1.0
# date: 2018-03-20 00:00:00
# date: 2018-03-20 00:00:00, current_spot_open: 50.0, OTM Put: 48.5, ATM Put: 50.0, ATM Call: 50.0, OTM Call: 51.0,                 left wing: 1.5, right wing: 1.0
# date: 2018-05-08 00:00:00
# date: 2018-05-08 00:00:00, current_spot_open: 51.0, OTM Put: 49.5, ATM Put: 51.0, ATM Call: 51.0, OTM Call: 65.0,                 left wing: 1.5, right wing: 14.0
# date: 2018-06-15 00:00:00
# date: 2018-06-15 00:00:00, current_spot_open: 49.0, OTM Put: 42.5, ATM Put: 49.0, ATM Call: 49.0, OTM Call: 50.0,                 left wing: 6.5, right wing: 1.0
# date: 2018-09-05 00:00:00
# date: 2018-09-05 00:00:00, current_spot_open: 53.5, OTM Put: 35.0, ATM Put: 53.5, ATM Call: 53.5, OTM Call: 54.5,                 left wing: 18.5, right wing: 1.0
# date: 2018-10-25 00:00:00
# date: 2018-10-25 00:00:00, current_spot_open: 55.0, OTM Put: 53.5, ATM Put: 55.0, ATM Call: 55.0, OTM Call: 57.0,                 left wing: 1.5, right wing: 2.0
# date: 2018-11-13 00:00:00
# date: 2018-11-13 00:00:00, current_spot_open: 55.0, OTM Put: 52.5, ATM Put: 55.0, ATM Call: 55.0, OTM Call: 56.0,                 left wing: 2.5, right wing: 1.0
# date: 2018-12-13 00:00:00
# date: 2018-12-13 00:00:00, current_spot_open: 56.5, OTM Put: 54.5, ATM Put: 56.5, ATM Call: 56.5, OTM Call: 57.5,                 left wing: 2.0, right wing: 1.0
# date: 2018-12-18 00:00:00
# date: 2018-12-18 00:00:00, current_spot_open: 55.5, OTM Put: 53.5, ATM Put: 55.5, ATM Call: 55.5, OTM Call: 70.0,                 left wing: 2.0, right wing: 14.5
# date: 2019-04-17 00:00:00
# date: 2019-04-17 00:00:00, current_spot_open: 57.5, OTM Put: 56.0, ATM Put: 57.5, ATM Call: 57.5, OTM Call: 58.5,                 left wing: 1.5, right wing: 1.0
# date: 2019-06-25 00:00:00
# date: 2019-06-25 00:00:00, current_spot_open: 61.0, OTM Put: 59.5, ATM Put: 61.0, ATM Call: 61.0, OTM Call: 62.5,                 left wing: 1.5, right wing: 1.5
# date: 2019-07-30 00:00:00
# date: 2019-07-30 00:00:00, current_spot_open: 60.0, OTM Put: 58.0, ATM Put: 60.0, ATM Call: 60.0, OTM Call: 61.0,                 left wing: 2.0, right wing: 1.0
# date: 2019-09-24 00:00:00
# date: 2019-09-24 00:00:00, current_spot_open: 64.0, OTM Put: 55.0, ATM Put: 64.0, ATM Call: 64.0, OTM Call: 65.0,                 left wing: 9.0, right wing: 1.0
# date: 2019-10-03 00:00:00
# date: 2019-10-03 00:00:00, current_spot_open: 64.0, OTM Put: 62.0, ATM Put: 64.0, ATM Call: 64.0, OTM Call: 65.0,                 left wing: 2.0, right wing: 1.0
# date: 2019-12-03 00:00:00
# date: 2019-12-03 00:00:00, current_spot_open: 63.0, OTM Put: 61.5, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 64.0,                 left wing: 1.5, right wing: 1.0
# date: 2019-12-13 00:00:00
# date: 2019-12-13 00:00:00, current_spot_open: 63.0, OTM Put: 61.5, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 64.0,                 left wing: 1.5, right wing: 1.0
# date: 2019-12-20 00:00:00
# date: 2019-12-20 00:00:00, current_spot_open: 64.0, OTM Put: 55.5, ATM Put: 64.0, ATM Call: 64.0, OTM Call: 65.0,                 left wing: 8.5, right wing: 1.0
# date: 2020-02-04 00:00:00
# date: 2020-02-04 00:00:00, current_spot_open: 69.0, OTM Put: 67.5, ATM Put: 69.0, ATM Call: 69.0, OTM Call: 70.5,                 left wing: 1.5, right wing: 1.5
# date: 2020-02-28 00:00:00
# date: 2020-02-28 00:00:00, current_spot_open: 63.0, OTM Put: 58.0, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 66.5,                 left wing: 5.0, right wing: 3.5
# date: 2020-03-17 00:00:00
# Error: 2020-03-17 00:00:00, P
# Error: 2020-03-17 00:00:00, C
# date: 2020-04-15 00:00:00
# date: 2020-04-15 00:00:00, current_spot_open: 59.0, OTM Put: 53.0, ATM Put: 59.0, ATM Call: 59.0, OTM Call: 62.5,                 left wing: 6.0, right wing: 3.5
# date: 2020-04-21 00:00:00
# date: 2020-04-21 00:00:00, current_spot_open: 57.0, OTM Put: 48.0, ATM Put: 57.0, ATM Call: 57.0, OTM Call: 60.0,                 left wing: 9.0, right wing: 3.0
# date: 2020-05-29 00:00:00
# date: 2020-05-29 00:00:00, current_spot_open: 59.0, OTM Put: 30.0, ATM Put: 59.0, ATM Call: 59.0, OTM Call: 61.0,                 left wing: 29.0, right wing: 2.0
# date: 2020-06-12 00:00:00
# date: 2020-06-12 00:00:00, current_spot_open: 60.0, OTM Put: 56.5, ATM Put: 60.0, ATM Call: 60.0, OTM Call: 68.5,                 left wing: 3.5, right wing: 8.5
# date: 2020-06-26 00:00:00
# date: 2020-06-26 00:00:00, current_spot_open: 55.5, OTM Put: 50.5, ATM Put: 55.5, ATM Call: 55.5, OTM Call: 58.5,                 left wing: 5.0, right wing: 3.0
# date: 2020-08-20 00:00:00
# date: 2020-08-20 00:00:00, current_spot_open: 59.5, OTM Put: 57.5, ATM Put: 59.5, ATM Call: 59.5, OTM Call: 61.0,                 left wing: 2.0, right wing: 1.5
# date: 2020-09-18 00:00:00
# date: 2020-09-18 00:00:00, current_spot_open: 59.5, OTM Put: 57.0, ATM Put: 59.5, ATM Call: 59.5, OTM Call: 68.0,                 left wing: 2.5, right wing: 8.5
# date: 2020-10-01 00:00:00
# date: 2020-10-01 00:00:00, current_spot_open: 59.5, OTM Put: 50.0, ATM Put: 59.5, ATM Call: 59.5, OTM Call: 60.5,                 left wing: 9.5, right wing: 1.0
# date: 2020-12-01 00:00:00
# date: 2020-12-01 00:00:00, current_spot_open: 63.5, OTM Put: 61.0, ATM Put: 63.5, ATM Call: 63.5, OTM Call: 65.5,                 left wing: 2.5, right wing: 2.0
# date: 2020-12-11 00:00:00
# date: 2020-12-11 00:00:00, current_spot_open: 62.0, OTM Put: 59.5, ATM Put: 62.0, ATM Call: 62.0, OTM Call: 67.5,                 left wing: 2.5, right wing: 5.5
# date: 2020-12-15 00:00:00
# date: 2020-12-15 00:00:00, current_spot_open: 62.0, OTM Put: 50.0, ATM Put: 62.0, ATM Call: 62.0, OTM Call: 63.0,                 left wing: 12.0, right wing: 1.0
# date: 2021-01-26 00:00:00
# date: 2021-01-26 00:00:00, current_spot_open: 64.0, OTM Put: 62.0, ATM Put: 64.0, ATM Call: 64.0, OTM Call: 66.5,                 left wing: 2.0, right wing: 2.5
# date: 2021-02-12 00:00:00
# date: 2021-02-12 00:00:00, current_spot_open: 63.0, OTM Put: 61.0, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 65.0,                 left wing: 2.0, right wing: 2.0
# date: 2021-04-13 00:00:00
# date: 2021-04-13 00:00:00, current_spot_open: 64.5, OTM Put: 35.0, ATM Put: 64.5, ATM Call: 64.5, OTM Call: 65.5,                 left wing: 29.5, right wing: 1.0
# date: 2021-08-05 00:00:00
# date: 2021-08-05 00:00:00, current_spot_open: 67.0, OTM Put: 50.0, ATM Put: 67.0, ATM Call: 67.0, OTM Call: 68.0,                 left wing: 17.0, right wing: 1.0
# date: 2021-09-21 00:00:00
# date: 2021-09-21 00:00:00, current_spot_open: 66.0, OTM Put: 63.5, ATM Put: 66.0, ATM Call: 66.0, OTM Call: 67.5,                 left wing: 2.5, right wing: 1.5
# date: 2021-11-02 00:00:00
# date: 2021-11-02 00:00:00, current_spot_open: 67.5, OTM Put: 65.5, ATM Put: 67.5, ATM Call: 67.5, OTM Call: 69.0,                 left wing: 2.0, right wing: 1.5
# date: 2021-12-01 00:00:00
# date: 2021-12-01 00:00:00, current_spot_open: 66.0, OTM Put: 62.5, ATM Put: 66.0, ATM Call: 66.0, OTM Call: 68.0,                 left wing: 3.5, right wing: 2.0
# date: 2022-01-04 00:00:00
# date: 2022-01-04 00:00:00, current_spot_open: 71.0, OTM Put: 69.0, ATM Put: 71.0, ATM Call: 71.0, OTM Call: 72.5,                 left wing: 2.0, right wing: 1.5
# date: 2022-01-25 00:00:00
# date: 2022-01-25 00:00:00, current_spot_open: 67.0, OTM Put: 62.0, ATM Put: 67.0, ATM Call: 67.0, OTM Call: 69.0,                 left wing: 5.0, right wing: 2.0
# date: 2022-04-26 00:00:00
# date: 2022-04-26 00:00:00, current_spot_open: 73.5, OTM Put: 63.0, ATM Put: 73.5, ATM Call: 73.5, OTM Call: 76.0,                 left wing: 10.5, right wing: 2.5
# date: 2022-06-09 00:00:00
# date: 2022-06-09 00:00:00, current_spot_open: 73.5, OTM Put: 66.0, ATM Put: 73.5, ATM Call: 73.5, OTM Call: 85.0,                 left wing: 7.5, right wing: 11.5
# date: 2022-08-23 00:00:00
# Error: 2022-08-23 00:00:00, P
# Error: 2022-08-23 00:00:00, C
# date: 2022-11-03 00:00:00
# date: 2022-11-03 00:00:00, current_spot_open: 66.0, OTM Put: 45.0, ATM Put: 66.0, ATM Call: 66.0, OTM Call: 68.0,                 left wing: 21.0, right wing: 2.0
# C:\Users\asus\AppData\Local\Temp\ipykernel_52020\2080260267.py:17: FutureWarning: The behavior of Series.argmax/argmin with skipna=False and NAs, or with all-NAs is deprecated. In a future version this will raise ValueError.
#   return options.iloc[(options["delta"] - new_delta).abs().argmin()]["strike_price"]
# date: 2022-11-29 00:00:00
# date: 2022-11-29 00:00:00, current_spot_open: 70.0, OTM Put: 67.0, ATM Put: 70.0, ATM Call: 70.0, OTM Call: 72.0,                 left wing: 3.0, right wing: 2.0
# date: 2022-12-28 00:00:00
# date: 2022-12-28 00:00:00, current_spot_open: 71.5, OTM Put: 69.0, ATM Put: 71.5, ATM Call: 71.5, OTM Call: 74.0,                 left wing: 2.5, right wing: 2.5
# date: 2023-01-04 00:00:00
# date: 2023-01-04 00:00:00, current_spot_open: 71.0, OTM Put: 64.5, ATM Put: 71.0, ATM Call: 71.0, OTM Call: 73.0,                 left wing: 6.5, right wing: 2.0
# date: 2023-04-25 00:00:00
# date: 2023-04-25 00:00:00, current_spot_open: 69.5, OTM Put: 61.0, ATM Put: 69.5, ATM Call: 69.5, OTM Call: 71.0,                 left wing: 8.5, right wing: 1.5
# date: 2023-07-18 00:00:00
# date: 2023-07-18 00:00:00, current_spot_open: 66.0, OTM Put: 64.0, ATM Put: 66.0, ATM Call: 66.0, OTM Call: 67.5,                 left wing: 2.0, right wing: 1.5
# date: 2023-08-04 00:00:00
# date: 2023-08-04 00:00:00, current_spot_open: 65.0, OTM Put: 63.0, ATM Put: 65.0, ATM Call: 65.0, OTM Call: 68.5,                 left wing: 2.0, right wing: 3.5
# date: 2023-08-22 00:00:00
# date: 2023-08-22 00:00:00, current_spot_open: 63.0, OTM Put: 57.0, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 64.5,                 left wing: 6.0, right wing: 1.5

# %% [markdown]
# ### 1a close early when signal turns -1

# %%
pnl_dict = {}

for index, (ironcondor, target_profit, expiry) in ironcondor_tracker.items():
    print(f"Processing date: {index}, expiry: {expiry}")
    if ironcondor is not None:

        test_time_series = xlu_time_series.loc[index:expiry + pd.Timedelta(days=1)]
        options_test_df = xlu_filtered_options.loc[index:expiry + pd.Timedelta(days=1)]
        early_close = False

        for date, row in test_time_series.iterrows():
            if row["signal"] == -1:
                
                print(f"Closing on date: {date}")
                ic_strikes = ironcondor.strikes
                print(f"strike1: {ic_strikes['strike1']}, strike2: {ic_strikes['strike2']}, strike3: {ic_strikes['strike3']}, strike4: {ic_strikes['strike4']}")

                try:
                    long_put_buyback = options_test_df.loc[date][
                        (options_test_df.loc[date]["cp_flag"] == 'P') & 
                        (options_test_df.loc[date]["strike_price"] == ic_strikes["strike1"])
                    ]["best_offer"].values[0]
                except IndexError:
                    closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'P'] \
                    .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike1"]).abs()) \
                    .sort_values("distance").iloc[0]["strike_price"]
                    
                    # Select the best offer at the closest strike price
                    long_put_buyback = options_test_df.loc[date][
                        (options_test_df.loc[date]["cp_flag"] == 'P') &
                        (options_test_df.loc[date]["strike_price"] == closest_strike)
                    ]["best_offer"].values[0]
                print(f"Long put buyback: {long_put_buyback}")

                try:
                    short_put_sellback = options_test_df.loc[date][
                        (options_test_df.loc[date]["cp_flag"] == 'P') & 
                        (options_test_df.loc[date]["strike_price"] == ic_strikes["strike2"])
                    ]["best_bid"].values[0]
                except IndexError:
                    closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'P'] \
                    .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike2"]).abs()) \
                    .sort_values("distance").iloc[0]["strike_price"]
                    
                    # Select the best bid at the closest strike price
                    short_put_sellback = options_test_df.loc[date][
                        (options_test_df.loc[date]["cp_flag"] == 'P') &
                        (options_test_df.loc[date]["strike_price"] == closest_strike)
                    ]["best_bid"].values[0]
                print(f"Short put sellback: {short_put_sellback}")


                try:
                    short_call_sellback = options_test_df.loc[date][
                        (options_test_df.loc[date]["cp_flag"] == 'C') & 
                        (options_test_df.loc[date]["strike_price"] == ic_strikes["strike3"])
                    ]["best_bid"].values[0]
                except IndexError:
                    closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'C'] \
                    .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike3"]).abs()) \
                    .sort_values("distance").iloc[0]["strike_price"]
                    
                    # Select the best bid at the closest strike price
                    short_call_sellback = options_test_df.loc[date][
                        (options_test_df.loc[date]["cp_flag"] == 'C') &
                        (options_test_df.loc[date]["strike_price"] == closest_strike)
                    ]["best_bid"].values[0]
                print(f"Short call sellback: {short_call_sellback}")

                try:
                    long_call_buyback = options_test_df.loc[date][
                        (options_test_df.loc[date]["cp_flag"] == 'C') & 
                        (options_test_df.loc[date]["strike_price"] == ic_strikes["strike4"])
                    ]["best_offer"].values[0]
                except IndexError:
                    closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'C'] \
                    .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike4"]).abs()) \
                    .sort_values("distance").iloc[0]["strike_price"]
                    
                    # Select the best offer at the closest strike price
                    long_call_buyback = options_test_df.loc[date][
                        (options_test_df.loc[date]["cp_flag"] == 'C') &
                        (options_test_df.loc[date]["strike_price"] == closest_strike)
                    ]["best_offer"].values[0]
                print(f"Long call buyback: {long_call_buyback}")

                closing_cost = -long_put_buyback + short_put_sellback + short_call_sellback - long_call_buyback
                print(f"Closing cost: {closing_cost}")

                ironcondor.insert_spot(xlu_time_series.loc[date]["Close"])
                pnl_dict[index] = ironcondor.payoff() - closing_cost
                print(f"Close iron condor early on date: {date} when signal is -1, pnl: {pnl_dict[index]}")
                early_close = True
                break
        if not early_close:
            try:
                ironcondor.insert_spot(xlu_time_series.loc[expiry]["Close"])
            except KeyError:
                ironcondor.insert_spot(xlu_time_series.loc[expiry - pd.Timedelta(days=1)]["Close"])
            
            print(f"Let iron condor expire: {expiry}, pnl: {ironcondor.payoff()}")
            pnl_dict[index] = ironcondor.payoff()
# Out:
# Processing date: 2016-11-01 00:00:00, expiry: 2016-11-11 00:00:00
# Closing on date: 2016-11-10 00:00:00
# strike1: 47.5, strike2: 49.5, strike3: 49.5, strike4: 54.5
# Long put buyback: 1.44
# Short put sellback: 3.2
# Short call sellback: 0.01
# Long call buyback: 0.02
# Closing cost: 1.7500000000000002
# Close iron condor early on date: 2016-11-10 00:00:00 when signal is -1, pnl: -2.6400000000000006
# Processing date: 2016-11-29 00:00:00, expiry: 2016-12-09 00:00:00
# Let iron condor expire: 2016-12-09 00:00:00, pnl: 0.7599990844726563
# Processing date: 2016-12-13 00:00:00, expiry: 2016-12-23 00:00:00
# Let iron condor expire: 2016-12-23 00:00:00, pnl: 0.8099993896484375
# Processing date: 2016-12-28 00:00:00, expiry: 2017-01-06 00:00:00
# Let iron condor expire: 2017-01-06 00:00:00, pnl: 0.36999816894531246
# Processing date: 2017-01-20 00:00:00, expiry: 2017-02-03 00:00:00
# Closing on date: 2017-02-03 00:00:00
# strike1: 45.5, strike2: 48.5, strike3: 48.5, strike4: 49.5
# Long put buyback: 0.03
# Short put sellback: 0.35
# Short call sellback: 0.75
# Long call buyback: 0.27
# Closing cost: 0.7999999999999998
# Close iron condor early on date: 2017-02-03 00:00:00 when signal is -1, pnl: -0.42000152587890616
# Processing date: 2017-01-31 00:00:00, expiry: 2017-02-10 00:00:00
# Closing on date: 2017-02-03 00:00:00
# strike1: 41.0, strike2: 48.5, strike3: 48.5, strike4: 49.5
# Long put buyback: 0.02
# Short put sellback: 0.35
# Short call sellback: 0.75
# Long call buyback: 0.27
# Closing cost: 0.81
# Close iron condor early on date: 2017-02-03 00:00:00 when signal is -1, pnl: -0.4600015258789063
# Processing date: 2017-02-22 00:00:00, expiry: 2017-03-03 00:00:00
# Processing date: 2022-01-04 00:00:00, expiry: 2022-01-14 00:00:00
# Closing on date: 2022-01-14 00:00:00
# strike1: 69.0, strike2: 71.0, strike3: 71.0, strike4: 72.5
# Long put buyback: 0.7
# Short put sellback: 1.71
# Short call sellback: 0.21
# Long call buyback: 0.07
# Closing cost: 1.15
# Close iron condor early on date: 2022-01-14 00:00:00 when signal is -1, pnl: -1.8799984741210936
# Processing date: 2022-01-25 00:00:00, expiry: 2022-02-04 00:00:00
# Closing on date: 2022-02-02 00:00:00
# strike1: 62.0, strike2: 67.0, strike3: 67.0, strike4: 69.0
# Long put buyback: 0.08
# Short put sellback: 0.15
# Short call sellback: 2.41
# Long call buyback: 1.02
# Closing cost: 1.46
# Close iron condor early on date: 2022-02-02 00:00:00 when signal is -1, pnl: -2.06
# Processing date: 2022-04-26 00:00:00, expiry: 2022-05-06 00:00:00
# Closing on date: 2022-05-04 00:00:00
# strike1: 63.0, strike2: 73.5, strike3: 73.5, strike4: 76.0
# Long put buyback: 0.03
# Short put sellback: 1.45
# Short call sellback: 0.35
# Long call buyback: 0.03
# Closing cost: 1.74
# Close iron condor early on date: 2022-05-04 00:00:00 when signal is -1, pnl: -2.8200027465820314
# Processing date: 2022-06-09 00:00:00, expiry: 2022-06-17 00:00:00
# Closing on date: 2022-06-15 00:00:00
# strike1: 66.0, strike2: 73.5, strike3: 73.5, strike4: 85.0
# Long put buyback: 1.05
# Short put sellback: 6.55
# Short call sellback: 0.0
# Long call buyback: 0.04
# Closing cost: 5.46
# Close iron condor early on date: 2022-06-15 00:00:00 when signal is -1, pnl: -10.200003356933593
# Processing date: 2022-11-03 00:00:00, expiry: 2022-11-11 00:00:00
# Let iron condor expire: 2022-11-11 00:00:00, pnl: -0.45000000000000007
# Processing date: 2022-11-29 00:00:00, expiry: 2022-12-09 00:00:00
# Let iron condor expire: 2022-12-09 00:00:00, pnl: 0.5699981689453125
# Processing date: 2022-12-28 00:00:00, expiry: 2023-01-06 00:00:00
# Let iron condor expire: 2023-01-06 00:00:00, pnl: 0.82
# Processing date: 2023-01-04 00:00:00, expiry: 2023-01-13 00:00:00
# Closing on date: 2023-01-13 00:00:00
# strike1: 64.5, strike2: 71.0, strike3: 71.0, strike4: 73.0
# Long put buyback: 0.03
# Short put sellback: 0.68
# Short call sellback: 1.07
# Long call buyback: 0.29
# Closing cost: 1.4300000000000002
# Close iron condor early on date: 2023-01-13 00:00:00 when signal is -1, pnl: -0.4400018310546876
# Processing date: 2023-04-25 00:00:00, expiry: 2023-05-05 00:00:00
# Let iron condor expire: 2023-05-05 00:00:00, pnl: 0.799998779296875
# Processing date: 2023-07-18 00:00:00, expiry: 2023-07-28 00:00:00
# Closing on date: 2023-07-21 00:00:00
# strike1: 64.0, strike2: 66.0, strike3: 66.0, strike4: 67.5
# Long put buyback: 0.06
# Short put sellback: 0.14
# Short call sellback: 2.74
# Long call buyback: 1.59
# Closing cost: 1.2300000000000002
# Close iron condor early on date: 2023-07-21 00:00:00 when signal is -1, pnl: -1.7200000000000002
# Processing date: 2023-08-04 00:00:00, expiry: 2023-08-18 00:00:00
# Let iron condor expire: 2023-08-18 00:00:00, pnl: -0.259998321533203
# Processing date: 2023-08-22 00:00:00, expiry: 2023-09-01 00:00:00
# Let iron condor expire: 2023-09-01 00:00:00, pnl: 1.0799990844726564

# %%
pd.DataFrame(pnl_dict.items(), columns=["Date", "PnL"]).set_index("Date").PnL.cumsum().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### 1a optimisation

# %%
# Function to evaluate the Sharpe ratio based on current thresholds
def evaluate_strategy(upper_threshold, lower_threshold, xlu_time_series, xlu_filtered_options):
    # Update signals
    xlu_time_series["signal"] = np.where(xlu_time_series["vrp"] > upper_threshold, 1, 
                                          np.where(xlu_time_series["vrp"] < lower_threshold, -1, 0))
    xlu_time_series["action"] = np.where((xlu_time_series["signal"] == 1) & (xlu_time_series.index.weekday != 4), 1, 
                                          np.where((xlu_time_series["signal"] == -1) & (xlu_time_series.index.weekday != 4), -1, 0))
    
    xlu_time_series = ensure_weekly_action(xlu_time_series)
    xlu_time_series["action"] = xlu_time_series["action"].shift()
    
    ironcondor_tracker = {}
    pnl_dict = {}

    def find_nearest_strike_delta(atm_spot, date_index, delta_target, option_df, cp_flag):
        options = option_df.loc[date_index].query(f"cp_flag == '{cp_flag}'")
        atm_delta = options.query("strike_price == @atm_spot")["delta"]
        try:
            if isinstance(atm_delta, pd.Series):
                atm_delta = atm_delta.values[0]
        except IndexError:
            return None
        new_delta = atm_delta + delta_target
        return options.iloc[(options["delta"] - new_delta).abs().argmin()]["strike_price"]

    for index, row in xlu_time_series.iterrows():
        if row["action"] == 1:  # Long Iron Condor
            direction = "short"
            index_loc = xlu_time_series.index.get_loc(index)
            current_spot_open = myround(xlu_time_series.iloc[index_loc]["Open"], 0.5)
            atm_put_strike = atm_call_strike = current_spot_open
            otm_put_strike = find_nearest_strike_delta(current_spot_open, index, 0.4, xlu_filtered_options, "P")
            otm_call_strike = find_nearest_strike_delta(current_spot_open, index, -0.3, xlu_filtered_options, "C")

            if otm_put_strike is None or otm_call_strike is None:
                continue

            strikes = {
                "strike1": otm_put_strike,
                "strike2": atm_put_strike,
                "strike3": atm_call_strike,
                "strike4": otm_call_strike
            }

            premiums = {
                "premium1": xlu_filtered_options.loc[
                    (xlu_filtered_options.index == index) & 
                    (xlu_filtered_options["strike_price"] == strikes["strike1"]) & 
                    (xlu_filtered_options["cp_flag"] == 'P'), "best_offer"
                ].values[0],  # Get the value directly
                "premium2": xlu_filtered_options.loc[
                    (xlu_filtered_options.index == index) & 
                    (xlu_filtered_options["strike_price"] == strikes["strike2"]) & 
                    (xlu_filtered_options["cp_flag"] == 'P'), "best_bid"
                ].values[0],  # Get the value directly
                "premium3": xlu_filtered_options.loc[
                    (xlu_filtered_options.index == index) & 
                    (xlu_filtered_options["strike_price"] == strikes["strike3"]) & 
                    (xlu_filtered_options["cp_flag"] == 'C'), "best_bid"
                ].values[0],  # Get the value directly
                "premium4": xlu_filtered_options.loc[
                    (xlu_filtered_options.index == index) & 
                    (xlu_filtered_options["strike_price"] == strikes["strike4"]) & 
                    (xlu_filtered_options["cp_flag"] == 'C'), "best_offer"
                ].values[0]   # Get the value directly
            }

            expiry = xlu_filtered_options.loc[index]["exdate"].max()
            ironcondor = IronCondor(direction=direction, strikes=strikes, premiums=premiums, expiry=expiry)
            ironcondor_tracker[index] = (ironcondor, ironcondor.target_profit(), expiry)

            # Early exit processing based on signal changes
            initial_premium = ironcondor.initial_cashflow()
            early_exit = False

            # Loop through potential exit dates to monitor PnL
            for date in xlu_time_series.loc[index:expiry + pd.Timedelta(days=1)].index:
                # Calculate unrealized PnL
                ironcondor.insert_spot(xlu_time_series.loc[date]["Close"])
                unrealized_pnl = ironcondor.payoff()

                # Check if the action signal changes to -1 for closing the position
                if xlu_time_series.loc[date]["signal"] == -1:
                    print(f"Closing position early on date: {date} due to signal change")
                    pnl_dict[index] = unrealized_pnl
                    early_exit = True
                    break

            # If position is not closed early, let it expire
            if not early_exit:
                try:
                    ironcondor.insert_spot(xlu_time_series.loc[expiry]["Close"])
                except KeyError:
                    ironcondor.insert_spot(xlu_time_series.loc[expiry - pd.Timedelta(days=1)]["Close"])
                pnl_dict[index] = ironcondor.payoff()

    # Calculate the Sharpe ratio based on the final PnL
    returns = np.array(list(pnl_dict.values()))
    sharpe_ratio = np.mean(returns) / np.std(returns) if np.std(returns) != 0 else 0

    # Calculate Maximum Drawdown
    cumulative_returns = np.cumsum(returns)
    peak = np.maximum.accumulate(cumulative_returns)
    drawdown = (peak - cumulative_returns) / peak
    max_drawdown = np.max(drawdown)

    # Combine Sharpe Ratio and Drawdown into a single objective function
    weight_sharpe = 1  # Weight for Sharpe Ratio
    weight_drawdown = -1  # Negative weight for Drawdown (to minimize it)

    combined_score = weight_sharpe * sharpe_ratio + weight_drawdown * max_drawdown

    return combined_score

# %%
from skopt import gp_minimize

def objective(params):
    upper_threshold, lower_threshold = params
    score = evaluate_strategy(upper_threshold, lower_threshold, xlu_time_series, xlu_filtered_options)
    return -score  # Negate to convert to minimization problem

# Define the bounds for parameters
bounds = [(0, 5), (-5, 0)]  # Example bounds; adjust as necessary

# Run Bayesian optimization
result = gp_minimize(objective, dimensions=bounds, n_calls=50, random_state=42)

# Retrieve and display the results
best_params = result.x
best_score = -result.fun

print("Best Upper Threshold:", best_params[0])
print("Best Lower Threshold:", best_params[1])
print("Best Score (Combined Metric):", best_score)
# Out:
# c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\numpy\core\_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\numpy\core\_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\numpy\core\_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 12
#       9 bounds = [(0, 5), (-5, 0)]  # Example bounds; adjust as necessary
#      11 # Run Bayesian optimization
# ---> 12 result = gp_minimize(objective, dimensions=bounds, n_calls=50, random_state=42)
#      14 # Retrieve and display the results
#      15 best_params = result.x
#
# File c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\skopt\optimizer\gp.py:281, in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size, space_constraint)
#     273 if base_estimator is None:
#     274     base_estimator = cook_estimator(
#     275         "GP",
#     276         space=space,
#     277         random_state=rng.randint(0, np.iinfo(np.int32).max),
#     278         noise=noise,
#     279     )
# --> 281 return base_minimize(
#     282     func,
#     283     space,
#     284     base_estimator=base_estimator,
#     285     acq_func=acq_func,
#     286     xi=xi,
#     287     kappa=kappa,
#     288     acq_optimizer=acq_optimizer,
#     289     n_calls=n_calls,
#     290     n_points=n_points,
#     291     n_random_starts=n_random_starts,
#     292     n_initial_points=n_initial_points,
#     293     initial_point_generator=initial_point_generator,
#     294     n_restarts_optimizer=n_restarts_optimizer,
#     295     x0=x0,
#     296     y0=y0,
#     297     random_state=rng,
#     298     verbose=verbose,
#     299     space_constraint=space_constraint,
#     300     callback=callback,
#     301     n_jobs=n_jobs,
#     302     model_queue_size=model_queue_size,
#     303 )
#
# File c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\skopt\optimizer\base.py:332, in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size, space_constraint)
#     330 for _ in range(n_calls):
#     331     next_x = optimizer.ask()
# --> 332     next_y = func(next_x)
#     333     result = optimizer.tell(next_x, next_y)
#     334     result.specs = specs
#
# Cell In[76], line 5, in objective(params)
#       3 def objective(params):
#       4     upper_threshold, lower_threshold = params
# ----> 5     score = evaluate_strategy(upper_threshold, lower_threshold, xlu_time_series, xlu_filtered_options)
#       6     return -score
#
# Cell In[75], line 105, in evaluate_strategy(upper_threshold, lower_threshold, xlu_time_series, xlu_filtered_options)
#     103 peak = np.maximum.accumulate(cumulative_returns)
#     104 drawdown = (peak - cumulative_returns) / peak
# --> 105 max_drawdown = np.max(drawdown)
#     107 # Combine Sharpe Ratio and Drawdown into a single objective function
#     108 weight_sharpe = 1  # Weight for Sharpe Ratio
#
# File c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\numpy\core\fromnumeric.py:2810, in max(a, axis, out, keepdims, initial, where)
#    2692 @array_function_dispatch(_max_dispatcher)
#    2693 @set_module('numpy')
#    2694 def max(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2695          where=np._NoValue):
#    2696     """
#    2697     Return the maximum of an array or maximum along an axis.
#    2698
#    (...)
#    2808     5
#    2809     """
# -> 2810     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2811                           keepdims=keepdims, initial=initial, where=where)
#
# File c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\numpy\core\fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
# Define the parameter space for upper and lower thresholds
space = [
    Real(-2.5, 2.5, name="upper_threshold"),
    Real(-2.5, 2.5, name="lower_threshold")
]

# Run Bayesian optimization
result = gp_minimize(
    func=objective,
    dimensions=space,
    n_calls=50,  # Number of optimization iterations
    random_state=42  # For reproducibility
)

# Display optimal thresholds
optimal_upper = result.x[0]
optimal_lower = result.x[1]
print(f"Optimal upper_threshold: {optimal_upper}, Optimal lower_threshold: {optimal_lower}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 5
#       2 space  = [Real(1.0, 2.5, name="upper_threshold"), Real(-2.5, -1.0, name="lower_threshold")]
#       4 # Run Bayesian Optimization
# ----> 5 result = gp_minimize(lambda params: objective(params, xlu_time_series, xlu_filtered_options), space, n_calls=50, random_state=0)
#       7 # Print best found thresholds
#       8 print(f"Best upper_threshold: {result.x[0]}, Best lower_threshold: {result.x[1]}")
#
# File c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\skopt\optimizer\gp.py:281, in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size, space_constraint)
#     273 if base_estimator is None:
#     274     base_estimator = cook_estimator(
#     275         "GP",
#     276         space=space,
#     277         random_state=rng.randint(0, np.iinfo(np.int32).max),
#     278         noise=noise,
#     279     )
# --> 281 return base_minimize(
#     282     func,
#     283     space,
#     284     base_estimator=base_estimator,
#     285     acq_func=acq_func,
#     286     xi=xi,
#     287     kappa=kappa,
#     288     acq_optimizer=acq_optimizer,
#     289     n_calls=n_calls,
#     290     n_points=n_points,
#     291     n_random_starts=n_random_starts,
#     292     n_initial_points=n_initial_points,
#     293     initial_point_generator=initial_point_generator,
#     294     n_restarts_optimizer=n_restarts_optimizer,
#     295     x0=x0,
#     296     y0=y0,
#     297     random_state=rng,
#     298     verbose=verbose,
#     299     space_constraint=space_constraint,
#     300     callback=callback,
#     301     n_jobs=n_jobs,
#     302     model_queue_size=model_queue_size,
#     303 )
#
# File c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\skopt\optimizer\base.py:332, in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size, space_constraint)
#     330 for _ in range(n_calls):
#     331     next_x = optimizer.ask()
# --> 332     next_y = func(next_x)
#     333     result = optimizer.tell(next_x, next_y)
#     334     result.specs = specs
#
# Cell In[33], line 5, in <lambda>(params)
#       2 space  = [Real(1.0, 2.5, name="upper_threshold"), Real(-2.5, -1.0, name="lower_threshold")]
#       4 # Run Bayesian Optimization
# ----> 5 result = gp_minimize(lambda params: objective(params, xlu_time_series, xlu_filtered_options), space, n_calls=50, random_state=0)
#       7 # Print best found thresholds
#       8 print(f"Best upper_threshold: {result.x[0]}, Best lower_threshold: {result.x[1]}")
#
# Cell In[32], line 49, in objective(params, xlu_time_series, xlu_filtered_options)
#      46     target_profit = ironcondor.target_profit()  # Define target profit
#      48     # Track P&L
# ---> 49     pnl_dict[index] = calculate_pnl(ironcondor, target_profit, xlu_time_series, xlu_filtered_options, expiry)
#      51 # Calculate Sharpe Ratio, avoiding division by zero
#      52 pnl_series = pd.Series(pnl_dict)
#
# Cell In[32], line 69, in calculate_pnl(ironcondor, target_profit, xlu_time_series, xlu_filtered_options, expiry)
#      67 pnl = 0
#      68 for date in xlu_time_series.loc[ironcondor.expiry:].index:
# ---> 69     closing_cost = calculate_closing_cost(date, ironcondor, xlu_filtered_options)
#      70     spot_price = xlu_time_series.at[date, "Close"] if date in xlu_time_series.index else 0
#      71     ironcondor.insert_spot(spot_price)
#
# Cell In[32], line 85, in calculate_closing_cost(date, ironcondor, xlu_filtered_options)
#      79 def calculate_closing_cost(date, ironcondor, xlu_filtered_options):
#      80     strikes = ironcondor.strikes
#      81     return (
#      82         get_option_premium(xlu_filtered_options, date, strikes["strike1"], 'P', "best_offer") -
#      83         get_option_premium(xlu_filtered_options, date, strikes["strike2"], 'P', "best_bid") +
#      84         get_option_premium(xlu_filtered_options, date, strikes["strike3"], 'C', "best_bid") -
# ---> 85         get_option_premium(xlu_filtered_options, date, strikes["strike4"], 'C', "best_offer")
#      86     )
#
# Cell In[32], line 60, in get_option_premium(options_df, date, strike_price, cp_flag, price_type)
#      59 def get_option_premium(options_df, date, strike_price, cp_flag, price_type):
# ---> 60     premium = options_df.loc[(options_df.index == date) &
#      61                              (options_df["strike_price"] == strike_price) &
#      62                              (options_df["cp_flag"] == cp_flag)][price_type]
#      63     return premium.iloc[0] if not premium.empty else 0
#
# File c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\pandas\core\arraylike.py:70, in OpsMixin.__and__(self, other)
#      68 @unpack_zerodim_and_defer("__and__")
#      69 def __and__(self, other):
# ---> 70     return self._logical_method(other, operator.and_)
#
# File c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\pandas\core\series.py:6130, in Series._logical_method(self, other, op)
#    6127 lvalues = self._values
#    6128 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6130 res_values = ops.logical_op(lvalues, rvalues, op)
#    6131 return self._construct_result(res_values, name=res_name)
#
# File c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\pandas\core\ops\array_ops.py:448, in logical_op(left, right, op)
#     446     is_other_int_dtype = rvalues.dtype.kind in "iu"
#     447     if not is_other_int_dtype:
# --> 448         rvalues = fill_bool(rvalues, lvalues)
#     450 else:
#     451     # i.e. scalar
#     452     is_other_int_dtype = lib.is_integer(rvalues)
#
# File c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\pandas\core\ops\array_ops.py:420, in logical_op.<locals>.fill_bool(x, left)
#     417         x[mask] = False
#     419 if left is None or left.dtype.kind == "b":
# --> 420     x = x.astype(bool)
#     421 return x
#
# KeyboardInterrupt:

# %% [markdown]
# ### 1b hold till expiry

# %%
pnl_dict = {}

for index, (ironcondor, target_profit, expiry) in ironcondor_tracker.items():
    print(f"Processing date: {index}, expiry: {expiry}")
    if ironcondor is not None:
        try:
            ironcondor.insert_spot(xlu_time_series.loc[expiry]["Close"])
            print(f"---Closing spot: {xlu_time_series.loc[expiry]['Close']}")
        except KeyError:
            ironcondor.insert_spot(xlu_time_series.loc[expiry - pd.Timedelta(days=1)]["Close"])
            print(f"---Closing spot: {xlu_time_series.loc[expiry - pd.Timedelta(days=1)]['Close']}")
        pnl_dict[index] = ironcondor.payoff()

        print(f"-Let iron condor expire: {expiry}, pnl: {pnl_dict[index]}")
        ic_strikes = ironcondor.strikes
        print(f"---strike1: {ic_strikes['strike1']}, strike2: {ic_strikes['strike2']}, strike3: {ic_strikes['strike3']}, strike4: {ic_strikes['strike4']}")
# Out:
# Processing date: 2016-11-01 00:00:00, expiry: 2016-11-11 00:00:00
# ---Closing spot: 46.220001220703125
# -Let iron condor expire: 2016-11-11 00:00:00, pnl: -0.8900000000000001
# ---strike1: 47.5, strike2: 49.5, strike3: 49.5, strike4: 54.5
# Processing date: 2016-11-29 00:00:00, expiry: 2016-12-09 00:00:00
# ---Closing spot: 47.959999084472656
# -Let iron condor expire: 2016-12-09 00:00:00, pnl: 0.7599990844726563
# ---strike1: 43.0, strike2: 48.0, strike3: 48.0, strike4: 49.0
# Processing date: 2016-12-13 00:00:00, expiry: 2016-12-23 00:00:00
# ---Closing spot: 48.61000061035156
# -Let iron condor expire: 2016-12-23 00:00:00, pnl: 0.8099993896484375
# ---strike1: 46.5, strike2: 48.5, strike3: 48.5, strike4: 49.5
# Processing date: 2016-12-28 00:00:00, expiry: 2017-01-06 00:00:00
# ---Closing spot: 48.83000183105469
# -Let iron condor expire: 2017-01-06 00:00:00, pnl: 0.36999816894531246
# Processing date: 2023-04-25 00:00:00, expiry: 2023-05-05 00:00:00
# ---Closing spot: 69.02999877929688
# -Let iron condor expire: 2023-05-05 00:00:00, pnl: 0.799998779296875
# ---strike1: 61.0, strike2: 69.5, strike3: 69.5, strike4: 71.0
# Processing date: 2023-07-18 00:00:00, expiry: 2023-07-28 00:00:00
# ---Closing spot: 67.04000091552734
# -Let iron condor expire: 2023-07-28 00:00:00, pnl: -0.030000915527343852
# ---strike1: 64.0, strike2: 66.0, strike3: 66.0, strike4: 67.5
# Processing date: 2023-08-04 00:00:00, expiry: 2023-08-18 00:00:00
# ---Closing spot: 63.4900016784668
# -Let iron condor expire: 2023-08-18 00:00:00, pnl: -0.259998321533203
# ---strike1: 63.0, strike2: 65.0, strike3: 65.0, strike4: 68.5
# Processing date: 2023-08-22 00:00:00, expiry: 2023-09-01 00:00:00
# ---Closing spot: 62.959999084472656
# -Let iron condor expire: 2023-09-01 00:00:00, pnl: 1.0799990844726564
# ---strike1: 57.0, strike2: 63.0, strike3: 63.0, strike4: 64.5

# %%
pd.DataFrame(pnl_dict.items(), columns=["Date", "PnL"]).set_index("Date").PnL.cumsum().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### scenario 2 long and short iron condor

# %%
ironcondor_tracker = {}

# def find_nearest_strike_delta(date_index, delta_target, option_df, cp_flag):
#     """
#     Helper function to find the strike with delta closest to delta_target
#     """
#     options = option_df.loc[date_index].query(f"cp_flag == '{cp_flag}'")
#     return options.iloc[(options["delta"] - delta_target).abs().argmin()]["strike_price"]

def find_nearest_strike_delta(atm_spot, date_index, delta_target, option_df, cp_flag):
    """
    Helper function to find the strike with delta closest to delta_target
    """

    options = option_df.loc[date_index].query(f"cp_flag == '{cp_flag}'")
    atm_delta = options.query("strike_price == @atm_spot")["delta"]
    try:
        if isinstance(atm_delta, pd.Series):
            atm_delta = atm_delta.values[0]
    except IndexError:
        print(f"Error: {date_index}, {cp_flag}")
        return None
    new_delta = atm_delta + delta_target
    return options.iloc[(options["delta"] - new_delta).abs().argmin()]["strike_price"]

for index, row in xlu_time_series.iterrows():
    if row["action"] == 1:
        print(f"date: {index}")
        direction = "short"

        index_loc = xlu_time_series.index.get_loc(index)

        current_spot_open = myround(xlu_time_series.iloc[index_loc]["Open"], 0.5)

        daily_options = xlu_filtered_options.loc[index]

        # atm_put_strike = daily_options[
        #     (daily_options["cp_flag"] == "P") &
        #     (daily_options["strike_price"] == prev_spot_close)
        # ]["strike_price"]
        # if isinstance(atm_put_strike, pd.Series):
        #     atm_put_strike = atm_put_strike.values[0]
        
        # atm_call_strike = daily_options[
        #     (daily_options["cp_flag"] == "C") &
        #     (daily_options["strike_price"] == prev_spot_close)
        # ]["strike_price"]
        # if isinstance(atm_call_strike, pd.Series):
        #     atm_call_strike = atm_call_strike.values[0]

        atm_put_strike = atm_call_strike = current_spot_open

        otm_put_strike = find_nearest_strike_delta(current_spot_open, index, 0.4, xlu_filtered_options, "P")
        otm_call_strike = find_nearest_strike_delta(current_spot_open, index, -0.3, xlu_filtered_options, "C")

        if otm_put_strike is None or otm_call_strike is None:
            continue
            
        else:
            print(f"date: {index}, current_spot_open: {current_spot_open}, OTM Put: {otm_put_strike}, ATM Put: {atm_put_strike}, ATM Call: {atm_call_strike}, OTM Call: {otm_call_strike}, \
                left wing: {abs(otm_put_strike - atm_put_strike)}, right wing: {abs(atm_call_strike - otm_call_strike)}")
            strikes = {
                "strike1": otm_put_strike,
                "strike2": atm_put_strike,
                "strike3": atm_call_strike,
                "strike4": otm_call_strike
            }

            premiums = {
                "premium1": xlu_filtered_options.loc[
                    (xlu_filtered_options.index == index) & 
                    (xlu_filtered_options["strike_price"] == strikes["strike1"]) & 
                    (xlu_filtered_options["cp_flag"] == 'P'), "best_offer"
                ],
                "premium2": xlu_filtered_options.loc[
                    (xlu_filtered_options.index == index) & 
                    (xlu_filtered_options["strike_price"] == strikes["strike2"]) & 
                    (xlu_filtered_options["cp_flag"] == 'P'), "best_bid"
                ],
                "premium3": xlu_filtered_options.loc[
                    (xlu_filtered_options.index == index) & 
                    (xlu_filtered_options["strike_price"] == strikes["strike3"]) & 
                    (xlu_filtered_options["cp_flag"] == 'C'), "best_bid"
                ],
                "premium4": xlu_filtered_options.loc[
                    (xlu_filtered_options.index == index) & 
                    (xlu_filtered_options["strike_price"] == strikes["strike4"]) & 
                    (xlu_filtered_options["cp_flag"] == 'C'), "best_offer"
                ]
            }        

            # print(f"date: {index}, Premiums: {premiums}")

            expiry = xlu_filtered_options.loc[index]["exdate"].max()

            ironcondor = IronCondor(direction=direction, strikes=strikes, premiums=premiums, expiry=expiry)
            ironcondor_tracker[index] = (ironcondor, ironcondor.target_profit().iloc[0], expiry)
    elif row["action"] == -1:
        print(f"date: {index}")
        direction = "long"

        index_loc = xlu_time_series.index.get_loc(index)

        current_spot_open = myround(xlu_time_series.iloc[index_loc]["Open"], 0.5)

        daily_options = xlu_filtered_options.loc[index]

        # atm_put_strike = daily_options[
        #     (daily_options["cp_flag"] == "P") &
        #     (daily_options["strike_price"] == prev_spot_close)
        # ]["strike_price"]
        # if isinstance(atm_put_strike, pd.Series):
        #     atm_put_strike = atm_put_strike.values[0]
        
        # atm_call_strike = daily_options[
        #     (daily_options["cp_flag"] == "C") &
        #     (daily_options["strike_price"] == prev_spot_close)
        # ]["strike_price"]
        # if isinstance(atm_call_strike, pd.Series):
        #     atm_call_strike = atm_call_strike.values[0]

        atm_put_strike = atm_call_strike = current_spot_open

        otm_put_strike = find_nearest_strike_delta(current_spot_open, index, 0.4, xlu_filtered_options, "P")
        otm_call_strike = find_nearest_strike_delta(current_spot_open, index, -0.3, xlu_filtered_options, "C")

        if otm_put_strike is None or otm_call_strike is None:
            continue
            
        else:
            print(f"date: {index}, current_spot_open: {current_spot_open}, OTM Put: {otm_put_strike}, ATM Put: {atm_put_strike}, ATM Call: {atm_call_strike}, OTM Call: {otm_call_strike}, \
                left wing: {abs(otm_put_strike - atm_put_strike)}, right wing: {abs(atm_call_strike - otm_call_strike)}")
            strikes = {
                "strike1": otm_put_strike,
                "strike2": atm_put_strike,
                "strike3": atm_call_strike,
                "strike4": otm_call_strike
            }

            premiums = {
                "premium1": xlu_filtered_options.loc[
                    (xlu_filtered_options.index == index) & 
                    (xlu_filtered_options["strike_price"] == strikes["strike1"]) & 
                    (xlu_filtered_options["cp_flag"] == 'P'), "best_bid"
                ],
                "premium2": xlu_filtered_options.loc[
                    (xlu_filtered_options.index == index) & 
                    (xlu_filtered_options["strike_price"] == strikes["strike2"]) & 
                    (xlu_filtered_options["cp_flag"] == 'P'), "best_offer"
                ],
                "premium3": xlu_filtered_options.loc[
                    (xlu_filtered_options.index == index) & 
                    (xlu_filtered_options["strike_price"] == strikes["strike3"]) & 
                    (xlu_filtered_options["cp_flag"] == 'C'), "best_offer"
                ],
                "premium4": xlu_filtered_options.loc[
                    (xlu_filtered_options.index == index) & 
                    (xlu_filtered_options["strike_price"] == strikes["strike4"]) & 
                    (xlu_filtered_options["cp_flag"] == 'C'), "best_bid"
                ]
            }        

            # print(f"date: {index}, Premiums: {premiums}")

            expiry = xlu_filtered_options.loc[index]["exdate"].max()

            ironcondor = IronCondor(direction=direction, strikes=strikes, premiums=premiums, expiry=expiry)
            ironcondor_tracker[index] = (ironcondor, ironcondor.target_profit().iloc[0], expiry)
# Out:
# date: 2016-11-01 00:00:00
# date: 2016-11-01 00:00:00, current_spot_open: 49.5, OTM Put: 47.5, ATM Put: 49.5, ATM Call: 49.5, OTM Call: 54.5,                 left wing: 2.0, right wing: 5.0
# date: 2016-11-14 00:00:00
# date: 2016-11-14 00:00:00, current_spot_open: 45.5, OTM Put: 40.5, ATM Put: 45.5, ATM Call: 45.5, OTM Call: 47.0,                 left wing: 5.0, right wing: 1.5
# date: 2016-11-15 00:00:00
# date: 2016-11-15 00:00:00, current_spot_open: 46.5, OTM Put: 42.5, ATM Put: 46.5, ATM Call: 46.5, OTM Call: 47.5,                 left wing: 4.0, right wing: 1.0
# date: 2016-11-29 00:00:00
# date: 2016-11-29 00:00:00, current_spot_open: 48.0, OTM Put: 43.0, ATM Put: 48.0, ATM Call: 48.0, OTM Call: 49.0,                 left wing: 5.0, right wing: 1.0
# date: 2016-12-13 00:00:00
# date: 2016-12-13 00:00:00, current_spot_open: 48.5, OTM Put: 46.5, ATM Put: 48.5, ATM Call: 48.5, OTM Call: 49.5,                 left wing: 2.0, right wing: 1.0
# date: 2016-12-28 00:00:00
# date: 2016-12-28 00:00:00, current_spot_open: 48.5, OTM Put: 47.0, ATM Put: 48.5, ATM Call: 48.5, OTM Call: 49.5,                 left wing: 1.5, right wing: 1.0
# date: 2017-01-20 00:00:00
# date: 2017-01-20 00:00:00, current_spot_open: 48.5, OTM Put: 45.5, ATM Put: 48.5, ATM Call: 48.5, OTM Call: 49.5,                 left wing: 3.0, right wing: 1.0
# date: 2017-01-31 00:00:00
# date: 2017-01-31 00:00:00, current_spot_open: 48.5, OTM Put: 41.0, ATM Put: 48.5, ATM Call: 48.5, OTM Call: 49.5,                 left wing: 7.5, right wing: 1.0
# date: 2017-02-22 00:00:00
# date: 2017-02-22 00:00:00, current_spot_open: 50.0, OTM Put: 41.5, ATM Put: 50.0, ATM Call: 50.0, OTM Call: 51.0,                 left wing: 8.5, right wing: 1.0
# date: 2017-03-09 00:00:00
# date: 2017-03-09 00:00:00, current_spot_open: 51.0, OTM Put: 50.0, ATM Put: 51.0, ATM Call: 51.0, OTM Call: 53.0,                 left wing: 1.0, right wing: 2.0
# date: 2017-03-16 00:00:00
# date: 2017-03-16 00:00:00, current_spot_open: 52.0, OTM Put: 51.0, ATM Put: 52.0, ATM Call: 52.0, OTM Call: 57.0,                 left wing: 1.0, right wing: 5.0
# date: 2017-04-06 00:00:00
# date: 2017-04-06 00:00:00, current_spot_open: 51.5, OTM Put: 48.0, ATM Put: 51.5, ATM Call: 51.5, OTM Call: 52.0,                 left wing: 3.5, right wing: 0.5
# date: 2017-05-18 00:00:00
# date: 2017-05-18 00:00:00, current_spot_open: 52.0, OTM Put: 51.0, ATM Put: 52.0, ATM Call: 52.0, OTM Call: 55.5,                 left wing: 1.0, right wing: 3.5
# date: 2017-06-02 00:00:00
# date: 2017-06-02 00:00:00, current_spot_open: 54.5, OTM Put: 53.5, ATM Put: 54.5, ATM Call: 54.5, OTM Call: 55.5,                 left wing: 1.0, right wing: 1.0
# date: 2017-06-30 00:00:00
# date: 2017-06-30 00:00:00, current_spot_open: 52.0, OTM Put: 47.5, ATM Put: 52.0, ATM Call: 52.0, OTM Call: 53.0,                 left wing: 4.5, right wing: 1.0
# date: 2017-07-21 00:00:00
# date: 2017-07-21 00:00:00, current_spot_open: 53.0, OTM Put: 44.5, ATM Put: 53.0, ATM Call: 53.0, OTM Call: 53.5,                 left wing: 8.5, right wing: 0.5
# date: 2017-08-15 00:00:00
# date: 2017-08-15 00:00:00, current_spot_open: 53.5, OTM Put: 44.5, ATM Put: 53.5, ATM Call: 53.5, OTM Call: 54.5,                 left wing: 9.0, right wing: 1.0
# date: 2017-09-14 00:00:00
# date: 2017-09-14 00:00:00, current_spot_open: 54.5, OTM Put: 45.0, ATM Put: 54.5, ATM Call: 54.5, OTM Call: 55.0,                 left wing: 9.5, right wing: 0.5
# date: 2017-09-29 00:00:00
# date: 2017-09-29 00:00:00, current_spot_open: 53.0, OTM Put: 51.0, ATM Put: 53.0, ATM Call: 53.0, OTM Call: 54.0,                 left wing: 2.0, right wing: 1.0
# C:\Users\asus\AppData\Local\Temp\ipykernel_52020\3226926340.py:24: FutureWarning: The behavior of Series.argmax/argmin with skipna=False and NAs, or with all-NAs is deprecated. In a future version this will raise ValueError.
#   return options.iloc[(options["delta"] - new_delta).abs().argmin()]["strike_price"]
# date: 2017-10-25 00:00:00
# date: 2017-10-25 00:00:00, current_spot_open: 54.5, OTM Put: 49.5, ATM Put: 54.5, ATM Call: 54.5, OTM Call: 55.5,                 left wing: 5.0, right wing: 1.0
# date: 2017-11-09 00:00:00
# date: 2017-11-09 00:00:00, current_spot_open: 55.5, OTM Put: 42.0, ATM Put: 55.5, ATM Call: 55.5, OTM Call: 56.0,                 left wing: 13.5, right wing: 0.5
# date: 2017-12-01 00:00:00
# date: 2017-12-01 00:00:00, current_spot_open: 57.0, OTM Put: 55.5, ATM Put: 57.0, ATM Call: 57.0, OTM Call: 61.5,                 left wing: 1.5, right wing: 4.5
# date: 2017-12-21 00:00:00
# date: 2017-12-21 00:00:00, current_spot_open: 52.5, OTM Put: 51.5, ATM Put: 52.5, ATM Call: 52.5, OTM Call: 53.5,                 left wing: 1.0, right wing: 1.0
# date: 2018-02-07 00:00:00
# date: 2018-02-07 00:00:00, current_spot_open: 48.5, OTM Put: 46.5, ATM Put: 48.5, ATM Call: 48.5, OTM Call: 50.0,                 left wing: 2.0, right wing: 1.5
# date: 2018-03-02 00:00:00
# date: 2018-03-02 00:00:00, current_spot_open: 49.0, OTM Put: 47.0, ATM Put: 49.0, ATM Call: 49.0, OTM Call: 50.5,                 left wing: 2.0, right wing: 1.5
# date: 2018-03-15 00:00:00
# date: 2018-03-15 00:00:00, current_spot_open: 50.0, OTM Put: 48.0, ATM Put: 50.0, ATM Call: 50.0, OTM Call: 51.0,                 left wing: 2.0, right wing: 1.0
# date: 2018-03-20 00:00:00
# date: 2018-03-20 00:00:00, current_spot_open: 50.0, OTM Put: 48.5, ATM Put: 50.0, ATM Call: 50.0, OTM Call: 51.0,                 left wing: 1.5, right wing: 1.0
# date: 2018-05-08 00:00:00
# date: 2018-05-08 00:00:00, current_spot_open: 51.0, OTM Put: 49.5, ATM Put: 51.0, ATM Call: 51.0, OTM Call: 65.0,                 left wing: 1.5, right wing: 14.0
# date: 2018-06-05 00:00:00
# date: 2018-06-05 00:00:00, current_spot_open: 50.0, OTM Put: 49.0, ATM Put: 50.0, ATM Call: 50.0, OTM Call: 53.0,                 left wing: 1.0, right wing: 3.0
# date: 2018-06-15 00:00:00
# date: 2018-06-15 00:00:00, current_spot_open: 49.0, OTM Put: 42.5, ATM Put: 49.0, ATM Call: 49.0, OTM Call: 50.0,                 left wing: 6.5, right wing: 1.0
# date: 2018-09-05 00:00:00
# date: 2018-09-05 00:00:00, current_spot_open: 53.5, OTM Put: 35.0, ATM Put: 53.5, ATM Call: 53.5, OTM Call: 54.5,                 left wing: 18.5, right wing: 1.0
# date: 2018-09-21 00:00:00
# date: 2018-09-21 00:00:00, current_spot_open: 53.0, OTM Put: 50.5, ATM Put: 53.0, ATM Call: 53.0, OTM Call: 54.0,                 left wing: 2.5, right wing: 1.0
# date: 2018-10-09 00:00:00
# date: 2018-10-09 00:00:00, current_spot_open: 54.0, OTM Put: 45.0, ATM Put: 54.0, ATM Call: 54.0, OTM Call: 55.0,                 left wing: 9.0, right wing: 1.0
# date: 2018-10-25 00:00:00
# date: 2018-10-25 00:00:00, current_spot_open: 55.0, OTM Put: 53.5, ATM Put: 55.0, ATM Call: 55.0, OTM Call: 57.0,                 left wing: 1.5, right wing: 2.0
# date: 2018-11-13 00:00:00
# date: 2018-11-13 00:00:00, current_spot_open: 55.0, OTM Put: 52.5, ATM Put: 55.0, ATM Call: 55.0, OTM Call: 56.0,                 left wing: 2.5, right wing: 1.0
# date: 2018-12-13 00:00:00
# date: 2018-12-13 00:00:00, current_spot_open: 56.5, OTM Put: 54.5, ATM Put: 56.5, ATM Call: 56.5, OTM Call: 57.5,                 left wing: 2.0, right wing: 1.0
# date: 2018-12-18 00:00:00
# date: 2018-12-18 00:00:00, current_spot_open: 55.5, OTM Put: 53.5, ATM Put: 55.5, ATM Call: 55.5, OTM Call: 70.0,                 left wing: 2.0, right wing: 14.5
# date: 2019-03-26 00:00:00
# date: 2019-03-26 00:00:00, current_spot_open: 58.5, OTM Put: 49.5, ATM Put: 58.5, ATM Call: 58.5, OTM Call: 59.5,                 left wing: 9.0, right wing: 1.0
# date: 2019-04-17 00:00:00
# date: 2019-04-17 00:00:00, current_spot_open: 57.5, OTM Put: 56.0, ATM Put: 57.5, ATM Call: 57.5, OTM Call: 58.5,                 left wing: 1.5, right wing: 1.0
# date: 2019-05-15 00:00:00
# date: 2019-05-15 00:00:00, current_spot_open: 58.0, OTM Put: 56.0, ATM Put: 58.0, ATM Call: 58.0, OTM Call: 59.0,                 left wing: 2.0, right wing: 1.0
# date: 2019-06-25 00:00:00
# date: 2019-06-25 00:00:00, current_spot_open: 61.0, OTM Put: 59.5, ATM Put: 61.0, ATM Call: 61.0, OTM Call: 62.5,                 left wing: 1.5, right wing: 1.5
# date: 2019-07-30 00:00:00
# date: 2019-07-30 00:00:00, current_spot_open: 60.0, OTM Put: 58.0, ATM Put: 60.0, ATM Call: 60.0, OTM Call: 61.0,                 left wing: 2.0, right wing: 1.0
# date: 2019-09-05 00:00:00
# date: 2019-09-05 00:00:00, current_spot_open: 63.5, OTM Put: 62.0, ATM Put: 63.5, ATM Call: 63.5, OTM Call: 65.0,                 left wing: 1.5, right wing: 1.5
# date: 2019-09-24 00:00:00
# date: 2019-09-24 00:00:00, current_spot_open: 64.0, OTM Put: 55.0, ATM Put: 64.0, ATM Call: 64.0, OTM Call: 65.0,                 left wing: 9.0, right wing: 1.0
# date: 2019-10-03 00:00:00
# date: 2019-10-03 00:00:00, current_spot_open: 64.0, OTM Put: 62.0, ATM Put: 64.0, ATM Call: 64.0, OTM Call: 65.0,                 left wing: 2.0, right wing: 1.0
# date: 2019-10-30 00:00:00
# date: 2019-10-30 00:00:00, current_spot_open: 63.5, OTM Put: 56.5, ATM Put: 63.5, ATM Call: 63.5, OTM Call: 64.5,                 left wing: 7.0, right wing: 1.0
# date: 2019-11-15 00:00:00
# date: 2019-11-15 00:00:00, current_spot_open: 62.5, OTM Put: 55.5, ATM Put: 62.5, ATM Call: 62.5, OTM Call: 63.5,                 left wing: 7.0, right wing: 1.0
# date: 2019-12-03 00:00:00
# date: 2019-12-03 00:00:00, current_spot_open: 63.0, OTM Put: 61.5, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 64.0,                 left wing: 1.5, right wing: 1.0
# date: 2019-12-13 00:00:00
# date: 2019-12-13 00:00:00, current_spot_open: 63.0, OTM Put: 61.5, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 64.0,                 left wing: 1.5, right wing: 1.0
# date: 2019-12-20 00:00:00
# date: 2019-12-20 00:00:00, current_spot_open: 64.0, OTM Put: 55.5, ATM Put: 64.0, ATM Call: 64.0, OTM Call: 65.0,                 left wing: 8.5, right wing: 1.0
# date: 2020-02-04 00:00:00
# date: 2020-02-04 00:00:00, current_spot_open: 69.0, OTM Put: 67.5, ATM Put: 69.0, ATM Call: 69.0, OTM Call: 70.5,                 left wing: 1.5, right wing: 1.5
# date: 2020-02-28 00:00:00
# date: 2020-02-28 00:00:00, current_spot_open: 63.0, OTM Put: 58.0, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 66.5,                 left wing: 5.0, right wing: 3.5
# date: 2020-03-05 00:00:00
# date: 2020-03-05 00:00:00, current_spot_open: 67.5, OTM Put: 58.0, ATM Put: 67.5, ATM Call: 67.5, OTM Call: 70.0,                 left wing: 9.5, right wing: 2.5
# date: 2020-03-17 00:00:00
# Error: 2020-03-17 00:00:00, P
# Error: 2020-03-17 00:00:00, C
# date: 2020-03-24 00:00:00
# Error: 2020-03-24 00:00:00, P
# Error: 2020-03-24 00:00:00, C
# date: 2020-04-15 00:00:00
# date: 2020-04-15 00:00:00, current_spot_open: 59.0, OTM Put: 53.0, ATM Put: 59.0, ATM Call: 59.0, OTM Call: 62.5,                 left wing: 6.0, right wing: 3.5
# date: 2020-04-21 00:00:00
# date: 2020-04-21 00:00:00, current_spot_open: 57.0, OTM Put: 48.0, ATM Put: 57.0, ATM Call: 57.0, OTM Call: 60.0,                 left wing: 9.0, right wing: 3.0
# date: 2020-05-29 00:00:00
# date: 2020-05-29 00:00:00, current_spot_open: 59.0, OTM Put: 30.0, ATM Put: 59.0, ATM Call: 59.0, OTM Call: 61.0,                 left wing: 29.0, right wing: 2.0
# date: 2020-06-12 00:00:00
# date: 2020-06-12 00:00:00, current_spot_open: 60.0, OTM Put: 56.5, ATM Put: 60.0, ATM Call: 60.0, OTM Call: 68.5,                 left wing: 3.5, right wing: 8.5
# date: 2020-06-26 00:00:00
# date: 2020-06-26 00:00:00, current_spot_open: 55.5, OTM Put: 50.5, ATM Put: 55.5, ATM Call: 55.5, OTM Call: 58.5,                 left wing: 5.0, right wing: 3.0
# date: 2020-07-22 00:00:00
# date: 2020-07-22 00:00:00, current_spot_open: 59.5, OTM Put: 30.0, ATM Put: 59.5, ATM Call: 59.5, OTM Call: 61.0,                 left wing: 29.5, right wing: 1.5
# date: 2020-07-30 00:00:00
# date: 2020-07-30 00:00:00, current_spot_open: 60.5, OTM Put: 50.5, ATM Put: 60.5, ATM Call: 60.5, OTM Call: 62.0,                 left wing: 10.0, right wing: 1.5
# date: 2020-08-20 00:00:00
# date: 2020-08-20 00:00:00, current_spot_open: 59.5, OTM Put: 57.5, ATM Put: 59.5, ATM Call: 59.5, OTM Call: 61.0,                 left wing: 2.0, right wing: 1.5
# date: 2020-09-04 00:00:00
# date: 2020-09-04 00:00:00, current_spot_open: 60.0, OTM Put: 57.0, ATM Put: 60.0, ATM Call: 60.0, OTM Call: 62.5,                 left wing: 3.0, right wing: 2.5
# date: 2020-09-18 00:00:00
# date: 2020-09-18 00:00:00, current_spot_open: 59.5, OTM Put: 57.0, ATM Put: 59.5, ATM Call: 59.5, OTM Call: 68.0,                 left wing: 2.5, right wing: 8.5
# date: 2020-10-01 00:00:00
# date: 2020-10-01 00:00:00, current_spot_open: 59.5, OTM Put: 50.0, ATM Put: 59.5, ATM Call: 59.5, OTM Call: 60.5,                 left wing: 9.5, right wing: 1.0
# date: 2020-11-06 00:00:00
# date: 2020-11-06 00:00:00, current_spot_open: 64.5, OTM Put: 61.0, ATM Put: 64.5, ATM Call: 64.5, OTM Call: 67.0,                 left wing: 3.5, right wing: 2.5
# date: 2020-12-01 00:00:00
# date: 2020-12-01 00:00:00, current_spot_open: 63.5, OTM Put: 61.0, ATM Put: 63.5, ATM Call: 63.5, OTM Call: 65.5,                 left wing: 2.5, right wing: 2.0
# date: 2020-12-11 00:00:00
# date: 2020-12-11 00:00:00, current_spot_open: 62.0, OTM Put: 59.5, ATM Put: 62.0, ATM Call: 62.0, OTM Call: 67.5,                 left wing: 2.5, right wing: 5.5
# date: 2020-12-15 00:00:00
# date: 2020-12-15 00:00:00, current_spot_open: 62.0, OTM Put: 50.0, ATM Put: 62.0, ATM Call: 62.0, OTM Call: 63.0,                 left wing: 12.0, right wing: 1.0
# date: 2021-01-26 00:00:00
# date: 2021-01-26 00:00:00, current_spot_open: 64.0, OTM Put: 62.0, ATM Put: 64.0, ATM Call: 64.0, OTM Call: 66.5,                 left wing: 2.0, right wing: 2.5
# date: 2021-02-12 00:00:00
# date: 2021-02-12 00:00:00, current_spot_open: 63.0, OTM Put: 61.0, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 65.0,                 left wing: 2.0, right wing: 2.0
# date: 2021-03-02 00:00:00
# date: 2021-03-02 00:00:00, current_spot_open: 59.5, OTM Put: 56.5, ATM Put: 59.5, ATM Call: 59.5, OTM Call: 69.0,                 left wing: 3.0, right wing: 9.5
# date: 2021-03-25 00:00:00
# date: 2021-03-25 00:00:00, current_spot_open: 63.0, OTM Put: 45.0, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 64.0,                 left wing: 18.0, right wing: 1.0
# date: 2021-04-13 00:00:00
# date: 2021-04-13 00:00:00, current_spot_open: 64.5, OTM Put: 35.0, ATM Put: 64.5, ATM Call: 64.5, OTM Call: 65.5,                 left wing: 29.5, right wing: 1.0
# date: 2021-07-23 00:00:00
# date: 2021-07-23 00:00:00, current_spot_open: 65.0, OTM Put: 50.0, ATM Put: 65.0, ATM Call: 65.0, OTM Call: 66.5,                 left wing: 15.0, right wing: 1.5
# date: 2021-07-29 00:00:00
# date: 2021-07-29 00:00:00, current_spot_open: 66.5, OTM Put: 64.0, ATM Put: 66.5, ATM Call: 66.5, OTM Call: 67.5,                 left wing: 2.5, right wing: 1.0
# date: 2021-08-05 00:00:00
# date: 2021-08-05 00:00:00, current_spot_open: 67.0, OTM Put: 50.0, ATM Put: 67.0, ATM Call: 67.0, OTM Call: 68.0,                 left wing: 17.0, right wing: 1.0
# date: 2021-09-10 00:00:00
# date: 2021-09-10 00:00:00, current_spot_open: 69.5, OTM Put: 67.5, ATM Put: 69.5, ATM Call: 69.5, OTM Call: 72.5,                 left wing: 2.0, right wing: 3.0
# date: 2021-09-21 00:00:00
# date: 2021-09-21 00:00:00, current_spot_open: 66.0, OTM Put: 63.5, ATM Put: 66.0, ATM Call: 66.0, OTM Call: 67.5,                 left wing: 2.5, right wing: 1.5
# date: 2021-10-06 00:00:00
# date: 2021-10-06 00:00:00, current_spot_open: 64.5, OTM Put: 40.0, ATM Put: 64.5, ATM Call: 64.5, OTM Call: 66.0,                 left wing: 24.5, right wing: 1.5
# date: 2021-11-02 00:00:00
# date: 2021-11-02 00:00:00, current_spot_open: 67.5, OTM Put: 65.5, ATM Put: 67.5, ATM Call: 67.5, OTM Call: 69.0,                 left wing: 2.0, right wing: 1.5
# date: 2021-12-01 00:00:00
# date: 2021-12-01 00:00:00, current_spot_open: 66.0, OTM Put: 62.5, ATM Put: 66.0, ATM Call: 66.0, OTM Call: 68.0,                 left wing: 3.5, right wing: 2.0
# date: 2021-12-07 00:00:00
# date: 2021-12-07 00:00:00, current_spot_open: 68.5, OTM Put: 59.0, ATM Put: 68.5, ATM Call: 68.5, OTM Call: 70.0,                 left wing: 9.5, right wing: 1.5
# date: 2022-01-04 00:00:00
# date: 2022-01-04 00:00:00, current_spot_open: 71.0, OTM Put: 69.0, ATM Put: 71.0, ATM Call: 71.0, OTM Call: 72.5,                 left wing: 2.0, right wing: 1.5
# date: 2022-01-25 00:00:00
# date: 2022-01-25 00:00:00, current_spot_open: 67.0, OTM Put: 62.0, ATM Put: 67.0, ATM Call: 67.0, OTM Call: 69.0,                 left wing: 5.0, right wing: 2.0
# date: 2022-02-03 00:00:00
# date: 2022-02-03 00:00:00, current_spot_open: 69.0, OTM Put: 65.5, ATM Put: 69.0, ATM Call: 69.0, OTM Call: 70.5,                 left wing: 3.5, right wing: 1.5
# date: 2022-03-08 00:00:00
# date: 2022-03-08 00:00:00, current_spot_open: 72.0, OTM Put: 68.5, ATM Put: 72.0, ATM Call: 72.0, OTM Call: 76.0,                 left wing: 3.5, right wing: 4.0
# date: 2022-04-08 00:00:00
# date: 2022-04-08 00:00:00, current_spot_open: 77.0, OTM Put: 73.0, ATM Put: 77.0, ATM Call: 77.0, OTM Call: 79.0,                 left wing: 4.0, right wing: 2.0
# date: 2022-04-26 00:00:00
# date: 2022-04-26 00:00:00, current_spot_open: 73.5, OTM Put: 63.0, ATM Put: 73.5, ATM Call: 73.5, OTM Call: 76.0,                 left wing: 10.5, right wing: 2.5
# date: 2022-05-05 00:00:00
# date: 2022-05-05 00:00:00, current_spot_open: 72.0, OTM Put: 68.5, ATM Put: 72.0, ATM Call: 72.0, OTM Call: 74.0,                 left wing: 3.5, right wing: 2.0
# date: 2022-06-09 00:00:00
# date: 2022-06-09 00:00:00, current_spot_open: 73.5, OTM Put: 66.0, ATM Put: 73.5, ATM Call: 73.5, OTM Call: 85.0,                 left wing: 7.5, right wing: 11.5
# C:\Users\asus\AppData\Local\Temp\ipykernel_52020\3226926340.py:24: FutureWarning: The behavior of Series.argmax/argmin with skipna=False and NAs, or with all-NAs is deprecated. In a future version this will raise ValueError.
#   return options.iloc[(options["delta"] - new_delta).abs().argmin()]["strike_price"]
# date: 2022-06-16 00:00:00
# date: 2022-06-16 00:00:00, current_spot_open: 66.0, OTM Put: 63.0, ATM Put: 66.0, ATM Call: 66.0, OTM Call: 71.0,                 left wing: 3.0, right wing: 5.0
# date: 2022-08-23 00:00:00
# Error: 2022-08-23 00:00:00, P
# Error: 2022-08-23 00:00:00, C
# date: 2022-09-09 00:00:00
# date: 2022-09-09 00:00:00, current_spot_open: 77.5, OTM Put: 74.0, ATM Put: 77.5, ATM Call: 77.5, OTM Call: 79.5,                 left wing: 3.5, right wing: 2.0
# date: 2022-10-04 00:00:00
# date: 2022-10-04 00:00:00, current_spot_open: 68.0, OTM Put: 45.0, ATM Put: 68.0, ATM Call: 68.0, OTM Call: 70.5,                 left wing: 23.0, right wing: 2.5
# date: 2022-11-03 00:00:00
# date: 2022-11-03 00:00:00, current_spot_open: 66.0, OTM Put: 45.0, ATM Put: 66.0, ATM Call: 66.0, OTM Call: 68.0,                 left wing: 21.0, right wing: 2.0
# date: 2022-11-29 00:00:00
# date: 2022-11-29 00:00:00, current_spot_open: 70.0, OTM Put: 67.0, ATM Put: 70.0, ATM Call: 70.0, OTM Call: 72.0,                 left wing: 3.0, right wing: 2.0
# date: 2022-12-28 00:00:00
# date: 2022-12-28 00:00:00, current_spot_open: 71.5, OTM Put: 69.0, ATM Put: 71.5, ATM Call: 71.5, OTM Call: 74.0,                 left wing: 2.5, right wing: 2.5
# date: 2023-01-04 00:00:00
# date: 2023-01-04 00:00:00, current_spot_open: 71.0, OTM Put: 64.5, ATM Put: 71.0, ATM Call: 71.0, OTM Call: 73.0,                 left wing: 6.5, right wing: 2.0
# date: 2023-03-03 00:00:00
# date: 2023-03-03 00:00:00, current_spot_open: 65.5, OTM Put: 55.0, ATM Put: 65.5, ATM Call: 65.5, OTM Call: 67.5,                 left wing: 10.5, right wing: 2.0
# date: 2023-03-23 00:00:00
# date: 2023-03-23 00:00:00, current_spot_open: 64.5, OTM Put: 61.0, ATM Put: 64.5, ATM Call: 64.5, OTM Call: 78.0,                 left wing: 3.5, right wing: 13.5
# date: 2023-03-28 00:00:00
# date: 2023-03-28 00:00:00, current_spot_open: 65.5, OTM Put: 55.0, ATM Put: 65.5, ATM Call: 65.5, OTM Call: 67.0,                 left wing: 10.5, right wing: 1.5
# date: 2023-04-25 00:00:00
# date: 2023-04-25 00:00:00, current_spot_open: 69.5, OTM Put: 61.0, ATM Put: 69.5, ATM Call: 69.5, OTM Call: 71.0,                 left wing: 8.5, right wing: 1.5
# date: 2023-07-18 00:00:00
# date: 2023-07-18 00:00:00, current_spot_open: 66.0, OTM Put: 64.0, ATM Put: 66.0, ATM Call: 66.0, OTM Call: 67.5,                 left wing: 2.0, right wing: 1.5
# date: 2023-08-04 00:00:00
# date: 2023-08-04 00:00:00, current_spot_open: 65.0, OTM Put: 63.0, ATM Put: 65.0, ATM Call: 65.0, OTM Call: 68.5,                 left wing: 2.0, right wing: 3.5
# date: 2023-08-22 00:00:00
# date: 2023-08-22 00:00:00, current_spot_open: 63.0, OTM Put: 57.0, ATM Put: 63.0, ATM Call: 63.0, OTM Call:
                                          np.where((xlu_time_series_copy["signal"] == -1) & (xlu_time_series_copy.index.weekday != 4), -1, 0))

    # Ensure weekly action
    xlu_time_series_copy = ensure_weekly_action(xlu_time_series_copy)
    xlu_time_series_copy["action"] = xlu_time_series_copy["action"].shift()

    # Initialize the tracker and PnL dictionary
    ironcondor_tracker = {}
    pnl_dict = {}

    for index, row in xlu_time_series_copy.iterrows():
        if row["action"] == 1:
            current_spot_open = row["Open"]

            # Attempt to get the strikes
            strike1 = find_nearest_strike_delta(current_spot_open, index, 0.4, xlu_filtered_options, "P")
            strike2 = current_spot_open
            strike3 = current_spot_open
            strike4 = find_nearest_strike_delta(current_spot_open, index, -0.3, xlu_filtered_options, "C")

            # Filter the options DataFrame
            premium1_row = xlu_filtered_options[(xlu_filtered_options.index == index) & (xlu_filtered_options["strike_price"] == strike1) & (xlu_filtered_options["cp_flag"] == 'P')]
            premium2_row = xlu_filtered_options[(xlu_filtered_options.index == index) & (xlu_filtered_options["strike_price"] == strike2) & (xlu_filtered_options["cp_flag"] == 'P')]
            premium3_row = xlu_filtered_options[(xlu_filtered_options.index == index) & (xlu_filtered_options["strike_price"] == strike3) & (xlu_filtered_options["cp_flag"] == 'C')]
            premium4_row = xlu_filtered_options[(xlu_filtered_options.index == index) & (xlu_filtered_options["strike_price"] == strike4) & (xlu_filtered_options["cp_flag"] == 'C')]

            # Check if any of the filtered rows are empty
            if premium1_row.empty or premium2_row.empty or premium3_row.empty or premium4_row.empty:
                print(f"Skipping index {index}: One of the premium rows is empty")
                continue  # Skip to the next iteration if any premium is missing

            # Get the premiums safely
            premiums = {
                "premium1": premium1_row["best_offer"].values[0],
                "premium2": premium2_row["best_bid"].values[0],
                "premium3": premium3_row["best_bid"].values[0],
                "premium4": premium4_row["best_offer"].values[0],
            }

            expiry = xlu_filtered_options.loc[index]["exdate"].max()
            ironcondor = IronCondor(direction="long", strikes={"strike1": strike1, "strike2": strike2, "strike3": strike3, "strike4": strike4}, premiums=premiums, expiry=expiry)
            ironcondor_tracker[index] = (ironcondor, expiry)

        elif row["action"] == -1:
            current_spot_open = row["Open"]

            # Attempt to get the strikes
            strike1 = find_nearest_strike_delta(current_spot_open, index, 0.4, xlu_filtered_options, "P")
            strike2 = current_spot_open
            strike3 = current_spot_open
            strike4 = find_nearest_strike_delta(current_spot_open, index, -0.3, xlu_filtered_options, "C")

            # Filter the options DataFrame
            premium1_row = xlu_filtered_options[(xlu_filtered_options.index == index) & (xlu_filtered_options["strike_price"] == strike1) & (xlu_filtered_options["cp_flag"] == 'P')]
            premium2_row = xlu_filtered_options[(xlu_filtered_options.index == index) & (xlu_filtered_options["strike_price"] == strike2) & (xlu_filtered_options["cp_flag"] == 'P')]
            premium3_row = xlu_filtered_options[(xlu_filtered_options.index == index) & (xlu_filtered_options["strike_price"] == strike3) & (xlu_filtered_options["cp_flag"] == 'C')]
            premium4_row = xlu_filtered_options[(xlu_filtered_options.index == index) & (xlu_filtered_options["strike_price"] == strike4) & (xlu_filtered_options["cp_flag"] == 'C')]

            # Check if any of the filtered rows are empty
            if premium1_row.empty or premium2_row.empty or premium3_row.empty or premium4_row.empty:
                print(f"Skipping index {index}: One of the premium rows is empty")
                continue  # Skip to the next iteration if any premium is missing

            # Get the premiums safely
            premiums = {
                "premium1": premium1_row["best_bid"].values[0],
                "premium2": premium2_row["best_offer"].values[0],
                "premium3": premium3_row["best_offer"].values[0],
                "premium4": premium4_row["best_bid"].values[0],
            }

            expiry = xlu_filtered_options.loc[index]["exdate"].max()
            ironcondor = IronCondor(direction="short", strikes={"strike1": strike1, "strike2": strike2, "strike3": strike3, "strike4": strike4}, premiums=premiums, expiry=expiry)
            ironcondor_tracker[index] = (ironcondor, expiry)

    # Calculate PnL
    for date, (ironcondor, expiry) in ironcondor_tracker.items():
        try:
            ironcondor.insert_spot(xlu_time_series_copy.at[expiry, "Close"])
            pnl_dict[date] = ironcondor.payoff()
        except KeyError:
            continue
        except AttributeError:
            pnl_dict[date] = 0

    # Calculate Sharpe Ratio
    pnl_series = pd.Series(pnl_dict)
    if pnl_series.std() == 0:  # Prevent division by zero
        return np.inf
    sharpe_ratio = pnl_series.mean() / pnl_series.std()

    # Return negative Sharpe ratio for minimization
    return -sharpe_ratio

# %%
from skopt import gp_minimize

# Define the bounds for the thresholds
space = [Real(0.5, 3.0, name='upper_threshold'), Real(-3.0, -0.5, name='lower_threshold')]

# Run Bayesian Optimization
res = gp_minimize(objective, space, n_calls=50, random_state=0)

# Output the optimized thresholds
optimized_upper_threshold = res.x[0]
optimized_lower_threshold = res.x[1]
print(f"Optimized Upper Threshold: {optimized_upper_threshold}, Optimized Lower Threshold: {optimized_lower_threshold}")
# Out:
# Error: 2016-11-03 00:00:00, P
# Error: 2016-11-03 00:00:00, C
# Skipping index 2016-11-03 00:00:00: One of the premium rows is empty
# Error: 2016-11-14 00:00:00, P
# Error: 2016-11-14 00:00:00, C
# Skipping index 2016-11-14 00:00:00: One of the premium rows is empty
# Error: 2016-11-15 00:00:00, P
# Error: 2016-11-15 00:00:00, C
# Skipping index 2016-11-15 00:00:00: One of the premium rows is empty
# Error: 2017-01-20 00:00:00, P
# Error: 2017-01-20 00:00:00, C
# Skipping index 2017-01-20 00:00:00: One of the premium rows is empty
# Error: 2017-02-03 00:00:00, P
# Error: 2017-02-03 00:00:00, C
# Skipping index 2017-02-03 00:00:00: One of the premium rows is empty
# Error: 2017-02-07 00:00:00, P
# Error: 2017-02-07 00:00:00, C
# Skipping index 2017-02-07 00:00:00: One of the premium rows is empty
# Error: 2017-02-22 00:00:00, P
# Error: 2017-02-22 00:00:00, C
# Skipping index 2017-02-22 00:00:00: One of the premium rows is empty
# Error: 2017-02-28 00:00:00, P
# Error: 2017-02-28 00:00:00, C
# Skipping index 2017-02-28 00:00:00: One of the premium rows is empty
# Error: 2017-03-23 00:00:00, P
# Error: 2017-03-23 00:00:00, C
# Skipping index 2017-03-23 00:00:00: One of the premium rows is empty
# Error: 2017-04-06 00:00:00, P
# Error: 2017-04-06 00:00:00, C
# Skipping index 2017-04-06 00:00:00: One of the premium rows is empty
# Error: 2017-05-18 00:00:00, P
# Error: 2017-05-18 00:00:00, C
# Skipping index 2017-05-18 00:00:00: One of the premium rows is empty
# Error: 2017-05-23 00:00:00, P
# Error: 2017-05-23 00:00:00, C
# Skipping index 2017-05-23 00:00:00: One of the premium rows is empty
# Error: 2017-06-02 00:00:00, P
# Error: 2017-06-02 00:00:00, C
# Skipping index 2017-06-02 00:00:00: One of the premium rows is empty
# Error: 2017-06-30 00:00:00, P
# Error: 2017-06-30 00:00:00, C
# Skipping index 2017-06-30 00:00:00: One of the premium rows is empty
# Error: 2017-07-28 00:00:00, P
# Error: 2017-07-28 00:00:00, C
# Skipping index 2017-07-28 00:00:00: One of the premium rows is empty
# Error: 2017-08-15 00:00:00, P
# Error: 2017-08-15 00:00:00, C
# Skipping index 2017-08-15 00:00:00: One of the premium rows is empty
# Error: 2017-09-12 00:00:00, P
# Error: 2017-09-12 00:00:00, C
# Skipping index 2017-09-12 00:00:00: One of the premium rows is empty
# Error: 2017-09-29 00:00:00, P
# Error: 2017-09-29 00:00:00, C
# Skipping index 2017-09-29 00:00:00: One of the premium rows is empty
# Error: 2017-10-26 00:00:00, P
# Error: 2017-10-26 00:00:00, C
# Skipping index 2017-10-26 00:00:00: One of the premium rows is empty
# Error: 2017-11-09 00:00:00, P
# Error: 2017-11-09 00:00:00, C
# Skipping index 2017-11-09 00:00:00: One of the premium rows is empty
# Error: 2017-11-15 00:00:00, P
# Error: 2017-11-15 00:00:00, C
# Skipping index 2017-11-15 00:00:00: One of the premium rows is empty
# Error: 2017-11-21 00:00:00, P
# Error: 2017-11-21 00:00:00, C
# Skipping index 2017-11-21 00:00:00: One of the premium rows is empty
# Error: 2017-12-14 00:00:00, P
# Error: 2017-12-14 00:00:00, C
# Skipping index 2017-12-14 00:00:00: One of the premium rows is empty
# Error: 2017-12-20 00:00:00, P
# Error: 2017-12-20 00:00:00, C
# Skipping index 2017-12-20 00:00:00: One of the premium rows is empty
# Error: 2018-01-12 00:00:00, P
# Error: 2018-01-12 00:00:00, C
# Skipping index 2018-01-12 00:00:00: One of the premium rows is empty
# Error: 2018-02-07 00:00:00, P
# Error: 2018-02-07 00:00:00, C
# Skipping index 2018-02-07 00:00:00: One of the premium rows is empty
# Error: 2018-03-20 00:00:00, P
# Error: 2018-03-20 00:00:00, C
# Skipping index 2018-03-20 00:00:00: One of the premium rows is empty
# Error: 2018-05-10 00:00:00, P
# Error: 2018-05-10 00:00:00, C
# Skipping index 2018-05-10 00:00:00: One of the premium rows is empty
# Error: 2018-05-15 00:00:00, P
# Error: 2018-05-15 00:00:00, C
# Skipping index 2018-05-15 00:00:00: One of the premium rows is empty
# Error: 2018-06-05 00:00:00, P
# Error: 2018-06-05 00:00:00, C
# Skipping index 2018-06-05 00:00:00: One of the premium rows is empty
# Error: 2018-06-27 00:00:00, P
# Error: 2018-06-27 00:00:00, C
# Skipping index 2018-06-27 00:00:00: One of the premium rows is empty
# Error: 2018-09-05 00:00:00, P
# Error: 2018-09-05 00:00:00, C
# Skipping index 2018-09-05 00:00:00: One of the premium rows is empty
# Error: 2018-09-11 00:00:00, P
# Error: 2018-09-11 00:00:00, C
# Skipping index 2018-09-11 00:00:00: One of the premium rows is empty
# Error: 2018-09-21 00:00:00, P
# Error: 2018-09-21 00:00:00, C
# Skipping index 2018-09-21 00:00:00: One of the premium rows is empty
# Error: 2018-10-02 00:00:00, P
# Error: 2018-10-02 00:00:00, C
# Skipping index 2018-10-02 00:00:00: One of the premium rows is empty
# Error: 2018-10-09 00:00:00, P
# Error: 2018-10-09 00:00:00, C
# Skipping index 2018-10-09 00:00:00: One of the premium rows is empty
# Error: 2018-10-16 00:00:00, P
# Error: 2018-10-16 00:00:00, C
# Skipping index 2018-10-16 00:00:00: One of the premium rows is empty
# Error: 2018-10-25 00:00:00, P
# Error: 2018-10-25 00:00:00, C
# Skipping index 2018-10-25 00:00:00: One of the premium rows is empty
# Error: 2018-10-30 00:00:00, P
# Error: 2018-10-30 00:00:00, C
# Skipping index 2018-10-30 00:00:00: One of the premium rows is empty
# Error: 2018-11-13 00:00:00, P
# Error: 2018-11-13 00:00:00, C
# Skipping index 2018-11-13 00:00:00: One of the premium rows is empty
# Error: 2018-12-18 00:00:00, P
# Error: 2018-12-18 00:00:00, C
# Skipping index 2018-12-18 00:00:00: One of the premium rows is empty
# Error: 2019-01-04 00:00:00, P
# Error: 2019-01-04 00:00:00, C
# Skipping index 2019-01-04 00:00:00: One of the premium rows is empty
# Error: 2019-01-16 00:00:00, P
# Error: 2019-01-16 00:00:00, C
# Skipping index 2019-01-16 00:00:00: One of the premium rows is empty
# Error: 2019-03-26 00:00:00, P
# Error: 2019-03-26 00:00:00, C
# Skipping index 2019-03-26 00:00:00: One of the premium rows is empty
# Error: 2019-04-03 00:00:00, P
# Error: 2019-04-03 00:00:00, C
# Skipping index 2019-04-03 00:00:00: One of the premium rows is empty
# Error: 2019-05-15 00:00:00, P
# Error: 2019-05-15 00:00:00, C
# Skipping index 2019-05-15 00:00:00: One of the premium rows is empty
# Error: 2019-06-07 00:00:00, P
# Error: 2019-06-07 00:00:00, C
# Skipping index 2019-06-07 00:00:00: One of the premium rows is empty
# Error: 2019-06-14 00:00:00, P
# Error: 2019-06-14 00:00:00, C
# Skipping index 2019-06-14 00:00:00: One of the premium rows is empty
# Error: 2019-06-25 00:00:00, P
# Error: 2019-06-25 00:00:00, C
# Skipping index 2019-06-25 00:00:00: One of the premium rows is empty
# Error: 2019-07-25 00:00:00, P
# Error: 2019-07-25 00:00:00, C
# Skipping index 2019-07-25 00:00:00: One of the premium rows is empty
# Error: 2019-07-30 00:00:00, P
# Error: 2019-07-30 00:00:00, C
# Skipping index 2019-07-30 00:00:00: One of the premium rows is empty
# Error: 2019-08-20 00:00:00, P
# Error: 2019-08-20 00:00:00, C
# Skipping index 2019-08-20 00:00:00: One of the premium rows is empty
# Error: 2019-09-05 00:00:00, P
# Error: 2019-09-05 00:00:00, C
# Skipping index 2019-09-05 00:00:00: One of the premium rows is empty
# Error: 2019-09-10 00:00:00, P
# Error: 2019-09-10 00:00:00, C
# Skipping index 2019-09-10 00:00:00: One of the premium rows is empty
# Error: 2019-09-24 00:00:00, P
# Error: 2019-09-24 00:00:00, C
# Skipping index 2019-09-24 00:00:00: One of the premium rows is empty
# Error: 2019-10-16 00:00:00, P
# Error: 2019-10-16 00:00:00, C
# Skipping index 2019-10-16 00:00:00: One of the premium rows is empty
# Error: 2019-10-30 00:00:00, P
# Error: 2019-10-30 00:00:00, C
# Skipping index 2019-10-30 00:00:00: One of the premium rows is empty
# Error: 2019-11-07 00:00:00, P
# Error: 2019-11-07 00:00:00, C
# Skipping index 2019-11-07 00:00:00: One of the premium rows is empty
# Error: 2019-11-15 00:00:00, P
# Error: 2019-11-15 00:00:00, C
# Skipping index 2019-11-15 00:00:00: One of the premium rows is empty
# Error: 2019-12-03 00:00:00, P
# Error: 2019-12-03 00:00:00, C
# Skipping index 2019-12-03 00:00:00: One of the premium rows is empty
# Error: 2019-12-18 00:00:00, P
# Error: 2019-12-18 00:00:00, C
# Skipping index 2019-12-18 00:00:00: One of the premium rows is empty
# Error: 2020-01-07 00:00:00, P
# Error: 2020-01-07 00:00:00, C
# Skipping index 2020-01-07 00:00:00: One of the premium rows is empty
# Error: 2020-01-17 00:00:00, P
# Error: 2020-01-17 00:00:00, C
# Skipping index 2020-01-17 00:00:00: One of the premium rows is empty
# Error: 2020-01-23 00:00:00, P
# Error: 2020-01-23 00:00:00, C
# Skipping index 2020-01-23 00:00:00: One of the premium rows is empty
# Error: 2020-01-29 00:00:00, P
# Error: 2020-01-29 00:00:00, C
# Skipping index 2020-01-29 00:00:00: One of the premium rows is empty
# Error: 2020-02-06 00:00:00, P
# Error: 2020-02-06 00:00:00, C
# Skipping index 2020-02-06 00:00:00: One of the premium rows is empty
# Error: 2020-02-21 00:00:00, P
# Error: 2020-02-21 00:00:00, C
# Skipping index 2020-02-21 00:00:00: One of the premium rows is empty
# Error: 2020-02-28 00:00:00, P
# Error: 2020-02-28 00:00:00, C
# Skipping index 2020-02-28 00:00:00: One of the premium rows is empty
# Error: 2020-03-03 00:00:00, P
# Error: 2020-03-03 00:00:00, C
# Skipping index 2020-03-03 00:00:00: One of the premium rows is empty
# Error: 2020-03-17 00:00:00, P
# Error: 2020-03-17 00:00:00, C
# Skipping index 2020-03-17 00:00:00: One of the premium rows is empty
# Error: 2020-03-24 00:00:00, P
# Error: 2020-03-24 00:00:00, C
# Skipping index 2020-03-24 00:00:00: One of the premium rows is empty
# Error: 2020-04-16 00:00:00, P
# Error: 2020-04-16 00:00:00, C
# Skipping index 2020-04-16 00:00:00: One of the premium rows is empty
# Error: 2020-06-12 00:00:00, P
# Error: 2020-06-12 00:00:00, C
# Skipping index 2020-06-12 00:00:00: One of the premium rows is empty
# Error: 2020-07-06 00:00:00, P
# Error: 2020-07-06 00:00:00, C
# Skipping index 2020-07-06 00:00:00: One of the premium rows is empty
# Error: 2020-07-21 00:00:00, P
# Error: 2020-07-21 00:00:00, C
# Skipping index 2020-07-21 00:00:00: One of the premium rows is empty
# Error: 2020-07-30 00:00:00, P
# Error: 2020-07-30 00:00:00, C
# Skipping index 2020-07-30 00:00:00: One of the premium rows is empty
# Error: 2020-08-11 00:00:00, P
# Error: 2020-08-11 00:00:00, C
# Skipping index 2020-08-11 00:00:00: One of the premium rows is empty
# Error: 2020-09-03 00:00:00, P
# Error: 2020-09-03 00:00:00, C
# Skipping index 2020-09-03 00:00:00: One of the premium rows is empty
# Error: 2020-09-09 00:00:00, P
# Error: 2020-09-09 00:00:00, C
# Skipping index 2020-09-09 00:00:00: One of the premium rows is empty
# Error: 2020-10-08 00:00:00, P
# Error: 2020-10-08 00:00:00, C
# Skipping index 2020-10-08 00:00:00: One of the premium rows is empty
# Error: 2020-11-06 00:00:00, P
# Error: 2020-11-06 00:00:00, C
# Skipping index 2020-11-06 00:00:00: One of the premium rows is empty
# Error: 2020-11-10 00:00:00, P
# Error: 2020-11-10 00:00:00, C
# Skipping index 2020-11-10 00:00:00: One of the premium rows is empty
# Error: 2020-12-11 00:00:00, P
# Error: 2020-12-11 00:00:00, C
# Skipping index 2020-12-11 00:00:00: One of the premium rows is empty
# Error: 2020-12-15 00:00:00, P
# Error: 2020-12-15 00:00:00, C
# Skipping index 2020-12-15 00:00:00: One of the premium rows is empty
# Error: 2021-01-08 00:00:00, P
# Error: 2021-01-08 00:00:00, C
# Skipping index 2021-01-08 00:00:00: One of the premium rows is empty
# Error: 2021-01-12 00:00:00, P
# Error: 2021-01-12 00:00:00, C
# Skipping index 2021-01-12 00:00:00: One of the premium rows is empty
# Error: 2021-01-26 00:00:00, P
# Error: 2021-01-26 00:00:00, C
# Skipping index 2021-01-26 00:00:00: One of the premium rows is empty
# Error: 2021-02-02 00:00:00, P
# Error: 2021-02-02 00:00:00, C
# Skipping index 2021-02-02 00:00:00: One of the premium rows is empty
# Error: 2021-02-26 00:00:00, P
# Error: 2021-02-26 00:00:00, C
# Skipping index 2021-02-26 00:00:00: One of the premium rows is empty
# Error: 2021-03-02 00:00:00, P
# Error: 2021-03-02 00:00:00, C
# Skipping index 2021-03-02 00:00:00: One of the premium rows is empty
# Error: 2021-03-19 00:00:00, P
# Error: 2021-03-19 00:00:00, C
# Skipping index 2021-03-19 00:00:00: One of the premium rows is empty
# Error: 2021-03-24 00:00:00, P
# Error: 2021-03-24 00:00:00, C
# Skipping index 2021-03-24 00:00:00: One of the premium rows is empty
# Error: 2021-04-13 00:00:00, P
# Error: 2021-04-13 00:00:00, C
# Skipping index 2021-04-13 00:00:00: One of the premium rows is empty
# Error: 2021-05-12 00:00:00, P
# Error: 2021-05-12 00:00:00, C
# Skipping index 2021-05-12 00:00:00: One of the premium rows is empty
# Error: 2021-06-24 00:00:00, P
# Error: 2021-06-24 00:00:00, C
# Skipping index 2021-06-24 00:00:00: One of the premium rows is empty
# Error: 2021-06-29 00:00:00, P
# Error: 2021-06-29 00:00:00, C
# Skipping index 2021-06-29 00:00:00: One of the premium rows is empty
# Error: 2021-07-23 00:00:00, P
# Error: 2021-07-23 00:00:00, C
# Skipping index 2021-07-23 00:00:00: One of the premium rows is empty
# Error: 2021-07-29 00:00:00, P
# Error: 2021-07-29 00:00:00, C
# Skipping index 2021-07-29 00:00:00: One of the premium rows is empty
# Error: 2021-08-05 00:00:00, P
# Error: 2021-08-05 00:00:00, C
# Skipping index 2021-08-05 00:00:00: One of the premium rows is empty
# Error: 2021-08-25 00:00:00, P
# Error: 2021-08-25 00:00:00, C
# Skipping index 2021-08-25 00:00:00: One of the premium rows is empty
# Error: 2021-09-10 00:00:00, P
# Error: 2021-09-10 00:00:00, C
# Skipping index 2021-09-10 00:00:00: One of the premium rows is empty
# Error: 2021-09-21 00:00:00, P
# Error: 2021-09-21 00:00:00, C
# Skipping index 2021-09-21 00:00:00: One of the premium rows is empty
# Error: 2021-10-06 00:00:00, P
# Error: 2021-10-06 00:00:00, C
# Skipping index 2021-10-06 00:00:00: One of the premium rows is empty
# Error: 2021-10-12 00:00:00, P
# Error: 2021-10-12 00:00:00, C
# Skipping index 2021-10-12 00:00:00: One of the premium rows is empty
# Error: 2021-10-22 00:00:00, P
# Error: 2021-10-22 00:00:00, C
# Skipping index 2021-10-22 00:00:00: One of the premium rows is empty
# Error: 2021-11-12 00:00:00, P
# Error: 2021-11-12 00:00:00, C
# Skipping index 2021-11-12 00:00:00: One of the premium rows is empty
# Error: 2021-11-16 00:00:00, P
# Error: 2021-11-16 00:00:00, C
# Skipping index 2021-11-16 00:00:00: One of the premium rows is empty
# Error: 2021-12-07 00:00:00, P
# Error: 2021-12-07 00:00:00, C
# Skipping index 2021-12-07 00:00:00: One of the premium rows is empty
# Error: 2022-01-04 00:00:00, P
# Error: 2022-01-04 00:00:00, C
# Skipping index 2022-01-04 00:00:00: One of the premium rows is empty
# Error: 2022-02-03 00:00:00, P
# Error: 2022-02-03 00:00:00, C
# Skipping index 2022-02-03 00:00:00: One of the premium rows is empty
# Error: 2022-02-08 00:00:00, P
# Error: 2022-02-08 00:00:00, C
# Skipping index 2022-02-08 00:00:00: One of the premium rows is empty
# Error: 2022-03-01 00:00:00, P
# Error: 2022-03-01 00:00:00, C
# Skipping index 2022-03-01 00:00:00: One of the premium rows is empty
# Error: 2022-04-08 00:00:00, P
# Error: 2022-04-08 00:00:00, C
# Skipping index 2022-04-08 00:00:00: One of the premium rows is empty
# Error: 2022-05-04 00:00:00, P
# Error: 2022-05-04 00:00:00, C
# Skipping index 2022-05-04 00:00:00: One of the premium rows is empty
# Error: 2022-05-12 00:00:00, P
# Error: 2022-05-12 00:00:00, C
# Skipping index 2022-05-12 00:00:00: One of the premium rows is empty
# Error: 2022-05-26 00:00:00, P
# Error: 2022-05-26 00:00:00, C
# Skipping index 2022-05-26 00:00:00: One of the premium rows is empty
# Error: 2022-06-16 00:00:00, P
# Error: 2022-06-16 00:00:00, C
# Skipping index 2022-06-16 00:00:00: One of the premium rows is empty
# Error: 2022-06-22 00:00:00, P
# Error: 2022-06-22 00:00:00, C
# Skipping index 2022-06-22 00:00:00: One of the premium rows is empty
# Error: 2022-07-07 00:00:00, P
# Error: 2022-07-07 00:00:00, C
# Skipping index 2022-07-07 00:00:00: One of the premium rows is empty
# Error: 2022-08-02 00:00:00, P
# Error: 2022-08-02 00:00:00, C
# Skipping index 2022-08-02 00:00:00: One of the premium rows is empty
# Error: 2022-08-23 00:00:00, P
# Error: 2022-08-23 00:00:00, C
# Skipping index 2022-08-23 00:00:00: One of the premium rows is empty
# Error: 2022-09-07 00:00:00, P
# Error: 2022-09-07 00:00:00, C
# Skipping index 2022-09-07 00:00:00: One of the premium rows is empty
# Error: 2022-10-04 00:00:00, P
# Error: 2022-10-04 00:00:00, C
# Skipping index 2022-10-04 00:00:00: One of the premium rows is empty
# Error: 2022-11-15 00:00:00, P
# Error: 2022-11-15 00:00:00, C
# Skipping index 2022-11-15 00:00:00: One of the premium rows is empty
# Error: 2022-11-22 00:00:00, P
# Error: 2022-11-22 00:00:00, C
# Skipping index 2022-11-22 00:00:00: One of the premium rows is empty
# Error: 2022-11-29 00:00:00, P
# Error: 2022-11-29 00:00:00, C
# Skipping index 2022-11-29 00:00:00: One of the premium rows is empty
# Error: 2022-12-14 00:00:00, P
# Error: 2022-12-14 00:00:00, C
# Skipping index 2022-12-14 00:00:00: One of the premium rows is empty
# Error: 2023-01-20 00:00:00, P
# Error: 2023-01-20 00:00:00, C
# Skipping index 2023-01-20 00:00:00: One of the premium rows is empty
# Error: 2023-02-08 00:00:00, P
# Error: 2023-02-08 00:00:00, C
# Skipping index 2023-02-08 00:00:00: One of the premium rows is empty
# Error: 2023-02-14 00:00:00, P
# Error: 2023-02-14 00:00:00, C
# Skipping index 2023-02-14 00:00:00: One of the premium rows is empty
# Error: 2023-03-03 00:00:00, P
# Error: 2023-03-03 00:00:00, C
# Skipping index 2023-03-03 00:00:00: One of the premium rows is empty
# Error: 2023-03-07 00:00:00, P
# Error: 2023-03-07 00:00:00, C
# Skipping index 2023-03-07 00:00:00: One of the premium rows is empty
# Error: 2023-03-23 00:00:00, P
# Error: 2023-03-23 00:00:00, C
# Skipping index 2023-03-23 00:00:00: One of the premium rows is empty
# Error: 2023-03-28 00:00:00, P
# Error: 2023-03-28 00:00:00, C
# Skipping index 2023-03-28 00:00:00: One of the premium rows is empty
# Error: 2023-05-18 00:00:00, P
# Error: 2023-05-18 00:00:00, C
# Skipping index 2023-05-18 00:00:00: One of the premium rows is empty
# Error: 2023-06-06 00:00:00, P
# Error: 2023-06-06 00:00:00, C
# Skipping index 2023-06-06 00:00:00: One of the premium rows is empty
# Error: 2023-06-28 00:00:00, P
# Error: 2023-06-28 00:00:00, C
# Skipping index 2023-06-28 00:00:00: One of the premium rows is empty
# Error: 2023-07-05 00:00:00, P
# Error: 2023-07-05 00:00:00, C
# Skipping index 2023-07-05 00:00:00: One of the premium rows is empty
# Error: 2023-07-18 00:00:00, P
# Error: 2023-07-18 00:00:00, C
# Skipping index 2023-07-18 00:00:00: One of the premium rows is empty
# Error: 2023-07-25 00:00:00, P
# Error: 2023-07-25 00:00:00, C
# Skipping index 2023-07-25 00:00:00: One of the premium rows is empty
# Error: 2023-08-08 00:00:00, P
# Error: 2023-08-08 00:00:00, C
# Skipping index 2023-08-08 00:00:00: One of the premium rows is empty
# Error: 2016-11-03 00:00:00, P
# Error: 2016-11-03 00:00:00, C
# Skipping index 2016-11-03 00:00:00: One of the premium rows is empty
# Error: 2016-11-14 00:00:00, P
# Error: 2016-11-14 00:00:00, C
# Skipping index 2016-11-14 00:00:00: One of the premium rows is empty
# Error: 2016-11-15 00:00:00, P
# Error: 2016-11-15 00:00:00, C
# Skipping index 2016-11-15 00:00:00: One of the premium rows is empty
# Error: 2017-02-03 00:00:00, P
# Error: 2017-02-03 00:00:00, C
# Skipping index 2017-02-03 00:00:00: One of the premium rows is empty
# Error: 2017-02-07 00:00:00, P
# Error: 2017-02-07 00:00:00, C
# Skipping index 2017-02-07 00:00:00: One of the premium rows is empty
# Error: 2017-02-28 00:00:00, P
# Error: 2017-02-28 00:00:00, C
# Skipping index 2017-02-28 00:00:00: One of the premium rows is empty
# Error: 2017-03-23 00:00:00, P
# Error: 2017-03-23 00:00:00, C
# Skipping index 2017-03-23 00:00:00: One of the premium rows is empty
# Error: 2017-05-19 00:00:00, P
# Error: 2017-05-19 00:00:00, C
# Skipping index 2017-05-19 00:00:00: One of the premium rows is empty
# Error: 2017-05-23 00:00:00, P
# Error: 2017-05-23 00:00:00, C
# Skipping index 2017-05-23 00:00:00: One of the premium rows is empty
# Error: 2017-06-30 00:00:00, P
# Error: 2017-06-30 00:00:00, C
# Skipping index 2017-06-30 00:00:00: One of the premium rows is empty
# Error: 2017-07-05 00:00:00, P
# Error: 2017-07-05 00:00:00, C
# Skipping index 2017-07-05 00:00:00: One of the premium rows is empty
# Error: 2017-07-28 00:00:00, P
# Error: 2017-07-28 00:00:00, C
# Skipping index 2017-07-28 00:00:00: One of the premium rows is empty
# Error: 2017-08-15 00:00:00, P
# Error: 2017-08-15 00:00:00, C
# Skipping index 2017-08-15 00:00:00: One of the premium rows is empty
# Error: 2017-09-12 00:00:00, P
# Error: 2017-09-12 00:00:00, C
# Skipping index 2017-09-12 00:00:00: One of the premium rows is empty
# Error: 2017-09-29 00:00:00, P
# Error: 2017-09-29 00:00:00, C
# Skipping index 2017-09-29 00:00:00: One of the premium rows is empty
# Error: 2017-11-09 00:00:00, P
# Error: 2017-11-09 00:00:00, C
# Skipping index 2017-11-09 00:00:00: One of the premium rows is empty
# Error: 2017-11-15 00:00:00, P
# Error: 2017-11-15 00:00:00, C
# Skipping index 2017-11-15 00:00:00: One of the premium rows is empty
# Error: 2017-11-21 00:00:00, P
# Error: 2017-11-21 00:00:00, C
# Skipping index 2017-11-21 00:00:00: One of the premium rows is empty
# Error: 2017-12-14 00:00:00, P
# Error: 2017-12-14 00:00:00, C
# Skipping index 2017-12-14 00:00:00: One of the premium rows is empty
# Error: 2017-12-20 00:00:00, P
# Error: 2017-12-20 00:00:00, C
# Skipping index 2017-12-20 00:00:00: One of the premium rows is empty
# Error: 2018-01-12 00:00:00, P
# Error: 2018-01-12 00:00:00, C
# Skipping index 2018-01-12 00:00:00: One of the premium rows is empty
# Error: 2018-02-07 00:00:00, P
# Error: 2018-02-07 00:00:00, C
# Skipping index 2018-02-07 00:00:00: One of the premium rows is empty
# Error: 2018-05-10 00:00:00, P
# Error: 2018-05-10 00:00:00, C
# Skipping index 2018-05-10 00:00:00: One of the premium rows is empty
# Error: 2018-05-15 00:00:00, P
# Error: 2018-05-15 00:00:00, C
# Skipping index 2018-05-15 00:00:00: One of the premium rows is empty
# Error: 2018-06-05 00:00:00, P
# Error: 2018-06-05 00:00:00, C
# Skipping index 2018-06-05 00:00:00: One of the premium rows is empty
# Error: 2018-06-27 00:00:00, P
# Error: 2018-06-27 00:00:00, C
# Skipping index 2018-06-27 00:00:00: One of the premium rows is empty
# Error: 2018-09-07 00:00:00, P
# Error: 2018-09-07 00:00:00, C
# Skipping index 2018-09-07 00:00:00: One of the premium rows is empty
# Error: 2018-09-11 00:00:00, P
# Error: 2018-09-11 00:00:00, C
# Skipping index 2018-09-11 00:00:00: One of the premium rows is empty
# Error: 2018-09-21 00:00:00, P
# Error: 2018-09-21 00:00:00, C
# Skipping index 2018-09-21 00:00:00: One of the premium rows is empty
# Error: 2018-10-02 00:00:00, P
# Error: 2018-10-02 00:00:00, C
# Skipping index 2018-10-02 00:00:00: One of the premium rows is empty
# Error: 2018-10-09 00:00:00, P
# Error: 2018-10-09 00:00:00, C
# Skipping index 2018-10-09 00:00:00: One of the premium rows is empty
# Error: 2018-10-16 00:00:00, P
# Error: 2018-10-16 00:00:00, C
# Skipping index 2018-10-16 00:00:00: One of the premium rows is empty
# Error: 2018-10-26 00:00:00, P
# Error: 2018-10-26 00:00:00, C
# Skipping index 2018-10-26 00:00:00: One of the premium rows is empty
# Error: 2018-10-30 00:00:00, P
# Error: 2018-10-30 00:00:00, C
# Skipping index 2018-10-30 00:00:00: One of the premium rows is empty
# Error: 2019-01-04 00:00:00, P
# Error: 2019-01-04 00:00:00, C
# Skipping index 2019-01-04 00:00:00: One of the premium rows is empty
# Error: 2019-01-16 00:00:00, P
# Error: 2019-01-16 00:00:00, C
# Skipping index 2019-01-16 00:00:00: One of the premium rows is empty
# Error: 2019-03-26 00:00:00, P
# Error: 2019-03-26 00:00:00, C
# Skipping index 2019-03-26 00:00:00: One of the premium rows is empty
# Error: 2019-04-03 00:00:00, P
# Error: 2019-04-03 00:00:00, C
# Skipping index 2019-04-03 00:00:00: One of the premium rows is empty
# Error: 2019-05-15 00:00:00, P
# Error: 2019-05-15 00:00:00, C
# Skipping index 2019-05-15 00:00:00: One of the premium rows is empty
# Error: 2019-06-07 00:00:00, P
# Error: 2019-06-07 00:00:00, C
# Skipping index 2019-06-07 00:00:00: One of the premium rows is empty
# Error: 2019-06-14 00:00:00, P
# Error: 2019-06-14 00:00:00, C
# Skipping index 2019-06-14 00:00:00: One of the premium rows is empty
# Error: 2019-07-25 00:00:00, P
# Error: 2019-07-25 00:00:00, C
# Skipping index 2019-07-25 00:00:00: One of the premium rows is empty
# Error: 2019-08-20 00:00:00, P
# Error: 2019-08-20 00:00:00, C
# Skipping index 2019-08-20 00:00:00: One of the premium rows is empty
# Error: 2019-09-05 00:00:00, P
# Error: 2019-09-05 00:00:00, C
# Skipping index 2019-09-05 00:00:00: One of the premium rows is empty
# Error: 2019-09-10 00:00:00, P
# Error: 2019-09-10 00:00:00, C
# Skipping index 2019-09-10 00:00:00: One of the premium rows is empty
# Error: 2019-10-16 00:00:00, P
# Error: 2019-10-16 00:00:00, C
# Skipping index 2019-10-16 00:00:00: One of the premium rows is empty
# Error: 2019-10-30 00:00:00, P
# Error: 2019-10-30 00:00:00, C
# Skipping index 2019-10-30 00:00:00: One of the premium rows is empty
# Error: 2019-11-07 00:00:00, P
# Error: 2019-11-07 00:00:00, C
# Skipping index 2019-11-07 00:00:00: One of the premium rows is empty
# Error: 2019-11-15 00:00:00, P
# Error: 2019-11-15 00:00:00, C
# Skipping index 2019-11-15 00:00:00: One of the premium rows is empty
# Error: 2019-12-18 00:00:00, P
# Error: 2019-12-18 00:00:00, C
# Skipping index 2019-12-18 00:00:00: One of the premium rows is empty
# Error: 2020-01-07 00:00:00, P
# Error: 2020-01-07 00:00:00, C
# Skipping index 2020-01-07 00:00:00: One of the premium rows is empty
# Error: 2020-01-17 00:00:00, P
# Error: 2020-01-17 00:00:00, C
# Skipping index 2020-01-17 00:00:00: One of the premium rows is empty
# Error: 2020-01-23 00:00:00, P
# Error: 2020-01-23 00:00:00, C
# Skipping index 2020-01-23 00:00:00: One of the premium rows is empty
# Error: 2020-01-29 00:00:00, P
# Error: 2020-01-29 00:00:00, C
# Skipping index 2020-01-29 00:00:00: One of the premium rows is empty
# Error: 2020-02-06 00:00:00, P
# Error: 2020-02-06 00:00:00, C
# Skipping index 2020-02-06 00:00:00: One of the premium rows is empty
# Error: 2020-02-21 00:00:00, P
# Error: 2020-02-21 00:00:00, C
# Skipping index 2020-02-21 00:00:00: One of the premium rows is empty
# Error: 2020-03-03 00:00:00, P
# Error: 2020-03-03 00:00:00, C
# Skipping index 2020-03-03 00:00:00: One of the premium rows is empty
# Error: 2020-03-19 00:00:00, P
# Error: 2020-03-19 00:00:00, C
# Skipping index 2020-03-19 00:00:00: One of the premium rows is empty
# Error: 2020-03-24 00:00:00, P
# Error: 2020-03-24 00:00:00, C
# Skipping index 2020-03-24 00:00:00: One of the premium rows is empty
# Error: 2020-03-31 00:00:00, P
# Error: 2020-03-31 00:00:00, C
# Skipping index 2020-03-31 00:00:00: One of the premium rows is empty
# Error: 2020-07-06 00:00:00, P
# Error: 2020-07-06 00:00:00, C
# Skipping index 2020-07-06 00:00:00: One of the premium rows is empty
# Error: 2020-07-21 00:00:00, P
# Error: 2020-07-21 00:00:00, C
# Skipping index 2020-07-21 00:00:00: One of the premium rows is empty
# Error: 2020-07-30 00:00:00, P
# Error: 2020-07-30 00:00:00, C
# Skipping index 2020-07-30 00:00:00: One of the premium rows is empty
# Error: 2020-08-11 00:00:00, P
# Error: 2020-08-11 00:00:00, C
# Skipping index 2020-08-11 00:00:00: One of the premium rows is empty
# Error: 2020-09-03 00:00:00, P
# Error: 2020-09-03 00:00:00, C
# Skipping index 2020-09-03 00:00:00: One of the premium rows is empty
# Error: 2020-09-09 00:00:00, P
# Error: 2020-09-09 00:00:00, C
# Skipping index 2020-09-09 00:00:00: One of the premium rows is empty
# Error: 2020-10-08 00:00:00, P
# Error: 2020-10-08 00:00:00, C
# Skipping index 2020-10-08 00:00:00: One of the premium rows is empty
# Error: 2020-11-06 00:00:00, P
# Error: 2020-11-06 00:00:00, C
# Skipping index 2020-11-06 00:00:00: One of the premium rows is empty
# Error: 2020-11-10 00:00:00, P
# Error: 2020-11-10 00:00:00, C
# Skipping index 2020-11-10 00:00:00: One of the premium rows is empty
# Error: 2021-01-08 00:00:00, P
# Error: 2021-01-08 00:00:00, C
# Skipping index 2021-01-08 00:00:00: One of the premium rows is empty
# Error: 2021-01-12 00:00:00, P
# Error: 2021-01-12 00:00:00, C
# Skipping index 2021-01-12 00:00:00: One of the premium rows is empty
# Error: 2021-01-27 00:00:00, P
# Error: 2021-01-27 00:00:00, C
# Skipping index 2021-01-27 00:00:00: One of the premium rows is empty
# Error: 2021-02-02 00:00:00, P
# Error: 2021-02-02 00:00:00, C
# Skipping index 2021-02-02 00:00:00: One of the premium rows is empty
# Error: 2021-02-26 00:00:00, P
# Error: 2021-02-26 00:00:00, C
# Skipping index 2021-02-26 00:00:00: One of the premium rows is empty
# Error: 2021-03-02 00:00:00, P
# Error: 2021-03-02 00:00:00, C
# Skipping index 2021-03-02 00:00:00: One of the premium rows is empty
# Error: 2021-03-19 00:00:00, P
# Error: 2021-03-19 00:00:00, C
# Skipping index 2021-03-19 00:00:00: One of the premium rows is empty
# Error: 2021-03-24 00:00:00, P
# Error: 2021-03-24 00:00:00, C
# Skipping index 2021-03-24 00:00:00: One of the premium rows is empty
# Error: 2021-05-12 00:00:00, P
# Error: 2021-05-12 00:00:00, C
# Skipping index 2021-05-12 00:00:00: One of the premium rows is empty
# Error: 2021-06-24 00:00:00, P
# Error: 2021-06-24 00:00:00, C
# Skipping index 2021-06-24 00:00:00: One of the premium rows is empty
# Error: 2021-06-29 00:00:00, P
# Error: 2021-06-29 00:00:00, C
# Skipping index 2021-06-29 00:00:00: One of the premium rows is empty
# Error: 2021-07-23 00:00:00, P
# Error: 2021-07-23 00:00:00, C
# Skipping index 2021-07-23 00:00:00: One of the premium rows is empty
# Error: 2021-07-27 00:00:00, P
# Error: 2021-07-27 00:00:00, C
# Skipping index 2021-07-27 00:00:00: One of the premium rows is empty
# Error: 2021-08-25 00:00:00, P
# Error: 2021-08-25 00:00:00, C
# Skipping index 2021-08-25 00:00:00: One of the premium rows is empty
# Error: 2021-09-10 00:00:00, P
# Error: 2021-09-10 00:00:00, C
# Skipping index 2021-09-10 00:00:00: One of the premium rows is empty
# Error: 2021-10-06 00:00:00, P
# Error: 2021-10-06 00:00:00, C
# Skipping index 2021-10-06 00:00:00: One of the premium rows is empty
# Error: 2021-10-12 00:00:00, P
# Error: 2021-10-12 00:00:00, C
# Skipping index 2021-10-12 00:00:00: One of the premium rows is empty
# Error: 2021-10-22 00:00:00, P
# Error: 2021-10-22 00:00:00, C
# Skipping index 2021-10-22 00:00:00: One of the premium rows is empty
# Error: 2021-11-12 00:00:00, P
# Error: 2021-11-12 00:00:00, C
# Skipping index 2021-11-12 00:00:00: One of the premium rows is empty
# Error: 2021-11-16 00:00:00, P
# Error: 2021-11-16 00:00:00, C
# Skipping index 2021-11-16 00:00:00: One of the premium rows is empty
# Error: 2021-12-07 00:00:00, P
# Error: 2021-12-07 00:00:00, C
# Skipping index 2021-12-07 00:00:00: One of the premium rows is empty
# Error: 2022-02-03 00:00:00, P
# Error: 2022-02-03 00:00:00, C
# Skipping index 2022-02-03 00:00:00: One of the premium rows is empty
# Error: 2022-02-08 00:00:00, P
# Error: 2022-02-08 00:00:00, C
# Skipping index 2022-02-08 00:00:00: One of the premium rows is empty
# Error: 2022-03-01 00:00:00, P
# Error: 2022-03-01 00:00:00, C
# Skipping index 2022-03-01 00:00:00: One of the premium rows is empty
# Error: 2022-04-08 00:00:00, P
# Error: 2022-04-08 00:00:00, C
# Skipping index 2022-04-08 00:00:00: One of the premium rows is empty
# Error: 2022-05-04 00:00:00, P
# Error: 2022-05-04 00:00:00, C
# Skipping index 2022-05-04 00:00:00: One of the premium rows is empty
# Error: 2022-05-12 00:00:00, P
# Error: 2022-05-12 00:00:00, C
# Skipping index 2022-05-12 00:00:00: One of the premium rows is empty
# Error: 2022-05-26 00:00:00, P
# Error: 2022-05-26 00:00:00, C
# Skipping index 2022-05-26 00:00:00: One of the premium rows is empty
# Error: 2022-06-16 00:00:00, P
# Error: 2022-06-16 00:00:00, C
# Skipping index 2022-06-16 00:00:00: One of the premium rows is empty
# Error: 2022-06-22 00:00:00, P
# Error: 2022-06-22 00:00:00, C
# Skipping index 2022-06-22 00:00:00: One of the premium rows is empty
# Error: 2022-07-07 00:00:00, P
# Error: 2022-07-07 00:00:00, C
# Skipping index 2022-07-07 00:00:00: One of the premium rows is empty
# Error: 2022-08-02 00:00:00, P
# Error: 2022-08-02 00:00:00, C
# Skipping index 2022-08-02 00:00:00: One of the premium rows is empty
# Error: 2022-09-07 00:00:00, P
# Error: 2022-09-07 00:00:00, C
# Skipping index 2022-09-07 00:00:00: One of the premium rows is empty
# Error: 2022-10-04 00:00:00, P
# Error: 2022-10-04 00:00:00, C
# Skipping index 2022-10-04 00:00:00: One of the premium rows is empty
# Error: 2022-11-15 00:00:00, P
# Error: 2022-11-15 00:00:00, C
# Skipping index 2022-11-15 00:00:00: One of the premium rows is empty
# Error: 2022-11-22 00:00:00, P
# Error: 2022-11-22 00:00:00, C
# Skipping index 2022-11-22 00:00:00: One of the premium rows is empty
# Error: 2022-12-14 00:00:00, P
# Error: 2022-12-14 00:00:00, C
# Skipping index 2022-12-14 00:00:00: One of the premium rows is empty
# Error: 2023-01-20 00:00:00, P
# Error: 2023-01-20 00:00:00, C
# Skipping index 2023-01-20 00:00:00: One of the premium rows is empty
# Error: 2023-02-08 00:00:00, P
# Error: 2023-02-08 00:00:00, C
# Skipping index 2023-02-08 00:00:00: One of the premium rows is empty
# Error: 2023-02-14 00:00:00, P
# Error: 2023-02-14 00:00:00, C
# Skipping index 2023-02-14 00:00:00: One of the premium rows is empty
# Error: 2023-03-03 00:00:00, P
# Error: 2023-03-03 00:00:00, C
# Skipping index 2023-03-03 00:00:00: One of the premium rows is empty
# Error: 2023-03-07 00:00:00, P
# Error: 2023-03-07 00:00:00, C
# Skipping index 2023-03-07 00:00:00: One of the premium rows is empty
# Error: 2023-03-23 00:00:00, P
# Error: 2023-03-23 00:00:00, C
# Skipping index 2023-03-23 00:00:00: One of the premium rows is empty
# Error: 2023-03-28 00:00:00, P
# Error: 2023-03-28 00:00:00, C
# Skipping index 2023-03-28 00:00:00: One of the premium rows is empty
# Error: 2023-05-18 00:00:00, P
# Error: 2023-05-18 00:00:00, C
# Skipping index 2023-05-18 00:00:00: One of the premium rows is empty
# Error: 2023-06-06 00:00:00, P
# Error: 2023-06-06 00:00:00, C
# Skipping index 2023-06-06 00:00:00: One of the premium rows is empty
# Error: 2023-06-28 00:00:00, P
# Error: 2023-06-28 00:00:00, C
# Skipping index 2023-06-28 00:00:00: One of the premium rows is empty
# Error: 2023-07-05 00:00:00, P
# Error: 2023-07-05 00:00:00, C
# Skipping index 2023-07-05 00:00:00: One of the premium rows is empty
# Error: 2023-07-25 00:00:00, P
# Error: 2023-07-25 00:00:00, C
# Skipping index 2023-07-25 00:00:00: One of the premium rows is empty
# Error: 2023-08-08 00:00:00, P
# Error: 2023-08-08 00:00:00, C
# Skipping index 2023-08-08 00:00:00: One of the premium rows is empty
# Error: 2016-11-14 00:00:00, P
# Error: 2016-11-14 00:00:00, C
# Skipping index 2016-11-14 00:00:00: One of the premium rows is empty
# Error: 2016-11-15 00:00:00, P
# Error: 2016-11-15 00:00:00, C
# Skipping index 2016-11-15 00:00:00: One of the premium rows is empty
# Error: 2017-01-20 00:00:00, P
# Error: 2017-01-20 00:00:00, C
# Skipping index 2017-01-20 00:00:00: One of the premium rows is empty
# Error: 2017-02-22 00:00:00, P
# Error: 2017-02-22 00:00:00, C
# Skipping index 2017-02-22 00:00:00: One of the premium rows is empty
# Error: 2017-05-18 00:00:00, P
# Error: 2017-05-18 00:00:00, C
# Skipping index 2017-05-18 00:00:00: One of the premium rows is empty
# Error: 2017-06-02 00:00:00, P
# Error: 2017-06-02 00:00:00, C
# Skipping index 2017-06-02 00:00:00: One of the premium rows is empty
# Error: 2017-06-30 00:00:00, P
# Error: 2017-06-30 00:00:00, C
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[124], line 7
#       4 space = [Real(0.5, 3.0, name='upper_threshold'), Real(-3.0, -0.5, name='lower_threshold')]
#       6 # Run Bayesian Optimization
# ----> 7 res = gp_minimize(objective, space, n_calls=50, random_state=0)
#       9 # Output the optimized thresholds
#      10 optimized_upper_threshold = res.x[0]
#
# File c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\skopt\optimizer\gp.py:281, in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size, space_constraint)
#     273 if base_estimator is None:
#     274     base_estimator = cook_estimator(
#     275         "GP",
#     276         space=space,
#     277         random_state=rng.randint(0, np.iinfo(np.int32).max),
#     278         noise=noise,
#     279     )
# --> 281 return base_minimize(
#     282     func,
#     283     space,
#     284     base_estimator=base_estimator,
#     285     acq_func=acq_func,
#     286     xi=xi,
#     287     kappa=kappa,
#     288     acq_optimizer=acq_optimizer,
#     289     n_calls=n_calls,
#     290     n_points=n_points,
#     291     n_random_starts=n_random_starts,
#     292     n_initial_points=n_initial_points,
#     293     initial_point_generator=initial_point_generator,
#     294     n_restarts_optimizer=n_restarts_optimizer,
#     295     x0=x0,
#     296     y0=y0,
#     297     random_state=rng,
#     298     verbose=verbose,
#     299     space_constraint=space_constraint,
#     300     callback=callback,
#     301     n_jobs=n_jobs,
#     302     model_queue_size=model_queue_size,
#     303 )
#
# File c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\skopt\optimizer\base.py:332, in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size, space_constraint)
#     330 for _ in range(n_calls):
#     331     next_x = optimizer.ask()
# --> 332     next_y = func(next_x)
#     333     result = optimizer.tell(next_x, next_y)
#     334     result.specs = specs
#
# Cell In[123], line 67, in objective(params)
#      65 premium2_row = xlu_filtered_options[(xlu_filtered_options.index == index) & (xlu_filtered_options["strike_price"] == strike2) & (xlu_filtered_options["cp_flag"] == 'P')]
#      66 premium3_row = xlu_filtered_options[(xlu_filtered_options.index == index) & (xlu_filtered_options["strike_price"] == strike3) & (xlu_filtered_options["cp_flag"] == 'C')]
# ---> 67 premium4_row = xlu_filtered_options[(xlu_filtered_options.index == index) & (xlu_filtered_options["strike_price"] == strike4) & (xlu_filtered_options["cp_flag"] == 'C')]
#      69 # Check if any of the filtered rows are empty
#      70 if premium1_row.empty or premium2_row.empty or premium3_row.empty or premium4_row.empty:
#
# File c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\pandas\core\indexes\base.py:7197, in Index._cmp_method(self, other, op)
#    7194     result = op(self._values, other)
#    7196 elif isinstance(self._values, ExtensionArray):
# -> 7197     result = op(self._values, other)
#    7199 elif is_object_dtype(self.dtype) and not isinstance(self, ABCMultiIndex):
#    7200     # don't pass MultiIndex
#    7201     result = ops.comp_method_OBJECT_ARRAY(op, self._values, other)
#
# File c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\pandas\core\arrays\datetimelike.py:1025, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#    1022 result = op(self._ndarray.view("i8"), other_vals.view("i8"))
#    1024 o_mask = isna(other)
# -> 1025 mask = self._isnan | o_mask
#    1026 if mask.any():
#    1027     nat_result = op is operator.ne
#
# File c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\pandas\core\arrays\datetimelike.py:841, in DatetimeLikeArrayMixin._isnan(self)
#     836 @property  # NB: override with cache_readonly in immutable subclasses
#     837 def _isnan(self) -> npt.NDArray[np.bool_]:
#     838     """
#     839     return if each value is nan
#     840     """
# --> 841     return self.asi8 == iNaT
#
# KeyboardInterrupt:
