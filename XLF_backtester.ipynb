# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from data_wrangling import *

# %%
def myround(x, base=5):
    return base * round(x/base)

# %%
class Option:
    def __init__(self, strike: float, premium: float, expiry: str):
        self.strike = strike
        self.premium = premium
        self.expiry = expiry
        self.spot_price = None

    def insert_spot(self, spot_price: float):
        self.spot_price = spot_price
    
    def short_call(self):
        # Payoff for short call: premium received - intrinsic value of the option
        intrinsic_value = np.maximum(0, self.spot_price - self.strike)
        return self.premium - intrinsic_value
    
    def long_call(self):
        # Payoff for long call: intrinsic value - premium paid
        intrinsic_value = np.maximum(0, self.spot_price - self.strike)
        return intrinsic_value - self.premium
    
    def short_put(self):
        # Payoff for short put: premium received - intrinsic value of the option
        intrinsic_value = np.maximum(0, self.strike - self.spot_price)
        return self.premium - intrinsic_value
    
    def long_put(self):
        # Payoff for long put: intrinsic value - premium paid
        intrinsic_value = np.maximum(0, self.strike - self.spot_price)
        return intrinsic_value - self.premium


class IronCondor:
    def __init__(self, direction: str, strikes: dict, premiums: dict, expiry: str):
        """
        Initialize the Iron Condor strategy with strikes and premiums for the options.
        
        direction: long, (short) Iron Condor
        1. Short (Long) 1 OTM Put (strike 1)
        2. Long (Short) 1 close to ATM Put (strike 2)
        3. Long (Short) 1 close to ATM Call (strike 3)
        4. Short (Long) 1 OTM Call (strike 4)        

        strikes: a dictionary of strikes for the 4 options (strike1 to strike4)
        premiums: a dictionary of premiums for the 4 options (premium1 to premium4)
        expiry: expiration date of the options
        """
        self.strikes = strikes
        self.premiums = premiums
        self.direction = direction
        self.expiry = expiry
        self.short_put_option = Option(strikes['strike1'], premiums['premium1'], expiry)
        self.long_put_option = Option(strikes['strike2'], premiums['premium2'], expiry)
        self.long_call_option = Option(strikes['strike3'], premiums['premium3'], expiry)
        self.short_call_option = Option(strikes['strike4'], premiums['premium4'], expiry)

    def initial_cashflow(self):
        """
        Calculate the initial cashflow of the Iron Condor strategy.
        """
        if self.direction == "long":
            initial_cashflow = self.premiums['premium1'] - self.premiums['premium2'] - self.premiums['premium3'] + self.premiums['premium4']
        elif self.direction == "short":
            initial_cashflow = -self.premiums['premium1'] + self.premiums['premium2'] + self.premiums['premium3'] - self.premiums['premium4']
        
        return initial_cashflow

    def insert_spot(self, spot_price: float):
        """
        Insert the current spot price for all the options in the Iron Condor strategy.
        """
        self.short_put_option.insert_spot(spot_price)
        self.long_put_option.insert_spot(spot_price)
        self.long_call_option.insert_spot(spot_price)
        self.short_call_option.insert_spot(spot_price)
    
    def payoff(self):
        """
        Calculate the total payoff (profit or loss) of the Iron Condor strategy.
        
        direction: 'long' for long Iron Condor, 'short' for short Iron Condor
        """
        if self.direction == "long":
            short_put = self.short_put_option.short_put()
            long_put = self.long_put_option.long_put()
            long_call = self.long_call_option.long_call()
            short_call = self.short_call_option.short_call()
            total_payoff = short_put + long_put + long_call + short_call
        elif self.direction == "short":
            long_put = -self.long_put_option.long_put()
            short_put = -self.short_put_option.short_put()
            short_call = -self.short_call_option.short_call()
            long_call = -self.long_call_option.long_call()
            total_payoff = long_put + short_put + short_call + long_call
        
        return total_payoff.iloc[0] if isinstance(total_payoff, pd.Series) else total_payoff
    
    def target_profit(self):
        """
        Calculate the target profit for the Iron Condor strategy.
        """
        if self.direction == "long":
            self.long_call_option = Option(self.strikes['strike3'], self.premiums['premium3'], self.expiry)
            self.short_call_option = Option(self.strikes['strike4'], self.premiums['premium4'], self.expiry)
            self.long_call_option.insert_spot(self.strikes["strike4"] + 5)
            self.short_call_option.insert_spot(self.strikes["strike4"] + 5)
            target_profit = self.premiums["premium1"] - self.premiums["premium2"] + self.long_call_option.long_call() + self.short_call_option.short_call()
        elif self.direction == "short":
            target_profit = self.initial_cashflow()
        
        return target_profit

class OptionsBacktester:
    def __init__(self,
                 signal_df: pd.DataFrame,
                 spot_price_df: pd.DataFrame,
                 options_df: pd.DataFrame,
                 upper_threshold: float,
                 lower_threshold: float,
                 option_type: str,
                 dynamic_option_strategy: bool = False,
                 dynamic_strike: bool = False,):
        self.signal_df = signal_df
        self.signal_df.columns = ["signal"]
        self.spot_price_df = spot_price_df
        self.options_df = options_df
        self.upper_threshold = upper_threshold
        self.lower_threshold = lower_threshold
        self.option_type = option_type
        self.dynamic_option_strategy = dynamic_option_strategy
        self.dynamic_strike = dynamic_strike

        self.comb_df = pd.concat([self.signal_df, self.spot_price_df.shift(), self.options_df.shift()], axis=1)
        self.comb_df["action"] = np.where(self.comb_df["signal"] > self.upper_threshold, 1, np.where(self.comb_df["signal"] < self.lower_threshold, -1, 0))

    def long_short_vol_df(self):
        self.trading_df = {}
        for index, row in self.comb_df.iterrows():
            if row["action"] != 0:
                self.trading_df[index] = self.comb_df.loc[index]

# %% [markdown]
# # Filtering of Options Data

# %%
day_map = {0: "Monday", 1: "Tuesday", 2: "Wednesday", 3: "Thursday", 4: "Friday", 5: "Saturday", 6: "Sunday"}

xlf_options = pd.read_hdf("data/etf_options_data.hf5", key="XLF")
xlf_options = xlf_options.set_index("date")
xlf_options["strike_price"] = xlf_options["strike_price"] / 1000
xlf_filtered_options = xlf_options.groupby("date").apply(lambda x: x.query("exdate == exdate.max()")).reset_index(level=0, drop=True)
xlf_filtered_options["day"] = xlf_filtered_options.index.weekday.map(day_map)
xlf_filtered_options["ex_day"] = xlf_filtered_options["exdate"].dt.weekday.map(day_map)
xlf_filtered_options
# Out:
#            ticker     exdate cp_flag  strike_price  best_bid  best_offer  \
# date
# 2000-01-10    XLF 2000-01-22       P          25.0    2.1875      2.5625
# 2000-01-10    XLF 2000-01-22       C          21.0    1.6250      1.8750
# 2000-01-10    XLF 2000-01-22       C          22.0    0.8125      1.0625
# 2000-01-10    XLF 2000-01-22       C          24.0    0.0000      0.2500
# 2000-01-10    XLF 2000-01-22       C          27.0    0.0000      0.2500
# ...           ...        ...     ...           ...       ...         ...
# 2023-08-31    XLF 2023-09-08       P          33.0    0.0100      0.0200
# 2023-08-31    XLF 2023-09-08       P          34.0    0.0800      0.0900
# 2023-08-31    XLF 2023-09-08       C          20.0   14.3500     14.5000
# 2023-08-31    XLF 2023-09-08       P          45.0   10.5500     10.6500
# 2023-08-31    XLF 2023-09-08       P          46.0   11.5500     11.6500
#
#             open_interest  impl_volatility     delta     gamma     theta  \
# date
# 2000-01-10            7.0              NaN       NaN       NaN       NaN
# 2000-01-10            0.0         0.394415  0.859554  0.136843 -5.609140
# 2000-01-10            0.0         0.350680  0.683067  0.246816 -7.922166
# 2000-01-10           20.0         0.334072  0.174344  0.187546 -5.402895
# 2000-01-10           40.0         0.711056  0.096122  0.058438 -7.584281
# ...                   ...              ...       ...       ...       ...
# 2023-08-31         3132.0         0.166504 -0.043014  0.108096 -1.696144
# 2023-08-31         1018.0         0.117240 -0.240929  0.526923 -3.860507
# 2023-08-31            0.0         1.598871  0.992083  0.002674 -5.027189
# 2023-08-31            0.0              NaN       NaN       NaN       NaN
# 2023-08-31            0.0              NaN       NaN       NaN       NaN
#
#                 vega  volume       day    ex_day
# date
# 2000-01-10       NaN     0.0    Monday  Saturday
# 2000-01-10  0.908583     0.0    Monday  Saturday
# 2000-01-10  1.457483     0.0    Monday  Saturday
# 2000-01-10  1.053927     0.0    Monday  Saturday
# 2000-01-10  0.698776     0.0    Monday  Saturday
# ...              ...     ...       ...       ...
# 2023-08-31  0.465775     1.0  Thursday    Friday
# 2023-08-31  1.583924  1956.0  Thursday    Friday
# 2023-08-31  0.111001     0.0  Thursday    Friday
# 2023-08-31       NaN     0.0  Thursday    Friday
# 2023-08-31       NaN     0.0  Thursday    Friday
#
# [246145 rows x 15 columns]

# %% [markdown]
# # Pulling XLF Data

# %%
xlf_pred = pd.read_csv("data/xlf_pred.csv", parse_dates=True, index_col=0).rename(columns={"0": "Rolling Pred"})
xlf_iv = pd.read_csv("data/XLF_IV.csv", parse_dates=True, index_col=0)
xlf_vrp = (xlf_iv["Average IV"] - xlf_pred["Rolling Pred"]).dropna()

xlf_vrp_standardised = rolling_z_score(xlf_vrp, window=10)
xlf_vrp_standardised.plot()
# Out:
# <Axes: >

# %%
upper_threshold = 1.75
lower_threshold = -1.75

xlf_filtered_options["vrp"] = xlf_vrp_standardised
xlf_time_series = pd.read_hdf("data/etf_series.hf5", key="XLF")
xlf_time_series["day"] = xlf_time_series.index.weekday
xlf_time_series["vrp"] = xlf_vrp_standardised
xlf_time_series["signal"] = np.where(xlf_time_series["vrp"] > upper_threshold, 1, np.where(xlf_time_series["vrp"] < lower_threshold, -1, 0))
xlf_time_series["action"] = np.where((xlf_time_series["signal"] == 1)  & (xlf_time_series.index.weekday != 4), 1, 
                                     np.where((xlf_time_series["signal"] == -1) & (xlf_time_series.index.weekday != 4), -1, 
                                              0))
xlf_time_series.dropna(inplace=True)
xlf_time_series

def ensure_weekly_action(df):
    last_action = 0
    last_week = -1

    for i in range(len(df)):
        current_week = df.index[i].isocalendar()[1]  # Get the week number
        current_day = df["day"].iloc[i]

        if current_week != last_week:  # Reset at the start of a new week
            last_action = 0
            last_week = current_week

        if last_action != 0 and df["action"].iloc[i] != 0:
            # If an action has already occurred this week, set to 0
            df.at[df.index[i], "action"] = 0
        elif df["action"].iloc[i] != 0:
            # If this is the first action of the week, update last_action
            last_action = df["action"].iloc[i]

    return df

xlf_time_series = ensure_weekly_action(xlf_time_series)
xlf_time_series["action"] = xlf_time_series["action"].shift()
xlf_time_series
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2017-09-14  24.860001  24.920000  24.750000  24.799999  21.523062  47163200
# 2017-09-15  24.660000  24.790001  24.629999  24.770000  21.586683  59250200
# 2017-09-18  24.860001  25.070000  24.840000  25.059999  21.839409  44010400
# 2017-09-19  25.059999  25.309999  25.020000  25.250000  22.004993  58443300
# 2017-09-20  25.270000  25.490000  25.150000  25.400000  22.135714  70595500
# ...               ...        ...        ...        ...        ...       ...
# 2023-08-25  33.970001  34.119999  33.709999  33.990002  33.292690  40347200
# 2023-08-28  34.099998  34.299999  34.070000  34.180000  33.478794  34905300
# 2023-08-29  34.150002  34.500000  34.099998  34.490002  33.782436  43394300
# 2023-08-30  34.540001  34.709999  34.439999  34.509998  33.802017  33799900
# 2023-08-31  34.610001  34.619999  34.340000  34.380001  33.674690  27999700
#
#             day       vrp  signal  action
# Date
# 2017-09-14    3  0.707107       0     NaN
# 2017-09-15    4 -0.847265       0     0.0
# 2017-09-18    0 -0.664415       0     0.0
# 2017-09-19    1 -0.197025       0     0.0
# 2017-09-20    2  0.402541       0     0.0
# ...         ...       ...     ...     ...
# 2023-08-25    4 -1.080421       0     0.0
# 2023-08-28    0 -0.484978       0     0.0
# 2023-08-29    1 -0.118561       0     0.0
# 2023-08-30    2  0.418496       0     0.0
# 2023-08-31    3  1.876032       1     0.0
#
# [1501 rows x 10 columns]

# %% [markdown]
# ## short iron condor

# %%
xlf_time_series.resample("W").last()["Close"].diff().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
ironcondor_tracker = {}

def find_nearest_strike_delta(atm_spot, date_index, delta_target, option_df, cp_flag):
    """
    Helper function to find the strike with delta closest to delta_target
    """

    options = option_df.loc[date_index].query(f"cp_flag == '{cp_flag}'")
    atm_delta = options.query("strike_price == @atm_spot")["delta"]
    try:
        if isinstance(atm_delta, pd.Series):
            atm_delta = atm_delta.values[0]
    except IndexError:
        print(f"Error: {date_index}, {cp_flag}")
        return None
    new_delta = atm_delta + delta_target
    return options.iloc[(options["delta"] - new_delta).abs().argmin()]["strike_price"]

for index, row in xlf_time_series.iterrows():
    if row["action"] == 1:
        print(f"date: {index}")
        direction = "short"

        index_loc = xlf_time_series.index.get_loc(index)

        current_spot_open = myround(xlf_time_series.iloc[index_loc]["Open"], 0.5)

        daily_options = xlf_filtered_options.loc[index]

        # atm_put_strike = daily_options[
        #     (daily_options["cp_flag"] == "P") &
        #     (daily_options["strike_price"] == prev_spot_close)
        # ]["strike_price"]
        # if isinstance(atm_put_strike, pd.Series):
        #     atm_put_strike = atm_put_strike.values[0]
        
        # atm_call_strike = daily_options[
        #     (daily_options["cp_flag"] == "C") &
        #     (daily_options["strike_price"] == prev_spot_close)
        # ]["strike_price"]
        # if isinstance(atm_call_strike, pd.Series):
        #     atm_call_strike = atm_call_strike.values[0]

        atm_put_strike = atm_call_strike = current_spot_open

        otm_put_strike = find_nearest_strike_delta(current_spot_open, index, 0.4, xlf_filtered_options, "P")
        otm_call_strike = find_nearest_strike_delta(current_spot_open, index, -0.3, xlf_filtered_options, "C")

        if otm_put_strike is None or otm_call_strike is None:
            continue
            
        else:
            print(f"date: {index}, current_spot_open: {current_spot_open}, OTM Put: {otm_put_strike}, ATM Put: {atm_put_strike}, ATM Call: {atm_call_strike}, OTM Call: {otm_call_strike}, \
                left wing: {abs(otm_put_strike - atm_put_strike)}, right wing: {abs(atm_call_strike - otm_call_strike)}")
            strikes = {
                "strike1": otm_put_strike,
                "strike2": atm_put_strike,
                "strike3": atm_call_strike,
                "strike4": otm_call_strike
            }

            premiums = {
                "premium1": xlf_filtered_options.loc[
                    (xlf_filtered_options.index == index) & 
                    (xlf_filtered_options["strike_price"] == strikes["strike1"]) & 
                    (xlf_filtered_options["cp_flag"] == 'P'), "best_offer"
                ],
                "premium2": xlf_filtered_options.loc[
                    (xlf_filtered_options.index == index) & 
                    (xlf_filtered_options["strike_price"] == strikes["strike2"]) & 
                    (xlf_filtered_options["cp_flag"] == 'P'), "best_bid"
                ],
                "premium3": xlf_filtered_options.loc[
                    (xlf_filtered_options.index == index) & 
                    (xlf_filtered_options["strike_price"] == strikes["strike3"]) & 
                    (xlf_filtered_options["cp_flag"] == 'C'), "best_bid"
                ],
                "premium4": xlf_filtered_options.loc[
                    (xlf_filtered_options.index == index) & 
                    (xlf_filtered_options["strike_price"] == strikes["strike4"]) & 
                    (xlf_filtered_options["cp_flag"] == 'C'), "best_offer"
                ]
            }        

            # print(f"date: {index}, Premiums: {premiums}")

            expiry = xlf_filtered_options.loc[index]["exdate"].max()

            ironcondor = IronCondor(direction=direction, strikes=strikes, premiums=premiums, expiry=expiry)
            ironcondor_tracker[index] = (ironcondor, ironcondor.target_profit().iloc[0], expiry)
# Out:
# date: 2017-10-20 00:00:00
# date: 2017-10-20 00:00:00, current_spot_open: 26.5, OTM Put: 23.5, ATM Put: 26.5, ATM Call: 26.5, OTM Call: 27.0,                 left wing: 3.0, right wing: 0.5
# date: 2017-12-08 00:00:00
# date: 2017-12-08 00:00:00, current_spot_open: 28.0, OTM Put: 27.0, ATM Put: 28.0, ATM Call: 28.0, OTM Call: 28.5,                 left wing: 1.0, right wing: 0.5
# date: 2018-03-09 00:00:00
# date: 2018-03-09 00:00:00, current_spot_open: 29.5, OTM Put: 27.5, ATM Put: 29.5, ATM Call: 29.5, OTM Call: 30.0,                 left wing: 2.0, right wing: 0.5
# date: 2018-03-23 00:00:00
# date: 2018-03-23 00:00:00, current_spot_open: 27.5, OTM Put: 26.0, ATM Put: 27.5, ATM Call: 27.5, OTM Call: 30.0,                 left wing: 1.5, right wing: 2.5
# date: 2018-04-13 00:00:00
# date: 2018-04-13 00:00:00, current_spot_open: 28.0, OTM Put: 26.5, ATM Put: 28.0, ATM Call: 28.0, OTM Call: 30.0,                 left wing: 1.5, right wing: 2.0
# date: 2018-05-17 00:00:00
# date: 2018-05-17 00:00:00, current_spot_open: 28.0, OTM Put: 19.0, ATM Put: 28.0, ATM Call: 28.0, OTM Call: 28.5,                 left wing: 9.0, right wing: 0.5
# date: 2018-06-22 00:00:00
# date: 2018-06-22 00:00:00, current_spot_open: 27.5, OTM Put: 26.5, ATM Put: 27.5, ATM Call: 27.5, OTM Call: 30.5,                 left wing: 1.0, right wing: 3.0
# date: 2018-06-29 00:00:00
# date: 2018-06-29 00:00:00, current_spot_open: 27.0, OTM Put: 26.0, ATM Put: 27.0, ATM Call: 27.0, OTM Call: 29.0,                 left wing: 1.0, right wing: 2.0
# date: 2018-08-09 00:00:00
# date: 2018-08-09 00:00:00, current_spot_open: 28.5, OTM Put: 28.0, ATM Put: 28.5, ATM Call: 28.5, OTM Call: 29.5,                 left wing: 0.5, right wing: 1.0
# date: 2018-09-21 00:00:00
# date: 2018-09-21 00:00:00, current_spot_open: 29.0, OTM Put: 28.0, ATM Put: 29.0, ATM Call: 29.0, OTM Call: 30.0,                 left wing: 1.0, right wing: 1.0
# date: 2018-10-05 00:00:00
# date: 2018-10-05 00:00:00, current_spot_open: 28.0, OTM Put: 26.0, ATM Put: 28.0, ATM Call: 28.0, OTM Call: 29.0,                 left wing: 2.0, right wing: 1.0
# date: 2018-11-09 00:00:00
# date: 2018-11-09 00:00:00, current_spot_open: 27.5, OTM Put: 26.5, ATM Put: 27.5, ATM Call: 27.5, OTM Call: 28.5,                 left wing: 1.0, right wing: 1.0
# date: 2018-11-16 00:00:00
# date: 2018-11-16 00:00:00, current_spot_open: 26.5, OTM Put: 15.0, ATM Put: 26.5, ATM Call: 26.5, OTM Call: 27.5,                 left wing: 11.5, right wing: 1.0
# date: 2018-12-21 00:00:00
# date: 2018-12-21 00:00:00, current_spot_open: 23.0, OTM Put: 21.0, ATM Put: 23.0, ATM Call: 23.0, OTM Call: 24.0,                 left wing: 2.0, right wing: 1.0
# date: 2019-01-18 00:00:00
# date: 2019-01-18 00:00:00, current_spot_open: 25.5, OTM Put: 16.0, ATM Put: 25.5, ATM Call: 25.5, OTM Call: 26.0,                 left wing: 9.5, right wing: 0.5
# date: 2019-02-01 00:00:00
# date: 2019-02-01 00:00:00, current_spot_open: 26.0, OTM Put: 24.5, ATM Put: 26.0, ATM Call: 26.0, OTM Call: 26.5,                 left wing: 1.5, right wing: 0.5
# date: 2019-04-12 00:00:00
# date: 2019-04-12 00:00:00, current_spot_open: 27.0, OTM Put: 24.5, ATM Put: 27.0, ATM Call: 27.0, OTM Call: 27.5,                 left wing: 2.5, right wing: 0.5
# date: 2019-05-10 00:00:00
# date: 2019-05-10 00:00:00, current_spot_open: 27.0, OTM Put: 19.5, ATM Put: 27.0, ATM Call: 27.0, OTM Call: 28.0,                 left wing: 7.5, right wing: 1.0
# date: 2019-06-21 00:00:00
# date: 2019-06-21 00:00:00, current_spot_open: 27.5, OTM Put: 26.5, ATM Put: 27.5, ATM Call: 27.5, OTM Call: 28.5,                 left wing: 1.0, right wing: 1.0
# date: 2019-07-12 00:00:00
# date: 2019-07-12 00:00:00, current_spot_open: 28.0, OTM Put: 17.0, ATM Put: 28.0, ATM Call: 28.0, OTM Call: 28.5,                 left wing: 11.0, right wing: 0.5
# date: 2019-08-02 00:00:00
# date: 2019-08-02 00:00:00, current_spot_open: 27.5, OTM Put: 25.0, ATM Put: 27.5, ATM Call: 27.5, OTM Call: 28.0,                 left wing: 2.5, right wing: 0.5
# date: 2019-08-30 00:00:00
# date: 2019-08-30 00:00:00, current_spot_open: 27.0, OTM Put: 25.5, ATM Put: 27.0, ATM Call: 27.0, OTM Call: 27.5,                 left wing: 1.5, right wing: 0.5
# date: 2019-10-11 00:00:00
# date: 2019-10-11 00:00:00, current_spot_open: 27.5, OTM Put: 24.5, ATM Put: 27.5, ATM Call: 27.5, OTM Call: 28.5,                 left wing: 3.0, right wing: 1.0
# date: 2019-10-25 00:00:00
# date: 2019-10-25 00:00:00, current_spot_open: 28.5, OTM Put: 25.5, ATM Put: 28.5, ATM Call: 28.5, OTM Call: 29.0,                 left wing: 3.0, right wing: 0.5
# date: 2019-11-15 00:00:00
# date: 2019-11-15 00:00:00, current_spot_open: 30.0, OTM Put: 29.0, ATM Put: 30.0, ATM Call: 30.0, OTM Call: 31.0,                 left wing: 1.0, right wing: 1.0
# date: 2020-02-14 00:00:00
# date: 2020-02-14 00:00:00, current_spot_open: 31.0, OTM Put: 26.5, ATM Put: 31.0, ATM Call: 31.0, OTM Call: 31.5,                 left wing: 4.5, right wing: 0.5
# date: 2020-02-21 00:00:00
# date: 2020-02-21 00:00:00, current_spot_open: 31.0, OTM Put: 29.5, ATM Put: 31.0, ATM Call: 31.0, OTM Call: 32.0,                 left wing: 1.5, right wing: 1.0
# date: 2020-04-17 00:00:00
# date: 2020-04-17 00:00:00, current_spot_open: 22.0, OTM Put: 14.0, ATM Put: 22.0, ATM Call: 22.0, OTM Call: 24.0,                 left wing: 8.0, right wing: 2.0
# date: 2020-05-06 00:00:00
# date: 2020-05-06 00:00:00, current_spot_open: 22.0, OTM Put: 20.5, ATM Put: 22.0, ATM Call: 22.0, OTM Call: 25.5,                 left wing: 1.5, right wing: 3.5
# date: 2020-05-15 00:00:00
# date: 2020-05-15 00:00:00, current_spot_open: 21.0, OTM Put: 18.0, ATM Put: 21.0, ATM Call: 21.0, OTM Call: 22.5,                 left wing: 3.0, right wing: 1.5
# date: 2020-06-26 00:00:00
# date: 2020-06-26 00:00:00, current_spot_open: 23.0, OTM Put: 20.5, ATM Put: 23.0, ATM Call: 23.0, OTM Call: 25.0,                 left wing: 2.5, right wing: 2.0
# date: 2020-07-17 00:00:00
# date: 2020-07-17 00:00:00, current_spot_open: 24.0, OTM Put: 22.0, ATM Put: 24.0, ATM Call: 24.0, OTM Call: 25.0,                 left wing: 2.0, right wing: 1.0
# date: 2020-07-31 00:00:00
# date: 2020-07-31 00:00:00, current_spot_open: 24.0, OTM Put: 22.0, ATM Put: 24.0, ATM Call: 24.0, OTM Call: 25.0,                 left wing: 2.0, right wing: 1.0
# date: 2020-10-16 00:00:00
# date: 2020-10-16 00:00:00, current_spot_open: 25.0, OTM Put: 23.0, ATM Put: 25.0, ATM Call: 25.0, OTM Call: 26.0,                 left wing: 2.0, right wing: 1.0
# date: 2020-12-04 00:00:00
# date: 2020-12-04 00:00:00, current_spot_open: 29.0, OTM Put: 27.0, ATM Put: 29.0, ATM Call: 29.0, OTM Call: 30.0,                 left wing: 2.0, right wing: 1.0
# date: 2020-12-10 00:00:00
# date: 2020-12-10 00:00:00, current_spot_open: 28.5, OTM Put: 25.5, ATM Put: 28.5, ATM Call: 28.5, OTM Call: 29.5,                 left wing: 3.0, right wing: 1.0
# date: 2021-02-12 00:00:00
# date: 2021-02-12 00:00:00, current_spot_open: 31.0, OTM Put: 20.0, ATM Put: 31.0, ATM Call: 31.0, OTM Call: 32.0,                 left wing: 11.0, right wing: 1.0
# date: 2021-03-26 00:00:00
# date: 2021-03-26 00:00:00, current_spot_open: 34.0, OTM Put: 25.0, ATM Put: 34.0, ATM Call: 34.0, OTM Call: 35.0,                 left wing: 9.0, right wing: 1.0
# date: 2021-05-07 00:00:00
# date: 2021-05-07 00:00:00, current_spot_open: 37.0, OTM Put: 16.0, ATM Put: 37.0, ATM Call: 37.0, OTM Call: 38.0,                 left wing: 21.0, right wing: 1.0
# date: 2021-05-14 00:00:00
# date: 2021-05-14 00:00:00, current_spot_open: 37.5, OTM Put: 28.0, ATM Put: 37.5, ATM Call: 37.5, OTM Call: 38.5,                 left wing: 9.5, right wing: 1.0
# date: 2021-06-17 00:00:00
# Error: 2021-06-17 00:00:00, P
# Error: 2021-06-17 00:00:00, C
# date: 2021-07-09 00:00:00
# date: 2021-07-09 00:00:00, current_spot_open: 36.0, OTM Put: 29.0, ATM Put: 36.0, ATM Call: 36.0, OTM Call: 37.0,                 left wing: 7.0, right wing: 1.0
# date: 2021-07-16 00:00:00
# date: 2021-07-16 00:00:00, current_spot_open: 37.0, OTM Put: 35.5, ATM Put: 37.0, ATM Call: 37.0, OTM Call: 45.0,                 left wing: 1.5, right wing: 8.0
# date: 2021-07-30 00:00:00
# date: 2021-07-30 00:00:00, current_spot_open: 36.5, OTM Put: 34.0, ATM Put: 36.5, ATM Call: 36.5, OTM Call: 37.5,                 left wing: 2.5, right wing: 1.0
# date: 2021-08-06 00:00:00
# date: 2021-08-06 00:00:00, current_spot_open: 37.5, OTM Put: 23.0, ATM Put: 37.5, ATM Call: 37.5, OTM Call: 38.5,                 left wing: 14.5, right wing: 1.0
# date: 2021-08-20 00:00:00
# date: 2021-08-20 00:00:00, current_spot_open: 37.5, OTM Put: 33.5, ATM Put: 37.5, ATM Call: 37.5, OTM Call: 38.5,                 left wing: 4.0, right wing: 1.0
# date: 2021-09-16 00:00:00
# date: 2021-09-16 00:00:00, current_spot_open: 38.0, OTM Put: 36.0, ATM Put: 38.0, ATM Call: 38.0, OTM Call: 45.0,                 left wing: 2.0, right wing: 7.0
# date: 2021-10-15 00:00:00
# date: 2021-10-15 00:00:00, current_spot_open: 39.5, OTM Put: 37.5, ATM Put: 39.5, ATM Call: 39.5, OTM Call: 40.5,                 left wing: 2.0, right wing: 1.0
# date: 2021-11-05 00:00:00
# date: 2021-11-05 00:00:00, current_spot_open: 40.5, OTM Put: 39.0, ATM Put: 40.5, ATM Call: 40.5, OTM Call: 42.0,                 left wing: 1.5, right wing: 1.5
# date: 2021-11-11 00:00:00
# date: 2021-11-11 00:00:00, current_spot_open: 40.0, OTM Put: 38.0, ATM Put: 40.0, ATM Call: 40.0, OTM Call: 41.0,                 left wing: 2.0, right wing: 1.0
# date: 2021-12-16 00:00:00
# date: 2021-12-16 00:00:00, current_spot_open: 39.5, OTM Put: 38.0, ATM Put: 39.5, ATM Call: 39.5, OTM Call: 40.5,                 left wing: 1.5, right wing: 1.0
# date: 2022-02-18 00:00:00
# date: 2022-02-18 00:00:00, current_spot_open: 39.0, OTM Put: 35.0, ATM Put: 39.0, ATM Call: 39.0, OTM Call: 40.5,                 left wing: 4.0, right wing: 1.5
# date: 2022-03-17 00:00:00
# date: 2022-03-17 00:00:00, current_spot_open: 38.0, OTM Put: 25.0, ATM Put: 38.0, ATM Call: 38.0, OTM Call: 39.0,                 left wing: 13.0, right wing: 1.0
# date: 2022-03-31 00:00:00
# date: 2022-03-31 00:00:00, current_spot_open: 39.0, OTM Put: 37.0, ATM Put: 39.0, ATM Call: 39.0, OTM Call: 41.0,                 left wing: 2.0, right wing: 2.0
# date: 2022-04-14 00:00:00
# date: 2022-04-14 00:00:00, current_spot_open: 37.0, OTM Put: 35.5, ATM Put: 37.0, ATM Call: 37.0, OTM Call: 38.0,                 left wing: 1.5, right wing: 1.0
# date: 2022-05-13 00:00:00
# date: 2022-05-13 00:00:00, current_spot_open: 33.5, OTM Put: 30.0, ATM Put: 33.5, ATM Call: 33.5, OTM Call: 35.0,                 left wing: 3.5, right wing: 1.5
# date: 2022-07-01 00:00:00
# date: 2022-07-01 00:00:00, current_spot_open: 31.5, OTM Put: 24.0, ATM Put: 31.5, ATM Call: 31.5, OTM Call: 33.0,                 left wing: 7.5, right wing: 1.5
# date: 2022-07-14 00:00:00
# date: 2022-07-14 00:00:00, current_spot_open: 30.5, OTM Put: 27.0, ATM Put: 30.5, ATM Call: 30.5, OTM Call: 31.5,                 left wing: 3.5, right wing: 1.0
# date: 2022-07-29 00:00:00
# date: 2022-07-29 00:00:00, current_spot_open: 33.5, OTM Put: 29.5, ATM Put: 33.5, ATM Call: 33.5, OTM Call: 34.5,                 left wing: 4.0, right wing: 1.0
# date: 2022-08-12 00:00:00
# date: 2022-08-12 00:00:00, current_spot_open: 35.0, OTM Put: 20.0, ATM Put: 35.0, ATM Call: 35.0, OTM Call: 36.0,                 left wing: 15.0, right wing: 1.0
# date: 2022-10-14 00:00:00
# date: 2022-10-14 00:00:00, current_spot_open: 32.0, OTM Put: 30.0, ATM Put: 32.0, ATM Call: 32.0, OTM Call: 39.0,                 left wing: 2.0, right wing: 7.0
# date: 2022-11-11 00:00:00
# date: 2022-11-11 00:00:00, current_spot_open: 36.0, OTM Put: 34.0, ATM Put: 36.0, ATM Call: 36.0, OTM Call: 37.0,                 left wing: 2.0, right wing: 1.0
# date: 2022-11-18 00:00:00
# date: 2022-11-18 00:00:00, current_spot_open: 35.5, OTM Put: 33.5, ATM Put: 35.5, ATM Call: 35.5, OTM Call: 36.5,                 left wing: 2.0, right wing: 1.0
# date: 2022-12-16 00:00:00
# Error: 2022-12-16 00:00:00, P
# Error: 2022-12-16 00:00:00, C
# date: 2022-12-23 00:00:00
# date: 2022-12-23 00:00:00, current_spot_open: 33.5, OTM Put: 20.0, ATM Put: 33.5, ATM Call: 33.5, OTM Call: 34.5,                 left wing: 13.5, right wing: 1.0
# date: 2023-01-13 00:00:00
# date: 2023-01-13 00:00:00, current_spot_open: 35.5, OTM Put: 20.0, ATM Put: 35.5, ATM Call: 35.5, OTM Call: 36.5,                 left wing: 15.5, right wing: 1.0
# date: 2023-02-03 00:00:00
# date: 2023-02-03 00:00:00, current_spot_open: 36.5, OTM Put: 34.0, ATM Put: 36.5, ATM Call: 36.5, OTM Call: 37.5,                 left wing: 2.5, right wing: 1.0
# date: 2023-03-31 00:00:00
# date: 2023-03-31 00:00:00, current_spot_open: 32.0, OTM Put: 28.0, ATM Put: 32.0, ATM Call: 32.0, OTM Call: 33.0,                 left wing: 4.0, right wing: 1.0
# date: 2023-05-19 00:00:00
# date: 2023-05-19 00:00:00, current_spot_open: 33.0, OTM Put: 32.0, ATM Put: 33.0, ATM Call: 33.0, OTM Call: 34.0,                 left wing: 1.0, right wing: 1.0
# date: 2023-06-02 00:00:00
# date: 2023-06-02 00:00:00, current_spot_open: 32.5, OTM Put: 16.0, ATM Put: 32.5, ATM Call: 32.5, OTM Call: 33.5,                 left wing: 16.5, right wing: 1.0
# date: 2023-06-23 00:00:00
# date: 2023-06-23 00:00:00, current_spot_open: 32.5, OTM Put: 20.0, ATM Put: 32.5, ATM Call: 32.5, OTM Call: 33.0,                 left wing: 12.5, right wing: 0.5
# date: 2023-06-30 00:00:00
# date: 2023-06-30 00:00:00, current_spot_open: 33.5, OTM Put: 20.0, ATM Put: 33.5, ATM Call: 33.5, OTM Call: 34.0,                 left wing: 13.5, right wing: 0.5
# date: 2023-07-21 00:00:00
# date: 2023-07-21 00:00:00, current_spot_open: 35.5, OTM Put: 34.5, ATM Put: 35.5, ATM Call: 35.5, OTM Call: 36.5,                 left wing: 1.0, right wing: 1.0
# date: 2023-08-04 00:00:00
# date: 2023-08-04 00:00:00, current_spot_open: 35.0, OTM Put: 33.5, ATM Put: 35.0, ATM Call: 35.0, OTM Call: 36.0,                 left wing: 1.5, right wing: 1.0

# %% [markdown]
# ## close early when signal turns -1

# %%
pnl_dict = {}

for index, (ironcondor, target_profit, expiry) in ironcondor_tracker.items():
    print(f"Processing date: {index}, expiry: {expiry}")
    if ironcondor is not None:
        # Check if `expiry` date is present, or find the closest available date before `expiry`
        if expiry not in xlf_time_series.index:
            print(f"Expiry date {expiry} not found; finding closest available date.")
            # Find the latest date before the `expiry` that is available in `xlf_time_series`
            available_dates = xlf_time_series.loc[:expiry].index
            if available_dates.empty:
                print(f"No available data for range {index} to {expiry}, skipping this trade.")
                continue
            expiry = available_dates[-1]  # Use the last available date before expiry
            print(f"Using adjusted expiry date: {expiry}")

        test_time_series = xlf_time_series.loc[index:expiry + pd.Timedelta(days=1)]
        options_test_df = xlf_filtered_options.loc[index:expiry + pd.Timedelta(days=1)]
        early_close = False

        for date, row in test_time_series.iterrows():
            if row["signal"] == -1:
                
                print(f"Closing on date: {date}")
                ic_strikes = ironcondor.strikes
                print(f"strike1: {ic_strikes['strike1']}, strike2: {ic_strikes['strike2']}, strike3: {ic_strikes['strike3']}, strike4: {ic_strikes['strike4']}")
                try:
                    # Long put (buy to open, sell to close)
                    long_put_sellback = options_test_df.loc[date][
                        (options_test_df.loc[date]["cp_flag"] == 'P') & 
                        (options_test_df.loc[date]["strike_price"] == ic_strikes["strike1"])
                    ]["best_bid"].values[0]
                except IndexError:
                    closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'P'] \
                        .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike1"]).abs()) \
                        .sort_values("distance").iloc[0]["strike_price"]
                    
                    # Use closest strike for long put (sell to close)
                    long_put_sellback = options_test_df.loc[date][
                        (options_test_df.loc[date]["cp_flag"] == 'P') & 
                        (options_test_df.loc[date]["strike_price"] == closest_strike)
                    ]["best_bid"].values[0]
                print(f"Long put sellback: {long_put_sellback}")

                try:
                    # Short put (sell to open, buy to close)
                    short_put_buyback = options_test_df.loc[date][
                        (options_test_df.loc[date]["cp_flag"] == 'P') & 
                        (options_test_df.loc[date]["strike_price"] == ic_strikes["strike2"])
                    ]["best_offer"].values[0]
                except IndexError:
                    closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'P'] \
                        .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike2"]).abs()) \
                        .sort_values("distance").iloc[0]["strike_price"]
                    
                    # Use closest strike for short put (buy to close)
                    short_put_buyback = options_test_df.loc[date][
                        (options_test_df.loc[date]["cp_flag"] == 'P') & 
                        (options_test_df.loc[date]["strike_price"] == closest_strike)
                    ]["best_offer"].values[0]
                print(f"Short put buyback: {short_put_buyback}")

                try:
                    # Short call (sell to open, buy to close)
                    short_call_buyback = options_test_df.loc[date][
                        (options_test_df.loc[date]["cp_flag"] == 'C') & 
                        (options_test_df.loc[date]["strike_price"] == ic_strikes["strike3"])
                    ]["best_offer"].values[0]
                except IndexError:
                    closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'C'] \
                        .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike3"]).abs()) \
                        .sort_values("distance").iloc[0]["strike_price"]
                    
                    # Use closest strike for short call (buy to close)
                    short_call_buyback = options_test_df.loc[date][
                        (options_test_df.loc[date]["cp_flag"] == 'C') & 
                        (options_test_df.loc[date]["strike_price"] == closest_strike)
                    ]["best_offer"].values[0]
                print(f"Short call buyback: {short_call_buyback}")

                try:
                    # Long call (buy to open, sell to close)
                    long_call_sellback = options_test_df.loc[date][
                        (options_test_df.loc[date]["cp_flag"] == 'C') & 
                        (options_test_df.loc[date]["strike_price"] == ic_strikes["strike4"])
                    ]["best_bid"].values[0]
                except IndexError:
                    closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'C'] \
                        .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike4"]).abs()) \
                        .sort_values("distance").iloc[0]["strike_price"]
                    
                    # Use closest strike for long call (sell to close)
                    long_call_sellback = options_test_df.loc[date][
                        (options_test_df.loc[date]["cp_flag"] == 'C') & 
                        (options_test_df.loc[date]["strike_price"] == closest_strike)
                    ]["best_bid"].values[0]
                print(f"Long call sellback: {long_call_sellback}")

                # Now calculate the closing cost
                if None not in [long_put_sellback, short_put_buyback, short_call_buyback, long_call_sellback]:
                    closing_cost = long_put_sellback - short_put_buyback - short_call_buyback + long_call_sellback
                else:
                    closing_cost = None  # Handle missing values appropriately
                print(f"Closing cost: {closing_cost}")

                ironcondor.insert_spot(xlf_time_series.loc[date]["Close"])
                pnl_dict[index] = ironcondor.payoff() - closing_cost
                print(f"Close iron condor early on date: {date} when signal is -1, pnl: {pnl_dict[index]}")
                early_close = True
                break
        if not early_close:
            try:
                ironcondor.insert_spot(xlf_time_series.loc[expiry]["Close"])
            except KeyError:
                ironcondor.insert_spot(xlf_time_series.loc[expiry - pd.Timedelta(days=1)]["Close"])
            
            print(f"Let iron condor expire: {expiry}, pnl: {ironcondor.payoff()}")
            pnl_dict[index] = ironcondor.payoff()
# Out:
# Processing date: 2017-10-20 00:00:00, expiry: 2017-11-03 00:00:00
# Let iron condor expire: 2017-11-03 00:00:00, pnl: 0.09999931335449219
# Processing date: 2017-12-08 00:00:00, expiry: 2017-12-22 00:00:00
# Let iron condor expire: 2017-12-22 00:00:00, pnl: 0.4100007629394532
# Processing date: 2018-03-09 00:00:00, expiry: 2018-03-23 00:00:00
# Let iron condor expire: 2018-03-23 00:00:00, pnl: -1.51
# Processing date: 2018-03-23 00:00:00, expiry: 2018-04-06 00:00:00
# Let iron condor expire: 2018-04-06 00:00:00, pnl: 0.46000007629394524
# Processing date: 2018-04-13 00:00:00, expiry: 2018-04-27 00:00:00
# Let iron condor expire: 2018-04-27 00:00:00, pnl: 0.49000076293945316
# Processing date: 2018-05-17 00:00:00, expiry: 2018-05-25 00:00:00
# Let iron condor expire: 2018-05-25 00:00:00, pnl: 0.24000038146972658
# Processing date: 2018-06-22 00:00:00, expiry: 2018-07-06 00:00:00
# Let iron condor expire: 2018-07-06 00:00:00, pnl: -0.29999992370605466
# Processing date: 2018-06-29 00:00:00, expiry: 2018-07-13 00:00:00
# Let iron condor expire: 2018-07-13 00:00:00, pnl: 0.5399995422363282
# Processing date: 2018-08-09 00:00:00, expiry: 2018-08-17 00:00:00
# Let iron condor expire: 2018-08-17 00:00:00, pnl: -0.03999992370605471
# Processing date: 2018-09-21 00:00:00, expiry: 2018-10-05 00:00:00
# Let iron condor expire: 2018-10-05 00:00:00, pnl: -0.55
# Processing date: 2018-10-05 00:00:00, expiry: 2018-10-19 00:00:00
# Closing on date: 2018-10-12 00:00:00
# strike1: 26.0, strike2: 28.0, strike3: 28.0, strike4: 29.0
# Long put sellback: 0.32
# Short put buyback: 1.57
# Short call buyback: 0.08
# Long call sellback: 0.0
# Closing cost: -1.33
# Close iron condor early on date: 2018-10-12 00:00:00 when signal is -1, pnl: 0.410000305175781
# Processing date: 2018-11-09 00:00:00, expiry: 2018-11-23 00:00:00
# Let iron condor expire: 2018-11-23 00:00:00, pnl: -0.47000000000000003
# Processing date: 2018-11-16 00:00:00, expiry: 2018-11-30 00:00:00
# Let iron condor expire: 2018-11-30 00:00:00, pnl: 0.24000068664550778
# Processing date: 2018-12-21 00:00:00, expiry: 2019-01-04 00:00:00
# Let iron condor expire: 2019-01-04 00:00:00, pnl: -0.19000000000000006
# Processing date: 2019-01-18 00:00:00, expiry: 2019-02-01 00:00:00
# Let iron condor expire: 2019-02-01 00:00:00, pnl: -0.04999999999999999
# Processing date: 2019-02-01 00:00:00, expiry: 2019-02-15 00:00:00
# Let iron condor expire: 2019-02-15 00:00:00, pnl: 0.019999694824218733
# Processing date: 2019-04-12 00:00:00, expiry: 2019-04-26 00:00:00
# Let iron condor expire: 2019-04-26 00:00:00, pnl: 5.551115123125783e-17
# Processing date: 2019-05-10 00:00:00, expiry: 2019-05-24 00:00:00
# Let iron condor expire: 2019-05-24 00:00:00, pnl: 0.5800006103515625
# Processing date: 2019-06-21 00:00:00, expiry: 2019-07-05 00:00:00
# Let iron condor expire: 2019-07-05 00:00:00, pnl: -0.1399998474121094
# Processing date: 2019-07-12 00:00:00, expiry: 2019-07-26 00:00:00
# Let iron condor expire: 2019-07-26 00:00:00, pnl: -0.06999999999999998
# Processing date: 2019-08-02 00:00:00, expiry: 2019-08-16 00:00:00
# Let iron condor expire: 2019-08-16 00:00:00, pnl: -0.38000030517578115
# Processing date: 2019-08-30 00:00:00, expiry: 2019-09-13 00:00:00
# Let iron condor expire: 2019-09-13 00:00:00, pnl: 0.020000000000000018
# Processing date: 2019-10-11 00:00:00, expiry: 2019-10-25 00:00:00
# Let iron condor expire: 2019-10-25 00:00:00, pnl: -0.2699999999999999
# Processing date: 2019-10-25 00:00:00, expiry: 2019-11-08 00:00:00
# Let iron condor expire: 2019-11-08 00:00:00, pnl: -0.020000000000000018
# Processing date: 2019-11-15 00:00:00, expiry: 2019-11-29 00:00:00
# Let iron condor expire: 2019-11-29 00:00:00, pnl: 0.2800003814697266
# Processing date: 2020-02-14 00:00:00, expiry: 2020-02-28 00:00:00
# Let iron condor expire: 2020-02-28 00:00:00, pnl: -3.9399998474121087
# Processing date: 2020-02-21 00:00:00, expiry: 2020-03-06 00:00:00
# Let iron condor expire: 2020-03-06 00:00:00, pnl: -0.8300000000000001
# Processing date: 2020-04-17 00:00:00, expiry: 2020-05-01 00:00:00
# Let iron condor expire: 2020-05-01 00:00:00, pnl: 1.5200005340576173
# Processing date: 2020-05-06 00:00:00, expiry: 2020-05-15 00:00:00
# Let iron condor expire: 2020-05-15 00:00:00, pnl: -0.09000076293945303
# Processing date: 2020-05-15 00:00:00, expiry: 2020-05-29 00:00:00
# Closing on date: 2020-05-29 00:00:00
# strike1: 18.0, strike2: 21.0, strike3: 21.0, strike4: 22.5
# Long put sellback: 0.0
# Short put buyback: 0.11
# Short call buyback: 2.54
# Long call sellback: 1.23
# Closing cost: -1.42
# Close iron condor early on date: 2020-05-29 00:00:00 when signal is -1, pnl: 1.03
# Processing date: 2020-06-26 00:00:00, expiry: 2020-07-10 00:00:00
# Let iron condor expire: 2020-07-10 00:00:00, pnl: 0.7400009155273438
# Processing date: 2020-07-17 00:00:00, expiry: 2020-07-31 00:00:00
# Let iron condor expire: 2020-07-31 00:00:00, pnl: 0.8099993133544923
# Processing date: 2020-07-31 00:00:00, expiry: 2020-08-14 00:00:00
# Let iron condor expire: 2020-08-14 00:00:00, pnl: -0.22000000000000003
# Processing date: 2020-10-16 00:00:00, expiry: 2020-10-30 00:00:00
# Let iron condor expire: 2020-10-30 00:00:00, pnl: -0.40999938964843763
# Processing date: 2020-12-04 00:00:00, expiry: 2020-12-18 00:00:00
# Let iron condor expire: 2020-12-18 00:00:00, pnl: 0.2899997711181641
# Processing date: 2020-12-10 00:00:00, expiry: 2020-12-24 00:00:00
# Let iron condor expire: 2020-12-24 00:00:00, pnl: 0.33999923706054686
# Processing date: 2021-02-12 00:00:00, expiry: 2021-02-26 00:00:00
# Let iron condor expire: 2021-02-26 00:00:00, pnl: -0.24999999999999994
# Processing date: 2021-03-26 00:00:00, expiry: 2021-04-09 00:00:00
# Closing on date: 2021-03-26 00:00:00
# strike1: 25.0, strike2: 34.0, strike3: 34.0, strike4: 35.0
# Long put sellback: 0.0
# Short put buyback: 0.46
# Short call buyback: 0.81
# Long call sellback: 0.31
# Closing cost: -0.96
# Close iron condor early on date: 2021-03-26 00:00:00 when signal is -1, pnl: 1.4600010681152344
# Processing date: 2021-05-07 00:00:00, expiry: 2021-05-21 00:00:00
# Let iron condor expire: 2021-05-21 00:00:00, pnl: 0.19999816894531244
# Processing date: 2021-05-14 00:00:00, expiry: 2021-05-28 00:00:00
# Let iron condor expire: 2021-05-28 00:00:00, pnl: 0.33999832153320314
# Processing date: 2021-07-09 00:00:00, expiry: 2021-07-23 00:00:00
# Let iron condor expire: 2021-07-23 00:00:00, pnl: 0.590001678466797
# Processing date: 2021-07-16 00:00:00, expiry: 2021-07-30 00:00:00
# Let iron condor expire: 2021-07-30 00:00:00, pnl: 0.4100004577636719
# Processing date: 2021-07-30 00:00:00, expiry: 2021-08-13 00:00:00
# Let iron condor expire: 2021-08-13 00:00:00, pnl: -0.20000000000000018
# Processing date: 2021-08-06 00:00:00, expiry: 2021-08-20 00:00:00
# Let iron condor expire: 2021-08-20 00:00:00, pnl: 0.6100013732910156
# Processing date: 2021-08-20 00:00:00, expiry: 2021-09-03 00:00:00
# Let iron condor expire: 2021-09-03 00:00:00, pnl: 0.33000030517578127
# Processing date: 2021-09-16 00:00:00, expiry: 2021-09-30 00:00:00
# Closing on date: 2021-10-01 00:00:00
# strike1: 36.0, strike2: 38.0, strike3: 38.0, strike4: 45.0
# Long put sellback: 0.16
# Short put buyback: 0.61
# Short call buyback: 0.73
# Long call sellback: 0.0
# Closing cost: -1.18
# Close iron condor early on date: 2021-10-01 00:00:00 when signal is -1, pnl: 1.6399984741210938
# Processing date: 2021-10-15 00:00:00, expiry: 2021-10-29 00:00:00
# Let iron condor expire: 2021-10-29 00:00:00, pnl: 1.6784667968561262e-06
# Processing date: 2021-11-05 00:00:00, expiry: 2021-11-19 00:00:00
# Let iron condor expire: 2021-11-19 00:00:00, pnl: -0.649999542236328
# Processing date: 2021-11-11 00:00:00, expiry: 2021-11-19 00:00:00
# Let iron condor expire: 2021-11-19 00:00:00, pnl: -0.30999954223632814
# Processing date: 2021-12-16 00:00:00, expiry: 2021-12-23 00:00:00
# Let iron condor expire: 2021-12-23 00:00:00, pnl: -0.030000305175781283
# Processing date: 2022-02-18 00:00:00, expiry: 2022-03-04 00:00:00
# Let iron condor expire: 2022-03-04 00:00:00, pnl: -0.5500004577636718
# Processing date: 2022-03-17 00:00:00, expiry: 2022-03-31 00:00:00
# Let iron condor expire: 2022-03-31 00:00:00, pnl: 0.7300003051757812
# Processing date: 2022-03-31 00:00:00, expiry: 2022-04-14 00:00:00
# Let iron condor expire: 2022-04-14 00:00:00, pnl: -0.9500000000000001
# Processing date: 2022-04-14 00:00:00, expiry: 2022-04-22 00:00:00
# Let iron condor expire: 2022-04-22 00:00:00, pnl: -0.16000183105468752
# Processing date: 2022-05-13 00:00:00, expiry: 2022-05-27 00:00:00
# Let iron condor expire: 2022-05-27 00:00:00, pnl: -0.28
# Processing date: 2022-07-01 00:00:00, expiry: 2022-07-15 00:00:00
# Let iron condor expire: 2022-07-15 00:00:00, pnl: 0.8599993133544922
# Processing date: 2022-07-14 00:00:00, expiry: 2022-07-22 00:00:00
# Let iron condor expire: 2022-07-22 00:00:00, pnl: -0.13000000000000012
# Processing date: 2022-07-29 00:00:00, expiry: 2022-08-12 00:00:00
# Let iron condor expire: 2022-08-12 00:00:00, pnl: -0.16999999999999993
# Processing date: 2022-08-12 00:00:00, expiry: 2022-08-26 00:00:00
# Let iron condor expire: 2022-08-26 00:00:00, pnl: -0.44999877929687504
# Processing date: 2022-10-14 00:00:00, expiry: 2022-10-28 00:00:00
# Let iron condor expire: 2022-10-28 00:00:00, pnl: -0.9199986267089841
# Processing date: 2022-11-11 00:00:00, expiry: 2022-11-25 00:00:00
# Closing on date: 2022-11-11 00:00:00
# strike1: 34.0, strike2: 36.0, strike3: 36.0, strike4: 37.0
# Long put sellback: 0.09
# Short put buyback: 0.64
# Short call buyback: 0.56
# Long call sellback: 0.18
# Closing cost: -0.9300000000000002
# Close iron condor early on date: 2022-11-11 00:00:00 when signal is -1, pnl: 1.669998931884766
# Processing date: 2022-11-18 00:00:00, expiry: 2022-12-02 00:00:00
# Let iron condor expire: 2022-12-02 00:00:00, pnl: 0.3999996948242187
# Processing date: 2022-12-23 00:00:00, expiry: 2023-01-06 00:00:00
# Let iron condor expire: 2023-01-06 00:00:00, pnl: -0.18999999999999995
# Processing date: 2023-01-13 00:00:00, expiry: 2023-01-27 00:00:00
# Let iron condor expire: 2023-01-27 00:00:00, pnl: -5.551115123125783e-17
# Processing date: 2023-02-03 00:00:00, expiry: 2023-02-17 00:00:00
# Let iron condor expire: 2023-02-17 00:00:00, pnl: 0.6899993896484375
# Processing date: 2023-03-31 00:00:00, expiry: 2023-04-14 00:00:00
# Let iron condor expire: 2023-04-14 00:00:00, pnl: -0.010001068115234352
# Processing date: 2023-05-19 00:00:00, expiry: 2023-06-02 00:00:00
# Let iron condor expire: 2023-06-02 00:00:00, pnl: 0.3699992370605468
# Processing date: 2023-06-02 00:00:00, expiry: 2023-06-16 00:00:00
# Let iron condor expire: 2023-06-16 00:00:00, pnl: -0.30000000000000004
# Processing date: 2023-06-23 00:00:00, expiry: 2023-07-07 00:00:00
# Let iron condor expire: 2023-07-07 00:00:00, pnl: 0.0
# Processing date: 2023-06-30 00:00:00, expiry: 2023-07-14 00:00:00
# Let iron condor expire: 2023-07-14 00:00:00, pnl: -0.06
# Processing date: 2023-07-21 00:00:00, expiry: 2023-08-04 00:00:00
# Let iron condor expire: 2023-08-04 00:00:00, pnl: -0.030000152587890627
# Processing date: 2023-08-04 00:00:00, expiry: 2023-08-18 00:00:00
# Closing on date: 2023-08-18 00:00:00
# strike1: 33.5, strike2: 35.0, strike3: 35.0, strike4: 36.0
# Long put sellback: 0.24
# Short put buyback: 1.11
# Short call buyback: 0.09
# Long call sellback: 0.01
# Closing cost: -0.9500000000000001
# Close iron condor early on date: 2023-08-18 00:00:00 when signal is -1, pnl: 0.5699995422363282

# %%
pd.DataFrame(pnl_dict.items(), columns=["Date", "PnL"]).set_index("Date").PnL.cumsum().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Optimisation

# %%
from bayes_opt import BayesianOptimization

# %%
def myround(x, base=5):
    return base * round(x/base)

def calculate_sharpe_ratio(pnl_series):
    returns = pnl_series.pct_change().dropna()
    sharpe_ratio = np.mean(returns) / np.std(returns)
    return sharpe_ratio * np.sqrt(252)

def calculate_sortino_ratio(pnl_series):
    returns = pnl_series.pct_change().dropna()
    sortino_ratio = np.mean(returns) / np.std(returns[returns < 0])
    return sortino_ratio * np.sqrt(252)

def ensure_weekly_action(df):
    last_action = 0
    last_week = -1

    for i in range(len(df)):
        current_week = df.index[i].isocalendar()[1]  # Get the week number
        current_day = df["day"].iloc[i]

        if current_week != last_week:  # Reset at the start of a new week
            last_action = 0
            last_week = current_week

        if last_action != 0 and df["action"].iloc[i] != 0:
            # If an action has already occurred this week, set to 0
            df.at[df.index[i], "action"] = 0
        elif df["action"].iloc[i] != 0:
            # If this is the first action of the week, update last_action
            last_action = df["action"].iloc[i]

    return df

def find_nearest_strike_delta(atm_spot, date_index, delta_target, option_df, cp_flag):
    """
    Helper function to find the strike with delta closest to delta_target
    """

    options = option_df.loc[date_index].query(f"cp_flag == '{cp_flag}'")
    atm_delta = options.query("strike_price == @atm_spot")["delta"]
    try:
        if isinstance(atm_delta, pd.Series):
            atm_delta = atm_delta.values[0]
    except IndexError:
        print(f"Error: {date_index}, {cp_flag}")
        return None
    new_delta = atm_delta + delta_target
    return options.iloc[(options["delta"] - new_delta).abs().argmin()]["strike_price"]

class Option:
    def __init__(self, strike: float, premium: float, expiry: str):
        self.strike = strike
        self.premium = premium
        self.expiry = expiry
        self.spot_price = None

    def insert_spot(self, spot_price: float):
        self.spot_price = spot_price
    
    def short_call(self):
        # Payoff for short call: premium received - intrinsic value of the option
        intrinsic_value = np.maximum(0, self.spot_price - self.strike)
        return self.premium - intrinsic_value
    
    def long_call(self):
        # Payoff for long call: intrinsic value - premium paid
        intrinsic_value = np.maximum(0, self.spot_price - self.strike)
        return intrinsic_value - self.premium
    
    def short_put(self):
        # Payoff for short put: premium received - intrinsic value of the option
        intrinsic_value = np.maximum(0, self.strike - self.spot_price)
        return self.premium - intrinsic_value
    
    def long_put(self):
        # Payoff for long put: intrinsic value - premium paid
        intrinsic_value = np.maximum(0, self.strike - self.spot_price)
        return intrinsic_value - self.premium


class IronCondor:
    def __init__(self, direction: str, strikes: dict, premiums: dict, expiry: str):
        """
        Initialize the Iron Condor strategy with strikes and premiums for the options.
        
        direction: long, (short) Iron Condor
        1. Short (Long) 1 OTM Put (strike 1)
        2. Long (Short) 1 close to ATM Put (strike 2)
        3. Long (Short) 1 close to ATM Call (strike 3)
        4. Short (Long) 1 OTM Call (strike 4)        

        strikes: a dictionary of strikes for the 4 options (strike1 to strike4)
        premiums: a dictionary of premiums for the 4 options (premium1 to premium4)
        expiry: expiration date of the options
        """
        self.strikes = strikes
        self.premiums = premiums
        self.direction = direction
        self.expiry = expiry
        self.short_put_option = Option(strikes['strike1'], premiums['premium1'], expiry)
        self.long_put_option = Option(strikes['strike2'], premiums['premium2'], expiry)
        self.long_call_option = Option(strikes['strike3'], premiums['premium3'], expiry)
        self.short_call_option = Option(strikes['strike4'], premiums['premium4'], expiry)

    def initial_cashflow(self):
        """
        Calculate the initial cashflow of the Iron Condor strategy.
        """
        if self.direction == "long":
            initial_cashflow = self.premiums['premium1'] - self.premiums['premium2'] - self.premiums['premium3'] + self.premiums['premium4']
        elif self.direction == "short":
            initial_cashflow = -self.premiums['premium1'] + self.premiums['premium2'] + self.premiums['premium3'] - self.premiums['premium4']
        
        return initial_cashflow

    def insert_spot(self, spot_price: float):
        """
        Insert the current spot price for all the options in the Iron Condor strategy.
        """
        self.short_put_option.insert_spot(spot_price)
        self.long_put_option.insert_spot(spot_price)
        self.long_call_option.insert_spot(spot_price)
        self.short_call_option.insert_spot(spot_price)
    
    def payoff(self):
        """
        Calculate the total payoff (profit or loss) of the Iron Condor strategy.
        
        direction: 'long' for long Iron Condor, 'short' for short Iron Condor
        """
        if self.direction == "long":
            short_put = self.short_put_option.short_put()
            long_put = self.long_put_option.long_put()
            long_call = self.long_call_option.long_call()
            short_call = self.short_call_option.short_call()
            total_payoff = short_put + long_put + long_call + short_call
        elif self.direction == "short":
            long_put = -self.long_put_option.long_put()
            short_put = -self.short_put_option.short_put()
            short_call = -self.short_call_option.short_call()
            long_call = -self.long_call_option.long_call()
            total_payoff = long_put + short_put + short_call + long_call
        
        return total_payoff.iloc[0] if isinstance(total_payoff, pd.Series) else total_payoff
    
    def target_profit(self):
        """
        Calculate the target profit for the Iron Condor strategy.
        """
        if self.direction == "long":
            self.long_call_option = Option(self.strikes['strike3'], self.premiums['premium3'], self.expiry)
            self.short_call_option = Option(self.strikes['strike4'], self.premiums['premium4'], self.expiry)
            self.long_call_option.insert_spot(self.strikes["strike4"] + 5)
            self.short_call_option.insert_spot(self.strikes["strike4"] + 5)
            target_profit = self.premiums["premium1"] - self.premiums["premium2"] + self.long_call_option.long_call() + self.short_call_option.short_call()
        elif self.direction == "short":
            target_profit = self.initial_cashflow()
        
        return target_profit

class OptionsBacktester:
    def __init__(self,
                 signal_df: pd.DataFrame,
                 spot_price_df: pd.DataFrame,
                 options_df: pd.DataFrame,
                 upper_threshold: float,
                 lower_threshold: float,
                 option_type: str,
                 dynamic_option_strategy: bool = False,
                 dynamic_strike: bool = False,):
        self.signal_df = signal_df
        self.signal_df.columns = ["signal"]
        self.spot_price_df = spot_price_df
        self.options_df = options_df
        self.upper_threshold = upper_threshold
        self.lower_threshold = lower_threshold
        self.option_type = option_type
        self.dynamic_option_strategy = dynamic_option_strategy
        self.dynamic_strike = dynamic_strike

        self.comb_df = pd.concat([self.signal_df, self.spot_price_df.shift(), self.options_df.shift()], axis=1)
        self.comb_df["action"] = np.where(self.comb_df["signal"] > self.upper_threshold, 1, np.where(self.comb_df["signal"] < self.lower_threshold, -1, 0))

    def long_short_vol_df(self):
        self.trading_df = {}
        for index, row in self.comb_df.iterrows():
            if row["action"] != 0:
                self.trading_df[index] = self.comb_df.loc[index]

# %%
def objective_function(window, upper_threshold, lower_threshold):
    try:
        # Options data
        day_map = {0: "Monday", 1: "Tuesday", 2: "Wednesday", 3: "Thursday", 4: "Friday", 5: "Saturday", 6: "Sunday"}

        xlf_options = pd.read_hdf("data/etf_options_data.hf5", key="XLF")
        xlf_options = xlf_options.set_index("date")
        xlf_options["strike_price"] = xlf_options["strike_price"] / 1000
        xlf_filtered_options = xlf_options.groupby("date").apply(lambda x: x.query("exdate == exdate.max()")).reset_index(level=0, drop=True)
        xlf_filtered_options["day"] = xlf_filtered_options.index.weekday.map(day_map)
        xlf_filtered_options["ex_day"] = xlf_filtered_options["exdate"].dt.weekday.map(day_map)

        # Setting time series data
        xlf_pred = pd.read_csv("data/xlf_pred.csv", parse_dates=True, index_col=0).rename(columns={"0": "Rolling Pred"})
        xlf_iv = pd.read_csv("data/XLF_IV.csv", parse_dates=True, index_col=0)
        xlf_vrp = (xlf_iv["Average IV"] - xlf_pred["Rolling Pred"]).dropna()

        xlf_vrp_standardised = rolling_z_score(xlf_vrp, window=int(window))

        xlf_filtered_options["vrp"] = xlf_vrp_standardised
        xlf_time_series = pd.read_hdf("data/etf_series.hf5", key="XLF")
        xlf_time_series["day"] = xlf_time_series.index.weekday
        xlf_time_series["vrp"] = xlf_vrp_standardised
        xlf_time_series["signal"] = np.where(xlf_time_series["vrp"] > upper_threshold, 1, np.where(xlf_time_series["vrp"] < lower_threshold, -1, 0))
        xlf_time_series["action"] = np.where((xlf_time_series["signal"] == 1)  & (xlf_time_series.index.weekday != 4), 1, 
                                            np.where((xlf_time_series["signal"] == -1) & (xlf_time_series.index.weekday != 4), -1, 
                                                    0))
        xlf_time_series.dropna(inplace=True)
        xlf_time_series

        xlf_time_series = ensure_weekly_action(xlf_time_series)
        xlf_time_series["action"] = xlf_time_series["action"].shift(-1)

        # Strategy backtesting
        ironcondor_tracker = {}

        for index, row in xlf_time_series.iterrows():
            if row["action"] == 1:
                print(f"date: {index}")
                direction = "short"

                index_loc = xlf_time_series.index.get_loc(index)

                current_spot_open = myround(xlf_time_series.iloc[index_loc]["Open"], 0.5)

                daily_options = xlf_filtered_options.loc[index]

                atm_put_strike = atm_call_strike = current_spot_open

                otm_put_strike = find_nearest_strike_delta(current_spot_open, index, 0.4, xlf_filtered_options, "P")
                otm_call_strike = find_nearest_strike_delta(current_spot_open, index, -0.3, xlf_filtered_options, "C")

                if otm_put_strike is None or otm_call_strike is None:
                    continue
                    
                else:
                    print(f"date: {index}, current_spot_open: {current_spot_open}, OTM Put: {otm_put_strike}, ATM Put: {atm_put_strike}, ATM Call: {atm_call_strike}, OTM Call: {otm_call_strike}, \
                        left wing: {abs(otm_put_strike - atm_put_strike)}, right wing: {abs(atm_call_strike - otm_call_strike)}")
                    strikes = {
                        "strike1": otm_put_strike,
                        "strike2": atm_put_strike,
                        "strike3": atm_call_strike,
                        "strike4": otm_call_strike
                    }

                    premiums = {
                        "premium1": xlf_filtered_options.loc[
                            (xlf_filtered_options.index == index) & 
                            (xlf_filtered_options["strike_price"] == strikes["strike1"]) & 
                            (xlf_filtered_options["cp_flag"] == 'P'), "best_offer"
                        ],
                        "premium2": xlf_filtered_options.loc[
                            (xlf_filtered_options.index == index) & 
                            (xlf_filtered_options["strike_price"] == strikes["strike2"]) & 
                            (xlf_filtered_options["cp_flag"] == 'P'), "best_bid"
                        ],
                        "premium3": xlf_filtered_options.loc[
                            (xlf_filtered_options.index == index) & 
                            (xlf_filtered_options["strike_price"] == strikes["strike3"]) & 
                            (xlf_filtered_options["cp_flag"] == 'C'), "best_bid"
                        ],
                        "premium4": xlf_filtered_options.loc[
                            (xlf_filtered_options.index == index) & 
                            (xlf_filtered_options["strike_price"] == strikes["strike4"]) & 
                            (xlf_filtered_options["cp_flag"] == 'C'), "best_offer"
                        ]
                    }        

                    # print(f"date: {index}, Premiums: {premiums}")

                    expiry = xlf_filtered_options.loc[index]["exdate"].max()

                    ironcondor = IronCondor(direction=direction, strikes=strikes, premiums=premiums, expiry=expiry)
                    ironcondor_tracker[index] = (ironcondor, ironcondor.target_profit().iloc[0], expiry)

        # Calculate the payoff of the Iron Condor strategy
        pnl_dict = {}

        for index, (ironcondor, target_profit, expiry) in ironcondor_tracker.items():
            print(f"Processing date: {index}, expiry: {expiry}")
            if ironcondor is not None:
                # Check if `expiry` date is present, or find the closest available date before `expiry`
                if expiry not in xlf_time_series.index:
                    print(f"Expiry date {expiry} not found; finding closest available date.")
                    # Find the latest date before the `expiry` that is available in `xlf_time_series`
                    available_dates = xlf_time_series.loc[:expiry].index
                    if available_dates.empty:
                        print(f"No available data for range {index} to {expiry}, skipping this trade.")
                        continue
                    expiry = available_dates[-1]  # Use the last available date before expiry
                    print(f"Using adjusted expiry date: {expiry}")

                test_time_series = xlf_time_series.loc[index:expiry + pd.Timedelta(days=1)]
                options_test_df = xlf_filtered_options.loc[index:expiry + pd.Timedelta(days=1)]
                early_close = False

                for date, row in test_time_series.iterrows():
                    if row["signal"] == -1:
                        
                        print(f"Closing on date: {date}")
                        ic_strikes = ironcondor.strikes
                        print(f"strike1: {ic_strikes['strike1']}, strike2: {ic_strikes['strike2']}, strike3: {ic_strikes['strike3']}, strike4: {ic_strikes['strike4']}")
                        try:
                            # Long put (buy to open, sell to close)
                            long_put_sellback = options_test_df.loc[date][
                                (options_test_df.loc[date]["cp_flag"] == 'P') & 
                                (options_test_df.loc[date]["strike_price"] == ic_strikes["strike1"])
                            ]["best_bid"].values[0]
                        except IndexError:
                            closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'P'] \
                                .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike1"]).abs()) \
                                .sort_values("distance").iloc[0]["strike_price"]
                            
                            # Use closest strike for long put (sell to close)
                            long_put_sellback = options_test_df.loc[date][
                                (options_test_df.loc[date]["cp_flag"] == 'P') & 
                                (options_test_df.loc[date]["strike_price"] == closest_strike)
                            ]["best_bid"].values[0]
                        print(f"Long put sellback: {long_put_sellback}")

                        try:
                            # Short put (sell to open, buy to close)
                            short_put_buyback = options_test_df.loc[date][
                                (options_test_df.loc[date]["cp_flag"] == 'P') & 
                                (options_test_df.loc[date]["strike_price"] == ic_strikes["strike2"])
                            ]["best_offer"].values[0]
                        except IndexError:
                            closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'P'] \
                                .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike2"]).abs()) \
                                .sort_values("distance").iloc[0]["strike_price"]
                            
                            # Use closest strike for short put (buy to close)
                            short_put_buyback = options_test_df.loc[date][
                                (options_test_df.loc[date]["cp_flag"] == 'P') & 
                                (options_test_df.loc[date]["strike_price"] == closest_strike)
                            ]["best_offer"].values[0]
                        print(f"Short put buyback: {short_put_buyback}")

                        try:
                            # Short call (sell to open, buy to close)
                            short_call_buyback = options_test_df.loc[date][
                                (options_test_df.loc[date]["cp_flag"] == 'C') & 
                                (options_test_df.loc[date]["strike_price"] == ic_strikes["strike3"])
                            ]["best_offer"].values[0]
                        except IndexError:
                            closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'C'] \
                                .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike3"]).abs()) \
                                .sort_values("distance").iloc[0]["strike_price"]
                            
                            # Use closest strike for short call (buy to close)
                            short_call_buyback = options_test_df.loc[date][
                                (options_test_df.loc[date]["cp_flag"] == 'C') & 
                                (options_test_df.loc[date]["strike_price"] == closest_strike)
                            ]["best_offer"].values[0]
                        print(f"Short call buyback: {short_call_buyback}")

                        try:
                            # Long call (buy to open, sell to close)
                            long_call_sellback = options_test_df.loc[date][
                                (options_test_df.loc[date]["cp_flag"] == 'C') & 
                                (options_test_df.loc[date]["strike_price"] == ic_strikes["strike4"])
                            ]["best_bid"].values[0]
                        except IndexError:
                            closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'C'] \
                                .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike4"]).abs()) \
                                .sort_values("distance").iloc[0]["strike_price"]
                            
                            # Use closest strike for long call (sell to close)
                            long_call_sellback = options_test_df.loc[date][
                                (options_test_df.loc[date]["cp_flag"] == 'C') & 
                                (options_test_df.loc[date]["strike_price"] == closest_strike)
                            ]["best_bid"].values[0]
                        print(f"Long call sellback: {long_call_sellback}")

                        # Now calculate the closing cost
                        if None not in [long_put_sellback, short_put_buyback, short_call_buyback, long_call_sellback]:
                            closing_cost = long_put_sellback - short_put_buyback - short_call_buyback + long_call_sellback
                        else:
                            closing_cost = None  # Handle missing values appropriately
                        print(f"Closing cost: {closing_cost}")

                        ironcondor.insert_spot(xlf_time_series.loc[date]["Close"])
                        pnl_dict[index] = ironcondor.payoff() - closing_cost
                        print(f"Close iron condor early on date: {date} when signal is -1, pnl: {pnl_dict[index]}")
                        early_close = True
                        break
                if not early_close:
                    try:
                        ironcondor.insert_spot(xlf_time_series.loc[expiry]["Close"])
                        print(f"Let iron condor expire: {expiry}, pnl: {ironcondor.payoff()}")
                        pnl_dict[index] = ironcondor.payoff()    
                    except KeyError:
                        try:
                            ironcondor.insert_spot(xlf_time_series.loc[expiry + pd.Timedelta(days=1)]["Close"])
                            print(f"Let iron condor expire: {expiry}, pnl: {ironcondor.payoff()}")
                            pnl_dict[index] = ironcondor.payoff()           
                        except KeyError:
                            try:
                                ironcondor.insert_spot(xlf_time_series.loc[expiry - pd.Timedelta(days=1)]["Close"])
                                print(f"Let iron condor expire: {expiry}, pnl: {ironcondor.payoff()}")
                                pnl_dict[index] = ironcondor.payoff()    
                            except KeyError:
                                print(f"Warning: Unable to insert spot for index {index} with expiry {expiry}, PnL set to 0")
                                pnl_dict[index] = 0
                                continue
                                    
                    
                    # print(f"Let iron condor expire: {expiry}, pnl: {ironcondor.payoff()}")
                    # pnl_dict[index] = ironcondor.payoff()         

        pnl_series = pd.DataFrame(pnl_dict.items(), columns=["Date", "PnL"]).set_index("Date").PnL
        if pnl_series.empty:
            print("Warning: pnl_series is empty. Returning a large negative value to indicate failure.")
            return -10  # Large negative finite value to discourage this parameter set

        # Calculate returns and check standard deviation
        returns = pnl_series.pct_change().dropna()
        if returns.std() == 0:
            print("Warning: Standard deviation of returns is zero. Returning a large negative value.")
            return -10  # Avoid infinite Sharpe by returning -10

        # Calculate and return Sharpe ratio
        sharpe_ratio = calculate_sharpe_ratio(pnl_series)

        # Check for unreasonable Sharpe ratio values
        if np.isnan(sharpe_ratio) or np.isinf(sharpe_ratio) or sharpe_ratio > 10:
            print("Warning: Sharpe ratio is NaN, inf, or unreasonably high. Returning a large negative value.")
            return -10  # Return a large but finite negative value

        return sharpe_ratio

    except Exception as e:
        print(f"An error occurred: {e}. Returning a large negative value.")
        return -10  # Return a large negative value on error
            # sharpe_ratio = calculate_sharpe_ratio(pnl_series)

            # if np.isnan(sharpe_ratio) or np.isinf(sharpe_ratio) or sharpe_ratio > 10:
            #     print("Warning: Sharpe ratio is NaN, inf, or unreasonably high. Returning a large negative value.")
            #     return -10
            # return sharpe_ratio

# %%
pbounds = {
    'window': (5, 30),
    'upper_threshold': (1.0, 3.0),  # Adjust upper threshold range as necessary
    'lower_threshold': (-3.0, -1.0)  # Adjust lower threshold range as necessary
}

# Set up Bayesian optimization with lambda to pass additional arguments
optimizer = BayesianOptimization(
    f=lambda window, upper_threshold, lower_threshold: objective_function(
        window, upper_threshold, lower_threshold
    ),
    pbounds=pbounds,
    random_state=42,
    verbose=2
)

optimizer.maximize(init_points=10, n_iter=50)
# Out:
# |   iter    |  target   | lower_... | upper_... |  window   |
# -------------------------------------------------------------
# date: 2018-03-21 00:00:00
# date: 2018-03-21 00:00:00, current_spot_open: 29.0, OTM Put: 28.0, ATM Put: 29.0, ATM Call: 29.0, OTM Call: 30.0,                         left wing: 1.0, right wing: 1.0
# date: 2018-08-08 00:00:00
# date: 2018-08-08 00:00:00, current_spot_open: 28.5, OTM Put: 27.5, ATM Put: 28.5, ATM Call: 28.5, OTM Call: 29.0,                         left wing: 1.0, right wing: 0.5
# date: 2019-06-19 00:00:00
# Error: 2019-06-19 00:00:00, P
# Error: 2019-06-19 00:00:00, C
# date: 2022-04-12 00:00:00
# date: 2022-04-12 00:00:00, current_spot_open: 37.5, OTM Put: 35.0, ATM Put: 37.5, ATM Call: 37.5, OTM Call: 39.0,                         left wing: 2.5, right wing: 1.5
# Processing date: 2018-03-21 00:00:00, expiry: 2018-03-29 00:00:00
# Let iron condor expire: 2018-03-29 00:00:00, pnl: -0.5000000000000001
# Processing date: 2018-08-08 00:00:00, expiry: 2018-08-17 00:00:00
# Let iron condor expire: 2018-08-17 00:00:00, pnl: -0.01999992370605469
# Processing date: 2022-04-12 00:00:00, expiry: 2022-04-22 00:00:00
# Let iron condor expire: 2022-04-22 00:00:00, pnl: -0.3100018310546875
# Warning: Sharpe ratio is NaN, inf, or unreasonably high. Returning a large negative value.
# | 1         | -10.0     | -2.251    | 2.901     | 23.3      |
# date: 2017-10-04 00:00:00
# date: 2017-10-04 00:00:00, current_spot_open: 26.0, OTM Put: 24.5, ATM Put: 26.0, ATM Call: 26.0, OTM Call: 26.5,                         left wing: 1.5, right wing: 0.5
# date: 2017-10-16 00:00:00
# date: 2017-10-16 00:00:00, current_spot_open: 26.0, OTM Put: 17.5, ATM Put: 26.0, ATM Call: 26.0, OTM Call: 26.5,                         left wing: 8.5, right wing: 0.5
# date: 2017-11-14 00:00:00
# date: 2017-11-14 00:00:00, current_spot_open: 26.0, OTM Put: 23.5, ATM Put: 26.0, ATM Call: 26.0, OTM Call: 26.5,                         left wing: 2.5, right wing: 0.5
# date: 2017-12-06 00:00:00
# date: 2017-12-06 00:00:00, current_spot_open: 28.0, OTM Put: 27.0, ATM Put: 28.0, ATM Call: 28.0, OTM Call: 29.0,                         left wing: 1.0, right wing: 1.0
# date: 2017-12-12 00:00:00
# date: 2017-12-12 00:00:00, current_spot_open: 28.0, OTM Put: 26.0, ATM Put: 28.0, ATM Call: 28.0, OTM Call: 28.5,                         left wing: 2.0, right wing: 0.5
# date: 2017-12-20 00:00:00
# date: 2017-12-20 00:00:00, current_spot_open: 28.0, OTM Put: 27.0, ATM Put: 28.0, ATM Call: 28.0, OTM Call: 29.0,                         left wing: 1.0, right wing: 1.0
# date: 2018-01-03 00:00:00
# date: 2018-01-03 00:00:00, current_spot_open: 28.0, OTM Put: 26.5, ATM Put: 28.0, ATM Call: 28.0, OTM Call: 28.5,                         left wing: 1.5, right wing: 0.5
# date: 2018-02-27 00:00:00
# date: 2018-02-27 00:00:00, current_spot_open: 29.5, OTM Put: 28.5, ATM Put: 29.5, ATM Call: 29.5, OTM Call: 30.5,                         left wing: 1.0, right wing: 1.0
# date: 2018-03-07 00:00:00
# date: 2018-03-07 00:00:00, current_spot_open: 28.5, OTM Put: 13.0, ATM Put: 28.5, ATM Call: 28.5, OTM Call: 29.0,                         left wing: 15.5, right wing: 0.5
# date: 2018-03-20 00:00:00
# date: 2018-03-20 00:00:00, current_spot_open: 29.0, OTM Put: 28.0, ATM Put: 29.0, ATM Call: 29.0, OTM Call: 30.0,                         left wing: 1.0, right wing: 1.0
# date: 2018-04-03 00:00:00
# date: 2018-04-03 00:00:00, current_spot_open: 27.0, OTM Put: 20.0, ATM Put: 27.0, ATM Call: 27.0, OTM Call: 28.0,                         left wing: 7.0, right wing: 1.0
# date: 2018-04-11 00:00:00
# date: 2018-04-11 00:00:00, current_spot_open: 27.5, OTM Put: 26.0, ATM Put: 27.5, ATM Call: 27.5, OTM Call: 28.5,                         left wing: 1.5, right wing: 1.0
# date: 2018-04-18 00:00:00
# date: 2018-04-18 00:00:00, current_spot_open: 27.5, OTM Put: 26.0, ATM Put: 27.5, ATM Call: 27.5, OTM Call: 28.0,                         left wing: 1.5, right wing: 0.5
# date: 2018-05-09 00:00:00
# date: 2018-05-09 00:00:00, current_spot_open: 28.0, OTM Put: 26.5, ATM Put: 28.0, ATM Call: 28.0, OTM Call: 28.5,                         left wing: 1.5, right wing: 0.5
# date: 2018-05-14 00:00:00
# date: 2018-05-14 00:00:00, current_spot_open: 28.5, OTM Put: 27.5, ATM Put: 28.5, ATM Call: 28.5, OTM Call: 29.5,                         left wing: 1.0, right wing: 1.0
# date: 2018-06-06 00:00:00
# date: 2018-06-06 00:00:00, current_spot_open: 27.5, OTM Put: 14.0, ATM Put: 27.5, ATM Call: 27.5, OTM Call: 28.0,                         left wing: 13.5, right wing: 0.5
# date: 2018-06-13 00:00:00
# date: 2018-06-13 00:00:00, current_spot_open: 28.0, OTM Put: 27.0, ATM Put: 28.0, ATM Call: 28.0, OTM Call: 29.0,                         left wing: 1.0, right wing: 1.0
# date: 2018-06-20 00:00:00
# Error: 2018-06-20 00:00:00, P
# Error: 2018-06-20 00:00:00, C
# date: 2018-06-26 00:00:00
# date: 2018-06-26 00:00:00, current_spot_open: 27.0, OTM Put: 26.0, ATM Put: 27.0, ATM Call: 27.0, OTM Call: 28.0,                         left wing: 1.0, right wing: 1.0
# date: 2018-07-11 00:00:00
# date: 2018-07-11 00:00:00, current_spot_open: 27.0, OTM Put: 25.5, ATM Put: 27.0, ATM Call: 27.0, OTM Call: 27.5,                         left wing: 1.5, right wing: 0.5
# date: 2018-07-17 00:00:00
# date: 2018-07-17 00:00:00, current_spot_open: 27.5, OTM Put: 26.5, ATM Put: 27.5, ATM Call: 27.5, OTM Call: 28.0,                         left wing: 1.0, right wing: 0.5
# date: 2018-08-06 00:00:00
# date: 2018-08-06 00:00:00, current_spot_open: 28.0, OTM Put: 14.0, ATM Put: 28.0, ATM Call: 28.0, OTM Call: 28.5,                         left wing: 14.0, right wing: 0.5
# date: 2018-09-05 00:00:00
# date: 2018-09-05 00:00:00, current_spot_open: 28.5, OTM Put: 27.5, ATM Put: 28.5, ATM Call: 28.5, OTM Call: 29.0,                         left wing: 1.0, right wing: 0.5
# date: 2018-09-18 00:00:00
# date: 2018-09-18 00:00:00, current_spot_open: 28.0, OTM Put: 18.0, ATM Put: 28.0, ATM Call: 28.0, OTM Call: 29.0,                         left wing: 10.0, right wing: 1.0
# date: 2018-10-03 00:00:00
# date: 2018-10-03 00:00:00, current_spot_open: 28.0, OTM Put: 27.0, ATM Put: 28.0, ATM Call: 28.0, OTM Call: 28.5,                         left wing: 1.0, right wing: 0.5
# date: 2018-10-17 00:00:00
# date: 2018-10-17 00:00:00, current_spot_open: 26.5, OTM Put: 21.5, ATM Put: 26.5, ATM Call: 26.5, OTM Call: 27.0,                         left wing: 5.0, right wing: 0.5
# date: 2018-10-30 00:00:00
# date: 2018-10-30 00:00:00, current_spot_open: 25.5, OTM Put: 18.5, ATM Put: 25.5, ATM Call: 25.5, OTM Call: 26.5,                         left wing: 7.0, right wing: 1.0
# date: 2018-11-07 00:00:00
# date: 2018-11-07 00:00:00, current_spot_open: 27.0, OTM Put: 19.0, ATM Put: 27.0, ATM Call: 27.0, OTM Call: 27.5,                         left wing: 8.0, right wing: 0.5
# date: 2018-11-14 00:00:00
# date: 2018-11-14 00:00:00, current_spot_open: 27.0, OTM Put: 26.0, ATM Put: 27.0, ATM Call: 27.0, OTM Call: 40.0,                         left wing: 1.0, right wing: 13.0
# date: 2018-12-18 00:00:00
# date: 2018-12-18 00:00:00, current_spot_open: 24.0, OTM Put: 22.0, ATM Put: 24.0, ATM Call: 24.0, OTM Call: 25.0,                         left wing: 2.0, right wing: 1.0
# date: 2019-01-02 00:00:00
# date: 2019-01-02 00:00:00, current_spot_open: 23.5, OTM Put: 16.0, ATM Put: 23.5, ATM Call: 23.5, OTM Call: 24.5,                         left wing: 7.5, right wing: 1.0
# date: 2019-01-14 00:00:00
# date: 2019-01-14 00:00:00, current_spot_open: 24.5, OTM Put: 19.5, ATM Put: 24.5, ATM Call: 24.5, OTM Call: 25.0,                         left wing: 5.0, right wing: 0.5
# date: 2019-01-30 00:00:00
# date: 2019-01-30 00:00:00, current_spot_open: 26.0, OTM Put: 25.0, ATM Put: 26.0, ATM Call: 26.0, OTM Call: 26.5,                         left wing: 1.0, right wing: 0.5
# date: 2019-02-06 00:00:00
# date: 2019-02-06 00:00:00, current_spot_open: 26.0, OTM Put: 24.5, ATM Put: 26.0, ATM Call: 26.0, OTM Call: 26.5,                         left wing: 1.5, right wing: 0.5
# date: 2019-02-27 00:00:00
# date: 2019-02-27 00:00:00, current_spot_open: 26.5, OTM Put: 24.5, ATM Put: 26.5, ATM Call: 26.5, OTM Call: 27.0,                         left wing: 2.0, right wing: 0.5
# date: 2019-03-12 00:00:00
# date: 2019-03-12 00:00:00, current_spot_open: 26.5, OTM Put: 26.0, ATM Put: 26.5, ATM Call: 26.5, OTM Call: 33.0,                         left wing: 0.5, right wing: 6.5
# date: 2019-04-09 00:00:00
# date: 2019-04-09 00:00:00, current_spot_open: 26.5, OTM Put: 25.5, ATM Put: 26.5, ATM Call: 26.5, OTM Call: 27.0,                         left wing: 1.0, right wing: 0.5
# date: 2019-04-16 00:00:00
# date: 2019-04-16 00:00:00, current_spot_open: 27.0, OTM Put: 18.5, ATM Put: 27.0, ATM Call: 27.0, OTM Call: 27.5,                         left wing: 8.5, right wing: 0.5
# date: 2019-04-24 00:00:00
# date: 2019-04-24 00:00:00, current_spot_open: 27.5, OTM Put: 26.5, ATM Put: 27.5, ATM Call: 27.5, OTM Call: 28.0,                         left wing: 1.0, right wing: 0.5
# date: 2019-05-06 00:00:00
# date: 2019-05-06 00:00:00, current_spot_open: 27.5, OTM Put: 14.0, ATM Put: 27.5, ATM Call: 27.5, OTM Call: 28.0,                         left wing: 13.5, right wing: 0.5
# date: 2019-05-28 00:00:00
# date: 2019-05-28 00:00:00, current_spot_open: 27.0, OTM Put: 26.0, ATM Put: 27.0, ATM Call: 27.0, OTM Call: 32.0,                         left wing: 1.0, right wing: 5.0
# date: 2019-06-05 00:00:00
# date: 2019-06-05 00:00:00, current_spot_open: 27.0, OTM Put: 25.5, ATM Put: 27.0, ATM Call: 27.0, OTM Call: 27.5,                         left wing: 1.5, right wing: 0.5
# date: 2019-06-12 00:00:00
# date: 2019-06-12 00:00:00, current_spot_open: 27.5, OTM Put: 26.5, ATM Put: 27.5, ATM Call: 27.5, OTM Call: 40.0,                         left wing: 1.0, right wing: 12.5
# date: 2019-06-19 00:00:00
# Error: 2019-06-19 00:00:00, P
# Error: 2019-06-19 00:00:00, C
# date: 2019-07-02 00:00:00
# date: 2019-07-02 00:00:00, current_spot_open: 28.0, OTM Put: 27.0, ATM Put: 28.0, ATM Call: 28.0, OTM Call: 28.5,                         left wing: 1.0, right wing: 0.5
# date: 2019-07-08 00:00:00
# date: 2019-07-08 00:00:00, current_spot_open: 28.0, OTM Put: 27.0, ATM Put: 28.0, ATM Call: 28.0, OTM Call: 28.5,                         left wing: 1.0, right wing: 0.5
# date: 2019-07-17 00:00:00
# date: 2019-07-17 00:00:00, current_spot_open: 28.0, OTM Put: 27.0, ATM Put: 28.0, ATM Call: 28.0, OTM Call: 28.5,                         left wing: 1.0, right wing: 0.5
# date: 2019-07-30 00:00:00
# date: 2019-07-30 00:00:00, current_spot_open: 28.0, OTM Put: 17.0, ATM Put: 28.0, ATM Call: 28.0, OTM Call: 28.5,                         left wing: 11.0, right wing: 0.5
# date: 2019-08-14 00:00:00
# date: 2019-08-14 00:00:00, current_spot_open: 26.5, OTM Put: 25.5, ATM Put: 26.5, ATM Call: 26.5, OTM Call: 28.5,                         left wing: 1.0, right wing: 2.0
# date: 2019-08-28 00:00:00
# date: 2019-08-28 00:00:00, current_spot_open: 26.0, OTM Put: 19.0, ATM Put: 26.0, ATM Call: 26.0, OTM Call: 26.5,                         left wing: 7.0, right wing: 0.5
# date: 2019-09-03 00:00:00
# date: 2019-09-03 00:00:00, current_spot_open: 26.5, OTM Put: 24.5, ATM Put: 26.5, ATM Call: 26.5, OTM Call: 27.0,                         left wing: 2.0, right wing: 0.5
# date: 2019-09-11 00:00:00
# date: 2019-09-11 00:00:00, current_spot_open: 28.0, OTM Put: 26.5, ATM Put: 28.0, ATM Call: 28.0, OTM Call: 28.5,                         left wing: 1.5, right wing: 0.5
# date: 2019-09-18 00:00:00
# Error: 2019-09-18 00:00:00, P
# Error: 2019-09-18 00:00:00, C
# date: 2019-10-09 00:00:00
# date: 2019-10-09 00:00:00, current_spot_open: 27.0, OTM Put: 25.5, ATM Put: 27.0, ATM Call: 27.0, OTM Call: 27.5,                         left wing: 1.5, right wing: 0.5
# date: 2019-10-23 00:00:00
# date: 2019-10-23 00:00:00, current_spot_open: 28.5, OTM Put: 27.0, ATM Put: 28.5, ATM Call: 28.5, OTM Call: 29.0,                         left wing: 1.5, right wing: 0.5
# date: 2019-10-30 00:00:00
# date: 2019-10-30 00:00:00, current_spot_open: 29.0, OTM Put: 28.0, ATM Put: 29.0, ATM Call: 29.0, OTM Call: 29.5,                         left wing: 1.0, right wing: 0.5
# date: 2019-11-05 00:00:00
# date: 2019-11-05 00:00:00, current_spot_open: 29.5, OTM Put: 28.5, ATM Put: 29.5, ATM Call: 29.5, OTM Call: 30.0,                         left wing: 1.0, right wing: 0.5
# date: 2019-11-13 00:00:00
# date: 2019-11-13 00:00:00, current_spot_open: 29.5, OTM Put: 27.0, ATM Put: 29.5, ATM Call: 29.5, OTM Call: 30.0,                         left wing: 2.5, right wing: 0.5
# date: 2019-12-03 00:00:00
# date: 2019-12-03 00:00:00, current_spot_open: 29.5, OTM Put: 27.5, ATM Put: 29.5, ATM Call: 29.5, OTM Call: 30.0,                         left wing: 2.0, right wing: 0.5
# date: 2019-12-11 00:00:00
# date: 2019-12-11 00:00:00, current_spot_open: 30.5, OTM Put: 30.0, ATM Put: 30.5, ATM Call: 30.5, OTM Call: 32.5,                         left wing: 0.5, right wing: 2.0
# date: 2019-12-24 00:00:00
# date: 2019-12-24 00:00:00, current_spot_open: 30.5, OTM Put: 22.0, ATM Put: 30.5, ATM Call: 30.5, OTM Call: 31.0,                         left wing: 8.5, right wing: 0.5
# date: 2020-01-15 00:00:00
# date: 2020-01-15 00:00:00, current_spot_open: 30.5, OTM Put: 22.5, ATM Put: 30.5, ATM Call: 30.5, OTM Call: 31.0,                         left wing: 8.0, right wing: 0.5
# date: 2020-02-12 00:00:00
# date: 2020-02-12 00:00:00, current_spot_open: 31.5, OTM Put: 31.0, ATM Put: 31.5, ATM Call: 31.5, OTM Call: 46.0,                         left wing: 0.5, right wing: 14.5
# date: 2020-02-19 00:00:00
# date: 2020-02-19 00:00:00, current_spot_open: 31.0, OTM Put: 25.5, ATM Put: 31.0, ATM Call: 31.0, OTM Call: 31.5,                         left wing: 5.5, right wing: 0.5
# date: 2020-03-23 00:00:00
# Error: 2020-03-23 00:00:00, P
# Error: 2020-03-23 00:00:00, C
# date: 2020-03-31 00:00:00
# date: 2020-03-31 00:00:00, current_spot_open: 21.0, OTM Put: 18.0, ATM Put: 21.0, ATM Call: 21.0, OTM Call: 22.5,                         left wing: 3.0, right wing: 1.5
# date: 2020-04-15 00:00:00
# date: 2020-04-15 00:00:00, current_spot_open: 21.5, OTM Put: 17.5, ATM Put: 21.5, ATM Call: 21.5, OTM Call: 23.0,                         left wing: 4.0, right wing: 1.5
# date: 2020-04-22 00:00:00
# date: 2020-04-22 00:00:00, current_spot_open: 21.5, OTM Put: 18.5, ATM Put: 21.5, ATM Call: 21.5, OTM Call: 23.0,                         left wing: 3.0, right wing: 1.5
# date: 2020-05-04 00:00:00
# date: 2020-05-04 00:00:00, current_spot_open: 22.0, OTM Put: 19.5, ATM Put: 22.0, ATM Call: 22.0, OTM Call: 23.5,                         left wing: 2.5, right wing: 1.5
# date: 2020-05-13 00:00:00
# date: 2020-05-13 00:00:00, current_spot_open: 21.0, OTM Put: 19.0, ATM Put: 21.0, ATM Call: 21.0, OTM Call: 22.5,                         left wing: 2.0, right wing: 1.5
# date: 2020-06-02 00:00:00
# date: 2020-06-02 00:00:00, current_spot_open: 24.0, OTM Put: 22.0, ATM Put: 24.0, ATM Call: 24.0, OTM Call: 25.0,                         left wing: 2.0, right wing: 1.0
# date: 2020-06-10 00:00:00
# date: 2020-06-10 00:00:00, current_spot_open: 26.0, OTM Put: 24.5, ATM Put: 26.0, ATM Call: 26.0, OTM Call: 44.0,                         left wing: 1.5, right wing: 18.0
# date: 2020-06-23 00:00:00
# date: 2020-06-23 00:00:00, current_spot_open: 24.0, OTM Put: 22.0, ATM Put: 24.0, ATM Call: 24.0, OTM Call: 25.5,                         left wing: 2.0, right wing: 1.5
# date: 2020-06-26 00:00:00
# date: 2020-06-26 00:00:00, current_spot_open: 23.0, OTM Put: 20.5, ATM Put: 23.0, ATM Call: 23.0, OTM Call: 25.0,                         left wing: 2.5, right wing: 2.0
# date: 2020-07-08 00:00:00
# date: 2020-07-08 00:00:00, current_spot_open: 23.0, OTM Put: 20.0, ATM Put: 23.0, ATM Call: 23.0, OTM Call: 24.5,                         left wing: 3.0, right wing: 1.5
# date: 2020-07-15 00:00:00
# date: 2020-07-15 00:00:00, current_spot_open: 24.0, OTM Put: 21.5, ATM Put: 24.0, ATM Call: 24.0, OTM Call: 25.0,                         left wing: 2.5, right wing: 1.0
# date: 2020-07-28 00:00:00
# date: 2020-07-28 00:00:00, current_spot_open: 24.0, OTM Put: 22.5, ATM Put: 24.0, ATM Call: 24.0, OTM Call: 25.0,                         left wing: 1.5, right wing: 1.0
# date: 2020-08-04 00:00:00
# date: 2020-08-04 00:00:00, current_spot_open: 24.0, OTM Put: 22.5, ATM Put: 24.0, ATM Call: 24.0, OTM Call: 25.0,                         left wing: 1.5, right wing: 1.0
# date: 2020-08-12 00:00:00
# date: 2020-08-12 00:00:00, current_spot_open: 26.0, OTM Put: 25.0, ATM Put: 26.0, ATM Call: 26.0, OTM Call: 35.0,                         left wing: 1.0, right wing: 9.0
# date: 2020-08-19 00:00:00
# date: 2020-08-19 00:00:00, current_spot_open: 24.5, OTM Put: 22.5, ATM Put: 24.5, ATM Call: 24.5, OTM Call: 25.5,                         left wing: 2.0, right wing: 1.0
# date: 2020-09-09 00:00:00
# date: 2020-09-09 00:00:00, current_spot_open: 25.0, OTM Put: 23.5, ATM Put: 25.0, ATM Call: 25.0, OTM Call: 26.0,                         left wing: 1.5, right wing: 1.0
# date: 2020-10-12 00:00:00
# date: 2020-10-12 00:00:00, current_spot_open: 25.0, OTM Put: 15.0, ATM Put: 25.0, ATM Call: 25.0, OTM Call: 26.0,                         left wing: 10.0, right wing: 1.0
# date: 2020-10-28 00:00:00
# date: 2020-10-28 00:00:00, current_spot_open: 23.5, OTM Put: 20.5, ATM Put: 23.5, ATM Call: 23.5, OTM Call: 25.0,                         left wing: 3.0, right wing: 1.5
# date: 2020-11-18 00:00:00
# date: 2020-11-18 00:00:00, current_spot_open: 27.5, OTM Put: 26.5, ATM Put: 27.5, ATM Call: 27.5, OTM Call: 28.5,                         left wing: 1.0, right wing: 1.0
# date: 2020-12-01 00:00:00
# date: 2020-12-01 00:00:00, current_spot_open: 28.5, OTM Put: 27.0, ATM Put: 28.5, ATM Call: 28.5, OTM Call: 29.5,                         left wing: 1.5, right wing: 1.0
# date: 2020-12-08 00:00:00
# date: 2020-12-08 00:00:00, current_spot_open: 28.5, OTM Put: 5.0, ATM Put: 28.5, ATM Call: 28.5, OTM Call: 29.5,                         left wing: 23.5, right wing: 1.0
# date: 2020-12-22 00:00:00
# Error: 2020-12-22 00:00:00, P
# Error: 2020-12-22 00:00:00, C
# date: 2021-01-20 00:00:00
# date: 2021-01-20 00:00:00, current_spot_open: 31.0, OTM Put: 29.5, ATM Put: 31.0, ATM Call: 31.0, OTM Call: 32.0,                         left wing: 1.5, right wing: 1.0
# date: 2021-01-27 00:00:00
# date: 2021-01-27 00:00:00, current_spot_open: 29.5, OTM Put: 27.5, ATM Put: 29.5, ATM Call: 29.5, OTM Call: 31.5,                         left wing: 2.0, right wing: 2.0
# date: 2021-02-08 00:00:00
# date: 2021-02-08 00:00:00, current_spot_open: 31.0, OTM Put: 27.5, ATM Put: 31.0, ATM Call: 31.0, OTM Call: 32.0,                         left wing: 3.5, right wing: 1.0
# date: 2021-02-12 00:00:00
# date: 2021-02-12 00:00:00, current_spot_open: 31.0, OTM Put: 20.0, ATM Put: 31.0, ATM Call: 31.0, OTM Call: 32.0,                         left wing: 11.0, right wing: 1.0
# date: 2021-03-10 00:00:00
# date: 2021-03-10 00:00:00, current_spot_open: 34.0, OTM Put: 11.0, ATM Put: 34.0, ATM Call: 34.0, OTM Call: 35.0,                         left wing: 23.0, right wing: 1.0
# date: 2021-03-24 00:00:00
# date: 2021-03-24 00:00:00, current_spot_open: 33.5, OTM Put: 32.0, ATM Put: 33.5, ATM Call: 33.5, OTM Call: 34.5,                         left wing: 1.5, right wing: 1.0
# date: 2021-03-29 00:00:00
# date: 2021-03-29 00:00:00, current_spot_open: 34.0, OTM Put: 31.0, ATM Put: 34.0, ATM Call: 34.0, OTM Call: 35.0,                         left wing: 3.0, right wing: 1.0
# date: 2021-04-07 00:00:00
# date: 2021-04-07 00:00:00, current_spot_open: 35.0, OTM Put: 33.5, ATM Put: 35.0, ATM Call: 35.0, OTM Call: 36.0,                         left wing: 1.5, right wing: 1.0
# date: 2021-04-14 00:00:00
# date: 2021-04-14 00:00:00, current_spot_open: 35.0, OTM Put: 32.0, ATM Put: 35.0, ATM Call: 35.0, OTM Call: 36.0,                         left wing: 3.0, right wing: 1.0
# date: 2021-05-05 00:00:00
# date: 2021-05-05 00:00:00, current_spot_open: 37.0, OTM Put: 35.5, ATM Put: 37.0, ATM Call: 37.0, OTM Call: 38.0,                         left wing: 1.5, right wing: 1.0
# date: 2021-05-12 00:00:00
# date: 2021-05-12 00:00:00, current_spot_open: 37.5, OTM Put: 36.0, ATM Put: 37.5, ATM Call: 37.5, OTM Call: 44.0,                         left wing: 1.5, right wing: 6.5
# date: 2021-06-02 00:00:00
# date: 2021-06-02 00:00:00, current_spot_open: 38.5, OTM Put: 37.5, ATM Put: 38.5, ATM Call: 38.5, OTM Call: 39.5,                         left wing: 1.0, right wing: 1.0
# date: 2021-06-09 00:00:00
# date: 2021-06-09 00:00:00, current_spot_open: 38.0, OTM Put: 36.5, ATM Put: 38.0, ATM Call: 38.0, OTM Call: 39.0,                         left wing: 1.5, right wing: 1.0
# date: 2021-06-15 00:00:00
# date: 2021-06-15 00:00:00, current_spot_open: 37.0, OTM Put: 35.0, ATM Put: 37.0, ATM Call: 37.0, OTM Call: 38.0,                         left wing: 2.0, right wing: 1.0
# date: 2021-06-28 00:00:00
# date: 2021-06-28 00:00:00, current_spot_open: 37.0, OTM Put: 35.5, ATM Put: 37.0, ATM Call: 37.0, OTM Call: 38.5,                         left wing: 1.5, right wing: 1.5
# date: 2021-07-07 00:00:00
# date: 2021-07-07 00:00:00, current_spot_open: 36.0, OTM Put: 20.0, ATM Put: 36.0, ATM Call: 36.0, OTM Call: 37.0,                         left wing: 16.0, right wing: 1.0
# date: 2021-07-14 00:00:00
# date: 2021-07-14 00:00:00, current_spot_open: 36.5, OTM Put: 35.0, ATM Put: 36.5, ATM Call: 36.5, OTM Call: 37.5,                         left wing: 1.5, right wing: 1.0
# date: 2021-07-28 00:00:00
# date: 2021-07-28 00:00:00, current_spot_open: 36.5, OTM Put: 34.5, ATM Put: 36.5, ATM Call: 36.5, OTM Call: 37.5,                         left wing: 2.0, right wing: 1.0
# date: 2021-08-03 00:00:00
# date: 2021-08-03 00:00:00, current_spot_open: 36.5, OTM Put: 29.5, ATM Put: 36.5, ATM Call: 36.5, OTM Call: 37.5,                         left wing: 7.0, right wing: 1.0
# date: 2021-08-17 00:00:00
# date: 2021-08-17 00:00:00, current_spot_open: 38.0, OTM Put: 34.0, ATM Put: 38.0, ATM Call: 38.0, OTM Call: 39.0,                         left wing: 4.0, right wing: 1.0
# date: 2021-09-07 00:00:00
# date: 2021-09-07 00:00:00, current_spot_open: 38.0, OTM Put: 36.5, ATM Put: 38.0, ATM Call: 38.0, OTM Call: 39.0,                         left wing: 1.5, right wing: 1.0
# date: 2021-09-14 00:00:00
# date: 2021-09-14 00:00:00, current_spot_open: 38.0, OTM Put: 36.5, ATM Put: 38.0, ATM Call: 38.0, OTM Call: 41.5,                         left wing: 1.5, right wing: 3.5
# date: 2021-10-11 00:00:00
# date: 2021-10-11 00:00:00, current_spot_open: 39.0, OTM Put: 37.0, ATM Put: 39.0, ATM Call: 39.0, OTM Call: 40.5,                         left wing: 2.0, right wing: 1.5
# date: 2021-10-27 00:00:00
# date: 2021-10-27 00:00:00, current_spot_open: 40.5, OTM Put: 39.5, ATM Put: 40.5, ATM Call: 40.5, OTM Call: 50.0,                         left wing: 1.0, right wing: 9.5
# date: 2021-11-03 00:00:00
# date: 2021-11-03 00:00:00, current_spot_open: 40.0, OTM Put: 20.0, ATM Put: 40.0, ATM Call: 40.0, OTM Call: 41.0,                         left wing: 20.0, right wing: 1.0
# date: 2021-11-09 00:00:00
# date: 2021-11-09 00:00:00, current_spot_open: 40.0, OTM Put: 37.5, ATM Put: 40.0, ATM Call: 40.0, OTM Call: 41.0,                         left wing: 2.5, right wing: 1.0
# date: 2021-11-30 00:00:00
# date: 2021-11-30 00:00:00, current_spot_open: 38.5, OTM Put: 36.5, ATM Put: 38.5, ATM Call: 38.5, OTM Call: 40.5,                         left wing: 2.0, right wing: 2.0
# date: 2021-12-14 00:00:00
# date: 2021-12-14 00:00:00, current_spot_open: 38.5, OTM Put: 35.5, ATM Put: 38.5, ATM Call: 38.5, OTM Call: 39.5,                         left wing: 3.0, right wing: 1.0
# date: 2021-12-28 00:00:00
# date: 2021-12-28 00:00:00, current_spot_open: 39.0, OTM Put: 35.0, ATM Put: 39.0, ATM Call: 39.0, OTM Call: 40.0,                         left wing: 4.0, right wing: 1.0
# date: 2022-01-11 00:00:00
# date: 2022-01-11 00:00:00, current_spot_open: 41.0, OTM Put: 5.0, ATM Put: 41.0, ATM Call: 41.0, OTM Call: 42.0,                         left wing: 36.0, right wing: 1.0
# date: 2022-01-26 00:00:00
# date: 2022-01-26 00:00:00, current_spot_open: 39.0, OTM Put: 36.5, ATM Put: 39.0, ATM Call: 39.0, OTM Call: 40.5,                         left wing: 2.5, right wing: 1.5
# date: 2022-02-08 00:00:00
# date: 2022-02-08 00:00:00, current_spot_open: 40.5, OTM Put: 34.5, ATM Put: 40.5, ATM Call: 40.5, OTM Call: 41.5,                         left wing: 6.0, right wing: 1.0
# date: 2022-02-16 00:00:00
# date: 2022-02-16 00:00:00, current_spot_open: 40.0, OTM Put: 35.5, ATM Put: 40.0, ATM Call: 40.0, OTM Call: 41.0,                         left wing: 4.5, right wing: 1.0
# date: 2022-03-15 00:00:00
# date: 2022-03-15 00:00:00, current_spot_open: 37.0, OTM Put: 32.0, ATM Put: 37.0, ATM Call: 37.0, OTM Call: 38.5,                         left wing: 5.0, right wing: 1.5
# date: 2022-03-28 00:00:00
# date: 2022-03-28 00:00:00, current_spot_open: 39.5, OTM Put: 37.5, ATM Put: 39.5, ATM Call: 39.5, OTM Call: 40.5,                         left wing: 2.0, right wing: 1.0
# date: 2022-04-06 00:00:00
# date: 2022-04-06 00:00:00, current_spot_open: 37.5, OTM Put: 35.0, ATM Put: 37.5, ATM Call: 37.5, OTM Call: 38.5,                         left wing: 2.5, right wing: 1.0
# date: 2022-04-08 00:00:00
# date: 2022-04-08 00:00:00, current_spot_open: 37.5, OTM Put: 20.0, ATM Put: 37.5, ATM Call: 37.5, OTM Call: 38.5,                         left wing: 17.5, right wing: 1.0
# date: 2022-05-11 00:00:00
# date: 2022-05-11 00:00:00, current_spot_open: 33.5, OTM Put: 31.0, ATM Put: 33.5, ATM Call: 33.5, OTM Call: 35.0,                         left wing: 2.5, right wing: 1.5
# date: 2022-05-18 00:00:00
# date: 2022-05-18 00:00:00, current_spot_open: 34.0, OTM Put: 32.0, ATM Put: 34.0, ATM Call: 34.0, OTM Call: 40.0,                         left wing: 2.0, right wing: 6.0
# date: 2022-06-08 00:00:00
# date: 2022-06-08 00:00:00, current_spot_open: 35.0, OTM Put: 33.5, ATM Put: 35.0, ATM Call: 35.0, OTM Call: 36.5,                         left wing: 1.5, right wing: 1.5
# date: 2022-06-22 00:00:00
# date: 2022-06-22 00:00:00, current_spot_open: 31.0, OTM Put: 20.0, ATM Put: 31.0, ATM Call: 31.0, OTM Call: 32.0,                         left wing: 11.0, right wing: 1.0
# date: 2022-06-29 00:00:00
# date: 2022-06-29 00:00:00, current_spot_open: 32.0, OTM Put: 30.5, ATM Put: 32.0, ATM Call: 32.0, OTM Call: 33.0,                         left wing: 1.5, right wing: 1.0
# date: 2022-07-05 00:00:00
# date: 2022-07-05 00:00:00, current_spot_open: 31.5, OTM Put: 28.0, ATM Put: 31.5, ATM Call: 31.5, OTM Call: 32.5,                         left wing: 3.5, right wing: 1.0
# date: 2022-07-12 00:00:00
# date: 2022-07-12 00:00:00, current_spot_open: 31.5, OTM Put: 28.5, ATM Put: 31.5, ATM Call: 31.5, OTM Call: 32.5,                         left wing: 3.0, right wing: 1.0
# date: 2022-07-27 00:00:00
# date: 2022-07-27 00:00:00, current_spot_open: 32.5, OTM Put: 20.0, ATM Put: 32.5, ATM Call: 32.5, OTM Call: 33.5,                         left wing: 12.5, right wing: 1.0
# date: 2022-08-10 00:00:00
# date: 2022-08-10 00:00:00, current_spot_open: 34.5, OTM Put: 32.5, ATM Put: 34.5, ATM Call: 34.5, OTM Call: 35.5,                         left wing: 2.0, right wing: 1.0
# date: 2022-08-17 00:00:00
# date: 2022-08-17 00:00:00, current_spot_open: 35.5, OTM Put: 33.0, ATM Put: 35.5, ATM Call: 35.5, OTM Call: 36.5,                         left wing: 2.5, right wing: 1.0
# date: 2022-09-14 00:00:00
# date: 2022-09-14 00:00:00, current_spot_open: 33.5, OTM Put: 32.0, ATM Put: 33.5, ATM Call: 33.5, OTM Call: 35.0,                         left wing: 1.5, right wing: 1.5
# date: 2022-09-21 00:00:00
# date: 2022-09-21 00:00:00, current_spot_open: 33.0, OTM Put: 32.0, ATM Put: 33.0, ATM Call: 33.0, OTM Call: 50.0,                         left wing: 1.0, right wing: 17.0
# date: 2022-10-12 00:00:00
# date: 2022-10-12 00:00:00, current_spot_open: 30.5, OTM Put: 28.0, ATM Put: 30.5, ATM Call: 30.5, OTM Call: 32.0,                         left wing: 2.5, right wing: 1.5
# date: 2022-11-08 00:00:00
# date: 2022-11-08 00:00:00, current_spot_open: 34.5, OTM Put: 32.5, ATM Put: 34.5, ATM Call: 34.5, OTM Call: 36.0,                         left wing: 2.0, right wing: 1.5
# date: 2022-11-16 00:00:00
# date: 2022-11-16 00:00:00, current_spot_open: 35.5, OTM Put: 34.0, ATM Put: 35.5, ATM Call: 35.5, OTM Call: 36.5,                         left wing: 1.5, right wing: 1.0
# date: 2022-11-30 00:00:00
# date: 2022-11-30 00:00:00, current_spot_open: 35.5, OTM Put: 20.0, ATM Put: 35.5, ATM Call: 35.5, OTM Call: 36.5,                         left wing: 15.5, right wing: 1.0
# date: 2022-12-13 00:00:00
# date: 2022-12-13 00:00:00, current_spot_open: 36.0, OTM Put: 34.5, ATM Put: 36.0, ATM Call: 36.0, OTM Call: 50.0,                         left wing: 1.5, right wing: 14.0
# date: 2022-12-21 00:00:00
# date: 2022-12-21 00:00:00, current_spot_open: 34.0, OTM Put: 32.0, ATM Put: 34.0, ATM Call: 34.0, OTM Call: 35.0,                         left wing: 2.0, right wing: 1.0
# date: 2023-01-11 00:00:00
# date: 2023-01-11 00:00:00, current_spot_open: 35.5, OTM Put: 30.0, ATM Put: 35.5, ATM Call: 35.5, OTM Call: 36.5,                         left wing: 5.5, right wing: 1.0
# date: 2023-01-25 00:00:00
# date: 2023-01-25 00:00:00, current_spot_open: 35.5, OTM Put: 20.0, ATM Put: 35.5, ATM Call: 35.5, OTM Call: 36.5,                         left wing: 15.5, right wing: 1.0
# date: 2023-02-01 00:00:00
# date: 2023-02-01 00:00:00, current_spot_open: 36.0, OTM Put: 20.0, ATM Put: 36.0, ATM Call: 36.0, OTM Call: 37.0,                         left wing: 16.0, right wing: 1.0
# date: 2023-03-01 00:00:00
# date: 2023-03-01 00:00:00, current_spot_open: 35.5, OTM Put: 33.5, ATM Put: 35.5, ATM Call: 35.5, OTM Call: 36.5,                         left wing: 2.0, right wing: 1.0
# date: 2023-03-27 00:00:00
# date: 2023-03-27 00:00:00, current_spot_open: 31.5, OTM Put: 29.0, ATM Put: 31.5, ATM Call: 31.5, OTM Call: 32.5,                         left wing: 2.5, right wing: 1.0
# date: 2023-04-11 00:00:00
# date: 2023-04-11 00:00:00, current_spot_open: 32.0, OTM Put: 20.0, ATM Put: 32.0, ATM Call: 32.0, OTM Call: 33.0,                         left wing: 12.0, right wing: 1.0
# date: 2023-04-19 00:00:00
# date: 2023-04-19 00:00:00, current_spot_open: 33.5, OTM Put: 32.0, ATM Put: 33.5, ATM Call: 33.5, OTM Call: 34.0,                         left wing: 1.5, right wing: 0.5
# date: 2023-05-17 00:00:00
# date: 2023-05-17 00:00:00, current_spot_open: 32.0, OTM Put: 20.0, ATM Put: 32.0, ATM Call: 32.0, OTM Call: 32.5,                         left wing: 12.0, right wing: 0.5
# date: 2023-05-31 00:00:00
# date: 2023-05-31 00:00:00, current_spot_open: 32.0, OTM Put: 31.0, ATM Put: 32.0, ATM Call: 32.0, OTM Call: 33.0,                         left wing: 1.0, right wing: 1.0
# date: 2023-06-13 00:00:00
# date: 2023-06-13 00:00:00, current_spot_open: 33.0, OTM Put: 20.0, ATM Put: 33.0, ATM Call: 33.0, OTM Call: 33.5,                         left wing: 13.0, right wing: 0.5
# date: 2023-06-21 00:00:00
# date: 2023-06-21 00:00:00, current_spot_open: 33.0, OTM Put: 30.0, ATM Put: 33.0, ATM Call: 33.0, OTM Call: 34.0,                         left wing: 3.0, right wing: 1.0
# date: 2023-06-28 00:00:00
# date: 2023-06-28 00:00:00, current_spot_open: 33.0, OTM Put: 32.0, ATM Put: 33.0, ATM Call: 33.0, OTM Call: 33.5,                         left wing: 1.0, right wing: 0.5
# date: 2023-07-18 00:00:00
# date: 2023-07-18 00:00:00, current_spot_open: 34.5, OTM Put: 20.0, ATM Put: 34.5, ATM Call: 34.5, OTM Call: 35.0,                         left wing: 14.5, right wing: 0.5
# date: 2023-08-02 00:00:00
# date: 2023-08-02 00:00:00, current_spot_open: 35.0, OTM Put: 33.5, ATM Put: 35.0, ATM Call: 35.0, OTM Call: 35.5,                         left wing: 1.5, right wing: 0.5
# date: 2023-08-09 00:00:00
# date: 2023-08-09 00:00:00, current_spot_open: 35.0, OTM Put: 34.0, ATM Put: 35.0, ATM Call: 35.0, OTM Call: 36.0,                         left wing: 1.0, right wing: 1.0
# date: 2023-08-16 00:00:00
# date: 2023-08-16 00:00:00, current_spot_open: 34.0, OTM Put: 29.5, ATM Put: 34.0, ATM Call: 34.0, OTM Call: 34.5,                         left wing: 4.5, right wing: 0.5
# date: 2023-08-23 00:00:00
# date: 2023-08-23 00:00:00, current_spot_open: 33.5, OTM Put: 20.0, ATM Put: 33.5, ATM Call: 33.5, OTM Call: 34.0,                         left wing: 13.5, right wing: 0.5
# date: 2023-08-30 00:00:00
# date: 2023-08-30 00:00:00, current_spot_open: 34.5, OTM Put: 33.5, ATM Put: 34.5, ATM Call: 34.5, OTM Call: 35.0,                         left wing: 1.0, right wing: 0.5
# Processing date: 2017-10-04 00:00:00, expiry: 2017-10-13 00:00:00
# Let iron condor expire: 2017-10-13 00:00:00, pnl: 0.21000083923339843
# Processing date: 2017-10-16 00:00:00, expiry: 2017-10-27 00:00:00
# Let iron condor expire: 2017-10-27 00:00:00, pnl: -0.15999999999999998
# Processing date: 2017-11-14 00:00:00, expiry: 2017-11-24 00:00:00
# Let iron condor expire: 2017-11-24 00:00:00, pnl: 0.12000068664550784
# Processing date: 2017-12-06 00:00:00, expiry: 2017-12-15 00:00:00
# Let iron condor expire: 2017-12-15 00:00:00, pnl: 0.35999946594238286
# Processing date: 2017-12-12 00:00:00, expiry: 2017-12-22 00:00:00
# Let iron condor expire: 2017-12-22 00:00:00, pnl: 0.41000076293945314
# Processing date: 2017-12-20 00:00:00, expiry: 2017-12-29 00:00:00
# Let iron condor expire: 2017-12-29 00:00:00, pnl: 0.27999984741210937
# Processing date: 2018-01-03 00:00:00, expiry: 2018-01-12 00:00:00
# Let iron condor expire: 2018-01-12 00:00:00, pnl: -0.11999999999999988
# Processing date: 2018-02-27 00:00:00, expiry: 2018-03-09 00:00:00
# Let iron condor expire: 2018-03-09 00:00:00, pnl: 0.3199992370605469
# Processing date: 2018-03-07 00:00:00, expiry: 2018-03-16 00:00:00
# Let iron condor expire: 2018-03-16 00:00:00, pnl: 0.1199991607666015
# Processing date: 2018-03-20 00:00:00, expiry: 2018-03-29 00:00:00
# Let iron condor expire: 2018-03-29 00:00:00, pnl: -0.5200000000000001
# Processing date: 2018-04-03 00:00:00, expiry: 2018-04-13 00:00:00
# Let iron condor expire: 2018-04-13 00:00:00, pnl: 0.3300009155273438
# Processing date: 2018-04-11 00:00:00, expiry: 2018-04-20 00:00:00
# Let iron condor expire: 2018-04-20 00:00:00, pnl: 0.32000083923339845
# Processing date: 2018-04-18 00:00:00, expiry: 2018-04-27 00:00:00
# Let iron condor expire: 2018-04-27 00:00:00, pnl: 0.28999923706054687
# Processing date: 2018-05-09 00:00:00, expiry: 2018-05-18 00:00:00
# Let iron condor expire: 2018-05-18 00:00:00, pnl: 0.3600007629394531
# Processing date: 2018-05-14 00:00:00, expiry: 2018-05-25 00:00:00
# Let iron condor expire: 2018-05-25 00:00:00, pnl: -0.1999996185302735
# Processing date: 2018-06-06 00:00:00, expiry: 2018-06-15 00:00:00
# Let iron condor expire: 2018-06-15 00:00:00, pnl: 0.41999931335449214
# Processing date: 2018-06-13 00:00:00, expiry: 2018-06-22 00:00:00
# Let iron condor expire: 2018-06-22 00:00:00, pnl: -0.47000030517578134
# Processing date: 2018-06-26 00:00:00, expiry: 2018-07-06 00:00:00
# Let iron condor expire: 2018-07-06 00:00:00, pnl: 0.1400000762939453
# Processing date: 2018-07-11 00:00:00, expiry: 2018-07-20 00:00:00
# Let iron condor expire: 2018-07-20 00:00:00, pnl: -0.06999999999999995
# Processing date: 2018-07-17 00:00:00, expiry: 2018-07-27 00:00:00
# Let iron condor expire: 2018-07-27 00:00:00, pnl: -0.11999999999999997
# Processing date: 2018-08-06 00:00:00, expiry: 2018-08-17 00:00:00
# Let iron condor expire: 2018-08-17 00:00:00, pnl: 0.22999992370605468
# Processing date: 2018-09-05 00:00:00, expiry: 2018-09-14 00:00:00
# Let iron condor expire: 2018-09-14 00:00:00, pnl: 0.08999954223632814
# Processing date: 2018-09-18 00:00:00, expiry: 2018-09-28 00:00:00
# Let iron condor expire: 2018-09-28 00:00:00, pnl: 0.04999992370605466
# Processing date: 2018-10-03 00:00:00, expiry: 2018-10-12 00:00:00
# Let iron condor expire: 2018-10-12 00:00:00, pnl: -0.59
# Processing date: 2018-10-17 00:00:00, expiry: 2018-10-26 00:00:00
# Let iron condor expire: 2018-10-26 00:00:00, pnl: -0.7799997711181642
# Processing date: 2018-10-30 00:00:00, expiry: 2018-11-09 00:00:00
# Let iron condor expire: 2018-11-09 00:00:00, pnl: -0.19999999999999996
# Processing date: 2018-11-07 00:00:00, expiry: 2018-11-16 00:00:00
# Let iron condor expire: 2018-11-16 00:00:00, pnl: 0.2600009155273437
# Processing date: 2018-11-14 00:00:00, expiry: 2018-11-23 00:00:00
# Let iron condor expire: 2018-11-23 00:00:00, pnl: -0.44000000000000006
# Processing date: 2018-12-18 00:00:00, expiry: 2018-12-31 00:00:00
# Let iron condor expire: 2018-12-31 00:00:00, pnl: 0.5799996948242188
# Processing date: 2019-01-02 00:00:00, expiry: 2019-01-11 00:00:00
# Let iron condor expire: 2019-01-11 00:00:00, pnl: -0.28
# Processing date: 2019-01-14 00:00:00, expiry: 2019-01-25 00:00:00
# Let iron condor expire: 2019-01-25 00:00:00, pnl: 0.0
# Processing date: 2019-01-30 00:00:00, expiry: 2019-02-08 00:00:00
# Let iron condor expire: 2019-02-08 00:00:00, pnl: 0.07000007629394531
# Processing date: 2019-02-06 00:00:00, expiry: 2019-02-15 00:00:00
# Let iron condor expire: 2019-02-15 00:00:00, pnl: -0.06000030517578121
# Processing date: 2019-02-27 00:00:00, expiry: 2019-03-08 00:00:00
# Let iron condor expire: 2019-03-08 00:00:00, pnl: -0.15000068664550775
# Processing date: 2019-03-12 00:00:00, expiry: 2019-03-22 00:00:00
# Let iron condor expire: 2019-03-22 00:00:00, pnl: -0.19000000000000003
# Processing date: 2019-04-09 00:00:00, expiry: 2019-04-18 00:00:00
# Let iron condor expire: 2019-04-18 00:00:00, pnl: -0.07000000000000006
# Processing date: 2019-04-16 00:00:00, expiry: 2019-04-26 00:00:00
# Let iron condor expire: 2019-04-26 00:00:00, pnl: -0.10000000000000002
# Processing date: 2019-04-24 00:00:00, expiry: 2019-05-03 00:00:00
# Let iron condor expire: 2019-05-03 00:00:00, pnl: -0.13999999999999996
# Processing date: 2019-05-06 00:00:00, expiry: 2019-05-17 00:00:00
# Let iron condor expire: 2019-05-17 00:00:00, pnl: -0.14000083923339857
# Processing date: 2019-05-28 00:00:00, expiry: 2019-06-07 00:00:00
# Let iron condor expire: 2019-06-07 00:00:00, pnl: 0.4099991607666015
# Processing date: 2019-06-05 00:00:00, expiry: 2019-06-14 00:00:00
# Let iron condor expire: 2019-06-14 00:00:00, pnl: 0.24000022888183592
# Processing date: 2019-06-12 00:00:00, expiry: 2019-06-21 00:00:00
# Let iron condor expire: 2019-06-21 00:00:00, pnl: 0.2699993133544922
# Processing date: 2019-07-02 00:00:00, expiry: 2019-07-12 00:00:00
# Let iron condor expire: 2019-07-12 00:00:00, pnl: 0.030000305175781228
# Processing date: 2019-07-08 00:00:00, expiry: 2019-07-19 00:00:00
# Let iron condor expire: 2019-07-19 00:00:00, pnl: 0.3200005340576172
# Processing date: 2019-07-17 00:00:00, expiry: 2019-07-26 00:00:00
# Let iron condor expire: 2019-07-26 00:00:00, pnl: -0.13
# Processing date: 2019-07-30 00:00:00, expiry: 2019-08-09 00:00:00
# Let iron condor expire: 2019-08-09 00:00:00, pnl: -0.38999992370605463
# Processing date: 2019-08-14 00:00:00, expiry: 2019-08-23 00:00:00
# Let iron condor expire: 2019-08-23 00:00:00, pnl: 0.2200003814697265
# Processing date: 2019-08-28 00:00:00, expiry: 2019-09-06 00:00:00
# Let iron condor expire: 2019-09-06 00:00:00, pnl: -0.020000000000000018
# Processing date: 2019-09-03 00:00:00, expiry: 2019-09-13 00:00:00
# Let iron condor expire: 2019-09-13 00:00:00, pnl: 0.040000000000000036
# Processing date: 2019-09-11 00:00:00, expiry: 2019-09-20 00:00:00
# Let iron condor expire: 2019-09-20 00:00:00, pnl: 0.4100000762939453
# Processing date: 2019-10-09 00:00:00, expiry: 2019-10-18 00:00:00
# Let iron condor expire: 2019-10-18 00:00:00, pnl: 0.0
# Processing date: 2019-10-23 00:00:00, expiry: 2019-11-01 00:00:00
# Let iron condor expire: 2019-11-01 00:00:00, pnl: -0.06
# Processing date: 2019-10-30 00:00:00, expiry: 2019-11-08 00:00:00
# Let iron condor expire: 2019-11-08 00:00:00, pnl: -0.10999999999999999
# Processing date: 2019-11-05 00:00:00, expiry: 2019-11-15 00:00:00
# Let iron condor expire: 2019-11-15 00:00:00, pnl: 0.15000000000000005
# Processing date: 2019-11-13 00:00:00, expiry: 2019-11-22 00:00:00
# Let iron condor expire: 2019-11-22 00:00:00, pnl: -0.01000007629394531
# Processing date: 2019-12-03 00:00:00, expiry: 2019-12-13 00:00:00
# Let iron condor expire: 2019-12-13 00:00:00, pnl: 0.010000000000000009
# Processing date: 2019-12-11 00:00:00, expiry: 2019-12-20 00:00:00
# Let iron condor expire: 2019-12-20 00:00:00, pnl: 0.18999969482421875
# Processing date: 2019-12-24 00:00:00, expiry: 2020-01-03 00:00:00
# Let iron condor expire: 2020-01-03 00:00:00, pnl: 0.11000000000000001
# Processing date: 2020-01-15 00:00:00, expiry: 2020-01-24 00:00:00
# Let iron condor expire: 2020-01-24 00:00:00, pnl: 0.28999938964843747
# Processing date: 2020-02-12 00:00:00, expiry: 2020-02-21 00:00:00
# Let iron condor expire: 2020-02-21 00:00:00, pnl: -0.16
# Processing date: 2020-02-19 00:00:00, expiry: 2020-02-28 00:00:00
# Let iron condor expire: 2020-02-28 00:00:00, pnl: -3.999999847412109
# Processing date: 2020-03-31 00:00:00, expiry: 2020-04-09 00:00:00
# Let iron condor expire: 2020-04-09 00:00:00, pnl: -0.26
# Processing date: 2020-04-15 00:00:00, expiry: 2020-04-24 00:00:00
# Let iron condor expire: 2020-04-24 00:00:00, pnl: 0.940000228881836
# Processing date: 2020-04-22 00:00:00, expiry: 2020-05-01 00:00:00
# Let iron condor expire: 2020-05-01 00:00:00, pnl: 0.6400005340576171
# Processing date: 2020-05-04 00:00:00, expiry: 2020-05-15 00:00:00
# Let iron condor expire: 2020-05-15 00:00:00, pnl: 0.12999923706054684
# Processing date: 2020-05-13 00:00:00, expiry: 2020-05-22 00:00:00
# Let iron condor expire: 2020-05-22 00:00:00, pnl: 0.03999992370605465
# Processing date: 2020-06-02 00:00:00, expiry: 2020-06-12 00:00:00
# Let iron condor expire: 2020-06-12 00:00:00, pnl: 0.6799999237060547
# Processing date: 2020-06-10 00:00:00, expiry: 2020-06-19 00:00:00
# Let iron condor expire: 2020-06-19 00:00:00, pnl: -0.52
# Processing date: 2020-06-23 00:00:00, expiry: 2020-07-02 00:00:00
# Let iron condor expire: 2020-07-02 00:00:00, pnl: -0.07000068664550774
# Processing date: 2020-06-26 00:00:00, expiry: 2020-07-10 00:00:00
# Let iron condor expire: 2020-07-10 00:00:00, pnl: 0.7400009155273438
# Processing date: 2020-07-08 00:00:00, expiry: 2020-07-17 00:00:00
# Let iron condor expire: 2020-07-17 00:00:00, pnl: 0.039999237060546866
# Processing date: 2020-07-15 00:00:00, expiry: 2020-07-24 00:00:00
# Let iron condor expire: 2020-07-24 00:00:00, pnl: 0.5599995422363282
# Processing date: 2020-07-28 00:00:00, expiry: 2020-08-07 00:00:00
# Let iron condor expire: 2020-08-07 00:00:00, pnl: -0.16000015258789063
# Processing date: 2020-08-04 00:00:00, expiry: 2020-08-14 00:00:00
# Let iron condor expire: 2020-08-14 00:00:00, pnl: -0.3899999999999999
# Processing date: 2020-08-12 00:00:00, expiry: 2020-08-21 00:00:00
# Let iron condor expire: 2020-08-21 00:00:00, pnl: -0.29
# Processing date: 2020-08-19 00:00:00, expiry: 2020-08-28 00:00:00
# Let iron condor expire: 2020-08-28 00:00:00, pnl: -0.23000061035156247
# Processing date: 2020-09-09 00:00:00, expiry: 2020-09-18 00:00:00
# Let iron condor expire: 2020-09-18 00:00:00, pnl: 0.39000030517578127
# Processing date: 2020-10-12 00:00:00, expiry: 2020-10-23 00:00:00
# Let iron condor expire: 2020-10-23 00:00:00, pnl: 0.47
# Processing date: 2020-10-28 00:00:00, expiry: 2020-11-06 00:00:00
# Let iron condor expire: 2020-11-06 00:00:00, pnl: -0.3199990844726562
# Processing date: 2020-11-18 00:00:00, expiry: 2020-11-27 00:00:00
# Let iron condor expire: 2020-11-27 00:00:00, pnl: -0.3999993133544921
# Processing date: 2020-12-01 00:00:00, expiry: 2020-12-11 00:00:00
# Let iron condor expire: 2020-12-11 00:00:00, pnl: 0.6599990844726563
# Processing date: 2020-12-08 00:00:00, expiry: 2020-12-18 00:00:00
# Let iron condor expire: 2020-12-18 00:00:00, pnl: 0.719999771118164
# Processing date: 2021-01-20 00:00:00, expiry: 2021-01-29 00:00:00
# Let iron condor expire: 2021-01-29 00:00:00, pnl: -0.7800000000000001
# Processing date: 2021-01-27 00:00:00, expiry: 2021-02-05 00:00:00
# Let iron condor expire: 2021-02-05 00:00:00, pnl: -0.31999938964843744
# Processing date: 2021-02-08 00:00:00, expiry: 2021-02-19 00:00:00
# Let iron condor expire: 2021-02-19 00:00:00, pnl: -0.28000000000000014
# Processing date: 2021-02-12 00:00:00, expiry: 2021-02-26 00:00:00
# Let iron condor expire: 2021-02-26 00:00:00, pnl: -0.24999999999999994
# Processing date: 2021-03-10 00:00:00, expiry: 2021-03-19 00:00:00
# Let iron condor expire: 2021-03-19 00:00:00, pnl: 0.5999987792968751
# Processing date: 2021-03-24 00:00:00, expiry: 2021-04-01 00:00:00
# Let iron condor expire: 2021-04-01 00:00:00, pnl: -0.2200012207031251
# Processing date: 2021-03-29 00:00:00, expiry: 2021-04-09 00:00:00
# Let iron condor expire: 2021-04-09 00:00:00, pnl: -0.17000000000000004
# Processing date: 2021-04-07 00:00:00, expiry: 2021-04-16 00:00:00
# Let iron condor expire: 2021-04-16 00:00:00, pnl: 0.28999847412109375
# Processing date: 2021-04-14 00:00:00, expiry: 2021-04-23 00:00:00
# Let iron condor expire: 2021-04-23 00:00:00, pnl: 0.28999893188476566
# Processing date: 2021-05-05 00:00:00, expiry: 2021-05-14 00:00:00
# Let iron condor expire: 2021-05-14 00:00:00, pnl: -0.22000106811523434
# Processing date: 2021-05-12 00:00:00, expiry: 2021-05-21 00:00:00
# Let iron condor expire: 2021-05-21 00:00:00, pnl: 0.8899981689453126
# Processing date: 2021-06-02 00:00:00, expiry: 2021-06-11 00:00:00
# Let iron condor expire: 2021-06-11 00:00:00, pnl: -0.34999862670898446
# Processing date: 2021-06-09 00:00:00, expiry: 2021-06-18 00:00:00
# Closing on date: 2021-06-18 00:00:00
# strike1: 36.5, strike2: 38.0, strike3: 38.0, strike4: 39.0
# Long put sellback: 1.53
# Short put buyback: 2.94
# Short call buyback: 0.06
# Long call sellback: 0.02
# Closing cost: -1.45
# Close iron condor early on date: 2021-06-18 00:00:00 when signal is -1, pnl: 0.6299999999999997
# Processing date: 2021-06-15 00:00:00, expiry: 2021-06-25 00:00:00
# Closing on date: 2021-06-18 00:00:00
# strike1: 35.0, strike2: 37.0, strike3: 37.0, strike4: 38.0
# Long put sellback: 0.59
# Short put buyback: 2.0
# Short call buyback: 0.12
# Long call sellback: 0.05
# Closing cost: -1.4800000000000002
# Close iron condor early on date: 2021-06-18 00:00:00 when signal is -1, pnl: 0.4499995422363283
# Processing date: 2021-06-28 00:00:00, expiry: 2021-07-09 00:00:00
# Let iron condor expire: 2021-07-09 00:00:00, pnl: 0.47999908447265627
# Processing date: 2021-07-07 00:00:00, expiry: 2021-07-16 00:00:00
# Let iron condor expire: 2021-07-16 00:00:00, pnl: 0.6000010681152345
# Processing date: 2021-07-14 00:00:00, expiry: 2021-07-23 00:00:00
# Let iron condor expire: 2021-07-23 00:00:00, pnl: 0.4299983215332031
# Processing date: 2021-07-28 00:00:00, expiry: 2021-08-06 00:00:00
# Let iron condor expire: 2021-08-06 00:00:00, pnl: -0.27
# Processing date: 2021-08-03 00:00:00, expiry: 2021-08-13 00:00:00
# Let iron condor expire: 2021-08-13 00:00:00, pnl: -0.24
# Processing date: 2021-08-17 00:00:00, expiry: 2021-08-27 00:00:00
# Let iron condor expire: 2021-08-27 00:00:00, pnl: -0.24000000000000005
# Processing date: 2021-09-07 00:00:00, expiry: 2021-09-17 00:00:00
# Let iron condor expire: 2021-09-17 00:00:00, pnl: 0.24000183105468748
# Processing date: 2021-09-14 00:00:00, expiry: 2021-09-24 00:00:00
# Let iron condor expire: 2021-09-24 00:00:00, pnl: 0.5999987792968751
# Processing date: 2021-10-11 00:00:00, expiry: 2021-10-22 00:00:00
# Let iron condor expire: 2021-10-22 00:00:00, pnl: -0.5999999999999999
# Processing date: 2021-10-27 00:00:00, expiry: 2021-11-05 00:00:00
# Let iron condor expire: 2021-11-05 00:00:00, pnl: 0.1600004577636719
# Processing date: 2021-11-03 00:00:00, expiry: 2021-11-12 00:00:00
# Let iron condor expire: 2021-11-12 00:00:00, pnl: 0.5599984741210937
# Processing date: 2021-11-09 00:00:00, expiry: 2021-11-19 00:00:00
# Let iron condor expire: 2021-11-19 00:00:00, pnl: -0.1999995422363282
# Processing date: 2021-11-30 00:00:00, expiry: 2021-12-10 00:00:00
# Let iron condor expire: 2021-12-10 00:00:00, pnl: 0.490000762939453
# Processing date: 2021-12-14 00:00:00, expiry: 2021-12-23 00:00:00
# Let iron condor expire: 2021-12-23 00:00:00, pnl: 0.5400003051757812
# Processing date: 2021-12-28 00:00:00, expiry: 2022-01-07 00:00:00
# Let iron condor expire: 2022-01-07 00:00:00, pnl: -0.24999999999999978
# Processing date: 2022-01-11 00:00:00, expiry: 2022-01-21 00:00:00
# Closing on date: 2022-01-21 00:00:00
# strike1: 5.0, strike2: 41.0, strike3: 41.0, strike4: 42.0
# Long put sellback: 0.0
# Short put buyback: 2.86
# Short call buyback: 0.06
# Long call sellback: 0.02
# Closing cost: -2.9
# Close iron condor early on date: 2022-01-21 00:00:00 when signal is -1, pnl: 0.9500007629394533
# ...
# date: 2023-05-17 00:00:00
# date: 2023-05-17 00:00:00, current_spot_open: 32.0, OTM Put: 20.0, ATM Put: 32.0, ATM Call: 32.0, OTM Call: 32.5,                         left wing: 12.0, right wing: 0.5
# date: 2023-05-31 00:00:00
# date: 2023-05-31 00:00:00, current_spot_open: 32.0, OTM Put: 31.0, ATM Put: 32.0, ATM Call: 32.0, OTM Call: 33.0,                         left wing: 1.0, right wing: 1.0
# date: 2023-06-13 00:00:00
# date: 2023-06-13 00:00:00, current_spot_open: 33.0, OTM Put: 20.0, ATM Put: 33.0, ATM Call: 33.0, OTM Call: 33.5,                         left wing: 13.0, right wing: 0.5
# date: 2023-06-21 00:00:00
# date: 2023-06-21 00:00:00, current_spot_open: 33.0, OTM Put: 30.0, ATM Put: 33.0, ATM Call: 33.0, OTM Call: 34.0,                         left wing: 3.0, right wing: 1.0
# date: 2023-06-28 00:00:00
# date: 2023-06-28 00:00:00, current_spot_open: 33.0, OTM Put: 32.0, ATM Put: 33.0, ATM Call: 33.0, OTM Call: 33.5,                         left wing: 1.0, right wing: 0.5
# date: 2023-07-19 00:00:00
# date: 2023-07-19 00:00:00, current_spot_open: 35.0, OTM Put: 32.0, ATM Put: 35.0, ATM Call: 35.0, OTM Call: 35.5,                         left wing: 3.0, right wing: 0.5
# date: 2023-08-02 00:00:00
# date: 2023-08-02 00:00:00, current_spot_open: 35.0, OTM Put: 33.5, ATM Put: 35.0, ATM Call: 35.0, OTM Call: 35.5,                         left wing: 1.5, right wing: 0.5
# date: 2023-08-30 00:00:00
# date: 2023-08-30 00:00:00, current_spot_open: 34.5, OTM Put: 33.5, ATM Put: 34.5, ATM Call: 34.5, OTM Call: 35.0,                         left wing: 1.0, right wing: 0.5
# Processing date: 2017-10-18 00:00:00, expiry: 2017-10-27 00:00:00
# Let iron condor expire: 2017-10-27 00:00:00, pnl: -0.060000686645507784
# Processing date: 2017-12-06 00:00:00, expiry: 2017-12-15 00:00:00
# Let iron condor expire: 2017-12-15 00:00:00, pnl: 0.35999946594238286
# Processing date: 2018-03-07 00:00:00, expiry: 2018-03-16 00:00:00
# Let iron condor expire: 2018-03-16 00:00:00, pnl: 0.1199991607666015
# Processing date: 2018-03-21 00:00:00, expiry: 2018-03-29 00:00:00
# Let iron condor expire: 2018-03-29 00:00:00, pnl: -0.5000000000000001
# Processing date: 2018-04-03 00:00:00, expiry: 2018-04-13 00:00:00
# Let iron condor expire: 2018-04-13 00:00:00, pnl: 0.3300009155273438
# Processing date: 2018-04-11 00:00:00, expiry: 2018-04-20 00:00:00
# Let iron condor expire: 2018-04-20 00:00:00, pnl: 0.32000083923339845
# Processing date: 2018-05-09 00:00:00, expiry: 2018-05-18 00:00:00
# Let iron condor expire: 2018-05-18 00:00:00, pnl: 0.3600007629394531
# Processing date: 2018-05-14 00:00:00, expiry: 2018-05-25 00:00:00
# Let iron condor expire: 2018-05-25 00:00:00, pnl: -0.1999996185302735
# Processing date: 2018-06-27 00:00:00, expiry: 2018-07-06 00:00:00
# Let iron condor expire: 2018-07-06 00:00:00, pnl: 0.3299999237060547
# Processing date: 2018-07-11 00:00:00, expiry: 2018-07-20 00:00:00
# Let iron condor expire: 2018-07-20 00:00:00, pnl: -0.06999999999999995
# Processing date: 2018-08-07 00:00:00, expiry: 2018-08-17 00:00:00
# Let iron condor expire: 2018-08-17 00:00:00, pnl: -0.0599999237060547
# Processing date: 2018-09-05 00:00:00, expiry: 2018-09-14 00:00:00
# Let iron condor expire: 2018-09-14 00:00:00, pnl: 0.08999954223632814
# Processing date: 2018-09-18 00:00:00, expiry: 2018-09-28 00:00:00
# Let iron condor expire: 2018-09-28 00:00:00, pnl: 0.04999992370605466
# Processing date: 2018-10-03 00:00:00, expiry: 2018-10-12 00:00:00
# Let iron condor expire: 2018-10-12 00:00:00, pnl: -0.59
# Processing date: 2018-11-07 00:00:00, expiry: 2018-11-16 00:00:00
# Let iron condor expire: 2018-11-16 00:00:00, pnl: 0.2600009155273437
# Processing date: 2018-11-14 00:00:00, expiry: 2018-11-23 00:00:00
# Let iron condor expire: 2018-11-23 00:00:00, pnl: -0.44000000000000006
# Processing date: 2018-12-18 00:00:00, expiry: 2018-12-31 00:00:00
# Let iron condor expire: 2018-12-31 00:00:00, pnl: 0.5799996948242188
# Processing date: 2019-01-02 00:00:00, expiry: 2019-01-11 00:00:00
# Let iron condor expire: 2019-01-11 00:00:00, pnl: -0.28
# Processing date: 2019-01-16 00:00:00, expiry: 2019-01-25 00:00:00
# Let iron condor expire: 2019-01-25 00:00:00, pnl: -0.09000000000000008
# Processing date: 2019-01-30 00:00:00, expiry: 2019-02-08 00:00:00
# Let iron condor expire: 2019-02-08 00:00:00, pnl: 0.07000007629394531
# Processing date: 2019-02-27 00:00:00, expiry: 2019-03-08 00:00:00
# Let iron condor expire: 2019-03-08 00:00:00, pnl: -0.15000068664550775
# Processing date: 2019-04-09 00:00:00, expiry: 2019-04-18 00:00:00
# Let iron condor expire: 2019-04-18 00:00:00, pnl: -0.07000000000000006
# Processing date: 2019-05-06 00:00:00, expiry: 2019-05-17 00:00:00
# Let iron condor expire: 2019-05-17 00:00:00, pnl: -0.14000083923339857
# Processing date: 2019-07-10 00:00:00, expiry: 2019-07-19 00:00:00
# Let iron condor expire: 2019-07-19 00:00:00, pnl: 0.29000053405761717
# Processing date: 2019-07-30 00:00:00, expiry: 2019-08-09 00:00:00
# Let iron condor expire: 2019-08-09 00:00:00, pnl: -0.38999992370605463
# Processing date: 2019-08-28 00:00:00, expiry: 2019-09-06 00:00:00
# Let iron condor expire: 2019-09-06 00:00:00, pnl: -0.020000000000000018
# Processing date: 2019-09-03 00:00:00, expiry: 2019-09-13 00:00:00
# Let iron condor expire: 2019-09-13 00:00:00, pnl: 0.040000000000000036
# Processing date: 2019-09-11 00:00:00, expiry: 2019-09-20 00:00:00
# Let iron condor expire: 2019-09-20 00:00:00, pnl: 0.4100000762939453
# Processing date: 2019-10-09 00:00:00, expiry: 2019-10-18 00:00:00
# Let iron condor expire: 2019-10-18 00:00:00, pnl: 0.0
# Processing date: 2019-10-23 00:00:00, expiry: 2019-11-01 00:00:00
# Let iron condor expire: 2019-11-01 00:00:00, pnl: -0.06
# Processing date: 2019-11-05 00:00:00, expiry: 2019-11-15 00:00:00
# Let iron condor expire: 2019-11-15 00:00:00, pnl: 0.15000000000000005
# Processing date: 2019-11-13 00:00:00, expiry: 2019-11-22 00:00:00
# Let iron condor expire: 2019-11-22 00:00:00, pnl: -0.01000007629394531
# Processing date: 2019-12-04 00:00:00, expiry: 2019-12-13 00:00:00
# Let iron condor expire: 2019-12-13 00:00:00, pnl: -0.020000000000000018
# Processing date: 2020-01-15 00:00:00, expiry: 2020-01-24 00:00:00
# Let iron condor expire: 2020-01-24 00:00:00, pnl: 0.28999938964843747
# Processing date: 2020-02-12 00:00:00, expiry: 2020-02-21 00:00:00
# Let iron condor expire: 2020-02-21 00:00:00, pnl: -0.16
# Processing date: 2020-02-19 00:00:00, expiry: 2020-02-28 00:00:00
# Let iron condor expire: 2020-02-28 00:00:00, pnl: -3.999999847412109
# Processing date: 2020-04-15 00:00:00, expiry: 2020-04-24 00:00:00
# Let iron condor expire: 2020-04-24 00:00:00, pnl: 0.940000228881836
# Processing date: 2020-04-22 00:00:00, expiry: 2020-05-01 00:00:00
# Let iron condor expire: 2020-05-01 00:00:00, pnl: 0.6400005340576171
# Processing date: 2020-05-04 00:00:00, expiry: 2020-05-15 00:00:00
# Let iron condor expire: 2020-05-15 00:00:00, pnl: 0.12999923706054684
# Processing date: 2020-05-13 00:00:00, expiry: 2020-05-22 00:00:00
# Let iron condor expire: 2020-05-22 00:00:00, pnl: 0.03999992370605465
# Processing date: 2020-06-10 00:00:00, expiry: 2020-06-19 00:00:00
# Let iron condor expire: 2020-06-19 00:00:00, pnl: -0.52
# Processing date: 2020-06-24 00:00:00, expiry: 2020-07-02 00:00:00
# Let iron condor expire: 2020-07-02 00:00:00, pnl: 0.5699993133544922
# Processing date: 2020-06-26 00:00:00, expiry: 2020-07-10 00:00:00
# Let iron condor expire: 2020-07-10 00:00:00, pnl: 0.7400009155273438
# Processing date: 2020-07-15 00:00:00, expiry: 2020-07-24 00:00:00
# Let iron condor expire: 2020-07-24 00:00:00, pnl: 0.5599995422363282
# Processing date: 2020-07-28 00:00:00, expiry: 2020-08-07 00:00:00
# Let iron condor expire: 2020-08-07 00:00:00, pnl: -0.16000015258789063
# Processing date: 2020-08-19 00:00:00, expiry: 2020-08-28 00:00:00
# Let iron condor expire: 2020-08-28 00:00:00, pnl: -0.23000061035156247
# Processing date: 2020-09-09 00:00:00, expiry: 2020-09-18 00:00:00
# Let iron condor expire: 2020-09-18 00:00:00, pnl: 0.39000030517578127
# Processing date: 2020-10-14 00:00:00, expiry: 2020-10-23 00:00:00
# Let iron condor expire: 2020-10-23 00:00:00, pnl: 0.3
# Processing date: 2020-11-18 00:00:00, expiry: 2020-11-27 00:00:00
# Let iron condor expire: 2020-11-27 00:00:00, pnl: -0.3999993133544921
# Processing date: 2020-12-02 00:00:00, expiry: 2020-12-11 00:00:00
# Let iron condor expire: 2020-12-11 00:00:00, pnl: 0.6499990844726562
# Processing date: 2020-12-08 00:00:00, expiry: 2020-12-18 00:00:00
# Let iron condor expire: 2020-12-18 00:00:00, pnl: 0.719999771118164
# Processing date: 2021-02-10 00:00:00, expiry: 2021-02-19 00:00:00
# Let iron condor expire: 2021-02-19 00:00:00, pnl: -0.22999984741210927
# Processing date: 2021-03-24 00:00:00, expiry: 2021-04-01 00:00:00
# Let iron condor expire: 2021-04-01 00:00:00, pnl: -0.2200012207031251
# Processing date: 2021-05-05 00:00:00, expiry: 2021-05-14 00:00:00
# Let iron condor expire: 2021-05-14 00:00:00, pnl: -0.22000106811523434
# Processing date: 2021-05-12 00:00:00, expiry: 2021-05-21 00:00:00
# Let iron condor expire: 2021-05-21 00:00:00, pnl: 0.8899981689453126
# Processing date: 2021-06-02 00:00:00, expiry: 2021-06-11 00:00:00
# Let iron condor expire: 2021-06-11 00:00:00, pnl: -0.34999862670898446
# Processing date: 2021-06-15 00:00:00, expiry: 2021-06-25 00:00:00
# Let iron condor expire: 2021-06-25 00:00:00, pnl: 0.6700003051757812
# Processing date: 2021-06-28 00:00:00, expiry: 2021-07-09 00:00:00
# Let iron condor expire: 2021-07-09 00:00:00, pnl: 0.47999908447265627
# Processing date: 2021-07-07 00:00:00, expiry: 2021-07-16 00:00:00
# Let iron condor expire: 2021-07-16 00:00:00, pnl: 0.6000010681152345
# Processing date: 2021-07-14 00:00:00, expiry: 2021-07-23 00:00:00
# Let iron condor expire: 2021-07-23 00:00:00, pnl: 0.4299983215332031
# Processing date: 2021-07-28 00:00:00, expiry: 2021-08-06 00:00:00
# Let iron condor expire: 2021-08-06 00:00:00, pnl: -0.27
# Processing date: 2021-08-03 00:00:00, expiry: 2021-08-13 00:00:00
# Let iron condor expire: 2021-08-13 00:00:00, pnl: -0.24
# Processing date: 2021-08-17 00:00:00, expiry: 2021-08-27 00:00:00
# Let iron condor expire: 2021-08-27 00:00:00, pnl: -0.24000000000000005
# Processing date: 2021-09-07 00:00:00, expiry: 2021-09-17 00:00:00
# Let iron condor expire: 2021-09-17 00:00:00, pnl: 0.24000183105468748
# Processing date: 2021-09-14 00:00:00, expiry: 2021-09-24 00:00:00
# Let iron condor expire: 2021-09-24 00:00:00, pnl: 0.5999987792968751
# Processing date: 2021-10-11 00:00:00, expiry: 2021-10-22 00:00:00
# Let iron condor expire: 2021-10-22 00:00:00, pnl: -0.5999999999999999
# Processing date: 2021-11-03 00:00:00, expiry: 2021-11-12 00:00:00
# Let iron condor expire: 2021-11-12 00:00:00, pnl: 0.5599984741210937
# Processing date: 2021-11-09 00:00:00, expiry: 2021-11-19 00:00:00
# Let iron condor expire: 2021-11-19 00:00:00, pnl: -0.1999995422363282
# Processing date: 2021-11-30 00:00:00, expiry: 2021-12-10 00:00:00
# Let iron condor expire: 2021-12-10 00:00:00, pnl: 0.490000762939453
# Processing date: 2021-12-14 00:00:00, expiry: 2021-12-23 00:00:00
# Let iron condor expire: 2021-12-23 00:00:00, pnl: 0.5400003051757812
# Processing date: 2021-12-28 00:00:00, expiry: 2022-01-07 00:00:00
# Let iron condor expire: 2022-01-07 00:00:00, pnl: -0.24999999999999978
# Processing date: 2022-01-11 00:00:00, expiry: 2022-01-21 00:00:00
# Let iron condor expire: 2022-01-21 00:00:00, pnl: -1.9499992370605466
# Processing date: 2022-02-08 00:00:00, expiry: 2022-02-18 00:00:00
# Let iron condor expire: 2022-02-18 00:00:00, pnl: -0.44999877929687493
# Processing date: 2022-02-16 00:00:00, expiry: 2022-02-25 00:00:00
# Let iron condor expire: 2022-02-25 00:00:00, pnl: -0.09000152587890631
# Processing date: 2022-03-15 00:00:00, expiry: 2022-03-25 00:00:00
# Let iron condor expire: 2022-03-25 00:00:00, pnl: -0.19000000000000017
# Processing date: 2022-03-28 00:00:00, expiry: 2022-04-08 00:00:00
# Let iron condor expire: 2022-04-08 00:00:00, pnl: -0.7800006103515624
# Processing date: 2022-04-12 00:00:00, expiry: 2022-04-22 00:00:00
# Let iron condor expire: 2022-04-22 00:00:00, pnl: -0.3100018310546875
# Processing date: 2022-05-11 00:00:00, expiry: 2022-05-20 00:00:00
# Let iron condor expire: 2022-05-20 00:00:00, pnl: 0.5299981689453125
# Processing date: 2022-06-22 00:00:00, expiry: 2022-07-01 00:00:00
# Let iron condor expire: 2022-07-01 00:00:00, pnl: -0.009999160766601511
# Processing date: 2022-06-29 00:00:00, expiry: 2022-07-08 00:00:00
# Let iron condor expire: 2022-07-08 00:00:00, pnl: 0.6499981689453125
# Processing date: 2022-07-12 00:00:00, expiry: 2022-07-22 00:00:00
# Let iron condor expire: 2022-07-22 00:00:00, pnl: -0.08000000000000007
# Processing date: 2022-07-27 00:00:00, expiry: 2022-08-05 00:00:00
# Let iron condor expire: 2022-08-05 00:00:00, pnl: -0.19
# Processing date: 2022-08-10 00:00:00, expiry: 2022-08-19 00:00:00
# Let iron condor expire: 2022-08-19 00:00:00, pnl: 0.22000091552734372
# Processing date: 2022-08-17 00:00:00, expiry: 2022-08-26 00:00:00
# Let iron condor expire: 2022-08-26 00:00:00, pnl: -1.0299987792968748
# Processing date: 2022-10-12 00:00:00, expiry: 2022-10-21 00:00:00
# Let iron condor expire: 2022-10-21 00:00:00, pnl: -0.33999999999999986
# Processing date: 2022-11-09 00:00:00, expiry: 2022-11-18 00:00:00
# Let iron condor expire: 2022-11-18 00:00:00, pnl: -0.38999893188476553
# Processing date: 2022-11-30 00:00:00, expiry: 2022-12-09 00:00:00
# Let iron condor expire: 2022-12-09 00:00:00, pnl: -0.20000122070312498
# Processing date: 2022-12-14 00:00:00, expiry: 2022-12-23 00:00:00
# Let iron condor expire: 2022-12-23 00:00:00, pnl: -0.3400000000000001
# Processing date: 2022-12-21 00:00:00, expiry: 2022-12-30 00:00:00
# Let iron condor expire: 2022-12-30 00:00:00, pnl: 0.41999923706054687
# Processing date: 2023-01-11 00:00:00, expiry: 2023-01-20 00:00:00
# Let iron condor expire: 2023-01-20 00:00:00, pnl: 0.6899984741210937
# Processing date: 2023-02-01 00:00:00, expiry: 2023-02-10 00:00:00
# Let iron condor expire: 2023-02-10 00:00:00, pnl: 0.23999832153320313
# Processing date: 2023-03-01 00:00:00, expiry: 2023-03-10 00:00:00
# Let iron condor expire: 2023-03-10 00:00:00, pnl: -1.3200000000000003
# Processing date: 2023-03-27 00:00:00, expiry: 2023-04-06 00:00:00
# Let iron condor expire: 2023-04-06 00:00:00, pnl: 0.370000228881836
# Processing date: 2023-04-11 00:00:00, expiry: 2023-04-21 00:00:00
# Let iron condor expire: 2023-04-21 00:00:00, pnl: -0.13
# Processing date: 2023-05-17 00:00:00, expiry: 2023-05-26 00:00:00
# Let iron condor expire: 2023-05-26 00:00:00, pnl: 0.3599993896484375
# Processing date: 2023-05-31 00:00:00, expiry: 2023-06-09 00:00:00
# Let iron condor expire: 2023-06-09 00:00:00, pnl: -0.45999999999999996
# Processing date: 2023-06-13 00:00:00, expiry: 2023-06-23 00:00:00
# Let iron condor expire: 2023-06-23 00:00:00, pnl: 0.24000167846679688
# Processing date: 2023-06-21 00:00:00, expiry: 2023-06-30 00:00:00
# Let iron condor expire: 2023-06-30 00:00:00, pnl: -0.12999908447265626
# Processing date: 2023-06-28 00:00:00, expiry: 2023-07-07 00:00:00
# Let iron condor expire: 2023-07-07 00:00:00, pnl: -0.09000000000000008
# Processing date: 2023-07-19 00:00:00, expiry: 2023-07-28 00:00:00
# Let iron condor expire: 2023-07-28 00:00:00, pnl: 0.24999923706054683
# Processing date: 2023-08-02 00:00:00, expiry: 2023-08-11 00:00:00
# Let iron condor expire: 2023-08-11 00:00:00, pnl: 0.38999816894531253
# Processing date: 2023-08-30 00:00:00, expiry: 2023-09-08 00:00:00
# Expiry date 2023-09-08 00:00:00 not found; finding closest available date.
# Using adjusted expiry date: 2023-08-31 00:00:00
# Let iron condor expire: 2023-08-31 00:00:00, pnl: 0.2400010681152344
# Warning: Sharpe ratio is NaN, inf, or unreasonably high. Returning a large negative value.
# | 60        | -10.0     | -2.479    | 1.544     | 8.031     |
# =============================================================
# c:\Users\asus\Documents\GitHub\GARCH-X-Volatility-Modelling-with-Equity-Options-Trading\.venv\lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)

# %%
res = optimizer.res
res_df = pd.DataFrame(res)
res_df[res_df["target"] > 0]
# Out:
#       target                                             params
# 2   8.379217  {'lower_threshold': -2.883832775663601, 'upper...
# 3   1.235520  {'lower_threshold': -1.583854844407909, 'upper...
# 12  3.018235  {'lower_threshold': -2.349535309692987, 'upper...
# 15  3.871197  {'lower_threshold': -2.3353627482331243, 'uppe...
# 16  4.536969  {'lower_threshold': -2.811143280426914, 'upper...
# 17  5.765998  {'lower_threshold': -2.1939315682391376, 'uppe...
# 19  2.288534  {'lower_threshold': -2.9182789926026595, 'uppe...
# 26  0.870722  {'lower_threshold': -1.6388303077397899, 'uppe...
# 39  1.144795  {'lower_threshold': -2.8844159733507713, 'uppe...
# 50  1.412835  {'lower_threshold': -1.9828485962785503, 'uppe...
# 52  2.623258  {'lower_threshold': -1.9886552124310624, 'uppe...

# %%
res_df.iloc[26]["params"]
# Out:
# {'lower_threshold': -1.6388303077397899,
#  'upper_threshold': 1.707683403509774,
#  'window': 8.602963521116479}

# %% [markdown]
# # Optimisation Results

# %%
def objective_function(window, upper_threshold, lower_threshold):
    # Options data
    day_map = {0: "Monday", 1: "Tuesday", 2: "Wednesday", 3: "Thursday", 4: "Friday", 5: "Saturday", 6: "Sunday"}

    xle_options = pd.read_hdf("data/etf_options_data.hf5", key="XLE")
    xle_options = xle_options.set_index("date")
    xle_options["strike_price"] = xle_options["strike_price"] / 1000
    xle_filtered_options = xle_options.groupby("date").apply(lambda x: x.query("exdate == exdate.max()")).reset_index(level=0, drop=True)
    xle_filtered_options["day"] = xle_filtered_options.index.weekday.map(day_map)
    xle_filtered_options["ex_day"] = xle_filtered_options["exdate"].dt.weekday.map(day_map)

    # Setting time series data
    xle_pred = pd.read_csv("data/xle_pred7030_new.csv", parse_dates=True, index_col=0).rename(columns={"0": "Rolling Pred"})
    xle_iv = pd.read_csv("data/XLE_IV.csv", parse_dates=True, index_col=0)
    xle_vrp = (xle_iv["Average IV"] - xle_pred["Rolling Pred"]).dropna()

    xle_vrp_standardised = rolling_z_score(xle_vrp, window=int(window))

    xle_filtered_options["vrp"] = xle_vrp_standardised
    xle_time_series = pd.read_hdf("data/etf_series.hf5", key="XLE")
    xle_time_series["day"] = xle_time_series.index.weekday
    xle_time_series["vrp"] = xle_vrp_standardised
    xle_time_series["signal"] = np.where(xle_time_series["vrp"] > upper_threshold, 1, np.where(xle_time_series["vrp"] < lower_threshold, -1, 0))
    xle_time_series["action"] = np.where((xle_time_series["signal"] == 1)  & (xle_time_series.index.weekday != 4), 1, 
                                        np.where((xle_time_series["signal"] == -1) & (xle_time_series.index.weekday != 4), -1, 
                                                0))
    xle_time_series.dropna(inplace=True)
    xle_time_series

    xle_time_series = ensure_weekly_action(xle_time_series)
    xle_time_series["action"] = xle_time_series["action"].shift(-1)

    # Strategy backtesting
    ironcondor_tracker = {}

    for index, row in xle_time_series.iterrows():
        if row["action"] == 1:
            print(f"date: {index}")
            direction = "short"

            index_loc = xle_time_series.index.get_loc(index)

            current_spot_open = myround(xle_time_series.iloc[index_loc]["Open"], 0.5)

            daily_options = xle_filtered_options.loc[index]

            atm_put_strike = atm_call_strike = current_spot_open

            otm_put_strike = find_nearest_strike_delta(current_spot_open, index, 0.4, xle_filtered_options, "P")
            otm_call_strike = find_nearest_strike_delta(current_spot_open, index, -0.3, xle_filtered_options, "C")

            if otm_put_strike is None or otm_call_strike is None:
                continue
                
            else:
                print(f"date: {index}, current_spot_open: {current_spot_open}, OTM Put: {otm_put_strike}, ATM Put: {atm_put_strike}, ATM Call: {atm_call_strike}, OTM Call: {otm_call_strike}, \
                    left wing: {abs(otm_put_strike - atm_put_strike)}, right wing: {abs(atm_call_strike - otm_call_strike)}")
                strikes = {
                    "strike1": otm_put_strike,
                    "strike2": atm_put_strike,
                    "strike3": atm_call_strike,
                    "strike4": otm_call_strike
                }

                premiums = {
                    "premium1": xle_filtered_options.loc[
                        (xle_filtered_options.index == index) & 
                        (xle_filtered_options["strike_price"] == strikes["strike1"]) & 
                        (xle_filtered_options["cp_flag"] == 'P'), "best_offer"
                    ],
                    "premium2": xle_filtered_options.loc[
                        (xle_filtered_options.index == index) & 
                        (xle_filtered_options["strike_price"] == strikes["strike2"]) & 
                        (xle_filtered_options["cp_flag"] == 'P'), "best_bid"
                    ],
                    "premium3": xle_filtered_options.loc[
                        (xle_filtered_options.index == index) & 
                        (xle_filtered_options["strike_price"] == strikes["strike3"]) & 
                        (xle_filtered_options["cp_flag"] == 'C'), "best_bid"
                    ],
                    "premium4": xle_filtered_options.loc[
                        (xle_filtered_options.index == index) & 
                        (xle_filtered_options["strike_price"] == strikes["strike4"]) & 
                        (xle_filtered_options["cp_flag"] == 'C'), "best_offer"
                    ]
                }        

                # print(f"date: {index}, Premiums: {premiums}")

                expiry = xle_filtered_options.loc[index]["exdate"].max()

                ironcondor = IronCondor(direction=direction, strikes=strikes, premiums=premiums, expiry=expiry)
                ironcondor_tracker[index] = (ironcondor, ironcondor.target_profit().iloc[0], expiry)

    # Calculate the payoff of the Iron Condor strategy
    pnl_dict = {}

    for index, (ironcondor, target_profit, expiry) in ironcondor_tracker.items():
        print(f"Processing date: {index}, expiry: {expiry}")
        if ironcondor is not None:
            # Check if `expiry` date is present, or find the closest available date before `expiry`
            if expiry not in xle_time_series.index:
                print(f"Expiry date {expiry} not found; finding closest available date.")
                # Find the latest date before the `expiry` that is available in `xle_time_series`
                available_dates = xle_time_series.loc[:expiry].index
                if available_dates.empty:
                    print(f"No available data for range {index} to {expiry}, skipping this trade.")
                    continue
                expiry = available_dates[-1]  # Use the last available date before expiry
                print(f"Using adjusted expiry date: {expiry}")

            test_time_series = xle_time_series.loc[index:expiry + pd.Timedelta(days=1)]
            options_test_df = xle_filtered_options.loc[index:expiry + pd.Timedelta(days=1)]
            early_close = False

            for date, row in test_time_series.iterrows():
                if row["signal"] == -1:
                    
                    print(f"Closing on date: {date}")
                    ic_strikes = ironcondor.strikes
                    print(f"strike1: {ic_strikes['strike1']}, strike2: {ic_strikes['strike2']}, strike3: {ic_strikes['strike3']}, strike4: {ic_strikes['strike4']}")
                    try:
                        # Long put (buy to open, sell to close)
                        long_put_sellback = options_test_df.loc[date][
                            (options_test_df.loc[date]["cp_flag"] == 'P') & 
                            (options_test_df.loc[date]["strike_price"] == ic_strikes["strike1"])
                        ]["best_bid"].values[0]
                    except IndexError:
                        closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'P'] \
                            .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike1"]).abs()) \
                            .sort_values("distance").iloc[0]["strike_price"]
                        
                        # Use closest strike for long put (sell to close)
                        long_put_sellback = options_test_df.loc[date][
                            (options_test_df.loc[date]["cp_flag"] == 'P') & 
                            (options_test_df.loc[date]["strike_price"] == closest_strike)
                        ]["best_bid"].values[0]
                    print(f"Long put sellback: {long_put_sellback}")

                    try:
                        # Short put (sell to open, buy to close)
                        short_put_buyback = options_test_df.loc[date][
                            (options_test_df.loc[date]["cp_flag"] == 'P') & 
                            (options_test_df.loc[date]["strike_price"] == ic_strikes["strike2"])
                        ]["best_offer"].values[0]
                    except IndexError:
                        closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'P'] \
                            .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike2"]).abs()) \
                            .sort_values("distance").iloc[0]["strike_price"]
                        
                        # Use closest strike for short put (buy to close)
                        short_put_buyback = options_test_df.loc[date][
                            (options_test_df.loc[date]["cp_flag"] == 'P') & 
                            (options_test_df.loc[date]["strike_price"] == closest_strike)
                        ]["best_offer"].values[0]
                    print(f"Short put buyback: {short_put_buyback}")

                    try:
                        # Short call (sell to open, buy to close)
                        short_call_buyback = options_test_df.loc[date][
                            (options_test_df.loc[date]["cp_flag"] == 'C') & 
                            (options_test_df.loc[date]["strike_price"] == ic_strikes["strike3"])
                        ]["best_offer"].values[0]
                    except IndexError:
                        closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'C'] \
                            .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike3"]).abs()) \
                            .sort_values("distance").iloc[0]["strike_price"]
                        
                        # Use closest strike for short call (buy to close)
                        short_call_buyback = options_test_df.loc[date][
                            (options_test_df.loc[date]["cp_flag"] == 'C') & 
                            (options_test_df.loc[date]["strike_price"] == closest_strike)
                        ]["best_offer"].values[0]
                    print(f"Short call buyback: {short_call_buyback}")

                    try:
                        # Long call (buy to open, sell to close)
                        long_call_sellback = options_test_df.loc[date][
                            (options_test_df.loc[date]["cp_flag"] == 'C') & 
                            (options_test_df.loc[date]["strike_price"] == ic_strikes["strike4"])
                        ]["best_bid"].values[0]
                    except IndexError:
                        closest_strike = options_test_df.loc[date][options_test_df.loc[date]["cp_flag"] == 'C'] \
                            .assign(distance=lambda x: (x["strike_price"] - ic_strikes["strike4"]).abs()) \
                            .sort_values("distance").iloc[0]["strike_price"]
                        
                        # Use closest strike for long call (sell to close)
                        long_call_sellback = options_test_df.loc[date][
                            (options_test_df.loc[date]["cp_flag"] == 'C') & 
                            (options_test_df.loc[date]["strike_price"] == closest_strike)
                        ]["best_bid"].values[0]
                    print(f"Long call sellback: {long_call_sellback}")

                    # Now calculate the closing cost
                    if None not in [long_put_sellback, short_put_buyback, short_call_buyback, long_call_sellback]:
                        closing_cost = long_put_sellback - short_put_buyback - short_call_buyback + long_call_sellback
                    else:
                        closing_cost = None  # Handle missing values appropriately
                    print(f"Closing cost: {closing_cost}")

                    ironcondor.insert_spot(xle_time_series.loc[date]["Close"])
                    pnl_dict[index] = ironcondor.payoff() - closing_cost
                    print(f"Close iron condor early on date: {date} when signal is -1, pnl: {pnl_dict[index]}")
                    early_close = True
                    break
            if not early_close:
                try:
                    ironcondor.insert_spot(xle_time_series.loc[expiry]["Close"])
                    print(f"Let iron condor expire: {expiry}, pnl: {ironcondor.payoff()}")
                    pnl_dict[index] = ironcondor.payoff()    
                except KeyError:
                    try:
                        ironcondor.insert_spot(xle_time_series.loc[expiry + pd.Timedelta(days=1)]["Close"])
                        print(f"Let iron condor expire: {expiry}, pnl: {ironcondor.payoff()}")
                        pnl_dict[index] = ironcondor.payoff()           
                    except KeyError:
                        try:
                            ironcondor.insert_spot(xle_time_series.loc[expiry - pd.Timedelta(days=1)]["Close"])
                            print(f"Let iron condor expire: {expiry}, pnl: {ironcondor.payoff()}")
                            pnl_dict[index] = ironcondor.payoff()    
                        except KeyError:
                            print(f"Warning: Unable to insert spot for index {index} with expiry {expiry}, PnL set to 0")
                            pnl_dict[index] = 0
                            continue
                                
                
                # print(f"Let iron condor expire: {expiry}, pnl: {ironcondor.payoff()}")
                # pnl_dict[index] = ironcondor.payoff()         

    pnl_series = pd.DataFrame(pnl_dict.items(), columns=["Date", "PnL"]).set_index("Date").PnL
    return pnl_series

pnl_series = objective_function(8.60, 1.707683403509774, -1.6388303077397899)
# Out:
# date: 2016-12-23 00:00:00
# date: 2016-12-23 00:00:00, current_spot_open: 76.5, OTM Put: 72.0, ATM Put: 76.5, ATM Call: 76.5, OTM Call: 78.5,                     left wing: 4.5, right wing: 2.0
# date: 2017-02-15 00:00:00
# date: 2017-02-15 00:00:00, current_spot_open: 73.5, OTM Put: 71.5, ATM Put: 73.5, ATM Call: 73.5, OTM Call: 75.0,                     left wing: 2.0, right wing: 1.5
# date: 2017-03-07 00:00:00
# date: 2017-03-07 00:00:00, current_spot_open: 72.5, OTM Put: 70.5, ATM Put: 72.5, ATM Call: 72.5, OTM Call: 96.0,                     left wing: 2.0, right wing: 23.5
# date: 2017-05-16 00:00:00
# date: 2017-05-16 00:00:00, current_spot_open: 68.5, OTM Put: 66.0, ATM Put: 68.5, ATM Call: 68.5, OTM Call: 70.5,                     left wing: 2.5, right wing: 2.0
# date: 2017-05-23 00:00:00
# date: 2017-05-23 00:00:00, current_spot_open: 68.0, OTM Put: 64.5, ATM Put: 68.0, ATM Call: 68.0, OTM Call: 69.5,                     left wing: 3.5, right wing: 1.5
# date: 2017-07-25 00:00:00
# date: 2017-07-25 00:00:00, current_spot_open: 66.0, OTM Put: 64.0, ATM Put: 66.0, ATM Call: 66.0, OTM Call: 67.5,                     left wing: 2.0, right wing: 1.5
# date: 2017-09-01 00:00:00
# date: 2017-09-01 00:00:00, current_spot_open: 63.0, OTM Put: 60.5, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 64.5,                     left wing: 2.5, right wing: 1.5
# date: 2017-09-08 00:00:00
# date: 2017-09-08 00:00:00, current_spot_open: 65.0, OTM Put: 63.0, ATM Put: 65.0, ATM Call: 65.0, OTM Call: 73.5,                     left wing: 2.0, right wing: 8.5
# date: 2017-10-16 00:00:00
# date: 2017-10-16 00:00:00, current_spot_open: 68.5, OTM Put: 66.5, ATM Put: 68.5, ATM Call: 68.5, OTM Call: 70.0,                     left wing: 2.0, right wing: 1.5
# date: 2017-11-13 00:00:00
# date: 2017-11-13 00:00:00, current_spot_open: 69.5, OTM Put: 67.5, ATM Put: 69.5, ATM Call: 69.5, OTM Call: 71.0,                     left wing: 2.0, right wing: 1.5
# date: 2018-01-10 00:00:00
# date: 2018-01-10 00:00:00, current_spot_open: 75.5, OTM Put: 74.0, ATM Put: 75.5, ATM Call: 75.5, OTM Call: 77.0,                     left wing: 1.5, right wing: 1.5
# date: 2018-03-05 00:00:00
# date: 2018-03-05 00:00:00, current_spot_open: 66.5, OTM Put: 32.0, ATM Put: 66.5, ATM Call: 66.5, OTM Call: 68.5,                     left wing: 34.5, right wing: 2.0
# date: 2018-03-16 00:00:00
# date: 2018-03-16 00:00:00, current_spot_open: 67.0, OTM Put: 61.0, ATM Put: 67.0, ATM Call: 67.0, OTM Call: 68.5,                     left wing: 6.0, right wing: 1.5
# date: 2018-04-18 00:00:00
# date: 2018-04-18 00:00:00, current_spot_open: 73.0, OTM Put: 50.0, ATM Put: 73.0, ATM Call: 73.0, OTM Call: 75.0,                     left wing: 23.0, right wing: 2.0
# date: 2018-05-04 00:00:00
# date: 2018-05-04 00:00:00, current_spot_open: 73.5, OTM Put: 67.5, ATM Put: 73.5, ATM Call: 73.5, OTM Call: 75.5,                     left wing: 6.0, right wing: 2.0
# date: 2018-06-20 00:00:00
# date: 2018-06-20 00:00:00, current_spot_open: 75.0, OTM Put: 70.5, ATM Put: 75.0, ATM Call: 75.0, OTM Call: 77.0,                     left wing: 4.5, right wing: 2.0
# date: 2018-08-14 00:00:00
# date: 2018-08-14 00:00:00, current_spot_open: 75.0, OTM Put: 73.0, ATM Put: 75.0, ATM Call: 75.0, OTM Call: 77.0,                     left wing: 2.0, right wing: 2.0
# date: 2018-09-04 00:00:00
# date: 2018-09-04 00:00:00, current_spot_open: 75.0, OTM Put: 73.0, ATM Put: 75.0, ATM Call: 75.0, OTM Call: 77.5,                     left wing: 2.0, right wing: 2.5
# date: 2018-10-09 00:00:00
# date: 2018-10-09 00:00:00, current_spot_open: 77.5, OTM Put: 72.0, ATM Put: 77.5, ATM Call: 77.5, OTM Call: 79.5,                     left wing: 5.5, right wing: 2.0
# date: 2018-12-03 00:00:00
# date: 2018-12-03 00:00:00, current_spot_open: 67.5, OTM Put: 62.5, ATM Put: 67.5, ATM Call: 67.5, OTM Call: 70.0,                     left wing: 5.0, right wing: 2.5
# date: 2019-01-11 00:00:00
# date: 2019-01-11 00:00:00, current_spot_open: 62.0, OTM Put: 58.0, ATM Put: 62.0, ATM Call: 62.0, OTM Call: 64.0,                     left wing: 4.0, right wing: 2.0
# date: 2019-02-20 00:00:00
# date: 2019-02-20 00:00:00, current_spot_open: 66.0, OTM Put: 55.0, ATM Put: 66.0, ATM Call: 66.0, OTM Call: 67.5,                     left wing: 11.0, right wing: 1.5
# date: 2019-04-12 00:00:00
# date: 2019-04-12 00:00:00, current_spot_open: 68.5, OTM Put: 66.0, ATM Put: 68.5, ATM Call: 68.5, OTM Call: 71.5,                     left wing: 2.5, right wing: 3.0
# date: 2019-06-21 00:00:00
# date: 2019-06-21 00:00:00, current_spot_open: 63.0, OTM Put: 53.5, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 65.0,                     left wing: 9.5, right wing: 2.0
# date: 2019-07-05 00:00:00
# date: 2019-07-05 00:00:00, current_spot_open: 63.0, OTM Put: 59.5, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 64.5,                     left wing: 3.5, right wing: 1.5
# date: 2019-07-31 00:00:00
# date: 2019-07-31 00:00:00, current_spot_open: 63.0, OTM Put: 61.0, ATM Put: 63.0, ATM Call: 63.0, OTM Call: 64.5,                     left wing: 2.0, right wing: 1.5
# date: 2019-09-13 00:00:00
# date: 2019-09-13 00:00:00, current_spot_open: 61.0, OTM Put: 58.5, ATM Put: 61.0, ATM Call: 61.0, OTM Call: 62.5,                     left wing: 2.5, right wing: 1.5
# date: 2019-10-25 00:00:00
# date: 2019-10-25 00:00:00, current_spot_open: 59.0, OTM Put: 49.5, ATM Put: 59.0, ATM Call: 59.0, OTM Call: 60.5,                     left wing: 9.5, right wing: 1.5
# date: 2019-11-29 00:00:00
# date: 2019-11-29 00:00:00, current_spot_open: 59.0, OTM Put: 56.0, ATM Put: 59.0, ATM Call: 59.0, OTM Call: 61.0,                     left wing: 3.0, right wing: 2.0
# date: 2020-01-24 00:00:00
# date: 2020-01-24 00:00:00, current_spot_open: 57.0, OTM Put: 54.21, ATM Put: 57.0, ATM Call: 57.0, OTM Call: 58.71,                     left wing: 2.789999999999999, right wing: 1.7100000000000009
# date: 2020-02-21 00:00:00
# date: 2020-02-21 00:00:00, current_spot_open: 54.5, OTM Put: 51.5, ATM Put: 54.5, ATM Call: 54.5, OTM Call: 56.5,                     left wing: 3.0, right wing: 2.0
# date: 2020-03-06 00:00:00
# date: 2020-03-06 00:00:00, current_spot_open: 43.5, OTM Put: 36.21, ATM Put: 43.5, ATM Call: 43.5, OTM Call: 47.5,                     left wing: 7.289999999999999, right wing: 4.0
# date: 2020-05-20 00:00:00
# date: 2020-05-20 00:00:00, current_spot_open: 38.5, OTM Put: 26.5, ATM Put: 38.5, ATM Call: 38.5, OTM Call: 40.0,                     left wing: 12.0, right wing: 1.5
# date: 2020-05-22 00:00:00
# date: 2020-05-22 00:00:00, current_spot_open: 38.5, OTM Put: 33.5, ATM Put: 38.5, ATM Call: 38.5, OTM Call: 41.5,                     left wing: 5.0, right wing: 3.0
# date: 2020-06-23 00:00:00
# date: 2020-06-23 00:00:00, current_spot_open: 40.0, OTM Put: 37.0, ATM Put: 40.0, ATM Call: 40.0, OTM Call: 43.0,                     left wing: 3.0, right wing: 3.0
# date: 2020-07-06 00:00:00
# date: 2020-07-06 00:00:00, current_spot_open: 38.0, OTM Put: 34.5, ATM Put: 38.0, ATM Call: 38.0, OTM Call: 41.0,                     left wing: 3.5, right wing: 3.0
# date: 2020-07-27 00:00:00
# date: 2020-07-27 00:00:00, current_spot_open: 37.5, OTM Put: 34.0, ATM Put: 37.5, ATM Call: 37.5, OTM Call: 39.5,                     left wing: 3.5, right wing: 2.0
# date: 2020-09-02 00:00:00
# date: 2020-09-02 00:00:00, current_spot_open: 35.5, OTM Put: 33.0, ATM Put: 35.5, ATM Call: 35.5, OTM Call: 37.5,                     left wing: 2.5, right wing: 2.0
# date: 2020-09-04 00:00:00
# date: 2020-09-04 00:00:00, current_spot_open: 35.5, OTM Put: 32.5, ATM Put: 35.5, ATM Call: 35.5, OTM Call: 38.0,                     left wing: 3.0, right wing: 2.5
# date: 2020-09-22 00:00:00
# date: 2020-09-22 00:00:00, current_spot_open: 32.0, OTM Put: 29.0, ATM Put: 32.0, ATM Call: 32.0, OTM Call: 34.0,                     left wing: 3.0, right wing: 2.0
# date: 2020-10-22 00:00:00
# date: 2020-10-22 00:00:00, current_spot_open: 29.5, OTM Put: 24.0, ATM Put: 29.5, ATM Call: 29.5, OTM Call: 31.0,                     left wing: 5.5, right wing: 1.5
# date: 2020-10-30 00:00:00
# date: 2020-10-30 00:00:00, current_spot_open: 28.5, OTM Put: 22.5, ATM Put: 28.5, ATM Call: 28.5, OTM Call: 31.5,                     left wing: 6.0, right wing: 3.0
# date: 2020-12-09 00:00:00
# Error: 2020-12-09 00:00:00, P
# Error: 2020-12-09 00:00:00, C
# date: 2021-03-30 00:00:00
# date: 2021-03-30 00:00:00, current_spot_open: 49.5, OTM Put: 45.5, ATM Put: 49.5, ATM Call: 49.5, OTM Call: 52.0,                     left wing: 4.0, right wing: 2.5
# date: 2021-04-16 00:00:00
# date: 2021-04-16 00:00:00, current_spot_open: 49.0, OTM Put: 46.0, ATM Put: 49.0, ATM Call: 49.0, OTM Call: 52.0,                     left wing: 3.0, right wing: 3.0
# date: 2021-05-28 00:00:00
# date: 2021-05-28 00:00:00, current_spot_open: 52.5, OTM Put: 49.0, ATM Put: 52.5, ATM Call: 52.5, OTM Call: 54.5,                     left wing: 3.5, right wing: 2.0
# date: 2021-06-16 00:00:00
# date: 2021-06-16 00:00:00, current_spot_open: 56.0, OTM Put: 52.0, ATM Put: 56.0, ATM Call: 56.0, OTM Call: 59.0,                     left wing: 4.0, right wing: 3.0
# date: 2021-08-13 00:00:00
# date: 2021-08-13 00:00:00, current_spot_open: 50.0, OTM Put: 47.0, ATM Put: 50.0, ATM Call: 50.0, OTM Call: 52.5,                     left wing: 3.0, right wing: 2.5
# date: 2021-10-15 00:00:00
# date: 2021-10-15 00:00:00, current_spot_open: 57.5, OTM Put: 54.0, ATM Put: 57.5, ATM Call: 57.5, OTM Call: 60.0,                     left wing: 3.5, right wing: 2.5
# date: 2022-03-07 00:00:00
# date: 2022-03-07 00:00:00, current_spot_open: 76.0, OTM Put: 66.0, ATM Put: 76.0, ATM Call: 76.0, OTM Call: 81.0,                     left wing: 10.0, right wing: 5.0
# date: 2022-04-04 00:00:00
# date: 2022-04-04 00:00:00, current_spot_open: 77.5, OTM Put: 72.5, ATM Put: 77.5, ATM Call: 77.5, OTM Call: 81.0,                     left wing: 5.0, right wing: 3.5
# date: 2022-04-20 00:00:00
# date: 2022-04-20 00:00:00, current_spot_open: 80.5, OTM Put: 74.5, ATM Put: 80.5, ATM Call: 80.5, OTM Call: 84.0,                     left wing: 6.0, right wing: 3.5
# date: 2022-05-20 00:00:00
# date: 2022-05-20 00:00:00, current_spot_open: 82.5, OTM Put: 75.0, ATM Put: 82.5, ATM Call: 82.5, OTM Call: 88.0,                     left wing: 7.5, right wing: 5.5
# date: 2022-06-03 00:00:00
# Error: 2022-06-03 00:00:00, P
# Error: 2022-06-03 00:00:00, C
# date: 2022-07-08 00:00:00
# date: 2022-07-08 00:00:00, current_spot_open: 72.0, OTM Put: 65.0, ATM Put: 72.0, ATM Call: 72.0, OTM Call: 77.0,                     left wing: 7.0, right wing: 5.0
# date: 2022-07-22 00:00:00
# date: 2022-07-22 00:00:00, current_spot_open: 72.0, OTM Put: 65.0, ATM Put: 72.0, ATM Call: 72.0, OTM Call: 76.5,                     left wing: 7.0, right wing: 4.5
# date: 2022-08-17 00:00:00
# date: 2022-08-17 00:00:00, current_spot_open: 76.5, OTM Put: 50.0, ATM Put: 76.5, ATM Call: 76.5, OTM Call: 80.0,                     left wing: 26.5, right wing: 3.5
# date: 2022-11-18 00:00:00
# date: 2022-11-18 00:00:00, current_spot_open: 90.5, OTM Put: 68.0, ATM Put: 90.5, ATM Call: 90.5, OTM Call: 95.0,                     left wing: 22.5, right wing: 4.5
# date: 2022-11-25 00:00:00
# date: 2022-11-25 00:00:00, current_spot_open: 92.5, OTM Put: 85.0, ATM Put: 92.5, ATM Call: 92.5, OTM Call: 97.0,                     left wing: 7.5, right wing: 4.5
# date: 2023-03-31 00:00:00
# date: 2023-03-31 00:00:00, current_spot_open: 82.5, OTM Put: 75.0, ATM Put: 82.5, ATM Call: 82.5, OTM Call: 85.5,                     left wing: 7.5, right wing: 3.0
# date: 2023-05-15 00:00:00
# date: 2023-05-15 00:00:00, current_spot_open: 79.0, OTM Put: 73.0, ATM Put: 79.0, ATM Call: 79.0, OTM Call: 82.0,                     left wing: 6.0, right wing: 3.0
# date: 2023-06-13 00:00:00
# date: 2023-06-13 00:00:00, current_spot_open: 81.5, OTM Put: 78.5, ATM Put: 81.5, ATM Call: 81.5, OTM Call: 85.0,                     left wing: 3.0, right wing: 3.5
# date: 2023-07-03 00:00:00
# date: 2023-07-03 00:00:00, current_spot_open: 81.5, OTM Put: 78.0, ATM Put: 81.5, ATM Call: 81.5, OTM Call: 84.0,                     left wing: 3.5, right wing: 2.5
# date: 2023-07-26 00:00:00
# date: 2023-07-26 00:00:00, current_spot_open: 85.5, OTM Put: 50.0, ATM Put: 85.5, ATM Call: 85.5, OTM Call: 88.0,                     left wing: 35.5, right wing: 2.5
# date: 2023-08-07 00:00:00
# date: 2023-08-07 00:00:00, current_spot_open: 87.5, OTM Put: 83.5, ATM Put: 87.5, ATM Call: 87.5, OTM Call: 90.0,                     left wing: 4.0, right wing: 2.5
# date: 2023-08-30 00:00:00
# date: 2023-08-30 00:00:00, current_spot_open: 89.0, OTM Put: 85.5, ATM Put: 89.0, ATM Call: 89.0, OTM Call: 91.0,                     left wing: 3.5, right wing: 2.0
# Processing date: 2016-12-23 00:00:00, expiry: 2017-01-06 00:00:00
# Let iron condor expire: 2017-01-06 00:00:00, pnl: 0.39999938964843745
# Processing date: 2017-02-15 00:00:00, expiry: 2017-02-24 00:00:00
# Let iron condor expire: 2017-02-24 00:00:00, pnl: -1.03
# Processing date: 2017-03-07 00:00:00, expiry: 2017-03-17 00:00:00
# Let iron condor expire: 2017-03-17 00:00:00, pnl: -0.54
# Processing date: 2017-05-16 00:00:00, expiry: 2017-05-26 00:00:00
# Let iron condor expire: 2017-05-26 00:00:00, pnl: -0.5999993896484375
# Processing date: 2017-05-23 00:00:00, expiry: 2017-06-02 00:00:00
# Let iron condor expire: 2017-06-02 00:00:00, pnl: -1.680003662109375
# Processing date: 2017-07-25 00:00:00, expiry: 2017-08-04 00:00:00
# Closing on date: 2017-08-04 00:00:00
# strike1: 64.0, strike2: 66.0, strike3: 66.0, strike4: 67.5
# Long put sellback: 0.24
# Short put buyback: 0.89
# Short call buyback: 0.59
# Long call sellback: 0.13
# Closing cost: -1.1099999999999999
# Close iron condor early on date: 2017-08-04 00:00:00 when signal is -1, pnl: 1.7799993896484372
# Processing date: 2017-09-01 00:00:00, expiry: 2017-09-15 00:00:00
# Closing on date: 2017-09-15 00:00:00
# strike1: 60.5, strike2: 63.0, strike3: 63.0, strike4: 64.5
# Long put sellback: 0.0
# Short put buyback: 0.08
# Short call buyback: 2.91
# Long call sellback: 1.43
# Closing cost: -1.5600000000000003
# Close iron condor early on date: 2017-09-15 00:00:00 when signal is -1, pnl: 1.3700000000000003
# Processing date: 2017-09-08 00:00:00, expiry: 2017-09-22 00:00:00
# Closing on date: 2017-09-15 00:00:00
# strike1: 63.0, strike2: 65.0, strike3: 65.0, strike4: 73.5
# Long put sellback: 0.05
# Short put buyback: 0.35
# Short call buyback: 1.19
# Long call sellback: 0.0
# Closing cost: -1.49
# Close iron condor early on date: 2017-09-15 00:00:00 when signal is -1, pnl: 1.910003662109375
# Processing date: 2017-10-16 00:00:00, expiry: 2017-10-27 00:00:00
# Let iron condor expire: 2017-10-27 00:00:00, pnl: -0.31000366210937497
# Processing date: 2017-11-13 00:00:00, expiry: 2017-11-24 00:00:00
# Closing on date: 2017-11-16 00:00:00
# strike1: 67.5, strike2: 69.5, strike3: 69.5, strike4: 71.0
# Long put sellback: 0.74
# Short put buyback: 2.49
# Short call buyback: 0.03
# Long call sellback: 0.0
# Closing cost: -1.7800000000000002
# Close iron condor early on date: 2017-11-16 00:00:00 when signal is -1, pnl: 0.7500000000000002
# Processing date: 2018-01-10 00:00:00, expiry: 2018-01-19 00:00:00
# Let iron condor expire: 2018-01-19 00:00:00, pnl: -0.049997253417968734
# Processing date: 2018-03-05 00:00:00, expiry: 2018-03-16 00:00:00
# Let iron condor expire: 2018-03-16 00:00:00, pnl: 0.98000244140625
# Processing date: 2018-03-16 00:00:00, expiry: 2018-03-29 00:00:00
# Closing on date: 2018-03-29 00:00:00
# strike1: 61.0, strike2: 67.0, strike3: 67.0, strike4: 68.5
# Long put sellback: 0.01
# Short put buyback: 0.55
# Short call buyback: 1.08
# Long call sellback: 0.34
# Closing cost: -1.28
# Close iron condor early on date: 2018-03-29 00:00:00 when signal is -1, pnl: 2.089996337890625
# Processing date: 2018-04-18 00:00:00, expiry: 2018-04-27 00:00:00
# Let iron condor expire: 2018-04-27 00:00:00, pnl: 0.6600003051757812
# Processing date: 2018-05-04 00:00:00, expiry: 2018-05-18 00:00:00
# Let iron condor expire: 2018-05-18 00:00:00, pnl: -0.36999999999999966
# Processing date: 2018-06-20 00:00:00, expiry: 2018-06-29 00:00:00
# Let iron condor expire: 2018-06-29 00:00:00, pnl: 0.6499975585937501
# Processing date: 2018-08-14 00:00:00, expiry: 2018-08-24 00:00:00
# Let iron condor expire: 2018-08-24 00:00:00, pnl: 0.6700009155273436
# Processing date: 2018-09-04 00:00:00, expiry: 2018-09-14 00:00:00
# Let iron condor expire: 2018-09-14 00:00:00, pnl: 0.4600021362304687
# Processing date: 2018-10-09 00:00:00, expiry: 2018-10-19 00:00:00
# Closing on date: 2018-10-12 00:00:00
# strike1: 72.0, strike2: 77.5, strike3: 77.5, strike4: 79.5
# Long put sellback: 0.87
# Short put buyback: 4.55
# Short call buyback: 0.16
# Long call sellback: 0.03
# Closing cost: -3.81
# Close iron condor early on date: 2018-10-12 00:00:00 when signal is -1, pnl: 0.81
# Processing date: 2018-12-03 00:00:00, expiry: 2018-12-14 00:00:00
# Let iron condor expire: 2018-12-14 00:00:00, pnl: -3.1099999999999994
# Processing date: 2019-01-11 00:00:00, expiry: 2019-01-25 00:00:00
# Let iron condor expire: 2019-01-25 00:00:00, pnl: 0.7099996948242189
# Processing date: 2019-02-20 00:00:00, expiry: 2019-03-01 00:00:00
# Let iron condor expire: 2019-03-01 00:00:00, pnl: 0.7200030517578127
# Processing date: 2019-04-12 00:00:00, expiry: 2019-04-26 00:00:00
# Expiry date 2019-04-26 00:00:00 not found; finding closest available date.
# Using adjusted expiry date: 2019-04-25 00:00:00
# Closing on date: 2019-04-25 00:00:00
# strike1: 66.0, strike2: 68.5, strike3: 68.5, strike4: 71.5
# Long put sellback: 0.32
# Short put buyback: 1.6
# Short call buyback: 0.22
# Long call sellback: 0.0
# Closing cost: -1.5
# Close iron condor early on date: 2019-04-25 00:00:00 when signal is -1, pnl: 1.559996337890625
# Processing date: 2019-06-21 00:00:00, expiry: 2019-07-05 00:00:00
# Let iron condor expire: 2019-07-05 00:00:00, pnl: 1.4499998474121094
# Processing date: 2019-07-05 00:00:00, expiry: 2019-07-19 00:00:00
# Closing on date: 2019-07-19 00:00:00
# strike1: 59.5, strike2: 63.0, strike3: 63.0, strike4: 64.5
# Long put sellback: 0.1
# Short put buyback: 0.9
# Short call buyback: 0.78
# Long call sellback: 0.22
# Closing cost: -1.36
# Close iron condor early on date: 2019-07-19 00:00:00 when signal is -1, pnl: 2.319998321533203
# Processing date: 2019-07-31 00:00:00, expiry: 2019-08-09 00:00:00
# Let iron condor expire: 2019-08-09 00:00:00, pnl: -0.9300000000000002
# Processing date: 2019-09-13 00:00:00, expiry: 2019-09-27 00:00:00
# Closing on date: 2019-09-27 00:00:00
# strike1: 58.5, strike2: 61.0, strike3: 61.0, strike4: 62.5
# Long put sellback: 0.56
# Short put buyback: 1.75
# Short call buyback: 0.37
# Long call sellback: 0.08
# Closing cost: -1.48
# Close iron condor early on date: 2019-09-27 00:00:00 when signal is -1, pnl: 1.4100010681152344
# Processing date: 2019-10-25 00:00:00, expiry: 2019-11-08 00:00:00
# Let iron condor expire: 2019-11-08 00:00:00, pnl: -0.24000000000000005
# Processing date: 2019-11-29 00:00:00, expiry: 2019-12-13 00:00:00
# Let iron condor expire: 2019-12-13 00:00:00, pnl: 0.1099986267089843
# Processing date: 2020-01-24 00:00:00, expiry: 2020-02-07 00:00:00
# Closing on date: 2020-02-03 00:00:00
# strike1: 54.21, strike2: 57.0, strike3: 57.0, strike4: 58.71
# Long put sellback: 1.63
# Short put buyback: 4.35
# Short call buyback: 0.03
# Long call sellback: 0.0
# Closing cost: -2.7499999999999996
# Close iron condor early on date: 2020-02-03 00:00:00 when signal is -1, pnl: 1.2900000000000005
# Processing date: 2020-02-21 00:00:00, expiry: 2020-03-06 00:00:00
# Let iron condor expire: 2020-03-06 00:00:00, pnl: -1.4999999999999996
# Processing date: 2020-03-06 00:00:00, expiry: 2020-03-20 00:00:00
# Closing on date: 2020-03-10 00:00:00
# strike1: 36.21, strike2: 43.5, strike3: 43.5, strike4: 47.5
# Long put sellback: 2.38
# Short put buyback: 8.15
# Short call buyback: 0.14
# Long call sellback: 0.0
# Closing cost: -5.91
# Close iron condor early on date: 2020-03-10 00:00:00 when signal is -1, pnl: 1.6400000000000015
# Processing date: 2020-05-20 00:00:00, expiry: 2020-05-29 00:00:00
# Let iron condor expire: 2020-05-29 00:00:00, pnl: 1.150001678466797
# Processing date: 2020-05-22 00:00:00, expiry: 2020-06-05 00:00:00
# Let iron condor expire: 2020-06-05 00:00:00, pnl: -0.8900000000000006
# Processing date: 2020-06-23 00:00:00, expiry: 2020-07-02 00:00:00
# Let iron condor expire: 2020-07-02 00:00:00, pnl: -0.9199998474121094
# Processing date: 2020-07-06 00:00:00, expiry: 2020-07-17 00:00:00
# Let iron condor expire: 2020-07-17 00:00:00, pnl: 0.5799986267089844
# Processing date: 2020-07-27 00:00:00, expiry: 2020-08-07 00:00:00
# Let iron condor expire: 2020-08-07 00:00:00, pnl: 1.2000003051757813
# Processing date: 2020-09-02 00:00:00, expiry: 2020-09-11 00:00:00
# Let iron condor expire: 2020-09-11 00:00:00, pnl: -1.27
# Processing date: 2020-09-04 00:00:00, expiry: 2020-09-18 00:00:00
# Let iron condor expire: 2020-09-18 00:00:00, pnl: -0.2899993896484374
# Processing date: 2020-09-22 00:00:00, expiry: 2020-10-02 00:00:00
# Let iron condor expire: 2020-10-02 00:00:00, pnl: -1.3700005340576173
# Processing date: 2020-10-22 00:00:00, expiry: 2020-10-30 00:00:00
# Let iron condor expire: 2020-10-30 00:00:00, pnl: 0.30999931335449227
# Processing date: 2020-10-30 00:00:00, expiry: 2020-11-13 00:00:00
# Let iron condor expire: 2020-11-13 00:00:00, pnl: -0.9100000000000001
# Processing date: 2021-03-30 00:00:00, expiry: 2021-04-09 00:00:00
# Let iron condor expire: 2021-04-09 00:00:00, pnl: 0.39999862670898434
# Processing date: 2021-04-16 00:00:00, expiry: 2021-04-30 00:00:00
# Let iron condor expire: 2021-04-30 00:00:00, pnl: 1.3500006103515623
# Processing date: 2021-05-28 00:00:00, expiry: 2021-06-11 00:00:00
# Expiry date 2021-06-11 00:00:00 not found; finding closest available date.
# Using adjusted expiry date: 2021-06-10 00:00:00
# Let iron condor expire: 2021-06-10 00:00:00, pnl: -0.47
# Processing date: 2021-06-16 00:00:00, expiry: 2021-06-30 00:00:00
# Closing on date: 2021-06-21 00:00:00
# strike1: 52.0, strike2: 56.0, strike3: 56.0, strike4: 59.0
# Long put sellback: 0.4
# Short put buyback: 2.39
# Short call buyback: 0.46
# Long call sellback: 0.09
# Closing cost: -2.3600000000000003
# Close iron condor early on date: 2021-06-21 00:00:00 when signal is -1, pnl: 2.319999694824219
# Processing date: 2021-08-13 00:00:00, expiry: 2021-08-27 00:00:00
# Closing on date: 2021-08-20 00:00:00
# strike1: 47.0, strike2: 50.0, strike3: 50.0, strike4: 52.5
# Long put sellback: 1.63
# Short put buyback: 4.25
# Short call buyback: 0.07
# Long call sellback: 0.01
# Closing cost: -2.68
# Close iron condor early on date: 2021-08-20 00:00:00 when signal is -1, pnl: 1.2300000000000004
# Processing date: 2021-10-15 00:00:00, expiry: 2021-10-29 00:00:00
# Closing on date: 2021-10-28 00:00:00
# strike1: 54.0, strike2: 57.5, strike3: 57.5, strike4: 60.0
# Long put sellback: 0.09
# Short put buyback: 0.86
# Short call buyback: 1.21
# Long call sellback: 0.29
# Closing cost: -1.69
# Close iron condor early on date: 2021-10-28 00:00:00 when signal is -1, pnl: 3.0600015258789064
# Processing date: 2022-03-07 00:00:00, expiry: 2022-03-18 00:00:00
# Closing on date: 2022-03-11 00:00:00
# strike1: 66.0, strike2: 76.0, strike3: 76.0, strike4: 81.0
# Long put sellback: 0.15
# Short put buyback: 2.54
# Short call buyback: 2.85
# Long call sellback: 0.92
# Closing cost: -4.32
# Close iron condor early on date: 2022-03-11 00:00:00 when signal is -1, pnl: 7.430001525878906
# Processing date: 2022-04-04 00:00:00, expiry: 2022-04-14 00:00:00
# Closing on date: 2022-04-12 00:00:00
# strike1: 72.5, strike2: 77.5, strike3: 77.5, strike4: 81.0
# Long put sellback: 0.17
# Short put buyback: 1.22
# Short call buyback: 2.17
# Long call sellback: 0.62
# Closing cost: -2.5999999999999996
# Close iron condor early on date: 2022-04-12 00:00:00 when signal is -1, pnl: 4.1200018310546875
# Processing date: 2022-04-20 00:00:00, expiry: 2022-04-29 00:00:00
# Closing on date: 2022-04-26 00:00:00
# strike1: 74.5, strike2: 80.5, strike3: 80.5, strike4: 84.0
# Long put sellback: 2.45
# Short put buyback: 7.05
# Short call buyback: 0.31
# Long call sellback: 0.07
# Closing cost: -4.839999999999999
# Close iron condor early on date: 2022-04-26 00:00:00 when signal is -1, pnl: 1.3299999999999983
# Processing date: 2022-05-20 00:00:00, expiry: 2022-06-03 00:00:00
# Let iron condor expire: 2022-06-03 00:00:00, pnl: -1.9500000000000002
# Processing date: 2022-07-08 00:00:00, expiry: 2022-07-22 00:00:00
# Let iron condor expire: 2022-07-22 00:00:00, pnl: 2.7300015258789063
# Processing date: 2022-07-22 00:00:00, expiry: 2022-08-05 00:00:00
# Closing on date: 2022-08-05 00:00:00
# strike1: 65.0, strike2: 72.0, strike3: 72.0, strike4: 76.5
# Long put sellback: 0.21
# Short put buyback: 1.52
# Short call buyback: 2.67
# Long call sellback: 0.7
# Closing cost: -3.2800000000000002
# Close iron condor early on date: 2022-08-05 00:00:00 when signal is -1, pnl: 5.6699981689453125
# Processing date: 2022-08-17 00:00:00, expiry: 2022-08-26 00:00:00
# Let iron condor expire: 2022-08-26 00:00:00, pnl: -0.8900000000000006
# Processing date: 2022-11-18 00:00:00, expiry: 2022-12-02 00:00:00
# Let iron condor expire: 2022-12-02 00:00:00, pnl: 3.33999755859375
# Processing date: 2022-11-25 00:00:00, expiry: 2022-12-09 00:00:00
# Let iron condor expire: 2022-12-09 00:00:00, pnl: -4.120000000000001
# Processing date: 2023-03-31 00:00:00, expiry: 2023-04-14 00:00:00
# Let iron condor expire: 2023-04-14 00:00:00, pnl: -0.45999999999999996
# Processing date: 2023-05-15 00:00:00, expiry: 2023-05-26 00:00:00
# Let iron condor expire: 2023-05-26 00:00:00, pnl: 2.0199966430664062
# Processing date: 2023-06-13 00:00:00, expiry: 2023-06-23 00:00:00
# Let iron condor expire: 2023-06-23 00:00:00, pnl: -1.04
# Processing date: 2023-07-03 00:00:00, expiry: 2023-07-14 00:00:00
# Let iron condor expire: 2023-07-14 00:00:00, pnl: 1.5499969482421876
# Processing date: 2023-07-26 00:00:00, expiry: 2023-08-04 00:00:00
# Let iron condor expire: 2023-08-04 00:00:00, pnl: 0.39000183105468744
# Processing date: 2023-08-07 00:00:00, expiry: 2023-08-18 00:00:00
# Closing on date: 2023-08-16 00:00:00
# strike1: 83.5, strike2: 87.5, strike3: 87.5, strike4: 90.0
# Long put sellback: 0.26
# Short put buyback: 1.47
# Short call buyback: 1.07
# Long call sellback: 0.28
# Closing cost: -2.0
# Close iron condor early on date: 2023-08-16 00:00:00 when signal is -1, pnl: 3.310001525878906
# Processing date: 2023-08-30 00:00:00, expiry: 2023-09-08 00:00:00
# Expiry date 2023-09-08 00:00:00 not found; finding closest available date.
# Using adjusted expiry date: 2023-08-31 00:00:00
# Let iron condor expire: 2023-08-31 00:00:00, pnl: 1.4099981689453125

# %%
pnl_series.cumsum().plot()
# Out:
# <Axes: xlabel='Date'>
