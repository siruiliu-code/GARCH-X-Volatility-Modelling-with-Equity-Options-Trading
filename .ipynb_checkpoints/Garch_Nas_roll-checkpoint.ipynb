# %%
#!pip install arch

# %%
from arch import arch_model
import pandas as pd
import wrds
import numpy as np
import yfinance as yf

# %%
nasbramlidb =\
(
    wrds
    .Connection()
)
# Out:
# Enter your WRDS username [nasruddinislambinramli]:nasbramli
# Enter your password:········
# WRDS recommends setting up a .pgpass file.
# Create .pgpass file now [y/n]?: y
# Created .pgpass file successfully.
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done

# %%
fama_french_query =\
(
    """
    SELECT date, mktrf, smb, hml, rf 
    FROM ff.factors_monthly
    WHERE date >= '2000-01-01' AND date < '2024-01-01'
    """
)

# %%
ff_df =\
(
    db
    .raw_sql(fama_french_query)
)

# %%
(
    ff_df
    .to_csv('fama_french.csv', index = False)
)

# %%
fama_french =\
(
    pd
    .read_csv('fama_french.csv')
)

# %%
fama_french
# Out:
#            date   mktrf     smb     hml      rf
# 0    2000-01-01 -0.0474  0.0577 -0.0188  0.0041
# 1    2000-02-01  0.0245  0.2136 -0.0959  0.0043
# 2    2000-03-01  0.0520 -0.1720  0.0813  0.0047
# 3    2000-04-01 -0.0640 -0.0668  0.0726  0.0046
# 4    2000-05-01 -0.0442 -0.0605  0.0475  0.0050
# ..          ...     ...     ...     ...     ...
# 283  2023-08-01 -0.0239 -0.0320 -0.0108  0.0045
# 284  2023-09-01 -0.0524 -0.0249  0.0145  0.0043
# 285  2023-10-01 -0.0318 -0.0388  0.0019  0.0047
# 286  2023-11-01  0.0883 -0.0003  0.0166  0.0044
# 287  2023-12-01  0.0487  0.0636  0.0492  0.0043
#
# [288 rows x 5 columns]

# %%
fama_french["Date"]=\
(
    fama_french
    .date
    .apply(lambda x: str(x)
          )
)

fama_french["Date"]=\
(
    pd
    .to_datetime(fama_french.Date,
                 format="%Y-%m-%d"
                )
)

fama_french =\
(
    fama_french
    .set_index("Date", inplace = False)
)

# %%
fama_french =\
(
    fama_french
    .drop(columns=['date'])
)

# %%
fama_french
# Out:
#              mktrf     smb     hml      rf
# Date
# 2000-01-01 -0.0474  0.0577 -0.0188  0.0041
# 2000-02-01  0.0245  0.2136 -0.0959  0.0043
# 2000-03-01  0.0520 -0.1720  0.0813  0.0047
# 2000-04-01 -0.0640 -0.0668  0.0726  0.0046
# 2000-05-01 -0.0442 -0.0605  0.0475  0.0050
# ...            ...     ...     ...     ...
# 2023-08-01 -0.0239 -0.0320 -0.0108  0.0045
# 2023-09-01 -0.0524 -0.0249  0.0145  0.0043
# 2023-10-01 -0.0318 -0.0388  0.0019  0.0047
# 2023-11-01  0.0883 -0.0003  0.0166  0.0044
# 2023-12-01  0.0487  0.0636  0.0492  0.0043
#
# [288 rows x 4 columns]

# %%
fama_french =\
(
    fama_french[['smb', 'hml']]
)

# %%
fama_french
# Out:
#                smb     hml
# Date
# 2000-01-01  0.0577 -0.0188
# 2000-02-01  0.2136 -0.0959
# 2000-03-01 -0.1720  0.0813
# 2000-04-01 -0.0668  0.0726
# 2000-05-01 -0.0605  0.0475
# ...            ...     ...
# 2023-08-01 -0.0320 -0.0108
# 2023-09-01 -0.0249  0.0145
# 2023-10-01 -0.0388  0.0019
# 2023-11-01 -0.0003  0.0166
# 2023-12-01  0.0636  0.0492
#
# [288 rows x 2 columns]

# %%
file_path =\
(
    'all_tickers_time_series.hf5'
)

with pd.HDFStore(file_path, 'r') as hdf_file:
    keys =\
    (
        hdf_file.keys()
    )

# %%
russell = {}

for key in keys:
    
    data =\
    (
        pd
        .read_hdf('all_tickers_time_series.hf5', 
                  key=key)
    )
    
    if isinstance(data, pd.Series):
        
        data =\
        (
            data
            .to_frame()
        )
        
    data =\
    (
        data
        .drop_duplicates()
    )
    
    data =\
    (
        data
        .dropna()
    )
    
    if isinstance(data, pd.DataFrame) and 'date' in data.columns:
        data['Date'] =\
        (
            pd
            .to_datetime(data['date'], 
                         format="%Y-%m-%d")
        )
        
        data =\
        (
            data
            .drop(columns=['date'])
        )
        
        data =\
        (
            data
            .set_index('Date')
        )
    
    
    russell[key] = data

# %%
stock_data = {}

# %%
for ticker, data in russell.items():

    df =\
    (
        pd
        .DataFrame(data)
    )

    print(f"Columns for {ticker}: {df.columns.tolist()}")
    
    if 'prc' in df.columns:
        
        df['returns'] =\
        (
            np.log(df['prc']
                   /
                   df['prc'].shift(1)
                  )
        )
        
        df['r_vol'] =\
        (
            df['returns']
            .rolling(window = 252)
            .std()
            *
            np
            .sqrt
            (252)
        )
        
        
        stock_data[ticker] = df
    else:
        print(f"'prc' column not found for {ticker}. Available columns: {df.columns.tolist()}")
# Out:
# Columns for /A: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AA: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AAL: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AAON: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AAP: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AAPL: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ABBV: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ABNB: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ABT: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ACGL: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ACHC: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ACI: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ACM: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ACN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ADBE: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ADC: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ADI: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ADM: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ADP: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ADSK: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ADT: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AEE: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AEP: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AES: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AFG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AFL: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AFRM: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AGCO: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AGNC: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AGO: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AGR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AIG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AIZ: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AJG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AKAM: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AL: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ALAB: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ALB: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ALGM: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ALGN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ALK: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ALL: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ALLE: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ALLY: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ALNY: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ALSN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AM: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AMAT: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AMCR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AMD: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AME: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AMED: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AMG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AMGN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AMH: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AMKR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AMP: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AMT: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AMZN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ANET: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ANSS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AON: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AOS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /APA: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /APD: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /APG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /APH: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /APLS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /APO: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /APP: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /APPF: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /APTV: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ARE: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ARES: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ARMK: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ARW: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ASH: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ATI: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ATO: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ATR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AVB: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AVGO: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AVT: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AVTR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AVY: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AWI: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AWK: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AXON: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AXP: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AXS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AXTA: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AYI: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AZEK: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AZO: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AZPN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /AZTA: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BA: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BAC: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BAH: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BALL: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BAX: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BBWI: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BBY: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BC: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BDX: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BEN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BEPC: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BERY: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BFAM: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BHF: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BIIB: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BILL: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BIO: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BIRK: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BJ: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BK: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BKNG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BKR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BLD: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BLDR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BLK: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BMRN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BMY: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BOKF: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BPOP: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BRBR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BRKR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BRO: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BROS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BRX: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BSX: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BSY: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BURL: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BWA: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BWXT: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BX: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BXP: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /BYD: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /C: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CACC: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CACI: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CAG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CAH: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CAR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CARR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CART: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CASY: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CAT: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CAVA: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CB: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CBOE: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CBRE: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CBSH: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CC: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CCCS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CCI: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CCK: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CCL: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CDNS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CDW: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CE: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CEG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CELH: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CERT: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CF: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CFG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CFLT: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CFR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CGNX: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CHD: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CHDN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CHE: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CHH: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CHK: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CHRD: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CHRW: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CHTR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CI: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CIEN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CINF: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CIVI: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CL: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CLF: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CLH: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CLVT: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CLX: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CMA: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CMCSA: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CME: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CMG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CMI: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CMS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CNA: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CNC: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CNH: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CNM: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CNP: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CNXC: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /COF: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /COHR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /COIN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /COKE: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /COLB: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /COLD: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /COLM: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /COO: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /COP: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /COR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /COST: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /COTY: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CPB: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CPNG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CPRI: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CPRT: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CPT: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CRBG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CRH: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CRI: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CRL: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CRM: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CROX: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CRUS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CRWD: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CSCO: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CSGP: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CSL: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CSX: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CTAS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CTLT: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CTRA: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CTSH: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CTVA: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CUBE: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CUZ: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CVNA: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CVS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CVX: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CW: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CWEN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CXT: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /CZR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /D: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DAL: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DAR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DASH: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DAY: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DBX: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DCI: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DD: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DDOG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DDS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DE: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DECK: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DELL: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DFS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DGX: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DHI: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DHR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DINO: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DIS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DJT: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DKNG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DKS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DLB: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DLR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DLTR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DNB: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DOC: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DOCS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DOCU: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DOV: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DOW: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DOX: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DPZ: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DRI: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DT: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DTE: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DTM: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DUK: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DUOL: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DV: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DVA: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DVN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DXC: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /DXCM: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EA: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EBAY: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ECL: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ED: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EEFT: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EFX: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EGP: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EHC: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EIX: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EL: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ELAN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ELF: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ELS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ELV: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EME: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EMN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EMR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ENOV: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ENPH: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ENTG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EOG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EPAM: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EPR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EQH: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EQIX: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EQR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EQT: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ES: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ESAB: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ESI: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ESS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ESTC: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ETN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ETR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /ETSY: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EVR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EVRG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EW: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EWBC: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EXAS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EXC: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EXEL: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EXP: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EXPD: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EXPE: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /EXR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /F: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FAF: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FANG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FAST: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FBIN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FCN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FCNCA: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FCX: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FDS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FDX: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FE: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FERG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FFIV: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FHB: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FHN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FI: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FICO: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FIS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FITB: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FIVE: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FIVN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FIX: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FLO: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FLS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FMC: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FNB: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FND: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FNF: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FOUR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FOX: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FOXA: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FRPT: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FRT: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FSLR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FTI: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FTNT: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FTRE: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FTV: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FWONA: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FWONK: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /FYBR: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /G: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GAP: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GD: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GDDY: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GE: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GEHC: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GEN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GEV: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GFS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GGG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GILD: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GIS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GL: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GLOB: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GLPI: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GLW: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GM: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GME: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GMED: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GNRC: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GNTX: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GO: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GOOG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GOOGL: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GPC: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GPK: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GPN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GRMN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GTES: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GTLB: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GWRE: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GWW: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /GXO: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /H: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /HAL: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /HAS: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /HAYW: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /HBAN: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /HCA: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /HCP: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /HD: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /HEI: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /HES: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /HHH: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /HIG: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /HII: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /HIW: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /HLI: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# Columns for /HLT: ['ticker', 'openprc', 'askhi', 'bidlo', 'prc', 'vol', 'dlstdt', 'dlstcd', 'nextdt', 'dlprc']
# ...
# Columns for /BLK/meta/values_block_0/meta: [0]
# 'prc' column not found for /BLK/meta/values_block_0/meta. Available columns: [0]
# Columns for /BLDR/meta/values_block_0/meta: [0]
# 'prc' column not found for /BLDR/meta/values_block_0/meta. Available columns: [0]
# Columns for /BLD/meta/values_block_0/meta: [0]
# 'prc' column not found for /BLD/meta/values_block_0/meta. Available columns: [0]
# Columns for /BKR/meta/values_block_0/meta: [0]
# 'prc' column not found for /BKR/meta/values_block_0/meta. Available columns: [0]
# Columns for /BKNG/meta/values_block_0/meta: [0]
# 'prc' column not found for /BKNG/meta/values_block_0/meta. Available columns: [0]
# Columns for /BK/meta/values_block_0/meta: [0]
# 'prc' column not found for /BK/meta/values_block_0/meta. Available columns: [0]
# Columns for /BJ/meta/values_block_0/meta: [0]
# 'prc' column not found for /BJ/meta/values_block_0/meta. Available columns: [0]
# Columns for /BIRK/meta/values_block_0/meta: [0]
# 'prc' column not found for /BIRK/meta/values_block_0/meta. Available columns: [0]
# Columns for /BIO/meta/values_block_0/meta: [0]
# 'prc' column not found for /BIO/meta/values_block_0/meta. Available columns: [0]
# Columns for /BILL/meta/values_block_0/meta: [0]
# 'prc' column not found for /BILL/meta/values_block_0/meta. Available columns: [0]
# Columns for /BIIB/meta/values_block_0/meta: [0]
# 'prc' column not found for /BIIB/meta/values_block_0/meta. Available columns: [0]
# Columns for /BHF/meta/values_block_0/meta: [0]
# 'prc' column not found for /BHF/meta/values_block_0/meta. Available columns: [0]
# Columns for /BG/meta/values_block_0/meta: [0]
# 'prc' column not found for /BG/meta/values_block_0/meta. Available columns: [0]
# Columns for /BFAM/meta/values_block_0/meta: [0]
# 'prc' column not found for /BFAM/meta/values_block_0/meta. Available columns: [0]
# Columns for /BERY/meta/values_block_0/meta: [0]
# 'prc' column not found for /BERY/meta/values_block_0/meta. Available columns: [0]
# Columns for /BEPC/meta/values_block_0/meta: [0]
# 'prc' column not found for /BEPC/meta/values_block_0/meta. Available columns: [0]
# Columns for /BEN/meta/values_block_0/meta: [0]
# 'prc' column not found for /BEN/meta/values_block_0/meta. Available columns: [0]
# Columns for /BDX/meta/values_block_0/meta: [0]
# 'prc' column not found for /BDX/meta/values_block_0/meta. Available columns: [0]
# Columns for /BC/meta/values_block_0/meta: [0]
# 'prc' column not found for /BC/meta/values_block_0/meta. Available columns: [0]
# Columns for /BBY/meta/values_block_0/meta: [0]
# 'prc' column not found for /BBY/meta/values_block_0/meta. Available columns: [0]
# Columns for /BBWI/meta/values_block_0/meta: [0]
# 'prc' column not found for /BBWI/meta/values_block_0/meta. Available columns: [0]
# Columns for /BAX/meta/values_block_0/meta: [0]
# 'prc' column not found for /BAX/meta/values_block_0/meta. Available columns: [0]
# Columns for /BALL/meta/values_block_0/meta: [0]
# 'prc' column not found for /BALL/meta/values_block_0/meta. Available columns: [0]
# Columns for /BAH/meta/values_block_0/meta: [0]
# 'prc' column not found for /BAH/meta/values_block_0/meta. Available columns: [0]
# Columns for /BAC/meta/values_block_0/meta: [0]
# 'prc' column not found for /BAC/meta/values_block_0/meta. Available columns: [0]
# Columns for /BA/meta/values_block_0/meta: [0]
# 'prc' column not found for /BA/meta/values_block_0/meta. Available columns: [0]
# Columns for /AZTA/meta/values_block_0/meta: [0]
# 'prc' column not found for /AZTA/meta/values_block_0/meta. Available columns: [0]
# Columns for /AZPN/meta/values_block_0/meta: [0]
# 'prc' column not found for /AZPN/meta/values_block_0/meta. Available columns: [0]
# Columns for /AZO/meta/values_block_0/meta: [0]
# 'prc' column not found for /AZO/meta/values_block_0/meta. Available columns: [0]
# Columns for /AZEK/meta/values_block_0/meta: [0]
# 'prc' column not found for /AZEK/meta/values_block_0/meta. Available columns: [0]
# Columns for /AYI/meta/values_block_0/meta: [0]
# 'prc' column not found for /AYI/meta/values_block_0/meta. Available columns: [0]
# Columns for /AXTA/meta/values_block_0/meta: [0]
# 'prc' column not found for /AXTA/meta/values_block_0/meta. Available columns: [0]
# Columns for /AXS/meta/values_block_0/meta: [0]
# 'prc' column not found for /AXS/meta/values_block_0/meta. Available columns: [0]
# Columns for /AXP/meta/values_block_0/meta: [0]
# 'prc' column not found for /AXP/meta/values_block_0/meta. Available columns: [0]
# Columns for /AXON/meta/values_block_0/meta: [0]
# 'prc' column not found for /AXON/meta/values_block_0/meta. Available columns: [0]
# Columns for /AWK/meta/values_block_0/meta: [0]
# 'prc' column not found for /AWK/meta/values_block_0/meta. Available columns: [0]
# Columns for /AWI/meta/values_block_0/meta: [0]
# 'prc' column not found for /AWI/meta/values_block_0/meta. Available columns: [0]
# Columns for /AVY/meta/values_block_0/meta: [0]
# 'prc' column not found for /AVY/meta/values_block_0/meta. Available columns: [0]
# Columns for /AVTR/meta/values_block_0/meta: [0]
# 'prc' column not found for /AVTR/meta/values_block_0/meta. Available columns: [0]
# Columns for /AVT/meta/values_block_0/meta: [0]
# 'prc' column not found for /AVT/meta/values_block_0/meta. Available columns: [0]
# Columns for /AVGO/meta/values_block_0/meta: [0]
# 'prc' column not found for /AVGO/meta/values_block_0/meta. Available columns: [0]
# Columns for /AVB/meta/values_block_0/meta: [0]
# 'prc' column not found for /AVB/meta/values_block_0/meta. Available columns: [0]
# Columns for /ATR/meta/values_block_0/meta: [0]
# 'prc' column not found for /ATR/meta/values_block_0/meta. Available columns: [0]
# Columns for /ATO/meta/values_block_0/meta: [0]
# 'prc' column not found for /ATO/meta/values_block_0/meta. Available columns: [0]
# Columns for /ATI/meta/values_block_0/meta: [0]
# 'prc' column not found for /ATI/meta/values_block_0/meta. Available columns: [0]
# Columns for /ASH/meta/values_block_0/meta: [0]
# 'prc' column not found for /ASH/meta/values_block_0/meta. Available columns: [0]
# Columns for /ARW/meta/values_block_0/meta: [0]
# 'prc' column not found for /ARW/meta/values_block_0/meta. Available columns: [0]
# Columns for /ARMK/meta/values_block_0/meta: [0]
# 'prc' column not found for /ARMK/meta/values_block_0/meta. Available columns: [0]
# Columns for /ARES/meta/values_block_0/meta: [0]
# 'prc' column not found for /ARES/meta/values_block_0/meta. Available columns: [0]
# Columns for /ARE/meta/values_block_0/meta: [0]
# 'prc' column not found for /ARE/meta/values_block_0/meta. Available columns: [0]
# Columns for /AR/meta/values_block_0/meta: [0]
# 'prc' column not found for /AR/meta/values_block_0/meta. Available columns: [0]
# Columns for /APTV/meta/values_block_0/meta: [0]
# 'prc' column not found for /APTV/meta/values_block_0/meta. Available columns: [0]
# Columns for /APPF/meta/values_block_0/meta: [0]
# 'prc' column not found for /APPF/meta/values_block_0/meta. Available columns: [0]
# Columns for /APP/meta/values_block_0/meta: [0]
# 'prc' column not found for /APP/meta/values_block_0/meta. Available columns: [0]
# Columns for /APO/meta/values_block_0/meta: [0]
# 'prc' column not found for /APO/meta/values_block_0/meta. Available columns: [0]
# Columns for /APLS/meta/values_block_0/meta: [0]
# 'prc' column not found for /APLS/meta/values_block_0/meta. Available columns: [0]
# Columns for /APH/meta/values_block_0/meta: [0]
# 'prc' column not found for /APH/meta/values_block_0/meta. Available columns: [0]
# Columns for /APG/meta/values_block_0/meta: [0]
# 'prc' column not found for /APG/meta/values_block_0/meta. Available columns: [0]
# Columns for /APD/meta/values_block_0/meta: [0]
# 'prc' column not found for /APD/meta/values_block_0/meta. Available columns: [0]
# Columns for /APA/meta/values_block_0/meta: [0]
# 'prc' column not found for /APA/meta/values_block_0/meta. Available columns: [0]
# Columns for /AOS/meta/values_block_0/meta: [0]
# 'prc' column not found for /AOS/meta/values_block_0/meta. Available columns: [0]
# Columns for /AON/meta/values_block_0/meta: [0]
# 'prc' column not found for /AON/meta/values_block_0/meta. Available columns: [0]
# Columns for /ANSS/meta/values_block_0/meta: [0]
# 'prc' column not found for /ANSS/meta/values_block_0/meta. Available columns: [0]
# Columns for /ANET/meta/values_block_0/meta: [0]
# 'prc' column not found for /ANET/meta/values_block_0/meta. Available columns: [0]
# Columns for /AN/meta/values_block_0/meta: [0]
# 'prc' column not found for /AN/meta/values_block_0/meta. Available columns: [0]
# Columns for /AMZN/meta/values_block_0/meta: [0]
# 'prc' column not found for /AMZN/meta/values_block_0/meta. Available columns: [0]
# Columns for /AMT/meta/values_block_0/meta: [0]
# 'prc' column not found for /AMT/meta/values_block_0/meta. Available columns: [0]
# Columns for /AMP/meta/values_block_0/meta: [0]
# 'prc' column not found for /AMP/meta/values_block_0/meta. Available columns: [0]
# Columns for /AMKR/meta/values_block_0/meta: [0]
# 'prc' column not found for /AMKR/meta/values_block_0/meta. Available columns: [0]
# Columns for /AMH/meta/values_block_0/meta: [0]
# 'prc' column not found for /AMH/meta/values_block_0/meta. Available columns: [0]
# Columns for /AMGN/meta/values_block_0/meta: [0]
# 'prc' column not found for /AMGN/meta/values_block_0/meta. Available columns: [0]
# Columns for /AMG/meta/values_block_0/meta: [0]
# 'prc' column not found for /AMG/meta/values_block_0/meta. Available columns: [0]
# Columns for /AMED/meta/values_block_0/meta: [0]
# 'prc' column not found for /AMED/meta/values_block_0/meta. Available columns: [0]
# Columns for /AME/meta/values_block_0/meta: [0]
# 'prc' column not found for /AME/meta/values_block_0/meta. Available columns: [0]
# Columns for /AMD/meta/values_block_0/meta: [0]
# 'prc' column not found for /AMD/meta/values_block_0/meta. Available columns: [0]
# Columns for /AMCR/meta/values_block_0/meta: [0]
# 'prc' column not found for /AMCR/meta/values_block_0/meta. Available columns: [0]
# Columns for /AMAT/meta/values_block_0/meta: [0]
# 'prc' column not found for /AMAT/meta/values_block_0/meta. Available columns: [0]
# Columns for /AM/meta/values_block_0/meta: [0]
# 'prc' column not found for /AM/meta/values_block_0/meta. Available columns: [0]
# Columns for /ALSN/meta/values_block_0/meta: [0]
# 'prc' column not found for /ALSN/meta/values_block_0/meta. Available columns: [0]
# Columns for /ALNY/meta/values_block_0/meta: [0]
# 'prc' column not found for /ALNY/meta/values_block_0/meta. Available columns: [0]
# Columns for /ALLY/meta/values_block_0/meta: [0]
# 'prc' column not found for /ALLY/meta/values_block_0/meta. Available columns: [0]
# Columns for /ALLE/meta/values_block_0/meta: [0]
# 'prc' column not found for /ALLE/meta/values_block_0/meta. Available columns: [0]
# Columns for /ALL/meta/values_block_0/meta: [0]
# 'prc' column not found for /ALL/meta/values_block_0/meta. Available columns: [0]
# Columns for /ALK/meta/values_block_0/meta: [0]
# 'prc' column not found for /ALK/meta/values_block_0/meta. Available columns: [0]
# Columns for /ALGN/meta/values_block_0/meta: [0]
# 'prc' column not found for /ALGN/meta/values_block_0/meta. Available columns: [0]
# Columns for /ALGM/meta/values_block_0/meta: [0]
# 'prc' column not found for /ALGM/meta/values_block_0/meta. Available columns: [0]
# Columns for /ALB/meta/values_block_0/meta: [0]
# 'prc' column not found for /ALB/meta/values_block_0/meta. Available columns: [0]
# Columns for /ALAB/meta/values_block_0/meta: [0]
# 'prc' column not found for /ALAB/meta/values_block_0/meta. Available columns: [0]
# Columns for /AL/meta/values_block_0/meta: [0]
# 'prc' column not found for /AL/meta/values_block_0/meta. Available columns: [0]
# Columns for /AKAM/meta/values_block_0/meta: [0]
# 'prc' column not found for /AKAM/meta/values_block_0/meta. Available columns: [0]
# Columns for /AJG/meta/values_block_0/meta: [0]
# 'prc' column not found for /AJG/meta/values_block_0/meta. Available columns: [0]
# Columns for /AIZ/meta/values_block_0/meta: [0]
# 'prc' column not found for /AIZ/meta/values_block_0/meta. Available columns: [0]
# Columns for /AIG/meta/values_block_0/meta: [0]
# 'prc' column not found for /AIG/meta/values_block_0/meta. Available columns: [0]
# Columns for /AGR/meta/values_block_0/meta: [0]
# 'prc' column not found for /AGR/meta/values_block_0/meta. Available columns: [0]
# Columns for /AGO/meta/values_block_0/meta: [0]
# 'prc' column not found for /AGO/meta/values_block_0/meta. Available columns: [0]
# Columns for /AGNC/meta/values_block_0/meta: [0]
# 'prc' column not found for /AGNC/meta/values_block_0/meta. Available columns: [0]
# Columns for /AGCO/meta/values_block_0/meta: [0]
# 'prc' column not found for /AGCO/meta/values_block_0/meta. Available columns: [0]
# Columns for /AFRM/meta/values_block_0/meta: [0]
# 'prc' column not found for /AFRM/meta/values_block_0/meta. Available columns: [0]
# Columns for /AFL/meta/values_block_0/meta: [0]
# 'prc' column not found for /AFL/meta/values_block_0/meta. Available columns: [0]
# Columns for /AFG/meta/values_block_0/meta: [0]
# 'prc' column not found for /AFG/meta/values_block_0/meta. Available columns: [0]
# Columns for /AES/meta/values_block_0/meta: [0]
# 'prc' column not found for /AES/meta/values_block_0/meta. Available columns: [0]
# Columns for /AEP/meta/values_block_0/meta: [0]
# 'prc' column not found for /AEP/meta/values_block_0/meta. Available columns: [0]
# Columns for /AEE/meta/values_block_0/meta: [0]
# 'prc' column not found for /AEE/meta/values_block_0/meta. Available columns: [0]
# Columns for /ADT/meta/values_block_0/meta: [0]
# 'prc' column not found for /ADT/meta/values_block_0/meta. Available columns: [0]
# Columns for /ADSK/meta/values_block_0/meta: [0]
# 'prc' column not found for /ADSK/meta/values_block_0/meta. Available columns: [0]
# Columns for /ADP/meta/values_block_0/meta: [0]
# 'prc' column not found for /ADP/meta/values_block_0/meta. Available columns: [0]
# Columns for /ADM/meta/values_block_0/meta: [0]
# 'prc' column not found for /ADM/meta/values_block_0/meta. Available columns: [0]
# Columns for /ADI/meta/values_block_0/meta: [0]
# 'prc' column not found for /ADI/meta/values_block_0/meta. Available columns: [0]
# Columns for /ADC/meta/values_block_0/meta: [0]
# 'prc' column not found for /ADC/meta/values_block_0/meta. Available columns: [0]
# Columns for /ADBE/meta/values_block_0/meta: [0]
# 'prc' column not found for /ADBE/meta/values_block_0/meta. Available columns: [0]
# Columns for /ACN/meta/values_block_0/meta: [0]
# 'prc' column not found for /ACN/meta/values_block_0/meta. Available columns: [0]
# Columns for /ACM/meta/values_block_0/meta: [0]
# 'prc' column not found for /ACM/meta/values_block_0/meta. Available columns: [0]
# Columns for /ACI/meta/values_block_0/meta: [0]
# 'prc' column not found for /ACI/meta/values_block_0/meta. Available columns: [0]
# Columns for /ACHC/meta/values_block_0/meta: [0]
# 'prc' column not found for /ACHC/meta/values_block_0/meta. Available columns: [0]
# Columns for /ACGL/meta/values_block_0/meta: [0]
# 'prc' column not found for /ACGL/meta/values_block_0/meta. Available columns: [0]
# Columns for /ABT/meta/values_block_0/meta: [0]
# 'prc' column not found for /ABT/meta/values_block_0/meta. Available columns: [0]
# Columns for /ABNB/meta/values_block_0/meta: [0]
# 'prc' column not found for /ABNB/meta/values_block_0/meta. Available columns: [0]
# Columns for /ABBV/meta/values_block_0/meta: [0]
# 'prc' column not found for /ABBV/meta/values_block_0/meta. Available columns: [0]
# Columns for /AAPL/meta/values_block_0/meta: [0]
# 'prc' column not found for /AAPL/meta/values_block_0/meta. Available columns: [0]
# Columns for /AAP/meta/values_block_0/meta: [0]
# 'prc' column not found for /AAP/meta/values_block_0/meta. Available columns: [0]
# Columns for /AAON/meta/values_block_0/meta: [0]
# 'prc' column not found for /AAON/meta/values_block_0/meta. Available columns: [0]
# Columns for /AAL/meta/values_block_0/meta: [0]
# 'prc' column not found for /AAL/meta/values_block_0/meta. Available columns: [0]
# Columns for /AA/meta/values_block_0/meta: [0]
# 'prc' column not found for /AA/meta/values_block_0/meta. Available columns: [0]
# Columns for /A/meta/values_block_0/meta: [0]
# 'prc' column not found for /A/meta/values_block_0/meta. Available columns: [0]

# %%
# Check for duplicates in returns
for ticker, data in stock_data.items():
    
    r_vol =\
    (
        data['r_vol']
    )
    
    # Check for duplicates
    if r_vol.index.duplicated().any():
        
        print(f"Duplicates found in returns for {ticker}. Resolving...")
        
        r_vol =\
        (
            r_vol[~r_vol.index.duplicated(keep='first')]  # Keep the first occurrence
        )
        
    # Check for duplicates in Fama-French factors
    if fama_french.index.duplicated().any():
        
        print("Duplicates found in Fama-French factors. Resolving...")
        
        fama_french =\
        (
            fama_french[~fama_french.index.duplicated(keep='first')]  # Keep the first occurrence
        )

    # Align with Fama-French factors
    aligned_r_vol =\
    (
        r_vol
        .reindex(fama_french.index)
        .dropna()
    )
    
    aligned_factors =\
    (
        fama_french
        .loc[aligned_r_vol.index] # Align factors with returns
    )

    # Now both aligned_returns and aligned_factors have the same index
    print(f"Aligned returns for {ticker}:\n{aligned_r_vol.head()}")
    
    print(f"Aligned Fama-French factors:\n{aligned_factors.head()}")
    
    # Fit the GARCH-X model
    model =\
    (
        arch_model(aligned_r_vol,
                   vol='Garch',
                   p=1, 
                   q=1,
                   x=aligned_factors.values,
                   dist='Normal')
    )
    
    try:
        results =\
        (
            model
            .fit(disp='off')
        )
        
        print(f"Results for {ticker}:")
        
        print(results.summary())
        
    except Exception as e:
        
        print(f"Error fitting GARCH model for {ticker}: {e}")
# Out:
# Aligned returns for /A:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /A: first_obs and last_obs produce in an empty array.
# Aligned returns for /AA:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AA: first_obs and last_obs produce in an empty array.
# Aligned returns for /AAL:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AAL: first_obs and last_obs produce in an empty array.
# Aligned returns for /AAON:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AAON: first_obs and last_obs produce in an empty array.
# Aligned returns for /AAP:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AAP: first_obs and last_obs produce in an empty array.
# Aligned returns for /AAPL:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AAPL: first_obs and last_obs produce in an empty array.
# Aligned returns for /ABBV:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ABBV: first_obs and last_obs produce in an empty array.
# Aligned returns for /ABNB:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ABNB: first_obs and last_obs produce in an empty array.
# Aligned returns for /ABT:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ABT: first_obs and last_obs produce in an empty array.
# Aligned returns for /ACGL:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ACGL: first_obs and last_obs produce in an empty array.
# Aligned returns for /ACHC:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ACHC: first_obs and last_obs produce in an empty array.
# Aligned returns for /ACI:
# Date
# 2001-02-01    0.707943
# 2001-03-01    0.734087
# 2001-05-01    0.704425
# 2001-06-01    0.595842
# 2001-08-01    0.639726
# Name: r_vol, dtype: float64
# Aligned Fama-French factors:
#                smb     hml
# Date
# 2001-02-01 -0.0078  0.1247
# 2001-03-01  0.0025  0.0642
# 2001-05-01  0.0250  0.0336
# 2001-06-01  0.0624 -0.0112
# 2001-08-01  0.0248  0.0231
# Results for /ACI:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  r_vol   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                46.7552
# Distribution:                  Normal   AIC:                          -85.5105
# Method:            Maximum Likelihood   BIC:                          -74.6009
#                                         No. Observations:                  113
# Date:                Sun, Oct 13 2024   Df Residuals:                      112
# Time:                        22:28:01   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             0.4941  1.192e-02     41.444      0.000 [  0.471,  0.517]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      8.8464e-04  7.705e-04      1.148      0.251 [-6.256e-04,2.395e-03]
# alpha[1]       0.9937      0.221      4.494  7.002e-06      [  0.560,  1.427]
# beta[1]    6.3050e-03  1.106e-02      0.570      0.569 [-1.537e-02,2.798e-02]
# =============================================================================
#
# Covariance estimator: robust
# Aligned returns for /ACM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ACM: first_obs and last_obs produce in an empty array.
# Aligned returns for /ACN:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ACN: first_obs and last_obs produce in an empty array.
# Aligned returns for /ADBE:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ADBE: first_obs and last_obs produce in an empty array.
# Aligned returns for /ADC:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ADC: first_obs and last_obs produce in an empty array.
# Aligned returns for /ADI:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ADI: first_obs and last_obs produce in an empty array.
# Aligned returns for /ADM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ADM: first_obs and last_obs produce in an empty array.
# Aligned returns for /ADP:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ADP: first_obs and last_obs produce in an empty array.
# Aligned returns for /ADSK:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ADSK: first_obs and last_obs produce in an empty array.
# Aligned returns for /ADT:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ADT: first_obs and last_obs produce in an empty array.
# Aligned returns for /AEE:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AEE: first_obs and last_obs produce in an empty array.
# Aligned returns for /AEP:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AEP: first_obs and last_obs produce in an empty array.
# Aligned returns for /AES:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AES: first_obs and last_obs produce in an empty array.
# Aligned returns for /AFG:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AFG: first_obs and last_obs produce in an empty array.
# Aligned returns for /AFL:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AFL: first_obs and last_obs produce in an empty array.
# Aligned returns for /AFRM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AFRM: first_obs and last_obs produce in an empty array.
# Aligned returns for /AGCO:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AGCO: first_obs and last_obs produce in an empty array.
# Aligned returns for /AGNC:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AGNC: first_obs and last_obs produce in an empty array.
# Aligned returns for /AGO:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AGO: first_obs and last_obs produce in an empty array.
# Aligned returns for /AGR:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AGR: first_obs and last_obs produce in an empty array.
# Aligned returns for /AIG:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AIG: first_obs and last_obs produce in an empty array.
# Aligned returns for /AIZ:
# Date
# 2001-02-01    0.509010
# 2001-03-01    0.520975
# 2001-05-01    0.489626
# 2001-06-01    0.463068
# 2001-08-01    0.431151
# Name: r_vol, dtype: float64
# Aligned Fama-French factors:
#                smb     hml
# Date
# 2001-02-01 -0.0078  0.1247
# 2001-03-01  0.0025  0.0642
# 2001-05-01  0.0250  0.0336
# 2001-06-01  0.0624 -0.0112
# 2001-08-01  0.0248  0.0231
# Results for /AIZ:
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.009579. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.003327. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.03701. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.09065. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  r_vol   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                17.3883
# Distribution:                  Normal   AIC:                          -26.7767
# Method:            Maximum Likelihood   BIC:                          -23.9445
#                                         No. Observations:                   15
# Date:                Sun, Oct 13 2024   Df Residuals:                       14
# Time:                        22:28:01   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             0.4291  8.528e-02      5.031  4.872e-07 [  0.262,  0.596]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      5.6416e-04  2.120e-03      0.266      0.790 [-3.590e-03,4.718e-03]
# alpha[1]       1.0000      3.502      0.286      0.775      [ -5.864,  7.864]
# beta[1]        0.0000      3.290      0.000      1.000      [ -6.448,  6.448]
# =============================================================================
#
# Covariance estimator: robust
# Aligned returns for /AJG:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AJG: first_obs and last_obs produce in an empty array.
# Aligned returns for /AKAM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AKAM: first_obs and last_obs produce in an empty array.
# Aligned returns for /AL:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AL: first_obs and last_obs produce in an empty array.
# Aligned returns for /ALAB:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ALAB: first_obs and last_obs produce in an empty array.
# Aligned returns for /ALB:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ALB: first_obs and last_obs produce in an empty array.
# Aligned returns for /ALGM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ALGM: first_obs and last_obs produce in an empty array.
# Aligned returns for /ALGN:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ALGN: first_obs and last_obs produce in an empty array.
# Aligned returns for /ALK:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ALK: first_obs and last_obs produce in an empty array.
# Aligned returns for /ALL:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ALL: first_obs and last_obs produce in an empty array.
# Aligned returns for /ALLE:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ALLE: first_obs and last_obs produce in an empty array.
# Aligned returns for /ALLY:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ALLY: first_obs and last_obs produce in an empty array.
# Aligned returns for /ALNY:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ALNY: first_obs and last_obs produce in an empty array.
# Aligned returns for /ALSN:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ALSN: first_obs and last_obs produce in an empty array.
# Aligned returns for /AM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AM: first_obs and last_obs produce in an empty array.
# Aligned returns for /AMAT:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AMAT: first_obs and last_obs produce in an empty array.
# Duplicates found in returns for /AMCR. Resolving...
# Aligned returns for /AMCR:
# Date
# 2001-02-01    0.477408
# 2001-03-01    0.458253
# 2001-05-01    0.365784
# 2001-06-01    0.354772
# 2001-08-01    0.335131
# Name: r_vol, dtype: float64
# Aligned Fama-French factors:
#                smb     hml
# Date
# 2001-02-01 -0.0078  0.1247
# 2001-03-01  0.0025  0.0642
# 2001-05-01  0.0250  0.0336
# 2001-06-01  0.0624 -0.0112
# 2001-08-01  0.0248  0.0231
# Results for /AMCR:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  r_vol   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                95.7810
# Distribution:                  Normal   AIC:                          -183.562
# Method:            Maximum Likelihood   BIC:                          -175.914
#                                         No. Observations:                   50
# Date:                Sun, Oct 13 2024   Df Residuals:                       49
# Time:                        22:28:01   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             0.2475  2.302e-03    107.539      0.000 [  0.243,  0.252]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      6.6949e-05  6.080e-05      1.101      0.271 [-5.221e-05,1.861e-04]
# alpha[1]       0.1998      0.126      1.583      0.114   [-4.763e-02,  0.447]
# beta[1]        0.7792  3.663e-02     21.272 2.081e-100      [  0.707,  0.851]
# =============================================================================
#
# Covariance estimator: robust
# Aligned returns for /AMD:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AMD: first_obs and last_obs produce in an empty array.
# Aligned returns for /AME:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AME: first_obs and last_obs produce in an empty array.
# Aligned returns for /AMED:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AMED: first_obs and last_obs produce in an empty array.
# Aligned returns for /AMG:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AMG: first_obs and last_obs produce in an empty array.
# Aligned returns for /AMGN:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AMGN: first_obs and last_obs produce in an empty array.
# Aligned returns for /AMH:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AMH: first_obs and last_obs produce in an empty array.
# Aligned returns for /AMKR:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AMKR: first_obs and last_obs produce in an empty array.
# Aligned returns for /AMP:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AMP: first_obs and last_obs produce in an empty array.
# Aligned returns for /AMT:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AMT: first_obs and last_obs produce in an empty array.
# Aligned returns for /AMZN:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AMZN: first_obs and last_obs produce in an empty array.
# Aligned returns for /AN:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AN: first_obs and last_obs produce in an empty array.
# Aligned returns for /ANET:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ANET: first_obs and last_obs produce in an empty array.
# Aligned returns for /ANSS:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ANSS: first_obs and last_obs produce in an empty array.
# Aligned returns for /AON:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AON: first_obs and last_obs produce in an empty array.
# Aligned returns for /AOS:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AOS: first_obs and last_obs produce in an empty array.
# Aligned returns for /APA:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /APA: first_obs and last_obs produce in an empty array.
# Aligned returns for /APD:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /APD: first_obs and last_obs produce in an empty array.
# Aligned returns for /APG:
# Date
# 2001-03-01    1.531621
# 2001-05-01    1.595551
# 2001-06-01    1.528926
# 2001-08-01    1.501291
# 2001-10-01    1.605932
# Name: r_vol, dtype: float64
# Aligned Fama-French factors:
#                smb     hml
# Date
# 2001-03-01  0.0025  0.0642
# 2001-05-01  0.0250  0.0336
# 2001-06-01  0.0624 -0.0112
# 2001-08-01  0.0248  0.0231
# 2001-10-01  0.0748 -0.0765
# Results for /APG:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  r_vol   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                2.58292
# Distribution:                  Normal   AIC:                           2.83415
# Method:            Maximum Likelihood   BIC:                           3.62305
#                                         No. Observations:                    9
# Date:                Sun, Oct 13 2024   Df Residuals:                        8
# Time:                        22:28:01   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             1.6306      0.217      7.503  6.232e-14 [  1.205,  2.057]
#                             Volatility Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# omega      2.6665e-03  8.932e-02  2.985e-02      0.976 [ -0.172,  0.178]
# alpha[1]       0.0000      2.203      0.000      1.000 [ -4.317,  4.317]
# beta[1]        1.0000      1.798      0.556      0.578 [ -2.523,  4.523]
# ========================================================================
#
# Covariance estimator: robust
# Aligned returns for /APH:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /APH: first_obs and last_obs produce in an empty array.
# Aligned returns for /APLS:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /APLS: first_obs and last_obs produce in an empty array.
# Aligned returns for /APO:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /APO: first_obs and last_obs produce in an empty array.
# Aligned returns for /APP:
# Date
# 2007-05-01    0.263958
# 2007-06-01    0.279184
# 2007-08-01    0.302757
# 2007-10-01    0.338877
# 2007-11-01    0.341331
# Name: r_vol, dtype: float64
# Aligned Fama-French factors:
#                smb     hml
# Date
# 2007-05-01  0.0024 -0.0065
# 2007-06-01  0.0075 -0.0105
# 2007-08-01 -0.0013 -0.0186
# 2007-10-01  0.0008 -0.0298
# 2007-11-01 -0.0293 -0.0094
# Results for /APP:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  r_vol   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                6.86448
# Distribution:                  Normal   AIC:                          -5.72896
# Method:            Maximum Likelihood   BIC:                           2.90657
#                                         No. Observations:                   64
# Date:                Sun, Oct 13 2024   Df Residuals:                       63
# Time:                        22:28:01   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             0.8828  4.300e-02     20.530  1.173e-93 [  0.799,  0.967]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      4.3786e-03  6.414e-03      0.683      0.495 [-8.193e-03,1.695e-02]
# alpha[1]       1.0000      0.684      1.461      0.144      [ -0.341,  2.341]
# beta[1]        0.0000      0.631      0.000      1.000      [ -1.237,  1.237]
# =============================================================================
#
# Covariance estimator: robust
# Aligned returns for /APPF:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /APPF: first_obs and last_obs produce in an empty array.
# Aligned returns for /APTV:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /APTV: first_obs and last_obs produce in an empty array.
# Aligned returns for /AR:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AR: first_obs and last_obs produce in an empty array.
# Aligned returns for /ARE:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ARE: first_obs and last_obs produce in an empty array.
# Aligned returns for /ARES:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ARES: first_obs and last_obs produce in an empty array.
# Aligned returns for /ARMK:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ARMK: first_obs and last_obs produce in an empty array.
# Aligned returns for /ARW:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ARW: first_obs and last_obs produce in an empty array.
# Aligned returns for /ASH:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ASH: first_obs and last_obs produce in an empty array.
# Aligned returns for /ATI:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ATI: first_obs and last_obs produce in an empty array.
# Aligned returns for /ATO:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ATO: first_obs and last_obs produce in an empty array.
# Aligned returns for /ATR:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ATR: first_obs and last_obs produce in an empty array.
# Aligned returns for /AVB:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AVB: first_obs and last_obs produce in an empty array.
# Aligned returns for /AVGO:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AVGO: first_obs and last_obs produce in an empty array.
# Aligned returns for /AVT:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AVT: first_obs and last_obs produce in an empty array.
# Aligned returns for /AVTR:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AVTR: first_obs and last_obs produce in an empty array.
# Aligned returns for /AVY:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AVY: first_obs and last_obs produce in an empty array.
# Aligned returns for /AWI:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AWI: first_obs and last_obs produce in an empty array.
# Aligned returns for /AWK:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AWK: first_obs and last_obs produce in an empty array.
# Aligned returns for /AXON:
# Date
# 2016-07-01    0.832911
# 2016-08-01    0.796160
# 2016-09-01    0.740765
# 2016-11-01    0.660786
# 2016-12-01    0.647598
# Name: r_vol, dtype: float64
# Aligned Fama-French factors:
#                smb     hml
# Date
# 2016-07-01  0.0249 -0.0132
# 2016-08-01  0.0116  0.0318
# 2016-09-01  0.0212 -0.0124
# 2016-11-01  0.0571  0.0821
# 2016-12-01  0.0010  0.0353
# Results for /AXON:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  r_vol   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -13.6801
# Distribution:                  Normal   AIC:                           35.3602
# Method:            Maximum Likelihood   BIC:                           43.3895
#                                         No. Observations:                   55
# Date:                Sun, Oct 13 2024   Df Residuals:                       54
# Time:                        22:28:01   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             0.9813      0.117      8.365  6.001e-17 [  0.751,  1.211]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      6.6376e-03  1.100e-02      0.603      0.546 [-1.493e-02,2.821e-02]
# alpha[1]       0.9983      0.322      3.102  1.920e-03      [  0.368,  1.629]
# beta[1]    1.6628e-03  1.316e-02      0.126      0.899 [-2.413e-02,2.746e-02]
# =============================================================================
#
# Covariance estimator: robust
# Aligned returns for /AXP:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AXP: first_obs and last_obs produce in an empty array.
# Aligned returns for /AXS:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AXS: first_obs and last_obs produce in an empty array.
# Aligned returns for /AXTA:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AXTA: first_obs and last_obs produce in an empty array.
# Aligned returns for /AYI:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AYI: first_obs and last_obs produce in an empty array.
# Aligned returns for /AZEK:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AZEK: first_obs and last_obs produce in an empty array.
# Aligned returns for /AZO:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AZO: first_obs and last_obs produce in an empty array.
# Aligned returns for /AZPN:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AZPN: first_obs and last_obs produce in an empty array.
# Aligned returns for /AZTA:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /AZTA: first_obs and last_obs produce in an empty array.
# Aligned returns for /BA:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BA: first_obs and last_obs produce in an empty array.
# Aligned returns for /BAC:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BAC: first_obs and last_obs produce in an empty array.
# Aligned returns for /BAH:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BAH: first_obs and last_obs produce in an empty array.
# Aligned returns for /BALL:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BALL: first_obs and last_obs produce in an empty array.
# Aligned returns for /BAX:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BAX: first_obs and last_obs produce in an empty array.
# Aligned returns for /BBWI:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BBWI: first_obs and last_obs produce in an empty array.
# Aligned returns for /BBY:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BBY: first_obs and last_obs produce in an empty array.
# Aligned returns for /BC:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BC: first_obs and last_obs produce in an empty array.
# Aligned returns for /BDX:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BDX: first_obs and last_obs produce in an empty array.
# Aligned returns for /BEN:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BEN: first_obs and last_obs produce in an empty array.
# Aligned returns for /BEPC:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BEPC: first_obs and last_obs produce in an empty array.
# Aligned returns for /BERY:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BERY: first_obs and last_obs produce in an empty array.
# Aligned returns for /BFAM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BFAM: first_obs and last_obs produce in an empty array.
# Aligned returns for /BG:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BG: first_obs and last_obs produce in an empty array.
# Aligned returns for /BHF:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BHF: first_obs and last_obs produce in an empty array.
# Aligned returns for /BIIB:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BIIB: first_obs and last_obs produce in an empty array.
# Aligned returns for /BILL:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BILL: first_obs and last_obs produce in an empty array.
# Aligned returns for /BIO:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BIO: first_obs and last_obs produce in an empty array.
# Aligned returns for /BIRK:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BIRK: first_obs and last_obs produce in an empty array.
# Aligned returns for /BJ:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BJ: first_obs and last_obs produce in an empty array.
# Aligned returns for /BK:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BK: first_obs and last_obs produce in an empty array.
# Aligned returns for /BKNG:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BKNG: first_obs and last_obs produce in an empty array.
# Aligned returns for /BKR:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BKR: first_obs and last_obs produce in an empty array.
# Aligned returns for /BLD:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BLD: first_obs and last_obs produce in an empty array.
# Aligned returns for /BLDR:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BLDR: first_obs and last_obs produce in an empty array.
# Aligned returns for /BLK:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BLK: first_obs and last_obs produce in an empty array.
# Aligned returns for /BMRN:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BMRN: first_obs and last_obs produce in an empty array.
# Aligned returns for /BMY:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BMY: first_obs and last_obs produce in an empty array.
# Aligned returns for /BOKF:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BOKF: first_obs and last_obs produce in an empty array.
# Aligned returns for /BPOP:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BPOP: first_obs and last_obs produce in an empty array.
# Aligned returns for /BR:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BR: first_obs and last_obs produce in an empty array.
# Aligned returns for /BRBR:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BRBR: first_obs and last_obs produce in an empty array.
# Aligned returns for /BRKR:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BRKR: first_obs and last_obs produce in an empty array.
# Aligned returns for /BRO:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BRO: first_obs and last_obs produce in an empty array.
# Aligned returns for /BROS:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BROS: first_obs and last_obs produce in an empty array.
# Aligned returns for /BRX:
# Date
# 2001-02-01    1.774877
# 2001-03-01    1.870316
# Name: r_vol, dtype: float64
# Aligned Fama-French factors:
#                smb     hml
# Date
# 2001-02-01 -0.0078  0.1247
# 2001-03-01  0.0025  0.0642
# Results for /BRX:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  r_vol   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                3.24696
# Distribution:                  Normal   AIC:                           1.50609
# Method:            Maximum Likelihood   BIC:                          -3.72132
#                                         No. Observations:                    2
# Date:                Sun, Oct 13 2024   Df Residuals:                        1
# Time:                        22:28:01   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             1.8226  5.359e-02     34.012 1.472e-253 [  1.718,  1.928]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      6.8314e-04  4.084e-05     16.729  8.035e-63  [6.031e-04,7.632e-04]
# alpha[1]       0.0100  3.253e-02      0.307      0.759 [-5.376e-02,7.376e-02]
# beta[1]        0.6900      0.397      1.737  8.230e-02   [-8.835e-02,  1.468]
# =============================================================================
#
# Covariance estimator: robust
# Aligned returns for /BSX:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BSX: first_obs and last_obs produce in an empty array.
# Aligned returns for /BSY:
# Date
# 2001-06-01    0.616888
# 2001-08-01    0.556224
# 2002-02-01    0.443440
# 2002-03-01    0.448809
# 2002-04-01    0.447160
# Name: r_vol, dtype: float64
# Aligned Fama-French factors:
#                smb     hml
# Date
# 2001-06-01  0.0624 -0.0112
# 2001-08-01  0.0248  0.0231
# 2002-02-01 -0.0101  0.0216
# 2002-03-01  0.0421  0.0106
# 2002-04-01  0.0596  0.0388
# Results for /BSY:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  r_vol   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                63.0077
# Distribution:                  Normal   AIC:                          -118.015
# Method:            Maximum Likelihood   BIC:                          -109.318
#                                         No. Observations:                   65
# Date:                Sun, Oct 13 2024   Df Residuals:                       64
# Time:                        22:28:01   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# ...
# Date:                Sun, Oct 13 2024   Df Residuals:                       75
# Time:                        22:28:05   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             0.7169  3.725e-02     19.242  1.632e-82 [  0.644,  0.790]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      7.6084e-03  5.671e-03      1.342      0.180 [-3.507e-03,1.872e-02]
# alpha[1]       1.0000      1.120      0.893      0.372      [ -1.195,  3.195]
# beta[1]        0.0000      0.732      0.000      1.000      [ -1.435,  1.435]
# =============================================================================
#
# Covariance estimator: robust
# Aligned returns for /WFC:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /WFC: first_obs and last_obs produce in an empty array.
# Aligned returns for /WFRD:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /WFRD: first_obs and last_obs produce in an empty array.
# Aligned returns for /WH:
# Date
# 2009-04-01    0.937506
# 2009-05-01    0.916314
# 2009-06-01    0.918207
# 2009-07-01    0.958199
# 2009-09-01    0.983676
# Name: r_vol, dtype: float64
# Aligned Fama-French factors:
#                smb     hml
# Date
# 2009-04-01  0.0539  0.0536
# 2009-05-01 -0.0252  0.0028
# 2009-06-01  0.0263 -0.0273
# 2009-07-01  0.0187  0.0483
# 2009-09-01  0.0243  0.0104
# Results for /WH:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  r_vol   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -8.17640
# Distribution:                  Normal   AIC:                           24.3528
# Method:            Maximum Likelihood   BIC:                           31.4896
#                                         No. Observations:                   44
# Date:                Sun, Oct 13 2024   Df Residuals:                       43
# Time:                        22:28:05   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             0.8411  6.200e-02     13.566  6.330e-42 [  0.720,  0.963]
#                               Volatility Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# omega          0.0488  4.210e-02      1.158      0.247 [-3.376e-02,  0.131]
# alpha[1]       0.5492      0.146      3.771  1.625e-04    [  0.264,  0.835]
# beta[1]    8.8057e-15      0.128  6.881e-14      1.000    [ -0.251,  0.251]
# ===========================================================================
#
# Covariance estimator: robust
# Aligned returns for /WHR:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /WHR: first_obs and last_obs produce in an empty array.
# Aligned returns for /WING:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /WING: first_obs and last_obs produce in an empty array.
# Aligned returns for /WLK:
# Date
# 2001-02-01    1.378239
# 2001-03-01    1.528605
# Name: r_vol, dtype: float64
# Aligned Fama-French factors:
#                smb     hml
# Date
# 2001-02-01 -0.0078  0.1247
# 2001-03-01  0.0025  0.0642
# Results for /WLK:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  r_vol   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                2.33778
# Distribution:                  Normal   AIC:                           3.32445
# Method:            Maximum Likelihood   BIC:                          -1.90297
#                                         No. Observations:                    2
# Date:                Sun, Oct 13 2024   Df Residuals:                        1
# Time:                        22:28:05   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             1.4534  8.443e-02     17.215  2.045e-66 [  1.288,  1.619]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      1.6958e-03  1.598e-04     10.610  2.675e-26 [1.383e-03,2.009e-03]
# alpha[1]       0.0100  5.668e-02      0.176      0.860     [ -0.101,  0.121]
# beta[1]        0.6900      0.383      1.800  7.184e-02  [-6.127e-02,  1.441]
# ============================================================================
#
# Covariance estimator: robust
# Aligned returns for /WM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /WM: first_obs and last_obs produce in an empty array.
# Aligned returns for /WMB:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /WMB: first_obs and last_obs produce in an empty array.
# Aligned returns for /WMS:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /WMS: first_obs and last_obs produce in an empty array.
# Aligned returns for /WMT:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /WMT: first_obs and last_obs produce in an empty array.
# Aligned returns for /WOLF:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /WOLF: first_obs and last_obs produce in an empty array.
# Aligned returns for /WPC:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /WPC: first_obs and last_obs produce in an empty array.
# Aligned returns for /WRB:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /WRB: first_obs and last_obs produce in an empty array.
# Aligned returns for /WSC:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /WSC: first_obs and last_obs produce in an empty array.
# Aligned returns for /WSM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /WSM: first_obs and last_obs produce in an empty array.
# Aligned returns for /WSO:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /WSO: first_obs and last_obs produce in an empty array.
# Aligned returns for /WST:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /WST: first_obs and last_obs produce in an empty array.
# Aligned returns for /WTFC:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /WTFC: first_obs and last_obs produce in an empty array.
# Aligned returns for /WTM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /WTM: first_obs and last_obs produce in an empty array.
# Aligned returns for /WTRG:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /WTRG: first_obs and last_obs produce in an empty array.
# Aligned returns for /WTW:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /WTW: first_obs and last_obs produce in an empty array.
# Aligned returns for /WU:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /WU: first_obs and last_obs produce in an empty array.
# Aligned returns for /WWD:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /WWD: first_obs and last_obs produce in an empty array.
# Aligned returns for /WY:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /WY: first_obs and last_obs produce in an empty array.
# Aligned returns for /WYNN:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /WYNN: first_obs and last_obs produce in an empty array.
# Aligned returns for /X:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /X: first_obs and last_obs produce in an empty array.
# Aligned returns for /XEL:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /XEL: first_obs and last_obs produce in an empty array.
# Aligned returns for /XOM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /XOM: first_obs and last_obs produce in an empty array.
# Aligned returns for /XP:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /XP: first_obs and last_obs produce in an empty array.
# Aligned returns for /XPO:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /XPO: first_obs and last_obs produce in an empty array.
# Aligned returns for /XRAY:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /XRAY: first_obs and last_obs produce in an empty array.
# Aligned returns for /XYL:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /XYL: first_obs and last_obs produce in an empty array.
# Aligned returns for /YETI:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /YETI: first_obs and last_obs produce in an empty array.
# Aligned returns for /YUM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /YUM: first_obs and last_obs produce in an empty array.
# Aligned returns for /Z:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /Z: first_obs and last_obs produce in an empty array.
# Aligned returns for /ZBH:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ZBH: first_obs and last_obs produce in an empty array.
# Aligned returns for /ZBRA:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ZBRA: first_obs and last_obs produce in an empty array.
# Aligned returns for /ZG:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ZG: first_obs and last_obs produce in an empty array.
# Aligned returns for /ZI:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ZI: first_obs and last_obs produce in an empty array.
# Aligned returns for /ZION:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ZION: first_obs and last_obs produce in an empty array.
# Aligned returns for /ZM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ZM: first_obs and last_obs produce in an empty array.
# Aligned returns for /ZS:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ZS: first_obs and last_obs produce in an empty array.
# Aligned returns for /ZTS:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /ZTS: first_obs and last_obs produce in an empty array.
# Aligned returns for /BRK/B:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [smb, hml]
# Index: []
# Error fitting GARCH model for /BRK/B: first_obs and last_obs produce in an empty array.
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07355. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.005653. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(

# %%
for ticker, data in stock_data.items():
    
    r_vol = data['r_vol']
    
    if r_vol.index.duplicated().any():
        print(f"Duplicates found in returns for {ticker}. Resolving...")
        r_vol =\
        (
            r_vol
            [~r_vol.index.duplicated(keep='first')]
        )
    
    if fama_french.index.duplicated().any():
        print("Duplicates found in Fama-French factors. Resolving...")
        fama_french =\
        (
            fama_french
            [~fama_french.index.duplicated(keep='first')]
        )

    r_vol.index =\
    (
        pd
        .to_datetime
        (r_vol.index)
    )
    
    fama_french.index =\
    (
        pd
        .to_datetime
        (fama_french.index)
    )
    
    aligned_factors =\
    (
        pd
        .merge_asof(r_vol.sort_index(), 
                    fama_french.sort_index(), 
                    left_index=True, 
                    right_index=True, 
                    direction='backward')
    )
    
    aligned_factors =\
    (
        aligned_factors
        .dropna()
    )

    aligned_r_vol =\
    (
        r_vol
        .loc
        [aligned_factors.index]
    )

    print(f"Aligned returns for {ticker}:\n{aligned_r_vol.head()}")
    
    print(f"Aligned Fama-French factors:\n{aligned_factors.head()}")
    
    model =\
    (
        arch_model(aligned_r_vol,
                   vol='Garch',
                   p=1, 
                   q=1,
                   x=aligned_factors.values,
                   dist='Normal')
    )
    
    try:
        results =\
        (
            model
            .fit
            (disp='off')
        )
        
        print(f"Results for {ticker}:")
        
        print(results.summary())
        
    except Exception as e:
        
        print(f"Error fitting GARCH model for {ticker}: {e}")
# Out:
# Aligned returns for /A:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /A: first_obs and last_obs produce in an empty array.
# Aligned returns for /AA:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AA: first_obs and last_obs produce in an empty array.
# Aligned returns for /AAL:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AAL: first_obs and last_obs produce in an empty array.
# Aligned returns for /AAON:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AAON: first_obs and last_obs produce in an empty array.
# Aligned returns for /AAP:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AAP: first_obs and last_obs produce in an empty array.
# Aligned returns for /AAPL:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AAPL: first_obs and last_obs produce in an empty array.
# Aligned returns for /ABBV:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ABBV: first_obs and last_obs produce in an empty array.
# Aligned returns for /ABNB:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ABNB: first_obs and last_obs produce in an empty array.
# Aligned returns for /ABT:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ABT: first_obs and last_obs produce in an empty array.
# Aligned returns for /ACGL:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ACGL: first_obs and last_obs produce in an empty array.
# Aligned returns for /ACHC:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ACHC: first_obs and last_obs produce in an empty array.
# Aligned returns for /ACI:
# Date
# 2001-01-02    0.698037
# 2001-01-03    0.698134
# 2001-01-04    0.697538
# 2001-01-05    0.698202
# 2001-01-08    0.698465
# Name: r_vol, dtype: float64
# Aligned Fama-French factors:
#                r_vol     smb     hml
# Date
# 2001-01-02  0.698037  0.0668 -0.0507
# 2001-01-03  0.698134  0.0668 -0.0507
# 2001-01-04  0.697538  0.0668 -0.0507
# 2001-01-05  0.698202  0.0668 -0.0507
# 2001-01-08  0.698465  0.0668 -0.0507
# Results for /ACI:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  r_vol   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                1561.95
# Distribution:                  Normal   AIC:                          -3115.89
# Method:            Maximum Likelihood   BIC:                          -3090.94
#                                         No. Observations:                 3778
# Date:                Mon, Oct 14 2024   Df Residuals:                     3777
# Time:                        14:49:23   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             0.5182  5.302e-03     97.740      0.000 [  0.508,  0.529]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      3.2304e-03  6.777e-05     47.668      0.000 [3.098e-03,3.363e-03]
# alpha[1]       0.2000  1.140e-02     17.543  6.709e-69     [  0.178,  0.222]
# beta[1]        0.7800  5.932e-03    131.485      0.000     [  0.768,  0.792]
# ============================================================================
#
# Covariance estimator: robust
# Aligned returns for /ACM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ACM: first_obs and last_obs produce in an empty array.
# Aligned returns for /ACN:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ACN: first_obs and last_obs produce in an empty array.
# Aligned returns for /ADBE:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ADBE: first_obs and last_obs produce in an empty array.
# Aligned returns for /ADC:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ADC: first_obs and last_obs produce in an empty array.
# Aligned returns for /ADI:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ADI: first_obs and last_obs produce in an empty array.
# Aligned returns for /ADM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ADM: first_obs and last_obs produce in an empty array.
# Aligned returns for /ADP:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ADP: first_obs and last_obs produce in an empty array.
# Aligned returns for /ADSK:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ADSK: first_obs and last_obs produce in an empty array.
# Aligned returns for /ADT:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ADT: first_obs and last_obs produce in an empty array.
# Aligned returns for /AEE:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AEE: first_obs and last_obs produce in an empty array.
# Aligned returns for /AEP:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AEP: first_obs and last_obs produce in an empty array.
# Aligned returns for /AES:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AES: first_obs and last_obs produce in an empty array.
# Aligned returns for /AFG:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AFG: first_obs and last_obs produce in an empty array.
# Aligned returns for /AFL:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AFL: first_obs and last_obs produce in an empty array.
# Aligned returns for /AFRM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AFRM: first_obs and last_obs produce in an empty array.
# Aligned returns for /AGCO:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AGCO: first_obs and last_obs produce in an empty array.
# Aligned returns for /AGNC:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AGNC: first_obs and last_obs produce in an empty array.
# Aligned returns for /AGO:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AGO: first_obs and last_obs produce in an empty array.
# Aligned returns for /AGR:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AGR: first_obs and last_obs produce in an empty array.
# Aligned returns for /AIG:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AIG: first_obs and last_obs produce in an empty array.
# Aligned returns for /AIZ:
# Date
# 2001-01-02    0.530859
# 2001-01-03    0.530712
# 2001-01-04    0.528422
# 2001-01-05    0.528538
# 2001-01-08    0.532007
# Name: r_vol, dtype: float64
# Aligned Fama-French factors:
#                r_vol     smb     hml
# Date
# 2001-01-02  0.530859  0.0668 -0.0507
# 2001-01-03  0.530712  0.0668 -0.0507
# 2001-01-04  0.528422  0.0668 -0.0507
# 2001-01-05  0.528538  0.0668 -0.0507
# 2001-01-08  0.532007  0.0668 -0.0507
# Results for /AIZ:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  r_vol   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                578.196
# Distribution:                  Normal   AIC:                          -1148.39
# Method:            Maximum Likelihood   BIC:                          -1131.09
#                                         No. Observations:                  558
# Date:                Mon, Oct 14 2024   Df Residuals:                      557
# Time:                        14:49:23   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             0.4537  2.832e-02     16.020  9.300e-58 [  0.398,  0.509]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      3.6088e-04  6.559e-05      5.502  3.755e-08 [2.323e-04,4.894e-04]
# alpha[1]       0.2000  3.371e-02      5.933  2.980e-09     [  0.134,  0.266]
# beta[1]        0.7799  3.516e-02     22.182 5.122e-109     [  0.711,  0.849]
# ============================================================================
#
# Covariance estimator: robust
# Aligned returns for /AJG:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AJG: first_obs and last_obs produce in an empty array.
# Aligned returns for /AKAM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AKAM: first_obs and last_obs produce in an empty array.
# Aligned returns for /AL:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AL: first_obs and last_obs produce in an empty array.
# Aligned returns for /ALAB:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ALAB: first_obs and last_obs produce in an empty array.
# Aligned returns for /ALB:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ALB: first_obs and last_obs produce in an empty array.
# Aligned returns for /ALGM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.01805. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07429. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Error fitting GARCH model for /ALGM: first_obs and last_obs produce in an empty array.
# Aligned returns for /ALGN:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ALGN: first_obs and last_obs produce in an empty array.
# Aligned returns for /ALK:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ALK: first_obs and last_obs produce in an empty array.
# Aligned returns for /ALL:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ALL: first_obs and last_obs produce in an empty array.
# Aligned returns for /ALLE:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ALLE: first_obs and last_obs produce in an empty array.
# Aligned returns for /ALLY:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ALLY: first_obs and last_obs produce in an empty array.
# Aligned returns for /ALNY:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ALNY: first_obs and last_obs produce in an empty array.
# Aligned returns for /ALSN:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ALSN: first_obs and last_obs produce in an empty array.
# Aligned returns for /AM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AM: first_obs and last_obs produce in an empty array.
# Aligned returns for /AMAT:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AMAT: first_obs and last_obs produce in an empty array.
# Duplicates found in returns for /AMCR. Resolving...
# Aligned returns for /AMCR:
# Date
# 2000-12-08    3.073656
# 2000-12-11    3.073645
# 2000-12-12    3.073067
# 2000-12-13    3.072873
# 2000-12-14    3.068985
# Name: r_vol, dtype: float64
# Aligned Fama-French factors:
#                r_vol     smb     hml
# Date
# 2000-12-08  3.073656  0.0073  0.0761
# 2000-12-11  3.073645  0.0073  0.0761
# 2000-12-12  3.073067  0.0073  0.0761
# 2000-12-13  3.072873  0.0073  0.0761
# 2000-12-14  3.068985  0.0073  0.0761
# Results for /AMCR:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  r_vol   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                3688.89
# Distribution:                  Normal   AIC:                          -7369.77
# Method:            Maximum Likelihood   BIC:                          -7348.19
#                                         No. Observations:                 1630
# Date:                Mon, Oct 14 2024   Df Residuals:                     1629
# Time:                        14:49:23   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             0.2457  3.298e-02      7.450  9.302e-14 [  0.181,  0.310]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      6.9444e-06  2.454e-06      2.829  4.664e-03  [2.134e-06,1.175e-05]
# alpha[1]       0.9691      0.422      2.299  2.150e-02      [  0.143,  1.795]
# beta[1]    7.1958e-05  3.605e-02  1.996e-03      0.998 [-7.058e-02,7.072e-02]
# =============================================================================
#
# Covariance estimator: robust
# Aligned returns for /AMD:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AMD: first_obs and last_obs produce in an empty array.
# Aligned returns for /AME:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AME: first_obs and last_obs produce in an empty array.
# Aligned returns for /AMED:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AMED: first_obs and last_obs produce in an empty array.
# Aligned returns for /AMG:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AMG: first_obs and last_obs produce in an empty array.
# Aligned returns for /AMGN:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AMGN: first_obs and last_obs produce in an empty array.
# Aligned returns for /AMH:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AMH: first_obs and last_obs produce in an empty array.
# Aligned returns for /AMKR:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AMKR: first_obs and last_obs produce in an empty array.
# Aligned returns for /AMP:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AMP: first_obs and last_obs produce in an empty array.
# Aligned returns for /AMT:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AMT: first_obs and last_obs produce in an empty array.
# Aligned returns for /AMZN:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AMZN: first_obs and last_obs produce in an empty array.
# Aligned returns for /AN:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AN: first_obs and last_obs produce in an empty array.
# Aligned returns for /ANET:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ANET: first_obs and last_obs produce in an empty array.
# Aligned returns for /ANSS:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ANSS: first_obs and last_obs produce in an empty array.
# Aligned returns for /AON:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AON: first_obs and last_obs produce in an empty array.
# Aligned returns for /AOS:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AOS: first_obs and last_obs produce in an empty array.
# Aligned returns for /APA:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /APA: first_obs and last_obs produce in an empty array.
# Aligned returns for /APD:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /APD: first_obs and last_obs produce in an empty array.
# Aligned returns for /APG:
# Date
# 2001-02-13    1.800048
# 2001-02-14    1.525015
# 2001-02-15    1.523723
# 2001-02-16    1.524027
# 2001-02-20    1.524784
# Name: r_vol, dtype: float64
# Aligned Fama-French factors:
#                r_vol     smb     hml
# Date
# 2001-02-13  1.800048 -0.0078  0.1247
# 2001-02-14  1.525015 -0.0078  0.1247
# 2001-02-15  1.523723 -0.0078  0.1247
# 2001-02-16  1.524027 -0.0078  0.1247
# 2001-02-20  1.524784 -0.0078  0.1247
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.04169. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Results for /APG:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  r_vol   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                463.136
# Distribution:                  Normal   AIC:                          -918.273
# Method:            Maximum Likelihood   BIC:                          -903.580
#                                         No. Observations:                  291
# Date:                Mon, Oct 14 2024   Df Residuals:                      290
# Time:                        14:49:24   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             1.5897  7.644e-04   2079.553      0.000 [  1.588,  1.591]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      1.2226e-05  1.623e-08    753.099      0.000  [1.219e-05,1.226e-05]
# alpha[1]       1.0000  4.125e-02     24.245 7.423e-130      [  0.919,  1.081]
# beta[1]    6.9822e-11  2.957e-02  2.362e-09      1.000 [-5.795e-02,5.795e-02]
# =============================================================================
#
# Covariance estimator: robust
# Aligned returns for /APH:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /APH: first_obs and last_obs produce in an empty array.
# Aligned returns for /APLS:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /APLS: first_obs and last_obs produce in an empty array.
# Aligned returns for /APO:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /APO: first_obs and last_obs produce in an empty array.
# Aligned returns for /APP:
# Date
# 2007-04-30    0.263769
# 2007-05-01    0.263958
# 2007-05-02    0.266039
# 2007-05-03    0.268377
# 2007-05-04    0.272171
# Name: r_vol, dtype: float64
# Aligned Fama-French factors:
#                r_vol     smb     hml
# Date
# 2007-04-30  0.263769 -0.0216 -0.0145
# 2007-05-01  0.263958  0.0024 -0.0065
# 2007-05-02  0.266039  0.0024 -0.0065
# 2007-05-03  0.268377  0.0024 -0.0065
# 2007-05-04  0.272171  0.0024 -0.0065
# Results for /APP:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  r_vol   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                378.366
# Distribution:                  Normal   AIC:                          -748.731
# Method:            Maximum Likelihood   BIC:                          -726.087
#                                         No. Observations:                 2124
# Date:                Mon, Oct 14 2024   Df Residuals:                     2123
# Time:                        14:49:24   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             0.8474  1.420e-02     59.693      0.000 [  0.820,  0.875]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      1.7814e-03  9.773e-05     18.227  3.174e-74 [1.590e-03,1.973e-03]
# alpha[1]       0.2000  1.044e-02     19.163  7.566e-82     [  0.180,  0.220]
# beta[1]        0.7800  1.026e-02     76.005      0.000     [  0.760,  0.800]
# ============================================================================
#
# Covariance estimator: robust
# Aligned returns for /APPF:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /APPF: first_obs and last_obs produce in an empty array.
# Aligned returns for /APTV:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /APTV: first_obs and last_obs produce in an empty array.
# Aligned returns for /AR:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AR: first_obs and last_obs produce in an empty array.
# Aligned returns for /ARE:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ARE: first_obs and last_obs produce in an empty array.
# Aligned returns for /ARES:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ARES: first_obs and last_obs produce in an empty array.
# Aligned returns for /ARMK:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ARMK: first_obs and last_obs produce in an empty array.
# Aligned returns for /ARW:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ARW: first_obs and last_obs produce in an empty array.
# Aligned returns for /ASH:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ASH: first_obs and last_obs produce in an empty array.
# Aligned returns for /ATI:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ATI: first_obs and last_obs produce in an empty array.
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.08907. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Aligned returns for /ATO:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ATO: first_obs and last_obs produce in an empty array.
# Aligned returns for /ATR:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ATR: first_obs and last_obs produce in an empty array.
# Aligned returns for /AVB:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AVB: first_obs and last_obs produce in an empty array.
# Aligned returns for /AVGO:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AVGO: first_obs and last_obs produce in an empty array.
# Aligned returns for /AVT:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AVT: first_obs and last_obs produce in an empty array.
# Aligned returns for /AVTR:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AVTR: first_obs and last_obs produce in an empty array.
# Aligned returns for /AVY:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AVY: first_obs and last_obs produce in an empty array.
# Aligned returns for /AWI:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AWI: first_obs and last_obs produce in an empty array.
# Aligned returns for /AWK:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AWK: first_obs and last_obs produce in an empty array.
# Aligned returns for /AXON:
# Date
# 2016-06-10    0.871585
# 2016-06-13    0.827657
# 2016-06-14    0.827701
# 2016-06-15    0.827124
# 2016-06-16    0.826684
# Name: r_vol, dtype: float64
# Aligned Fama-French factors:
#                r_vol     smb     hml
# Date
# 2016-06-10  0.871585  0.0061 -0.0148
# 2016-06-13  0.827657  0.0061 -0.0148
# 2016-06-14  0.827701  0.0061 -0.0148
# 2016-06-15  0.827124  0.0061 -0.0148
# 2016-06-16  0.826684  0.0061 -0.0148
# Results for /AXON:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  r_vol   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                349.805
# Distribution:                  Normal   AIC:                          -691.611
# Method:            Maximum Likelihood   BIC:                          -669.841
#                                         No. Observations:                 1707
# Date:                Mon, Oct 14 2024   Df Residuals:                     1706
# Time:                        14:49:24   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             1.0080  9.013e-05  1.118e+04      0.000 [  1.008,  1.008]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      3.0748e-06  2.962e-07     10.380  3.063e-25  [2.494e-06,3.655e-06]
# alpha[1]       1.0000  4.115e-02     24.301 1.891e-130      [  0.919,  1.081]
# beta[1]    3.4423e-10  3.211e-04  1.072e-06      1.000 [-6.294e-04,6.294e-04]
# =============================================================================
#
# Covariance estimator: robust
# Aligned returns for /AXP:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AXP: first_obs and last_obs produce in an empty array.
# Aligned returns for /AXS:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AXS: first_obs and last_obs produce in an empty array.
# Aligned returns for /AXTA:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AXTA: first_obs and last_obs produce in an empty array.
# Aligned returns for /AYI:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AYI: first_obs and last_obs produce in an empty array.
# Aligned returns for /AZEK:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AZEK: first_obs and last_obs produce in an empty array.
# Aligned returns for /AZO:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AZO: first_obs and last_obs produce in an empty array.
# Aligned returns for /AZPN:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AZPN: first_obs and last_obs produce in an empty array.
# Aligned returns for /AZTA:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /AZTA: first_obs and last_obs produce in an empty array.
# Aligned returns for /BA:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BA: first_obs and last_obs produce in an empty array.
# Aligned returns for /BAC:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BAC: first_obs and last_obs produce in an empty array.
# Aligned returns for /BAH:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BAH: first_obs and last_obs produce in an empty array.
# Aligned returns for /BALL:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BALL: first_obs and last_obs produce in an empty array.
# Aligned returns for /BAX:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BAX: first_obs and last_obs produce in an empty array.
# Aligned returns for /BBWI:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BBWI: first_obs and last_obs produce in an empty array.
# Aligned returns for /BBY:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BBY: first_obs and last_obs produce in an empty array.
# Aligned returns for /BC:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BC: first_obs and last_obs produce in an empty array.
# Aligned returns for /BDX:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BDX: first_obs and last_obs produce in an empty array.
# Aligned returns for /BEN:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BEN: first_obs and last_obs produce in an empty array.
# Aligned returns for /BEPC:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BEPC: first_obs and last_obs produce in an empty array.
# Aligned returns for /BERY:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BERY: first_obs and last_obs produce in an empty array.
# Aligned returns for /BFAM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BFAM: first_obs and last_obs produce in an empty array.
# Aligned returns for /BG:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BG: first_obs and last_obs produce in an empty array.
# Aligned returns for /BHF:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BHF: first_obs and last_obs produce in an empty array.
# Aligned returns for /BIIB:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BIIB: first_obs and last_obs produce in an empty array.
# Aligned returns for /BILL:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BILL: first_obs and last_obs produce in an empty array.
# Aligned returns for /BIO:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BIO: first_obs and last_obs produce in an empty array.
# Aligned returns for /BIRK:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BIRK: first_obs and last_obs produce in an empty array.
# Aligned returns for /BJ:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BJ: first_obs and last_obs produce in an empty array.
# Aligned returns for /BK:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BK: first_obs and last_obs produce in an empty array.
# Aligned returns for /BKNG:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BKNG: first_obs and last_obs produce in an empty array.
# Aligned returns for /BKR:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BKR: first_obs and last_obs produce in an empty array.
# Aligned returns for /BLD:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BLD: first_obs and last_obs produce in an empty array.
# Aligned returns for /BLDR:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BLDR: first_obs and last_obs produce in an empty array.
# Aligned returns for /BLK:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BLK: first_obs and last_obs produce in an empty array.
# Aligned returns for /BMRN:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BMRN: first_obs and last_obs produce in an empty array.
# Aligned returns for /BMY:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BMY: first_obs and last_obs produce in an empty array.
# Aligned returns for /BOKF:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BOKF: first_obs and last_obs produce in an empty array.
# Aligned returns for /BPOP:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BPOP: first_obs and last_obs produce in an empty array.
# Aligned returns for /BR:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BR: first_obs and last_obs produce in an empty array.
# Aligned returns for /BRBR:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BRBR: first_obs and last_obs produce in an empty array.
# Aligned returns for /BRKR:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BRKR: first_obs and last_obs produce in an empty array.
# Aligned returns for /BRO:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BRO: first_obs and last_obs produce in an empty array.
# Aligned returns for /BROS:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BROS: first_obs and last_obs produce in an empty array.
# Aligned returns for /BRX:
# Date
# 2001-01-02    1.714719
# 2001-01-03    1.716794
# 2001-01-04    1.716794
# 2001-01-05    1.720588
# 2001-01-08    1.716403
# Name: r_vol, dtype: float64
# Aligned Fama-French factors:
#                r_vol     smb     hml
# Date
# 2001-01-02  1.714719  0.0668 -0.0507
# 2001-01-03  1.716794  0.0668 -0.0507
# 2001-01-04  1.716794  0.0668 -0.0507
# 2001-01-05  1.720588  0.0668 -0.0507
# 2001-01-08  1.716403  0.0668 -0.0507
# Results for /BRX:
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.003659. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.02199. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:766: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  r_vol   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                90.0390
# Distribution:                  Normal   AIC:                          -172.078
# Method:            Maximum Likelihood   BIC:                          -164.430
#                                         No. Observations:                   50
# Date:                Mon, Oct 14 2024   Df Residuals:                       49
# ...
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      1.5302e-03  3.888e-05     39.359      0.000 [1.454e-03,1.606e-03]
# alpha[1]       0.2000  5.237e-03     38.190      0.000     [  0.190,  0.210]
# beta[1]        0.7800  5.136e-03    151.865      0.000     [  0.770,  0.790]
# ============================================================================
#
# Covariance estimator: robust
# Aligned returns for /WFC:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /WFC: first_obs and last_obs produce in an empty array.
# Aligned returns for /WFRD:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /WFRD: first_obs and last_obs produce in an empty array.
# Aligned returns for /WH:
# Date
# 2008-12-05    0.870865
# 2008-12-08    0.870982
# 2008-12-09    0.867138
# 2008-12-10    0.866175
# 2008-12-11    0.866095
# Name: r_vol, dtype: float64
# Aligned Fama-French factors:
#                r_vol     smb     hml
# Date
# 2008-12-05  0.870865  0.0346  0.0014
# 2008-12-08  0.870982  0.0346  0.0014
# 2008-12-09  0.867138  0.0346  0.0014
# 2008-12-10  0.866175  0.0346  0.0014
# 2008-12-11  0.866095  0.0346  0.0014
# Results for /WH:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  r_vol   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                554.169
# Distribution:                  Normal   AIC:                          -1100.34
# Method:            Maximum Likelihood   BIC:                          -1079.22
#                                         No. Observations:                 1451
# Date:                Mon, Oct 14 2024   Df Residuals:                     1450
# Time:                        14:49:34   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             0.8527  4.244e-03    200.920      0.000 [  0.844,  0.861]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      3.8157e-03  8.407e-04      4.539  5.653e-06 [2.168e-03,5.463e-03]
# alpha[1]       0.1800  2.725e-02      6.605  3.972e-11     [  0.127,  0.233]
# beta[1]        0.7020  5.394e-02     13.015  1.011e-38     [  0.596,  0.808]
# ============================================================================
#
# Covariance estimator: robust
# Aligned returns for /WHR:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /WHR: first_obs and last_obs produce in an empty array.
# Aligned returns for /WING:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /WING: first_obs and last_obs produce in an empty array.
# Aligned returns for /WLK:
# Date
# 2001-01-03    1.228217
# 2001-01-04    1.227794
# 2001-01-05    1.230767
# 2001-01-08    1.229229
# 2001-01-09    1.235559
# Name: r_vol, dtype: float64
# Aligned Fama-French factors:
#                r_vol     smb     hml
# Date
# 2001-01-03  1.228217  0.0668 -0.0507
# 2001-01-04  1.227794  0.0668 -0.0507
# 2001-01-05  1.230767  0.0668 -0.0507
# 2001-01-08  1.229229  0.0668 -0.0507
# 2001-01-09  1.235559  0.0668 -0.0507
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.07631. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.01861. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Results for /WLK:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  r_vol   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                104.287
# Distribution:                  Normal   AIC:                          -200.574
# Method:            Maximum Likelihood   BIC:                          -191.251
#                                         No. Observations:                   76
# Date:                Mon, Oct 14 2024   Df Residuals:                       75
# Time:                        14:49:34   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             1.5712  8.564e-04   1834.589      0.000 [  1.570,  1.573]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      1.5027e-05  1.282e-08   1172.432      0.000  [1.500e-05,1.505e-05]
# alpha[1]       1.0000  7.888e-02     12.678  7.807e-37      [  0.845,  1.155]
# beta[1]        0.0000  1.660e-02      0.000      1.000 [-3.253e-02,3.253e-02]
# =============================================================================
#
# Covariance estimator: robust
# Aligned returns for /WM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /WM: first_obs and last_obs produce in an empty array.
# Aligned returns for /WMB:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /WMB: first_obs and last_obs produce in an empty array.
# Aligned returns for /WMS:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /WMS: first_obs and last_obs produce in an empty array.
# Aligned returns for /WMT:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /WMT: first_obs and last_obs produce in an empty array.
# Aligned returns for /WOLF:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /WOLF: first_obs and last_obs produce in an empty array.
# Aligned returns for /WPC:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /WPC: first_obs and last_obs produce in an empty array.
# Aligned returns for /WRB:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /WRB: first_obs and last_obs produce in an empty array.
# Aligned returns for /WSC:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /WSC: first_obs and last_obs produce in an empty array.
# Aligned returns for /WSM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /WSM: first_obs and last_obs produce in an empty array.
# Aligned returns for /WSO:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /WSO: first_obs and last_obs produce in an empty array.
# Aligned returns for /WST:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /WST: first_obs and last_obs produce in an empty array.
# Aligned returns for /WTFC:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /WTFC: first_obs and last_obs produce in an empty array.
# Aligned returns for /WTM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /WTM: first_obs and last_obs produce in an empty array.
# Aligned returns for /WTRG:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /WTRG: first_obs and last_obs produce in an empty array.
# Aligned returns for /WTW:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /WTW: first_obs and last_obs produce in an empty array.
# Aligned returns for /WU:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /WU: first_obs and last_obs produce in an empty array.
# Aligned returns for /WWD:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /WWD: first_obs and last_obs produce in an empty array.
# Aligned returns for /WY:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /WY: first_obs and last_obs produce in an empty array.
# Aligned returns for /WYNN:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /WYNN: first_obs and last_obs produce in an empty array.
# Aligned returns for /X:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /X: first_obs and last_obs produce in an empty array.
# Aligned returns for /XEL:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /XEL: first_obs and last_obs produce in an empty array.
# Aligned returns for /XOM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /XOM: first_obs and last_obs produce in an empty array.
# Aligned returns for /XP:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /XP: first_obs and last_obs produce in an empty array.
# Aligned returns for /XPO:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /XPO: first_obs and last_obs produce in an empty array.
# Aligned returns for /XRAY:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /XRAY: first_obs and last_obs produce in an empty array.
# Aligned returns for /XYL:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /XYL: first_obs and last_obs produce in an empty array.
# Aligned returns for /YETI:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /YETI: first_obs and last_obs produce in an empty array.
# Aligned returns for /YUM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /YUM: first_obs and last_obs produce in an empty array.
# Aligned returns for /Z:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /Z: first_obs and last_obs produce in an empty array.
# Aligned returns for /ZBH:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ZBH: first_obs and last_obs produce in an empty array.
# Aligned returns for /ZBRA:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ZBRA: first_obs and last_obs produce in an empty array.
# Aligned returns for /ZG:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ZG: first_obs and last_obs produce in an empty array.
# Aligned returns for /ZI:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ZI: first_obs and last_obs produce in an empty array.
# Aligned returns for /ZION:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ZION: first_obs and last_obs produce in an empty array.
# Aligned returns for /ZM:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ZM: first_obs and last_obs produce in an empty array.
# Aligned returns for /ZS:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ZS: first_obs and last_obs produce in an empty array.
# Aligned returns for /ZTS:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /ZTS: first_obs and last_obs produce in an empty array.
# Aligned returns for /BRK/B:
# Series([], Name: r_vol, dtype: float64)
# Aligned Fama-French factors:
# Empty DataFrame
# Columns: [r_vol, smb, hml]
# Index: []
# Error fitting GARCH model for /BRK/B: first_obs and last_obs produce in an empty array.

# %%
start= '2000-01-01'
end= '2024-01-01'

# %%
xlu =\
(
    yf
    .download('XLU',
              start, 
              end)
)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
xlu
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2000-01-03  28.937500  28.937500  27.218750  27.453125  11.514973    176700
# 2000-01-04  27.468750  27.468750  26.625000  26.625000  11.167620     93500
# 2000-01-05  27.218750  27.421875  26.859375  27.296875  11.449435    273400
# 2000-01-06  27.250000  27.250000  26.937500  27.250000  11.429772     34500
# 2000-01-07  27.296875  27.484375  27.171875  27.484375  11.528077     46200
# ...               ...        ...        ...        ...        ...       ...
# 2023-12-22  62.639999  63.240002  62.500000  62.619999  61.195450  13223700
# 2023-12-26  62.520000  63.240002  62.500000  63.000000  61.566803   9537500
# 2023-12-27  62.880001  63.080002  62.639999  62.959999  61.527714   9492200
# 2023-12-28  62.759998  63.500000  62.759998  63.410000  61.967476   8673200
# 2023-12-29  63.270000  63.459999  62.910000  63.330002  61.889297  11239000
#
# [6037 rows x 6 columns]

# %%
log_ret=\
(
    np
    .log(xlu
         /xlu.shift(1))
    .dropna()
)

# %%
log_returns =\
(
    log_ret
    ['Adj Close']
)

# %%
log_returns =\
(
    pd
    .Series(log_returns)
)

# %%
figarch_model =\
(
    arch_model(log_returns, 
               vol='FIGARCH',
               p=1,
               q=1)
)

# %%
figarch_result =\
(
    figarch_model.fit()
)
# Out:
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001515. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# Iteration:      1,   Func. Count:      7,   Neg. LLF: 684984615458.3423
# Iteration:      2,   Func. Count:     22,   Neg. LLF: 11315530.670871638
# Iteration:      3,   Func. Count:     36,   Neg. LLF: 73951.41592960521
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -19184.402215869064
#             Iterations: 5
#             Function evaluations: 43
#             Gradient evaluations: 3

# %%
print(figarch_result.summary())
# Out:
#                     Constant Mean - FIGARCH Model Results
# ==============================================================================
# Dep. Variable:              Adj Close   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                    FIGARCH   Log-Likelihood:                19184.4
# Distribution:                  Normal   AIC:                          -38358.8
# Method:            Maximum Likelihood   BIC:                          -38325.3
#                                         No. Observations:                 6036
# Date:                Fri, Oct 25 2024   Df Residuals:                     6035
# Time:                        19:18:02   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu         5.2637e-04  9.853e-05      5.342  9.189e-08 [3.333e-04,7.195e-04]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      2.1637e-06  1.125e-10  1.923e+04      0.000 [2.163e-06,2.164e-06]
# phi            0.2000  4.122e-02      4.852  1.224e-06     [  0.119,  0.281]
# d              0.5000  3.360e-02     14.881  4.394e-50     [  0.434,  0.566]
# beta           0.6300  2.242e-02     28.097 1.077e-173     [  0.586,  0.674]
# ============================================================================
#
# Covariance estimator: robust

# %%
predicted_volatility =\
(
    figarch_result
    .conditional_volatility
)

# %%
predicted_volatility
# Out:
# Date
# 2000-01-04    0.016311
# 2000-01-05    0.017750
# 2000-01-06    0.018361
# 2000-01-07    0.018072
# 2000-01-10    0.017717
#                 ...
# 2023-12-22    0.013639
# 2023-12-26    0.013164
# 2023-12-27    0.012568
# 2023-12-28    0.011863
# 2023-12-29    0.011341
# Name: cond_vol, Length: 6036, dtype: float64

# %%
rmse =\
(
    np
    .sqrt(np.mean((log_returns - predicted_volatility) ** 2))
)

# %%
def smape(actual, predicted):
    return 100 * np.mean(np.abs(actual - predicted) / ((np.abs(actual) + np.abs(predicted)) / 2))

# %%
smape_value =\
(
    smape(log_returns, 
          predicted_volatility)
)

# %%
print(rmse)
print(smape_value)
# Out:
# 0.017276994526782
# 130.48927514967463

# %%
garch_model =\
(
    arch_model(log_returns, 
               vol='Garch',
               p=1,
               q=1)
)

# %%
import matplotlib.pyplot as plt

# %%
plt\
    .plot(log_returns, alpha = 0.7, label ='Actual')

plt\
    .plot(predicted_volatility, label = 'Predicted')

plt\
    .grid()

plt\
    .legend()

# %%
rolling_window = 5
predictions = []


for i in range(rolling_window, len(log_returns)):
    
    model =\
    (
        arch_model(log_returns[i-rolling_window:i],
                   vol='FIGARCH',
                   p=1,
                   q=1)
    )
    
    model_fit =\
    (
        model
        .fit(disp="off")
    )
    
    forecast =\
    (
        model_fit
        .forecast(horizon=1)
    )
    
    predictions.append(forecast.variance.values[-1, :][0])  # Store the predicted variance
# Out:
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003286. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001415. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 5.77e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 6.548e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 6.345e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 5.088e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 4.642e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.824e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001565. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002326. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003556. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003588. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003532. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 5.147e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0005351. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004177. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004195. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000403. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004024. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.892e-06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 1000 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 7.6e-06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 1000 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 6.446e-06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 1000 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.383e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 6.458e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 7.324e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 6.164e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 5.325e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:766: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 4.101e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001971. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001794. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001723. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001914. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001954. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004349. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004684. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0007115. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002854. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001752. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0005592. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0006468. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003446. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000216. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001849. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 4.975e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 2.792e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 2.582e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002457. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002303. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002573. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000256. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004212. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001875. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001678. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002278. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000225. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001344. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001162. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 7.679e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 6.277e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 4.859e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.444e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.29e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 3.611e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 5.136e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001125. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001066. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001127. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004242. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004595. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002778. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002802. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002893. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001828. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001315. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001584. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003743. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003823. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002758. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002212. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000249. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002239. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002326. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002578. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.324e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 6.436e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 6.649e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001608. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001982. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002023. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002204. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001875. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002056. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001232. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001533. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000219. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002257. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002671. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002682. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# ...
# estimating the model parameters. The scale of y is 3.826e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 4.321e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003815. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003677. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003005. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003032. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.00025. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.115e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 8.866e-06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 1000 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 6.83e-06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 1000 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 6.624e-06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 1000 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.238e-06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 1000 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 2.047e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 1.972e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 4.16e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 4.888e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 5.92e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 6.803e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 7.333e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 5.011e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 5.257e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 4.326e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002381. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0002977. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003791. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003749. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003741. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 9.619e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001103. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 8.864e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0001001. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 9.032e-05. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# /Users/nasruddinislambinramli/anaconda3/lib/python3.11/site-packages/arch/univariate/base.py:311: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 7.95e-06. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 1000 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(

# %%
actual_returns =\
(
    log_returns[rolling_window:]
)

# %%
predicted_volatility =\
(
    np
    .sqrt(predictions) 
)

# %%
prediction_dates =\
(
    actual_returns.index
)

# %%
plt\
    .plot(actual_returns.index,
          actual_returns.values,
          label='Actual')

plt\
    .plot(prediction_dates,
          predicted_volatility,
          label='Rolling Prediction (Volatility)')

plt\
    .grid()

plt\
    .legend()

# %%
roll_smape =\
(
    smape(actual_returns, predicted_volatility)
)

# %%
rmse_roll =\
(
    np.sqrt(np.mean((actual_returns.values - predicted_volatility) ** 2))
)

# %%
print(roll_smape)
print(rmse_roll)
# Out:
# 131.20553633450695
# 0.0167113064912702
